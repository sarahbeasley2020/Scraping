# %%
# Import statements
import pandas as pd
import numpy as np 
import csv 
from parsel import Selector
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import json
import re

# %%
'''
Class to describe a given company 
    @field: name: a string for the company name
    @field: description: a string for the company description
    @field: founders: a list of Founder objects
    @field: industries: a list of strings for different industries
    @field: website: a string for the website
    @field: lastStage: a string for the last stage of funding (eg. Series A)
    @field: linkedin: a string for the company's LinkedIn profile
    @field: location: a string for the company's location
'''
class Company:
    def __init__(self, companyName):
        self.name = companyName
        self.description = None
        self.founders = []
        self.industries = []
        self.website = None
        self.lastStage = None
        self.linkedin = None
    
    def toJson(self):
        return json.dumps(self, default=lambda o: o.__dict__)
    
'''
Class to describe a founder
    @field: name: a string for the founder's name
    @field: education: an list of education objects
    @field: experience: a list of experience objects
'''
class Founder:
    def __init__(self, founderName):
        self.name = founderName
        self.connections = None
        self.location = None
        self.education = []
        self.experience = []

'''
Class to help describe a founder's education
    @field: degree: a string to describe the degree objective
    @field: school: a string for the school attended
    @field: field: a string to describe the major
'''
class Education:
    def __init__(self, schoolName):
        self.school = schoolName
        self.degree = None
        self.field = None
'''
Class to help describe a founder's experience
    @field: companyName: a string to describe the company's name
    @field: title: a string to describe the title held
    @field: description: a string to describe the job description
'''       
class Experience:
    def __init__(self, companyName):
        self.companyName = companyName
        self.title = None
        self.dates = None

# %%
'''
Loads the dataframe from Query 1 and Query 2 and merges + drops duplicates and NaNs
    @param: csv1: path to CSV 1 (formed by Query 1)
    @param: csv2: path to CSV 2 (formed by Query 2)
    @return: df1: a merged dataframe of csv1 and csv2
'''
def loadBacktestData(csv1, csv2):
    df1 = pd.read_csv(csv1)
    df2 = pd.read_csv(csv2)
    df1 = df1.append(df2)
    df1 = df1.drop_duplicates(subset=['Organization Name'])
    df1 = df1[df1.Founders.notna()]
    df1 = df1[df1.LinkedIn.notna()]
    df1 = df1.reset_index()
    for i in range(len(df1)):
        if df1.iloc[i].LinkedIn.count('about') > 0:
            df1['LinkedIn'][i] = df1['LinkedIn'][i].split('about')[0]
    return df1

# Loads and combines both CSVs into df1 dataframe
df1 = loadBacktestData('backtest1.csv', 'backtest2.csv')
# Creates a company_data dictionary to store scraped data
company_data = {}
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
'''
Method to set up and log into the LinkedIn using chromedriver
    @param: driverPath: path to the chromedriver.exe file
    @param: liUsername: string of LI username
    @param: liPassword: string of LI password
    @return: driver: the Chrome Webdriver (can be passed into future function arguments)
'''
def setupDriver(driverPath, liUsername, liPassword):
    # Sets up Chrome Webdriver and navigates to LinkedIn
    driver = webdriver.Chrome(driverPath)
    driver.get('https://www.linkedin.com/')
    sleep(2.0)
    
    # Signs in with given credentials and returns the driver
    driver.find_element_by_xpath('//a[text()="Sign in"]').click()
    sleep(2.0)
    username_input = driver.find_element_by_name('session_key')
    username_input.send_keys(liUsername)
    password_input = driver.find_element_by_name('session_password')
    password_input.send_keys(liPassword)
    sleep(2.0)
    driver.find_element_by_xpath('//button[text()="Sign in"]').click()
    return driver

# Launches LinkedIn and logs in
driver = setupDriver('./chromedriver', 'julianvallyeason@gmail.com', 'Acceleprise1')

# %%
'''
Method to save the company data as a txt file (loadable as JSON)
    @param: data: company_data dictionary of Company objects
    @return: None
'''
def saveData(data, fileName):
    data_json = json.dumps(data, default=lambda x: x.__dict__)
    with open(fileName, 'w') as outfile:
        json.dump(data_json, outfile)

'''
Method to load company data into a dictionary (same structure as Company object)
    @param: dataFile: string path to saved txt file
    @return: dataDict: a dictionary with the same structure as a Company object
'''
def loadData(dataFile):
    with open(dataFile) as json_file:
        data = json.load(json_file)
    dataDict = json.loads(data)
    return dataDict

# %%
'''
Method to get the number of connections for a founder on that founder's LI profile
    @param: driver - the chromedriver used
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the number of connections found on the profile
'''
def addConnections(driver, founder_):
    conn_ = driver.find_elements_by_xpath('//ul[@class = "pv-top-card--list pv-top-card--list-bullet mt1"]/li[@class = "inline-block"]')
    try:
        founder_.connections = conn_[0].text
    except:
        print("Connections not found for {}".format(founder_.name))
        
'''
Method to get extract the founder location
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the location found on the profile
'''
def updateLocation(driver, founder_):
    loc_ = driver.find_elements_by_xpath('//li[@class = "t-16 t-black t-normal inline-block"]')
    try:
        founder_.location = loc_[0].text
    except:
        print("Location not found for {}".format(founder_.name))

# %%
'''
Method to get the School Name, FoS and Degree Name for all educational experiences for a founder
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all education experiences
'''
def getSchools(driver, founder_):
    schools = driver.find_elements_by_xpath('//div[@class="pv-entity__degree-info"]')
    for school_ in schools:
        try:
            educ_ = Education(school_.find_element_by_class_name('pv-entity__school-name').text)
            try:
                educ_.degree = school_.find_element_by_class_name('pv-entity__degree-name').text.split('\n')[1]
            except:
                print("No degree info found for {} at {}".format(founder_.name, educ_.school))
            try:
                educ_.field = school_.find_element_by_class_name('pv-entity__fos').text.split('\n')[1]
            except:
                print("No field of study for {} at {}".format(founder_.name, educ_.school))

            # Appends the temporary education object to the founder
            founder_.education.append(educ_)
        except:
            print("No schools found for {}".format(founder_.name))

# %%
'''
Method to get the Company Name, Title and Dates for all work experiences for a founder 
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all work experiences
'''
def getWorkExperience(driver, founder_):
    experiences = driver.find_elements_by_xpath('//a[@data-control-name="background_details_company"]')
    for exp in experiences:
        exp_lst = exp.text.split('\n')
        # The exp_ is formatted as [title, 'companyname', companyname, 'datesemployed', datesemployed, ..]
        try:
            if exp_lst[0] == 'Company Name':
                exp_ = Experience(exp_lst[1])
                founder_.experience.append(exp_)
            else:
                exp_ = Experience(exp_lst[2])
                try:
                    exp_.title = exp_lst[0]
                    exp_.dates = exp_lst[4]
                    founder_.experience.append(exp_)
                except:
                    founder_.experience.append(exp_)
        except:
            print("No experience found for {}".format(str(founder_.name)))

# %%
'''
Extracts the founder information from a LinkedIn search for a founder and adds the founder to the company
    @param: driver - the chromedriver used
    @param: founder - a string for the founder's name
    @param: company_ - the Company object for the company the founder is working at
'''

def getFounderInfo(driver, founder, company_):
    res_ = driver.find_element_by_xpath('//a[@data-control-name="search_srp_result"]')
    if res_:
        res_.click()
        sleep(2.0)
        # Scrolls to the bottom of the webpage (if no scroll, error where the full webpage doens't load)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/2);")
        sleep(0.75)
        # Creates a founder object for the given founder
        founder_ = Founder(founder)
        
        #Extracts data for connections
        addConnections(driver, founder_)
        
        #Extract founder location
        updateLocation(driver, founder_)

        # Extracts degree information (formatted as a list of items)
        getSchools(driver, founder_)
 
        # Extracts experience information (formatted as a list of items)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/3);")
        sleep(1.0)
        getWorkExperience(driver, founder_)
        
        # Appends the temporary founder object to the company
        company_.founders.append(founder_)
        sleep(1.0)
    else:
        founder_ = Founder(founder)
        company_.founders.append(founder_)
        print("{} not found for {}".format(company_.name, founder_.name))
        sleep(1.0)

# %%
'''
Method to search for founder and company on the search bar and extract founder information if found
    @param: driver - the chromedriver used 
    @param: founder - a string for the name of the founder to be searched
    @param: company_ = the company being searched
    @return: None
The founder object is populated and added to the company
'''
def searchForFounder(driver, founder, company_):
    # Finds the search bar on top of the LinkedIn page
    search = driver.find_elements_by_xpath('//input[@class="search-global-typeahead__input always-show-placeholder"]')
    sleep(0.5)
    search[0].click()
    for i in range(50):
        search[0].send_keys(Keys.RIGHT)
    # Clears any existing search
    for i in range(80):
        search[0].send_keys(Keys.BACKSPACE)
    # Types in founder name + company name and searches
#     search[0].send_keys(founder + " " + company_.name.split(" ")[0])
    search[0].send_keys(founder + " " + re.split(" |,", company_.name)[0])
    search[0].send_keys(Keys.ENTER)
    sleep(2.0)
    try:
        getFounderInfo(driver, founder, company_)
    except:
        print("{} not found for {}".format(founder, company_.name))

# %%
'''
Method to add LI information for a company into the company_data dictionary with a new company object
    @param: entry: a pandas series extracted from a single row in the dataframe from loadBacktestData
    @return: None
This method updates the company_data dictionary and returns nothing
'''
def scrapeLI(entry):
    # Adds a new company entry to the company_data dictionary and populates fields
    company_ = Company(entry['Organization Name'])
    company_.description = entry['Description']
    company_.industries = [i.strip() for i in entry['Industries'].split(',')]
    company_.website = entry['Website']
    company_.lastStage = entry['Last Funding Type']
    # Edge case where the LinkedIn link does not end in '/'
    if entry['LinkedIn'][-1] != '/':
        entry['LinkedIn'] = entry['LinkedIn'] + '/'
    company_.linkedin = entry['LinkedIn']
    company_.location = entry['Headquarters Location']
    
    # Generates a list of founder names
    founderNames = [i.strip() for i in entry['Founders'].split(',')]
    try:
        # For each founder in the list, the school name, degree, and major is extracted
        for founder in founderNames:
            searchForFounder(driver, founder, company_)
    except:
        print("Structural Error")
    # Adds the company to the company_data dictionary
    company_data[company_.name] = company_

# %%
for i in range(300,400):
    print(i)
    if i%5 == 0:
        sleep(5.0)
    scrapeLI(df1.iloc[i])
# Out:
# 300
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# 301
# Connections not found for Matt Casamassina
# Location not found for Matt Casamassina
# 302
# Connections not found for BM Chittaranjan
# Location not found for BM Chittaranjan
# No degree info found for John Torr at Indiana University - Kelley School of Business
# 303
# No field of study for Minh Tri Pham at Deutsche Schule Prag
# 304
# No field of study for Bjarke Felbo at Y Combinator
# No field of study for Bjarke Felbo at Massachusetts Institute of Technology
# No field of study for Sanjay Guruprasad at Massachusetts Institute of Technology
# No field of study for Sanjay Guruprasad at Y Combinator
# 305
# No field of study for Daniel Wisenhoff at Lunds tekniska högskola / The Faculty of Engineering at Lund University
# No degree info found for Daniel Wisenhoff at HBX | Harvard Business School
# No field of study for Daniel Wisenhoff at HBX | Harvard Business School
# No field of study for Daniel Wisenhoff at Copenhagen Business School
# No degree info found for Martin Hell at Lund University
# No degree info found for Martin Hell at Lund University
# 306
# 307
# 308
# 309
# No field of study for Aric Bartle at Stanford University
# No field of study for Aric Bartle at Stanford
# No degree info found for Sandra Dai at Shanghai Foreign Language School
# No field of study for Sandra Dai at Shanghai Foreign Language School
# 310
# No degree info found for Nicolas Morency at Centech MTL
# No field of study for Nicolas Morency at Centech MTL
# 311
# No degree info found for Surbhi Rathore at The Army Public School, New Delhi
# No field of study for Surbhi Rathore at The Army Public School, New Delhi
# No degree info found for Surbhi Rathore at Convent of Jesus and Mary, Ambala
# No field of study for Surbhi Rathore at Convent of Jesus and Mary, Ambala
# No field of study for Toshish Jawale at Government Polytechnic, Jalgaon
# 312
# 313
# 314
# 315
# No field of study for Alex Casassovici at College des Ingénieurs
# No degree info found for Erik Whiteford at Denver East High
# No field of study for Erik Whiteford at Denver East High
# 316
# No degree info found for Daniel Haudenschild at Boston University
# No field of study for Justin Smith at University of Illinois at Urbana-Champaign
# No field of study for Justin Smith at Illinois State University
# No degree info found for Quentin Reyes at Shanghai University of Finance and Economics
# No degree info found for Quentin Reyes at East China Normal University
# 317
# No field of study for Greg Lawton at The University of Manchester
# 318
# No degree info found for Yair Dovrat at Y Combinator
# No field of study for Yair Dovrat at Y Combinator
# 319
# No field of study for Christian Allouche at Université Paris-Sud (Paris XI)
# 320
# 321
# No degree info found for Antti Rauhala at Päivölä High School
# No field of study for Antti Rauhala at Päivölä High School
# 322
# No degree info found for Calvin Chung at Shanghai Jiao Tong University
# 323
# No field of study for Frie Pétré at Université catholique de Louvain
# 324
# No degree info found for Rob Fess at Saint Petersburg State Polytechnical University
# No degree info found for Rob Fess at Defense Language Institute
# No degree info found for Rob Fess at Saint Petersburg State Polytechnical University
# No degree info found for Rob Fess at Defense Language Institute
# 325
# 326
# No field of study for Jesse Proudman at Entrepreneurs Organization at MIT
# Lee Huffman not found for Strix Leviathan
# Ryan Tomayko not found for Strix Leviathan
# 327
# Marcus Dixon not found for ChAI
# 328
# No degree info found for Adam Ballai at EBHS
# No field of study for Adam Ballai at EBHS
# No degree info found for John Solis at UC Irvine
# No field of study for John Solis at UC Irvine
# 329
# No degree info found for Trung Vu at Venture Lab
# No field of study for Trung Vu at Venture Lab
# 330
# No degree info found for Philip Poulidis at University of Toronto
# No degree info found for Philip Poulidis at The University of Western Ontario
# 331
# 332
# Connections not found for Mart Abramov
# Location not found for Mart Abramov
# 333
# No field of study for Chris Shafer at Y Combinator
# No field of study for Joe Wingbermuehle at Y Combinator
# No field of study for Ryan Richt at Y Combinator
# 334
# No degree info found for Girisha Fernando at International School of Basel
# No field of study for Girisha Fernando at International School of Basel
# No field of study for Michel Mohler at University of Rochester
# 335
# No field of study for Jay Zimmermann at Linköpings universitet
# No degree info found for Jay Zimmermann at Willamette University
# No field of study for Jay Zimmermann at Willamette University
# No degree info found for Simon Telian at Zeppelin University, Friedrichshafen
# No degree info found for Simon Telian at Universidad Pablo de Olavide, de Sevilla
# 336
# Connections not found for Geethika Arachchige
# Location not found for Geethika Arachchige
# 337
# No field of study for Zaedo Musa at Copenhagen Business School
# No degree info found for Zaedo Musa at Roskilde University
# 338
# 339
# No degree info found for Jared Hobbs at Y Combinator
# No field of study for Jared Hobbs at Y Combinator
# No field of study for Sean O'Keefe at Warwick Business School
# 340
# 341
# No degree info found for Jeremy Lermitte at Fachhochschule Wiener Neustadt
# No field of study for Jeremy Lermitte at General Assembly
# 342
# No field of study for Lauren Taylor at Boston University Questrom School of Business
# No degree info found for Mike Festa at United States Air Force Academy
# 343
# 344
# No degree info found for Angel Poon at Hong Kong University of Science and Technology - School of Business and Management
# No field of study for Angel Poon at Hong Kong University of Science and Technology - School of Business and Management
# No degree info found for James Lin at John A. Rowland High School
# No field of study for James Lin at John A. Rowland High School
# 345
# 346
# Alberto Diaz not found for RIngLogix
# 347
# 348
# No degree info found for Eric V Cunningham at Indiana University of Pennsylvania
# No field of study for Eric V Cunningham at Indiana University of Pennsylvania
# 349
# Chris LaFleur not found for Debitrum
# 350
# Dmitrii Bendenko not found for LetKnow OÜ
# 351
# No degree info found for Callum Adamson at University of the Highlands and Islands - Perth College
# 352
# No field of study for Clinton Baird at Saint Louis University
# 353
# No degree info found for Ole Winther at Københavns Universitet - University of Copenhagen
# No field of study for Ole Winther at Københavns Universitet - University of Copenhagen
# 354
# No degree info found for Bruno Kramm at Danse Macabre Records
# No field of study for Bruno Kramm at Danse Macabre Records
# 355
# 356
# No field of study for Matthew Reeves at Queen's University
# No field of study for Matthew Reeves at ESADE Business School
# No field of study for Matthew Reeves at Y Combinator
# 357
# No degree info found for Andrew Flint at Semester at Sea
# 358
# No degree info found for Paul Roach at The University of Edinburgh
# No field of study for Paul Roach at The University of Edinburgh
# 359
# No degree info found for Ryo Kikuchi at EDHEC Business School
# No degree info found for Sayuri Kondo at Kuwasawa Design School
# No field of study for Sayuri Kondo at Kuwasawa Design School
# No degree info found for Sayuri Kondo at 早稲田大学 WASEDA University
# 360
# No degree info found for Don Stein at Indiana University - Kelley School of Business
# No degree info found for Don Stein at Draper University
# 361
# No degree info found for Jordan Walker at University of North Florida
# 362
# Connections not found for Marc de Kuyper
# Location not found for Marc de Kuyper
# 363
# No degree info found for Anton Isaykin at Saint-Petersburg State University Information Technologies, Mechanic and Optics (University ITMO)
# No field of study for Anton Isaykin at Saint-Petersburg State University Information Technologies, Mechanic and Optics (University ITMO)
# 364
# 365
# Connections not found for Joshua Jones
# Location not found for Joshua Jones
# 366
# No field of study for Peter Karakas at University of Debrecen
# No field of study for Peter Karakas at Machwart Andras High School
# No field of study for Peter Karakas at Machwart Andras High School
# 367
# No degree info found for Bas Peters at Fontys Hogeschool Eindhoven
# No degree info found for Jon Edvald at Háskóli Íslands
# No field of study for Jon Edvald at Háskóli Íslands
# 368
# Connections not found for William T. Dunne
# Location not found for William T. Dunne
# 369
# 370
# No degree info found for Rao Bhethanabotla at Stanford University
# 371
# No degree info found for Alexandre Attia at Tel Aviv University
# No degree info found for Elie Zerbib-Attal at Université Paris Descartes
# No field of study for Julien Vidal at Grenoble Ecole de Management
# No degree info found for Julien Vidal at Intégrale Prépa HEC
# No field of study for Julien Vidal at Intégrale Prépa HEC
# 372
# 373
# Don Jewell not found for Q5id
# 374
# 375
# 376
# 377
# 378
# No degree info found for Marko Topalovic at Data Science Dojo
# No field of study for Marko Topalovic at Data Science Dojo
# 379
# No field of study for Moritz Grotthuss at Altkönigschule Kronberg (AKS)
# No field of study for Sascha Klement at Humboldt School, Kiel
# 380
# 381
# No field of study for Patrick Schubert at Danmarks Tekniske Universitet
# 382
# No degree info found for Thani Shamsi at Anglia Ruskin University
# No degree info found for Thani Shamsi at Technische Universität Dresden
# 383
# No degree info found for Ben Labra at Columbia University in the City of New York
# No field of study for Ben Labra at Columbia University in the City of New York
# 384
# 385
# No field of study for Farhan Javed at Union Public Schools
# No degree info found for Rohan Chaudhary at Union Public Schools
# No field of study for Rohan Chaudhary at Union Public Schools
# 386
# No field of study for Aurélien Duval at Lycée Blaise Pascal, Châteauroux
# 387
# 388
# No field of study for Sam Zheng at Actuaries Institute Australia
# 389
# No degree info found for Sanela Luescher at KV Business School Zürich
# No field of study for Sanela Luescher at KV Business School Zürich
# 390
# 391
# No degree info found for Chris Stanley at Loyola High School, Los Angeles
# No field of study for Chris Stanley at Loyola High School, Los Angeles
# No degree info found for Xander Oltmann at University of California, Santa Cruz
# 392
# No degree info found for Lumin Chen at Ladue Horton Watkins High School
# No field of study for Lumin Chen at Ladue Horton Watkins High School
# 393
# 394
# 395
# No degree info found for Barry Oberholzer at Paul Roos Gimnasium/Gymnasium
# No field of study for Barry Oberholzer at Paul Roos Gimnasium/Gymnasium
# 396
# 397
# No degree info found for Eddie Liu at University of North Carolina at Chapel Hill School of Medicine
# 398
# Moti Tomashin not found for Vocalto
# Connections not found for Yaron Arohnson
# Location not found for Yaron Arohnson
# 399
# No field of study for Artem Koren at Stuyvesant High School

# %%
df1.iloc[270]
# Out:
# index                                                                                  303
# Organization Name                                                                 Dashbird
# Organization Name URL                     https://www.crunchbase.com/organization/dashbird
# Industries                               Application Performance Management, Developer ...
# Headquarters Location                                           Tallinn, Harjumaa, Estonia
# Description                              AWS Lambda monitoring & debugging platform.  S...
# Last Funding Amount                                                                2.1e+06
# Last Funding Amount Currency                                                           USD
# Last Funding Amount Currency (in USD)                                              2.1e+06
# Last Funding Type                                                                     Seed
# CB Rank (Company)                                                                    6,527
# Number of Funding Rounds                                                                 2
# LinkedIn                                        https://www.linkedin.com/company/11414046/
# Website                                                               https://dashbird.io/
# Founders                                     Annika Helendi, Mikk Kirštein, Taavi Rehemägi
# Name: 270, dtype: object

# %%
saveData(company_data, 'data300.txt')

# %%
# Used to extract and analyze the data from the saved text file

schools = {}
fields = {}
companynames = {}
jobtitle = {}

for key in loaded.keys():
    for founder in loaded[key]['founders']:
        if founder['education']:
            for educ_ in founder['education']:
                school = educ_['school'].lower()
                for word in school.split(' '):
                    if word in schools:
                        schools[word] += 1
                    else:
                        schools[word] = 1
                if educ_['field']:
                    field = educ_['field'].lower()
                    for word in field.split(' '):
                        if word in fields:
                            fields[word] += 1
                        else:
                            fields[word] = 1
        if founder['experience']:
            for exp_ in founder['experience']:
                companyName = exp_['companyName'].lower()
                for word in companyName.split(' '):
                    if word in companynames:
                        companynames[word] += 1
                    else:
                        companynames[word] = 1
                if exp_['title']:
                    title = exp_['title'].lower()
                    if title in jobtitle:
                        jobtitle[title] += 1
                    else:
                        jobtitle[title] = 1

# %%
''' Saves the extracted data to a CSV'''
# Out:
# ' Saves the extracted data to a CSV'

# %%
df_schools = pd.DataFrame.from_dict(schools, orient='index', columns=['freq'])
df_schools.sort_values(['freq'], ascending=False).to_csv('schools.csv')

# %%
df_fields = pd.DataFrame.from_dict(fields, orient='index', columns=['freq'])
df_fields.sort_values(['freq'], ascending=False).to_csv('fields.csv')

# %%
df_compnames = pd.DataFrame.from_dict(companynames, orient='index', columns=['freq'])
df_compnames.sort_values(['freq'], ascending=False).to_csv('companynames.csv')

# %%
df_titles = pd.DataFrame.from_dict(jobtitle, orient='index', columns=['freq'])
df_titles.sort_values(['freq'], ascending=False).to_csv('titles.csv')
