# %%
# Import statements
import pandas as pd
import numpy as np 
import csv 
import json
import re
import math

# %%
'''
Loads the dataframe from Query 1 and Query 2 and merges + drops duplicates and NaNs
    @param: csv1: path to CSV 1 (formed by Query 1)
    @param: csv2: path to CSV 2 (formed by Query 2)
    @return: df1: a merged dataframe of csv1 and csv2
'''
def loadBacktestData(csv1, csv2):
    df1 = pd.read_csv(csv1)
    df2 = pd.read_csv(csv2)
    df1 = df1.append(df2)
    df1_ = df1.drop_duplicates(subset=['Organization Name'])
    df1 = df1_[df1_.Founders.notna()]
    df1 = df1[df1.LinkedIn.notna()]
    df1 = df1.reset_index()
    for i in range(len(df1)):
        if df1.iloc[i].LinkedIn.count('about') > 0:
            df1['LinkedIn'][i] = df1['LinkedIn'][i].split('about')[0]
    df1 = df1.set_index('Organization Name')
    df1 = df1.drop('index', 1)
    df1['Organization Name'] = df1.index
    df1_ = df1_.set_index('Organization Name')
    return df1, df1_

# Loads and combines both CSVs into df1 dataframe
df1, df1_ = loadBacktestData('backtest1.csv', 'backtest2.csv')
df3, df3_ = loadBacktestData('FailedCompanies.csv', 'FailedCompanies.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
'''
Method to save the company data as a txt file (loadable as JSON)
    @param: data: company_data dictionary of Company objects
    @return: None
'''
def saveData(data, fileName):
    data_json = json.dumps(data, default=lambda x: x.__dict__)
    with open(fileName, 'w') as outfile:
        json.dump(data_json, outfile)

'''
Method to load company data into a dictionary (same structure as Company object)
    @param: dataFile: string path to saved txt file
    @return: dataDict: a dictionary with the same structure as a Company object
'''
def loadData(dataFile):
    with open(dataFile) as json_file:
        data = json.load(json_file)
    dataDict = json.loads(data)
    return dataDict

# %%
alldata = loadData('alldata_final.txt')
faileddata = loadData('failed1.txt')

# %%
'''
Structure of Company Dictionary Entry:
    @name - string for the company's name
    @description - string for a company description
    @founders - list of founder dictionaries (single founders)
        Structure of Founder Dictionary Entry
            @name - string for the founder's name
            @connections - string for the founder's # of connections
            @location - string for the founder's location 
            @education - list of education dictionaries (single education experiences)
                Structure of Education Dictionary Entry
                    @school - string for the school name
                    @degree - string for the degree objective (i.e. BS / BA)
                    @field - string for the field studied (i.e. Computer Science)
            @experience - list of experience dictionaries (single experiences)
                Structure of Experience Dictionary Entry
                    @companyName - string for the company's name
                    @title - string for the position held at the company
                    @dates - string for the dates worked at the company (i.e. May 2000 - Jun 2000)
    @industries - list of strings with the industries the company is involved in 
    @website - string for the company's website
    @lastStage - string for the last stage of funding received (i.e. Series A)
    @linkedin - string for the URL of the company's LI profile
    @location - string for the company's HQ location
'''
pass

# %%
df3_.index[0]
# Out:
# 'JOANY'

# %%
'''
Data Validation: Location
    Please note: county can also mean 'state'
'''
drop_city = {} ; drop_country = {} ; keep_city = {} ; keep_country = {}
drop_county = {} ; keep_county = {}
for i in range(len(df3_)):
    split_item = df3_.iloc[i]['Headquarters Location'].split(',')
    if df3_.index[i] not in faileddata:
        if split_item[0] not in drop_city:
            drop_city[split_item[0]] = 1
        else:
            drop_city[split_item[0]] += 1
        if split_item[-1] not in drop_country:
            drop_country[split_item[-1]] = 1
        else:
            drop_country[split_item[-1]] += 1
        if split_item[1] not in drop_county:
            drop_county[split_item[1]] = 1
        else:
            drop_county[split_item[1]] += 1
    else:
        if split_item[0] not in keep_city:
            keep_city[split_item[0]] = 1
        else:
            keep_city[split_item[0]] += 1
        if split_item[-1] not in keep_country:
            keep_country[split_item[-1]] = 1
        else:
            keep_country[split_item[-1]] += 1
        if split_item[1] not in keep_county:
            keep_county[split_item[1]] = 1
        else:
            keep_county[split_item[1]] += 1

drop_city = {k: v for k, v in sorted(drop_city.items(), key=lambda item: item[1], reverse=True)}
drop_country = {k: v for k, v in sorted(drop_country.items(), key=lambda item: item[1], reverse=True)}
keep_city = {k: v for k, v in sorted(keep_city.items(), key=lambda item: item[1], reverse=True)}
keep_country = {k: v for k, v in sorted(keep_country.items(), key=lambda item: item[1], reverse=True)}
drop_county = {k: v for k, v in sorted(keep_county.items(), key=lambda item: item[1], reverse=True)}
keep_county = {k: v for k, v in sorted(keep_county.items(), key=lambda item: item[1], reverse=True)}

for (i,j) in [(drop_country, keep_country), (drop_city, keep_city), (drop_county, keep_county)]:
    df_3 = pd.DataFrame.from_dict(i, orient='index', columns=['freq']).reset_index()
    #df_2 = pd.DataFrame.from_dict(j, orient='index', columns=['freq']).reset_index()
    df_item = pd.merge(df_3, df_3, on='index')
    df_item.columns = ['name', 'dropped', 'kept']
    df_item['dropped'] /= df_item['dropped'].sum()
    df_item['kept'] /= df_item['kept'].sum()
    df_item.set_index(['name'])
df_item.head(10)
# Out:
#           name   dropped      kept
# 0   California  0.270968  0.270968
# 1     New York  0.058065  0.058065
# 2      England  0.045161  0.045161
# 3   Washington  0.038710  0.038710
# 4      Florida  0.032258  0.032258
# 5        Texas  0.032258  0.032258
# 6     Colorado  0.025806  0.025806
# 7         Ohio  0.025806  0.025806
# 8     Illinois  0.025806  0.025806
# 9     Delaware  0.019355  0.019355

# %%
'''
Data Validation: Industries
'''     
drop_industries = {}
for name_ in df3_.index:
    for ind_ in [i.strip() for i in df3_.loc[name_]['Industries'].split(',')]:
        if ind_ not in drop_industries:
            drop_industries[ind_] = 1
        else:
            drop_industries[ind_] += 1
drop_industries = {k: v for k, v in sorted(drop_industries.items(), key=lambda item: item[1], reverse=True)} 
df_dropIndustries = pd.DataFrame.from_dict(drop_industries, orient='index', columns=['freq']).reset_index()

kept_industries = {}
for name_ in faileddata.keys():
    for ind_ in [i.strip() for i in df3.loc[name_]['Industries'].split(',')]:
        if ind_ not in kept_industries:
            kept_industries[ind_] = 1
        else:
            kept_industries[ind_] += 1
kept_industries = {k: v for k, v in sorted(kept_industries.items(), key=lambda item: item[1], reverse=True)}

# Brings it into a dataframe
df_keptIndustries = pd.DataFrame.from_dict(kept_industries, orient='index', columns=['freq']).reset_index()
df_industries = pd.merge(df_dropIndustries, df_keptIndustries, on='index')
df_industries.columns = ['name', 'dropped', 'kept']
df_industries['dropped'] /= df_industries['dropped'].sum()
df_industries['kept'] /= df_industries['kept'].sum()
df_industries.set_index(['name'])
df_industries.head(10)
# Out:
#                      name   dropped      kept
# 0                Software  0.202869  0.184971
# 1                    SaaS  0.058402  0.060694
# 2  Information Technology  0.049180  0.041908
# 3                Internet  0.028689  0.028902
# 4               Analytics  0.025615  0.026012
# 5                    Apps  0.023566  0.018786
# 6     Enterprise Software  0.023566  0.023121
# 7                  Mobile  0.022541  0.021676
# 8                     B2B  0.020492  0.020231
# 9             Mobile Apps  0.018443  0.011561

# %%
'''
General Data:
    # of Founders
    % Female Founders
    Median Funding Amount
'''
# Import Statement
import gender_guesser.detector as gender

d = gender.Detector()
numFounders = [] ; numFoundersDict = {} ; fundingAmount = [] ; genderDict = {} ;
femaleComp = 0 ; totalComp = 0
for i in range(len(df3)):
    founders_ = df3.iloc[i]['Founders'].split(',')
    amount_ = df3.iloc[i]['Last Funding Amount Currency (in USD)']
    if founders_:
        numFounders.append(len(founders_))
        hasWomen = False ; totalComp += 1
        for founder in founders_:
            founder = founder.strip()
            if founder:
                name = founder.split(' ')[0].strip()
                gen_ = d.get_gender(name)
                if gen_ not in genderDict:
                    genderDict[gen_] = 1
                else:
                    genderDict[gen_] += 1
                if not hasWomen:
                    if gen_ == "mostly_female" or gen_ == "female":
                        femaleComp += 1
                        hasWomen = True
    if amount_ and not math.isnan(amount_):
        try:
            fundingAmount.append(int(amount_))
        except:
            pass
print("Average number of founders is {}".format(str(np.mean(numFounders))))
print("Median number of founders is {}".format(str(np.median(numFounders))))
print("Mean funding amount is ${}".format(str(np.mean(fundingAmount))))
print("Median funding amount is ${}".format(str(np.median(fundingAmount))))
print(genderDict)
print("At least 1 female founder: {}".format(str((femaleComp + (genderDict['andy']/2))/totalComp)))
# Out:
# Average number of founders is 2.18871473354232
# Median number of founders is 2.0
# Mean funding amount is $7921352.245532759
# Median funding amount is $6000000.0
# {'male': 2604, 'unknown': 392, 'female': 243, 'mostly_female': 36, 'andy': 32, 'mostly_male': 184}
# At least 1 female founder: 0.16489028213166143

# %%
'''
General Data:
    Number of Founders by region
'''
countryFounders = {} ; countryByFounders = {}
for i in range(len(df3)):
    founders_ = len(df3.iloc[i]['Founders'].split(','))
    country_ = df3_.iloc[i]['Headquarters Location'].split(',')[-1]
    if not country_ in countryFounders:
        countryFounders[country_] = []
        countryFounders[country_].append(founders_)
    else:
        countryFounders[country_].append(founders_)
    if not country_ in countryByFounders:
        countryByFounders[country_] = founders_
    else:
        countryByFounders[country_] += founders_
averageFounders = {}
for country_ in countryFounders.keys():
    averageFounders[country_] = np.mean(countryFounders[country_])
averageFounders = {k: v for k, v in sorted(averageFounders.items(), key=lambda item: item[1], reverse=True)}                   
countryByFounders = {k: v for k, v in sorted(countryByFounders.items(), key=lambda item: item[1], reverse=True)}
df_countryFounders = pd.DataFrame.from_dict(countryByFounders, orient='index', columns=['freq']).reset_index()
df_averageFounders = pd.DataFrame.from_dict(averageFounders, orient='index', columns=['freq']).reset_index()
df_numFounders = pd.merge(df_countryFounders, df_averageFounders, on='index')
df_numFounders.columns = ['name', 'total', 'average']
df_numFounders.head(10)
# Out:
#                name  total   average
# 0     United States    255  2.056452
# 1    United Kingdom     20  1.818182
# 2            Canada     16  2.285714
# 3           Germany      8  4.000000
# 4   The Netherlands      5  2.500000
# 5            France      4  1.333333
# 6             Spain      4  4.000000
# 7         Australia      2  2.000000
# 8           Belgium      1  1.000000
# 9           Ireland      1  1.000000

# %%
type(df3.iloc[0]['Last Funding Amount Currency (in USD)'])
# Out:
# numpy.float64

# %%
import statsmodels.api as sm
from matplotlib import pyplot as plt
'''
General Data
    Regress funding against CB rank
'''
X = [] ; Y = []
for i in range(len(df3)):
    pos = df3.iloc[i]
    if not math.isnan(pos['Last Funding Amount Currency (in USD)']):
        y = pos['Last Funding Amount Currency (in USD)']
        x = int(pos['CB Rank (Company)'].replace(',',''))
        X.append(x)
        Y.append(y)
plt.xscale('log') ; plt.yscale('log') ; plt.scatter(X, Y) 
plt.xlabel('CB Rank') ; plt.ylabel('Amount Raised') ; 
plt.title('CB Rank vs. Amount Raised (USD)') ; plt.show()
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.175
# Model:                            OLS   Adj. R-squared:                  0.167
# Method:                 Least Squares   F-statistic:                     24.13
# Date:                Mon, 10 Aug 2020   Prob (F-statistic):           3.03e-06
# Time:                        15:33:59   Log-Likelihood:                -1881.4
# No. Observations:                 116   AIC:                             3767.
# Df Residuals:                     114   BIC:                             3772.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.72e+06   4.86e+05      7.654      0.000    2.76e+06    4.68e+06
# x1           -28.6781      5.838     -4.913      0.000     -40.242     -17.114
# ==============================================================================
# Omnibus:                       76.926   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              300.894
# Skew:                           2.506   Prob(JB):                     4.59e-66
# Kurtosis:                       9.093   Cond. No.                     1.61e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.61e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
'''
Data Validation: Rounds
'''
keptRoundNames = {} ; droppedRoundNames = {}
for name_ in df3_.index:
    round_ = df3_.loc[name_]['Last Funding Type']
    if name_ not in alldata.keys():
        if round_ not in droppedRoundNames:
            droppedRoundNames[round_] = 1
        else:
            droppedRoundNames[round_] += 1
    else:
        if round_ not in keptRoundNames:
            keptRoundNames[round_] = 1
        else:
            keptRoundNames[round_] += 1
print("Dropped round: {}".format(str(droppedRoundNames)))
print("Kept round: {}".format(str(keptRoundNames)))
# Out:
# Dropped round: {'Series A': 30, 'Seed': 198, 'Pre-Seed': 10}
# Kept round: {}

# %%
'''
Loads top schools data
'''
topSchools = pd.read_csv('topSchools.csv', index_col="Score_Rank")
topSchools = topSchools[['University', 'General_name']].head(100)

# %%
'''
Pedigree
    1. Do the majority of successful founders attend a top university?
'''
topcount = 0 ; schoolDict = {} ; founderCount = 0 ; schoolFound = False
for key in faileddata.keys():
    if faileddata[key]['founders']:
        for founder in faileddata[key]['founders']:
            if founder['education']:
                founderCount += 1 ; schoolFound = False
                for educ_ in founder['education']:
                    school_ = educ_['school'].lower()
                    if school_ not in schoolDict:
                        schoolDict[school_] = 1
                    else:
                        schoolDict[school_] += 1
                    if not schoolFound:
                        for topSchool_ in topSchools['University']:
                            if school_ in topSchool_.lower():
                                topcount += 1
                                schoolFound = True
                                break
                    if not schoolFound:
                        for topSchool_ in topSchools['General_name']:
                            if topSchool_ in school_.lower():
                                topcount += 1
                                schoolFound = True
                                break
schoolDict = {k: v for k, v in sorted(schoolDict.items(), key=lambda item: item[1], reverse=True)}                   
print("{} % of founders attended a Top 100 School at some point in their education".format(str(topcount / founderCount * 100)))

print("Top schools attended:")
count = 1
for k in schoolDict.keys():
    if count <= 10:
        print("{}. {}".format(str(count), k))
        count += 1
    else:
        break

df_school = pd.DataFrame.from_dict(schoolDict, orient='index', columns=['freq']).reset_index()
# Out:
# 38.81578947368421 % of founders attended a Top 100 School at some point in their education
# Top schools attended:
# 1. university of new haven
# 2. y combinator
# 3. massachusetts institute of technology
# 4. northeastern university
# 5. the university of texas at austin
# 6. cornell university
# 7. oregon state university
# 8. university of california, san diego
# 9. university of california, berkeley
# 10. brigham young university

# %%
'''
Pedigree
    2. Do the majority of successful founders attend graduate school?
'''
degreeDict = {} ; degreeCount = 0 ; gradCount = 0

def checkGraduateEducation(founder, degreeDict, degreeCount):
    if founder['education']:
        checkDegree = True
        for educ_ in founder['education']:
            if educ_['degree']:
                deg_ = educ_['degree'].lower()
                if checkDegree:
                    degreeCount += 1
                    checkDegree = False
                if deg_ not in degreeDict:
                    degreeDict[deg_] = 1
                else:
                    degreeDict[deg_] += 1
    return degreeDict, degreeCount

for key in faileddata.keys():
    if faileddata[key]['founders']:
        for founder in faileddata[key]['founders']:
            degreeDict, degreeCount = checkGraduateEducation(founder, degreeDict, degreeCount)

degreeDict = {k: v for k, v in sorted(degreeDict.items(), key=lambda item: item[1], reverse=True)}  
for key in degreeDict.keys():
    if key in ['mba', 'ms', 'msc', 'ph.d', 'phd', 'ma', 'jd', 'ph.d', 'md', 'mse', 'meng'] or 'master' in key or 'm.' in key or 'doctor' in key:
        gradCount += 1
print("{} percent of founders have postgraduate education".format(str(gradCount / degreeCount * 100)))
# Out:
# 21.73913043478261 percent of founders have postgraduate education

# %%
'''
Pedigree
    3. Do successful founders study certain fields over others?
'''
fieldDict = {}

def getFields(founder, fieldDict):
    if founder['education']:
        for educ_ in founder['education']:
            if educ_['field']:
                field = educ_['field'].lower()
                if field not in fieldDict:
                    fieldDict[field] = 1
                else:
                    fieldDict[field] += 1
    return fieldDict

for key in faileddata.keys():
    if faileddata[key]['founders']:
        for founder in faileddata[key]['founders']:
            fieldDict = getFields(founder, fieldDict)

fieldDict = {k: v for k, v in sorted(fieldDict.items(), key=lambda item: item[1], reverse=True)}
count = 0 ; totalCount = 0
computerFields = {} ; breakCount = 0
print("Most commonly studied fields:")
for k in fieldDict.keys():
    if breakCount < 10:
        print("{}. {}".format(str(breakCount+1), k))
        breakCount += 1
    if 'computer' in k:
        count += fieldDict[k]
        computerFields[k] = fieldDict[k]
    totalCount += fieldDict[k]
df_fields = pd.DataFrame.from_dict(fieldDict, orient='index', columns=['freq']).reset_index()
df_fields.head(10)
print("Percentage of founders that studied CS and related fields: {}%".format(str(100 * count/totalCount)))
# Out:
# Most commonly studied fields:
# 1. computer science
# 2. computer engineering
# 3. entrepreneurship/entrepreneurial studies
# 4. mechanical engineering
# 5. business administration and management, general
# 6. economics
# 7. graphic design
# 8. biology, general
# 9. electrical and computer engineering
# 10. electrical engineering
# Percentage of founders that studied CS and related fields: 22.131147540983605%

# %%
'''
Employment Background
    1. Do most founders have experience at startups (CEO, CFO, CTO, COO, Founder)
'''
posDict = {} ; ceosList = [] ; ctosList = []
for key in faileddata.keys():
    if faileddata[key]['founders']:
        for founder in faileddata[key]['founders']:
            if founder['experience']:
                firstCheck = True ; ceoCheck = False ; ctoCheck = False
                for exp_ in founder['experience']:
                    if (not key.split(' ')[0] in exp_['companyName']):
                        if exp_['title']:
                            if 'founder' in exp_['title'].lower() and firstCheck:
                                pass
                            else:
                                pos = exp_['title'].lower()
                                if pos not in posDict:
                                    posDict[pos] = 1
                                else:
                                    posDict[pos] += 1
                            firstCheck = False
                            if not ceoCheck:
                                if 'ceo' in exp_['title'].lower() or 'executive officer' in exp_['title'].lower():
                                    ceosList.append(founder)
                                    ceoCheck = True
                            if not ctoCheck:
                                if 'cto' == exp_['title'].lower() or ' cto' in exp_['title'].lower() or 'cto ' in exp_['title'].lower() or 'technology officer' in exp_['title'].lower() or 'technical officer' in exp_['title'].lower():
                                    ctosList.append(founder)
                                    ctoCheck = True
posDict = {k: v for k, v in sorted(posDict.items(), key=lambda item: item[1], reverse=True)}

df_pos = pd.DataFrame.from_dict(posDict, orient='index', columns=['freq']).reset_index()
print("Previous titles held by founders:")
df_pos.head(10)
# Out:
# Previous titles held by founders:
#                       index  freq
# 0                    mentor    19
# 1                   advisor    15
# 2  senior software engineer    11
# 3                   founder    11
# 4              board member    10
# 5                co-founder    10
# 6         software engineer     9
# 7                 president     9
# 8                       cto     8
# 9                       ceo     8

# %%
t=0
for key in faileddata.keys():
    t=t+1
t
past_founders = (11+10+16)/t
past_founders
# Out:
# 0.23870967741935484

# %%
'''
Pedigree & Employment:
    Profiles of CEOs vs. CTOs
'''
degreeDict = {} ; degreeCount = 0 ; gradCount = 0
for cto in ctosList:
    degreeDict, degreeCount = checkGraduateEducation(cto, degreeDict, degreeCount)
    
degreeDict = {k: v for k, v in sorted(degreeDict.items(), key=lambda item: item[1], reverse=True)}  
for key in degreeDict.keys():
    if key in ['mba', 'ms', 'msc', 'ph.d', 'phd', 'ma', 'jd', 'ph.d', 'md', 'mse', 'meng'] or 'master' in key or 'm.' in key or 'doctor' in key:
        gradCount += 1
print("{} percent of CTOs have postgraduate education".format(str(gradCount / degreeCount * 100)))

degreeDict = {} ; degreeCount = 0 ; gradCount = 0
for ceo in ceosList:
    degreeDict, degreeCount = checkGraduateEducation(ceo, degreeDict, degreeCount)

degreeDict = {k: v for k, v in sorted(degreeDict.items(), key=lambda item: item[1], reverse=True)}  
for key in degreeDict.keys():
    if key in ['mba', 'ms', 'msc', 'ph.d', 'phd', 'ma', 'jd', 'ph.d', 'md', 'mse', 'meng'] or 'master' in key or 'm.' in key or 'doctor' in key:
        gradCount += 1
print("{} percent of CEOs have postgraduate education".format(str(gradCount / degreeCount * 100)))

fieldDict = {}
for ceo in ceosList:
    fieldDict = getFields(ceo, fieldDict)
    
fieldDict = {k: v for k, v in sorted(fieldDict.items(), key=lambda item: item[1], reverse=True)}
count = 0 ; totalCount = 0
computerFields = {} ; breakCount = 0
print("Most commonly studied fields CEO:")
for k in fieldDict.keys():
    if breakCount < 10:
        print("{}. {}".format(str(breakCount+1), k))
        breakCount += 1
    if 'computer' in k or 'cs' == k or 'software' in k or 'data' in k or 'engine' in k:
        count += fieldDict[k]
        computerFields[k] = fieldDict[k]
    totalCount += fieldDict[k]
df_fields = pd.DataFrame.from_dict(fieldDict, orient='index', columns=['freq']).reset_index()
df_fields.head(10)
print("Percentage of CEOs that studied CS and engineering fields: {}%".format(str(100 * count/totalCount)))

fieldDict = {}
for cto in ctosList:
    fieldDict = getFields(cto, fieldDict)

fieldDict = {k: v for k, v in sorted(fieldDict.items(), key=lambda item: item[1], reverse=True)}
count = 0 ; totalCount = 0
computerFields = {} ; breakCount = 0
print("Most commonly studied fields CTO:")
for k in fieldDict.keys():
    if breakCount < 10:
        print("{}. {}".format(str(breakCount+1), k))
        breakCount += 1
    if 'computer' in k or 'cs' == k or 'software' in k or 'data' in k or 'engine' in k:
        count += fieldDict[k]
        computerFields[k] = fieldDict[k]
    totalCount += fieldDict[k]
df_fields = pd.DataFrame.from_dict(fieldDict, orient='index', columns=['freq']).reset_index()
df_fields.head(10)
print("Percentage of CTOs that studied CS and engineering fields: {}%".format(str(100 * count/totalCount)))

founderCount = 0 ; schoolDict = {}
for founder in ceosList:
    if founder['education']:
        founderCount += 1 ; schoolFound = False
        for educ_ in founder['education']:
            school_ = educ_['school'].lower()
            if school_ not in schoolDict:
                schoolDict[school_] = 1
            else:
                schoolDict[school_] += 1
schoolDict = {k: v for k, v in sorted(schoolDict.items(), key=lambda item: item[1], reverse=True)}
df_schoolCEOs = pd.DataFrame.from_dict(schoolDict, orient='index', columns=['freq']).reset_index()
print("CEO Schools:")
print(df_schoolCEOs.head(10))

founderCount = 0 ; schoolDict = {}
for founder in ctosList:
    if founder['education']:
        founderCount += 1 ; schoolFound = False
        for educ_ in founder['education']:
            school_ = educ_['school'].lower()
            if school_ not in schoolDict:
                schoolDict[school_] = 1
            else:
                schoolDict[school_] += 1
schoolDict = {k: v for k, v in sorted(schoolDict.items(), key=lambda item: item[1], reverse=True)}
df_schoolCTOs = pd.DataFrame.from_dict(schoolDict, orient='index', columns=['freq']).reset_index()
print("CTO Schools:")
print(df_schoolCTOs.head(10))
# Out:
# 15.384615384615385 percent of CTOs have postgraduate education
# 28.125 percent of CEOs have postgraduate education
# Most commonly studied fields CEO:
# 1. computer science
# 2. business administration and management, general
# 3. international studies, french, and environmental studies
# 4. business management and marketing
# 5. evolutionary biology
# 6. english literature
# 7. marketing intelligence - data science
# 8. computer science - applied maths
# 9. mathematics
# 10. software engineering, cognitive sciences
# Percentage of CEOs that studied CS and engineering fields: 28.8135593220339%
# Most commonly studied fields CTO:
# 1. computer science
# 2. computer engineering
# 3. software
# 4. engineering physics
# 5. artificial intelligence (media lab), health informatics, computer science
# 6. international business
# 7. harvard-mit program in health sciences and technology
# 8. computer science & statistics
# 9. computer science and cognitive psychology
# 10. computer programming
# Percentage of CTOs that studied CS and engineering fields: 65.21739130434783%
# CEO Schools:
#                                                index  freq
# 0  the university of chicago - booth school of bu...     2
# 1                                  mcgill university     2
# 2                                       y combinator     2
# 3                                 wingate university     2
# 4                      the open university of israel     2
# 5                            oregon state university     2
# 6                             university of la verne     1
# 7                                          hec paris     1
# 8  national school of computer science and applie...     1
# 9                                  lycée champollion     1
# CTO Schools:
#                                            index  freq
# 0          massachusetts institute of technology     3
# 1                      seoul national university     2
# 2                         university of canberra     1
# 3                     university of nevada, reno     1
# 4                             queen's university     1
# 5                 university of colorado boulder     1
# 6  university of science and technology of china     1
# 7                           ripon grammar school     1
# 8   iese business school - university of navarra     1
# 9                        northeastern university     1

# %%
'''
Employment Background (1) contd.
'''
entrepCount = 0 ; techCount = 0 ; busCount = 0 ; totalCount = 0
for i in range(len(df_pos)):
    pos = df_pos.iloc[i]
    totalCount += pos['freq']
    if 'founder' in pos['index'] or 'ceo' in pos['index'] or 'executive' in pos['index'] or 'board' in pos['index'] or 'president' in pos['index']:
        entrepCount += pos['freq']
    if ('engineer' in pos['index'] or 'cto' in pos['index'] or 'technology' in pos['index'] or 'computer' in pos['index'] or 'developer' in pos['index'] or 
        'science' in pos['index'] or 'data' in pos['index'] or 'research' in pos['index']):
        techCount += pos['freq']
    if ('business' in pos['index'] or 'analyst' in pos['index'] or 'product' in pos['index'] or 'manager' in pos['index'] or 'director' in pos['index'] or 
        'coo' in pos['index'] or 'operating' in pos['index'] or 'associate' in pos['index'] or 'financ' in pos['index'] or 'vp' in pos['index'] or 
        'consultant' in pos['index']):
        busCount += pos['freq']
print("{} percent entrepreneurial/executive".format(str(entrepCount * 100 / totalCount)))
print("{} percent tech".format(str(techCount * 100 / totalCount)))
print("{} percent business/finance/consulting".format(str(busCount * 100 / totalCount)))
# Out:
# 23.7012987012987 percent entrepreneurial/executive
# 30.51948051948052 percent tech
# 26.948051948051948 percent business/finance/consulting

# %%
'''
Employment Background
    2. Do founders have a lot of LinkedIn Connections
'''
connectDict = {} ; countDict = {} ; numFounders = 0 ; totalConnections = 0
for key in faileddata.keys():
    numFounders_ = 0 
    try:
        for founder in faileddata[key]['founders']:
            if founder['connections']:
                num = int([j for i in founder['connections'].split(' ') for j in i.split('+')][0])
                numFounders += 1 ; totalConnections += num
                numFounders_ += 1
                if key not in connectDict:
                    connectDict[key] = num
                else:
                    connectDict[key] += num
        connectDict[key] /= numFounders_
        countDict[key] = numFounders_
    except Exception as e:
        pass

print("Average number of connections is {}".format(str(totalConnections / numFounders)))

top100count = 0 ; top100founderCount = 0
for top_ in df3['Organization Name'][:100]:
    if top_ in connectDict:
        top100count += connectDict[top_] * countDict[top_]
        top100founderCount += countDict[top_]
print("Average number of connections in Top 100: {}".format(str(top100count / top100founderCount)))
# Out:
# Average number of connections is 451.8957055214724
# Average number of connections in Top 100: 451.8957055214724

# %%
'''
Employment Background
    3. Do founders come from certain job positions prior to starting their company? 
        - are they prior founders?
        - are they prior software engineers
'''
df_pos.head(10)
# Out:
#                       index  freq
# 0                    mentor    19
# 1                   advisor    15
# 2  senior software engineer    11
# 3                   founder    11
# 4              board member    10
# 5                co-founder    10
# 6         software engineer     9
# 7                 president     9
# 8                       cto     8
# 9                       ceo     8

# %%
'''
Employment Background
    4. Do founders come from certain companies (or industries)
'''
expDict_raw = {} ; expDict = {}
for key in faileddata.keys():
    for founder in faileddata[key]['founders']:
        if founder['experience']:
            for exp_ in founder['experience']:
                exp_name = exp_['companyName'].lower()
                if exp_name not in expDict_raw:
                    expDict_raw[exp_name] = 1
                else:
                    expDict_raw[exp_name] += 1
                short_name = re.split('\\s+|\\.|,', exp_name)
                for word in short_name:
                    if word in expDict.keys():
                        expDict[word] += 1
                    else:
                        expDict[word] = 1
expDict = {k: v for k, v in sorted(expDict.items(), key=lambda item: item[1], reverse=True)}
expDict;

expDict_raw = {k: v for k, v in sorted(expDict_raw.items(), key=lambda item: item[1], reverse=True)}
expDict_raw
# Out:
# {'facebook': 8,
#  'google': 6,
#  'cruise': 5,
#  'solutech, inc.': 5,
#  'techstars': 4,
#  'y combinator': 4,
#  'startup weekend': 4,
#  'oracle': 3,
#  'wit.ai (acquired by facebook)': 3,
#  'freelance': 3,
#  'dashride': 3,
#  'sobrio, llc': 3,
#  'talent sonar': 3,
#  'european innovation academy': 3,
#  'communitech': 3,
#  'vertisense inc.': 3,
#  'joany': 2,
#  'humanize health': 2,
#  'assembly made': 2,
#  'mckinsey & company': 2,
#  'twitter full-time': 2,
#  'aiden.ai': 2,
#  'apple': 2,
#  'nabla': 2,
#  'nuance communications': 2,
#  'university of connecticut': 2,
#  'salesforce': 2,
#  'griddable.io': 2,
#  'jobvention': 2,
#  'microsoft': 2,
#  'clusterhq': 2,
#  'cava capital': 2,
#  'confirm': 2,
#  'amazon': 2,
#  'drone complier': 2,
#  'looker': 2,
#  'artillery games': 2,
#  'nomiku': 2,
#  'candor': 2,
#  'scaphold, inc.': 2,
#  'zen99': 2,
#  'riseml': 2,
#  'ibm': 2,
#  'expensebot': 2,
#  'freeagent': 2,
#  'the american institute of architects, iowa chapter': 2,
#  'perfect dashboard': 2,
#  'perfect web extensions (acquired by ostraining)': 2,
#  'perfect web': 2,
#  'opendns': 2,
#  'consulting unplugged': 2,
#  'scroll': 2,
#  'bnp paribas': 2,
#  'for the future new haven': 2,
#  'scroll network': 2,
#  'solarcity': 2,
#  'yale peabody museum of natural history': 2,
#  'holberton school new haven': 2,
#  'isoplexis full-time': 2,
#  'blindly part-time': 2,
#  'freelance freelance': 2,
#  '1215 molecular diagnostics part-time': 2,
#  'scroll full-time': 2,
#  'rithmio': 2,
#  'cnverg': 2,
#  'muni tech, llc': 2,
#  'staffly, inc.': 2,
#  'visa': 2,
#  'salesforce.com': 2,
#  'blue orange bison': 2,
#  'instant api': 2,
#  'rootsrated media': 2,
#  'marketfox': 2,
#  'ieee': 2,
#  'halolife': 2,
#  'jeeliz': 2,
#  'chocolate soup': 2,
#  'first': 2,
#  'bithound': 2,
#  'transpose': 2,
#  'create inc.': 2,
#  'rigplenish, inc.': 2,
#  'ticketless': 2,
#  'city ai': 2,
#  'cupenya': 2,
#  'wasteless - sell more, waste less': 2,
#  'weissbeerger': 2,
#  'glassify': 2,
#  'israel defense forces': 2,
#  'unoceros corporation': 2,
#  'iambiq': 2,
#  'world bank group': 2,
#  'catalog': 2,
#  'cloakhire': 2,
#  'gazoo': 2,
#  'butlr health': 1,
#  'the cedars-sinai accelerator': 1,
#  'la care': 1,
#  'mvp health care': 1,
#  'kaiser permanente': 1,
#  'twitter': 1,
#  'smyte': 1,
#  'assembly made inc': 1,
#  'minefold': 1,
#  'calumo': 1,
#  'thoughtworks': 1,
#  'ticketsnow': 1,
#  'usaid': 1,
#  'tonic audio labs full-time': 1,
#  'filament!': 1,
#  'singly': 1,
#  'toviefor, inc.': 1,
#  'loopshot inc.': 1,
#  'nudge.ai': 1,
#  'sickkids foundation': 1,
#  'pathfactory (we used to be lookbookhq)': 1,
#  'the mobile experience company': 1,
#  'benevity full-time': 1,
#  'verafin': 1,
#  'nudge software inc.': 1,
#  'eloqua': 1,
#  'wisemobile': 1,
#  'fiksu': 1,
#  'mla': 1,
#  'forereads - vcflair - game of angels self-employed': 1,
#  'timista ltd': 1,
#  'asiance': 1,
#  'virtuoz (acquired by nuance: nuan)': 1,
#  'asiance korea': 1,
#  'iron horse web & media solutions': 1,
#  'julia balfour, llc.': 1,
#  'cruise automation': 1,
#  'clearstone': 1,
#  'dashride (acquired by cruise) full-time': 1,
#  'innovation quest': 1,
#  'groupcentric': 1,
#  'stimulus processing llc full-time': 1,
#  'surchx': 1,
#  'strategy factory': 1,
#  'lifelock': 1,
#  'internet america': 1,
#  'light ev part-time': 1,
#  'bebopbee, inc.': 1,
#  'careskore full-time': 1,
#  '1871': 1,
#  'the chicago lighthouse for people who are blind or visually impaired': 1,
#  'sinai health system full-time': 1,
#  'rosalind franklin university of medicine and science full-time': 1,
#  'captain james a. lovell federal health care center': 1,
#  'stockton cardiology medical group': 1,
#  'careskore': 1,
#  'linkedin': 1,
#  'yahoo!': 1,
#  'cornell university': 1,
#  'hewlett-packard': 1,
#  'aryaka networks, inc': 1,
#  'clearapp': 1,
#  'netscout': 1,
#  'eastwind networks': 1,
#  'blue coat systems': 1,
#  'solera networks': 1,
#  'adobe systems': 1,
#  'six digital exchange full-time': 1,
#  'global blockchain business council': 1,
#  'interwork alliance': 1,
#  'apexe3': 1,
#  'talos trading': 1,
#  'imentor': 1,
#  'redox': 1,
#  '...': 1,
#  'talentsonar': 1,
#  "crohn's & colitis foundation of america": 1,
#  'amazon.com': 1,
#  'webroot software': 1,
#  'modulus data': 1,
#  'elevate security': 1,
#  'zumigo inc.': 1,
#  'kenna security': 1,
#  'dotscience': 1,
#  'weaveworks': 1,
#  'clusterhq (was hybridcluster)': 1,
#  'digital crocus': 1,
#  'publisher discovery full-time': 1,
#  'cloudfind': 1,
#  'the property jungle': 1,
#  'bronco ltd': 1,
#  'melio full-time': 1,
#  'dblb': 1,
#  'project mayhem ventures': 1,
#  'the revenue collective': 1,
#  'seated': 1,
#  'summit partners': 1,
#  'digisure, inc.': 1,
#  'warburg pincus llc': 1,
#  'summit partners full-time': 1,
#  'strategic cyber ventures': 1,
#  'corvium': 1,
#  'invaluable full-time': 1,
#  'willow': 1,
#  'confirm.io - acquired facebook march 2018': 1,
#  'gasbuddy': 1,
#  'google full-time': 1,
#  'plug and play tech center': 1,
#  '(various)': 1,
#  'neumob (acquired by cloudflare) full-time': 1,
#  'cdnetworks (acquired by kddi)': 1,
#  'cloudflare, inc.': 1,
#  'neumob': 1,
#  'cdnetworks inc.': 1,
#  'freebsd': 1,
#  'cdnetworks japan co.,ltd.': 1,
#  'morpheus technology laboratories': 1,
#  'symbolic io corporation': 1,
#  'storagenix': 1,
#  'hp': 1,
#  'netapp': 1,
#  'willamette innovators network': 1,
#  'oregon aviation board': 1,
#  'helicopter association international': 1,
#  'private full-time': 1,
#  'rpas training and solutions': 1,
#  'aerosdb': 1,
#  'news corporation': 1,
#  'bling capital': 1,
#  'brighton angel partners': 1,
#  'real estate business llc': 1,
#  'artillery full-time': 1,
#  'wilbur labs': 1,
#  'artillery games, inc.': 1,
#  'redbeacon (acquired by the home depot)': 1,
#  'boomtown': 1,
#  'paysimple': 1,
#  'commerce ventures': 1,
#  'loop commerce': 1,
#  'ip commerce': 1,
#  'dave johnson and associates': 1,
#  'crowe horwath llp': 1,
#  'kpmg': 1,
#  'ernst & young llp': 1,
#  'demartino marketing group': 1,
#  'sourceress (yc s17)': 1,
#  'lightsail energy': 1,
#  'social impact capital': 1,
#  'green cow venture capital': 1,
#  'q venture partners': 1,
#  'stanford university': 1,
#  'university of california, berkeley': 1,
#  'helen keller national center for deaf-blind youths and adults': 1,
#  'fatty crab': 1,
#  'the international culinary center': 1,
#  "l'ecole": 1,
#  'crafactor llc': 1,
#  'oceanops': 1,
#  'antler': 1,
#  'avantida': 1,
#  'united arab shipping company (s.a.g.)': 1,
#  'zim': 1,
#  'grow movement': 1,
#  'npc south inc': 1,
#  'beaulieu america': 1,
#  'renuco': 1,
#  'fibrochem': 1,
#  'nabis': 1,
#  'cda | cannabis distribution association': 1,
#  'pioneer fund': 1,
#  'pando technologies llc': 1,
#  'callminer': 1,
#  'clickfox, the journey company': 1,
#  'elevated': 1,
#  'acertitude': 1,
#  'nice ltd': 1,
#  'weston fc': 1,
#  'glassdoor': 1,
#  'labine media': 1,
#  'capital one': 1,
#  'vcu brandcenter': 1,
#  'the martin agency': 1,
#  'balancegenics': 1,
#  'badd media': 1,
#  'dragonslayer': 1,
#  'smg': 1,
#  'thinktank holdings': 1,
#  'boys & girls club': 1,
#  'product perfect': 1,
#  'carvana': 1,
#  'ziptask': 1,
#  'toptal': 1,
#  'first american title': 1,
#  'self employed': 1,
#  'exec': 1,
#  'deloitte': 1,
#  'proton radio': 1,
#  'xfer records': 1,
#  'checkr': 1,
#  'nvidia': 1,
#  'university of freiburg': 1,
#  'nvidia full-time': 1,
#  'satoshipay': 1,
#  'zolar gmbh': 1,
#  'spacy': 1,
#  'private': 1,
#  'uber entertainment': 1,
#  'playfab, inc.': 1,
#  'immersive technology summit': 1,
#  'envelop vr': 1,
#  'start in cle': 1,
#  'entrepreneurship education consortium': 1,
#  'bounce innovation hub': 1,
#  'gener8tor': 1,
#  'blockland cleveland': 1,
#  'hotel engine': 1,
#  'smartcapital': 1,
#  'travelers haven': 1,
#  'given': 1,
#  'firmiq': 1,
#  'ia quant': 1,
#  'charrette venture group': 1,
#  'funnelwise': 1,
#  'valen energy - decentralized power systems part-time': 1,
#  'lostin.space full-time': 1,
#  'united states digital service': 1,
#  'reaction, inc.': 1,
#  'contabo gmbh full-time': 1,
#  'agh university of science and technology': 1,
#  'berkeley skydeck': 1,
#  'joomla!': 1,
#  'plesk': 1,
#  'perfect dashboard (exit)': 1,
#  'i2coalition': 1,
#  'wp engine': 1,
#  'perfect web sp. z o.o.': 1,
#  'joomla! bug squad': 1,
#  'majestic media sp. z o.o.': 1,
#  'heavy element self-employed': 1,
#  'the establishment nys part-time': 1,
#  "d'youville college full-time": 1,
#  'gripeo self-employed': 1,
#  'ellucian contract': 1,
#  'mongoose': 1,
#  'proulx|taylor': 1,
#  'gripeo': 1,
#  'campus labs full-time': 1,
#  'ellucian full-time': 1,
#  'modern tribe inc.': 1,
#  'four kitchens': 1,
#  'gripeo | resolve social': 1,
#  'simpleapply llc': 1,
#  'ellucian (formerly datatel)': 1,
#  'rocket full-time': 1,
#  'gabler holdings inc. self-employed': 1,
#  'stackpath full-time': 1,
#  'help.com': 1,
#  'easyrent.com': 1,
#  'affirm, inc.': 1,
#  'intercom': 1,
#  'staffjoy': 1,
#  'cultivation capital': 1,
#  'zyper full-time': 1,
#  'pullrequest full-time': 1,
#  'moonlight full-time': 1,
#  'staffjoy full-time': 1,
#  'q bio full-time': 1,
#  'grail, inc.': 1,
#  'klarismo': 1,
#  'atomico': 1,
#  'mindtrust full-time': 1,
#  'solutech, inc. full-time': 1,
#  'city of west haven contract': 1,
#  "unh mayor's advisory commission": 1,
#  'yale peabody museum of natural histroy': 1,
#  'court appointed special advocates for children': 1,
#  'forbes technology council': 1,
#  'city of middletown, ct internship': 1,
#  'yale university': 1,
#  'boeing': 1,
#  'relationalai': 1,
#  'eve': 1,
#  'light table': 1,
#  'readyforzero': 1,
#  'nike full-time': 1,
#  'techstars chicago': 1,
#  'aktive, inc.': 1,
#  'ocient': 1,
#  'university of illinois at urbana-champaign': 1,
#  'united technologies research center': 1,
#  'roadmap full-time': 1,
#  'growthcounsel': 1,
#  'kylie madison co.': 1,
#  'cheetah consulting': 1,
#  'the lending practice': 1,
#  'farm credit bank of texas': 1,
#  'emergent agile alliance': 1,
#  'rs2 software inc (north america)': 1,
#  'samsung electronics america': 1,
#  'serve, an american express company': 1,
#  'upstart': 1,
#  'stubhub': 1,
#  'san francisco': 1,
#  'medium full-time': 1,
#  'various startups': 1,
#  'yespath (acquired)': 1,
#  'clearstory data': 1,
#  'twilio inc. full-time': 1,
#  'lytics': 1,
#  'yespath full-time': 1,
#  'mintigo full-time': 1,
#  'pkware full-time': 1,
#  'arbré technologies, llc': 1,
#  'pkware': 1,
#  'the sasquatch studios': 1,
#  'mid-state technical college part-time': 1,
#  'arbré technologies, inc.': 1,
#  'warm living real estate, llc': 1,
#  'university of wisconsin - stevens point': 1,
#  'the page company full-time': 1,
#  'launch leads': 1,
#  'funcheaporfree: ❤️jordan page | hey freebs ✌\uf3fb @thebudgetbootcamp @productivitybootcamp': 1,
#  'outro.com': 1,
#  'inc. magazine freelance': 1,
#  'the church of jesus christ of latter-day saints': 1,
#  'threatmetrix': 1,
#  'igs | desenvolvimento de software full-time': 1,
#  'dress & go full-time': 1,
#  'cinemark brasil': 1,
#  'c&a brasil': 1,
#  'gft group': 1,
#  'formyl': 1,
#  'banyan, inc.': 1,
#  'peterson ventures': 1,
#  'outro': 1,
#  'adamatic inc': 1,
#  'best buddies international': 1,
#  'changelly': 1,
#  'clearblock limited': 1,
#  'blockex': 1,
#  'uk digital currency association': 1,
#  'cryptopay': 1,
#  'qadre': 1,
#  'statezero labs': 1,
#  'credits': 1,
#  'pokerstars.com': 1,
#  'n/a': 1,
#  'tiny organics': 1,
#  'chief': 1,
#  'human ventures co': 1,
#  'wondermento': 1,
#  'mind candy': 1,
#  'the dollar saas club full-time': 1,
#  'ingredient concerns': 1,
#  'flexsecure, inc.': 1,
#  'taking a health break': 1,
#  'instant api inc.': 1,
#  'cisco': 1,
#  'nokia siemens networks': 1,
#  'matcha': 1,
#  'pointer management company': 1,
#  'internmatch': 1,
#  'toad&co': 1,
#  'outdoor industry association': 1,
#  'rootsrated': 1,
#  'reflection riding arboretum & nature center': 1,
#  'lost art stationery': 1,
#  'rock/creek': 1,
#  'alpine camp for boys (summer position)': 1,
#  'the company lab (co.lab)': 1,
#  'lula lake land trust': 1,
#  'retina associates/itronix systems inc': 1,
#  'physician referral network (prn)': 1,
#  'wellsky': 1,
#  'intelligent retinal imaging systems': 1,
#  'trevia digital health': 1,
#  'itronix systems, inc.': 1,
#  'cerner corporation': 1,
#  'elbo freelance': 1,
#  'the access group': 1,
#  'link big ltd. full-time': 1,
#  'snowball studios- animation, visual effects & content full-time': 1,
#  'tribal ddb israel full-time': 1,
#  'devpost': 1,
#  'startupbootcamp': 1,
#  'cwt full-time': 1,
#  'tingz': 1,
#  'link big ltd.': 1,
#  'idf - 9900 // 8197 // cyber division': 1,
#  'idf / intelligence operations division': 1,
#  'washington university school of medicine in st. louis': 1,
#  'washington university mckelvey school of engineering full-time': 1,
#  'signet accel': 1,
#  'the ohio state university': 1,
#  'the ohio state university medical center': 1,
#  'tyche': 1,
#  'ford marrin': 1,
#  'mayer brown': 1,
#  'hon. judge ann aldrich': 1,
#  'information sciences institute': 1,
#  'johns hopkins university applied physics laboratory': 1,
#  'tyche analytics': 1,
#  'university of texas at austin': 1,
#  'naval undersea warfare center': 1,
#  'stilt inc. full-time': 1,
#  'marketfox full-time': 1,
#  'flash technos self-employed': 1,
#  'freshworks full-time': 1,
#  'mobio digital full-time': 1,
#  'bigbinary': 1,
#  'chatwoot': 1,
#  'furlenco': 1,
#  'rajagiri school of engineering & technology': 1,
#  'oyster™ full-time': 1,
#  'carrom': 1,
#  'store2be full-time': 1,
#  'freshworks inc. (formerly freshdesk)': 1,
#  'vidya academy of science and technology': 1,
#  'kelcor, llc': 1,
#  'the jumpfund': 1,
#  'rezli, inc.': 1,
#  'iron gaming': 1,
#  'cory allison consulting': 1,
#  'autodesk': 1,
#  'carta': 1,
#  'navdy': 1,
#  'storefront': 1,
#  'housecanary': 1,
#  'bridge road brick house llc': 1,
#  'rentpath': 1,
#  'lovely (acquired by rentpath)': 1,
#  'codenow': 1,
#  'hackbright academy': 1,
#  'lynx': 1,
#  '3d systems corporation': 1,
#  'coweb (acquired)': 1,
#  'webar.rocks self-employed': 1,
#  'spacegoo': 1,
#  'capstone square ai consulting': 1,
#  'nextlevel - building enterprise value': 1,
#  'minetta brook | intelligence from unstructured data via nlp / machine learning | fintech': 1,
#  'aelego business transfomation services': 1,
#  'tie seattle': 1,
#  'saxo bank': 1,
#  'minetta brook': 1,
#  'banc of america securities': 1,
#  'gemstone systems': 1,
#  'bloomberg': 1,
#  'self-employed freelance': 1,
#  'squash.io': 1,
#  'costek inc.': 1,
#  'roadmunk': 1,
#  'numo corp.': 1,
#  'dozr': 1,
#  'intel corporation': 1,
#  'social venture partners': 1,
#  'foodlink': 1,
#  'ja canada': 1,
#  'fairtunes': 1,
#  'cs, college of engineering, virginia tech': 1,
#  'arab academy for science and technology and maritime transport': 1,
#  'production and quality institute': 1,
#  'virginia tech department of computer science': 1,
#  'ipm consulting': 1,
#  'hope for hypothalamic hamartomas': 1,
#  'thrively/activity rocket': 1,
#  'kaplan test prep & admissions': 1,
#  'allied jewish federation of colorado': 1,
#  'shulman rogers': 1,
#  'maryland tech council': 1,
#  'dmv food truck association': 1,
#  'mindshare inc.': 1,
#  'main street': 1,
#  'forefront power': 1,
#  'distributed sun llc': 1,
#  'aecom': 1,
#  'saratoga associates': 1,
#  'remix self-employed': 1,
#  'midwood investment & development': 1,
#  'rebny (the real estate board of new york)': 1,
#  'hickey & associates': 1,
#  'houtman designs': 1,
#  'department of physics, university of british columbia': 1,
#  'triumf': 1,
#  'genxcomm inc.': 1,
#  'symmetry systems inc.': 1,
#  'the university of texas at austin': 1,
#  'm87': 1,
#  'accordion health inc.': 1,
#  'bonsai research, llc': 1,
#  'emory university': 1,
#  'wavebridge': 1,
#  'tensility venture partners': 1,
#  '7-eleven': 1,
#  'otainfo': 1,
#  'the founder institute': 1,
#  'de anza associated student body (dasb)': 1,
#  'veracity': 1,
#  'stanford hospital & clinics': 1,
#  'wells fargo': 1,
#  'retailigence corporation': 1,
#  'innovaspire': 1,
#  'e2 innovation': 1,
#  'minera chinalco peru s.a.': 1,
#  'southern peru copper corporation': 1,
#  'bucyrus international': 1,
#  'backus': 1,
#  'rebill full-time': 1,
#  'surco seguros': 1,
#  'ando': 1,
#  'coderhouse': 1,
#  'shopear': 1,
#  'emprear': 1,
#  'massachusetts institute of technology': 1,
#  'nuvem shop': 1,
#  'jtbd+': 1,
#  'shovel apps, inc.': 1,
#  'grupo edisur': 1,
#  'junior achievement argentina': 1,
#  'iae business school': 1,
#  'rockstart accelerator': 1,
#  'amboss': 1,
#  'heidelberg': 1,
#  'holidaycheck ag': 1,
#  'luke hughes | furniture in architecture': 1,
#  "consultant to premium brand sme's": 1,
#  'innoverne | saas | sharing economy': 1,
#  'snap-on business solutions': 1,
#  'omic': 1,
#  'dfuse full-time': 1,
#  'next ai': 1,
#  'founder institute part-time': 1,
#  'timechain full-time': 1,
#  "nukern inc. (techstars austin'17) full-time": 1,
#  'pme mtl - collégial en affaires': 1,
#  'technovation': 1,
#  'blockchain.io': 1,
#  'paymium': 1,
#  'oyst': 1,
#  'themecloud.io': 1,
#  'nanocloud': 1,
#  'osaka full-time': 1,
#  'founders factory full-time': 1,
#  'nanocloud software': 1,
#  'axa': 1,
#  'bnp paribas arbitrage': 1,
#  'koeppel rosen llc': 1,
#  'compushine, inc.': 1,
#  'probabilisti.co self-employed': 1,
#  'panopticon laboratories': 1,
#  'redowl analytics': 1,
#  'university of maryland school of medicine contract': 1,
#  'nomena, inc.': 1,
#  'earthrisk technologies': 1,
#  'blue marble energy': 1,
#  'clabs': 1,
#  'dorm room fund': 1,
#  'tolstoy': 1,
#  'energy intelligence': 1,
#  'medill national security journalism initiative': 1,
#  'mohua village': 1,
#  'edmund hillary fellowship (ehf)': 1,
#  'earth equity': 1,
#  'hypha/seeds': 1,
#  'geoship': 1,
#  'bandpay.me': 1,
#  'bandbasher inc': 1,
#  'degarr': 1,
#  'forbes': 1,
#  'yoi corp': 1,
#  'global renewable energy education network': 1,
#  'fuel cycle full-time': 1,
#  'kip solutions': 1,
#  'university of chicago': 1,
#  'frontline foods': 1,
#  'u.s. digital response': 1,
#  'baller dinner foundation': 1,
#  'amazon web services (aws)': 1,
#  'the institution of engineering and technology': 1,
#  'digital catapult full-time': 1,
#  'trackersense limited': 1,
#  'skillwise uk limited': 1,
#  'splitreq': 1,
#  'eam staffing services': 1,
#  'northern metals, inc.': 1,
#  'beef your book': 1,
#  'matias energy': 1,
#  'cms gas transmission': 1,
#  'anr pipeline': 1,
#  'qedit': 1,
#  'sapien': 1,
#  'deckard a.i. - intelligence for project management': 1,
#  'lovoo gmbh': 1,
#  'deeptech club freelance': 1,
#  'fightpandemics self-employed': 1,
#  'xu exponential game changers gmbh freelance': 1,
#  'beyond machine self-employed': 1,
#  'bitwala freelance': 1,
#  'mlberlin': 1,
#  'afs intercultural programs': 1,
#  'model european parliament italia': 1,
#  'synchronet': 1,
#  'gazoo, inc': 1,
#  'ispira technologies': 1,
#  'skylla engineering': 1,
#  'l-3 communications - titan group': 1,
#  'redbird learning inc': 1,
#  'zelus capital': 1,
#  'texas a&m engineering experiment station': 1,
#  'pivotpoint solutions': 1,
#  'harrison eurosports': 1,
#  'coastal media solutions': 1,
#  'archer dodge': 1,
#  'instant hollywood': 1}

# %%
'''
Employment Background
    5. Are there certain words or phrases in a founder's prior job description that stand out
'''
expDict
# Out:
# {'': 129,
#  'full-time': 67,
#  'inc': 62,
#  'of': 38,
#  'the': 27,
#  'university': 22,
#  'llc': 19,
#  '&': 14,
#  'freelance': 13,
#  '-': 12,
#  'self-employed': 11,
#  '(acquired': 11,
#  'by': 11,
#  'and': 11,
#  'ai': 10,
#  'health': 9,
#  'company': 9,
#  'facebook': 9,
#  'part-time': 9,
#  'for': 9,
#  'systems': 9,
#  'technology': 9,
#  'corporation': 9,
#  '|': 9,
#  'perfect': 9,
#  'center': 8,
#  'group': 8,
#  'digital': 8,
#  'capital': 8,
#  'web': 7,
#  'media': 7,
#  'io': 7,
#  'com': 7,
#  'google': 7,
#  'institute': 7,
#  'school': 7,
#  'cruise': 6,
#  'ltd': 6,
#  'solutions': 6,
#  'innovation': 6,
#  'partners': 6,
#  'tech': 6,
#  'energy': 6,
#  'technologies': 6,
#  'haven': 6,
#  'academy': 6,
#  'consulting': 6,
#  'solutech': 6,
#  'scroll': 6,
#  'engineering': 6,
#  'techstars': 5,
#  'software': 5,
#  'america': 5,
#  'science': 5,
#  'a': 5,
#  'business': 5,
#  'ventures': 5,
#  'network': 5,
#  'association': 5,
#  'venture': 5,
#  'new': 5,
#  'labs': 4,
#  'dashride': 4,
#  'y': 4,
#  'combinator': 4,
#  'salesforce': 4,
#  'networks': 4,
#  'blue': 4,
#  'amazon': 4,
#  'co': 4,
#  'international': 4,
#  'artillery': 4,
#  'american': 4,
#  'gmbh': 4,
#  'european': 4,
#  'o': 4,
#  'yale': 4,
#  'city': 4,
#  'bank': 4,
#  'texas': 4,
#  'instant': 4,
#  'intelligence': 4,
#  'startup': 4,
#  'weekend': 4,
#  'care': 3,
#  'assembly': 3,
#  'made': 3,
#  'twitter': 3,
#  'foundation': 3,
#  'oracle': 3,
#  'wit': 3,
#  'facebook)': 3,
#  'communications': 3,
#  'sobrio': 3,
#  'chicago': 3,
#  'medicine': 3,
#  'council': 3,
#  'talent': 3,
#  'sonar': 3,
#  'data': 3,
#  'security': 3,
#  'clusterhq': 3,
#  'summit': 3,
#  'confirm': 3,
#  'cdnetworks': 3,
#  'real': 3,
#  'estate': 3,
#  'games': 3,
#  'commerce': 3,
#  'associates': 3,
#  'social': 3,
#  'united': 3,
#  'club': 3,
#  'first': 3,
#  'in': 3,
#  'dashboard': 3,
#  'college': 3,
#  'gripeo': 3,
#  'ellucian': 3,
#  'contract': 3,
#  'bnp': 3,
#  'paribas': 3,
#  'peabody': 3,
#  'museum': 3,
#  'natural': 3,
#  'at': 3,
#  'limited': 3,
#  'api': 3,
#  'rootsrated': 3,
#  'israel': 3,
#  'marketfox': 3,
#  'services': 3,
#  'communitech': 3,
#  'vertisense': 3,
#  'gazoo': 3,
#  'accelerator': 2,
#  'joany': 2,
#  'humanize': 2,
#  'mckinsey': 2,
#  'nudge': 2,
#  'to': 2,
#  'aiden': 2,
#  'game': 2,
#  'apple': 2,
#  'nabla': 2,
#  'asiance': 2,
#  'nuance': 2,
#  'iron': 2,
#  'connecticut': 2,
#  'factory': 2,
#  'light': 2,
#  'careskore': 2,
#  'medical': 2,
#  'griddable': 2,
#  'global': 2,
#  'blockchain': 2,
#  'alliance': 2,
#  'jobvention': 2,
#  'microsoft': 2,
#  'project': 2,
#  'cava': 2,
#  'cyber': 2,
#  'neumob': 2,
#  'laboratories': 2,
#  'board': 2,
#  'drone': 2,
#  'complier': 2,
#  'private': 2,
#  'looker': 2,
#  'llp': 2,
#  'nomiku': 2,
#  'q': 2,
#  'stanford': 2,
#  'berkeley': 2,
#  'national': 2,
#  'arab': 2,
#  'candor': 2,
#  'scaphold': 2,
#  'fund': 2,
#  'holdings': 2,
#  'boys': 2,
#  'zen99': 2,
#  'nvidia': 2,
#  'riseml': 2,
#  'ibm': 2,
#  'education': 2,
#  'expensebot': 2,
#  'freeagent': 2,
#  'engine': 2,
#  'architects': 2,
#  'iowa': 2,
#  'chapter': 2,
#  'power': 2,
#  'extensions': 2,
#  'ostraining)': 2,
#  'joomla!': 2,
#  'sp': 2,
#  'z': 2,
#  '(formerly': 2,
#  'rocket': 2,
#  'staffjoy': 2,
#  'opendns': 2,
#  'unplugged': 2,
#  'future': 2,
#  'solarcity': 2,
#  'history': 2,
#  'holberton': 2,
#  'forbes': 2,
#  'isoplexis': 2,
#  'blindly': 2,
#  '1215': 2,
#  'molecular': 2,
#  'diagnostics': 2,
#  'rithmio': 2,
#  'research': 2,
#  'cnverg': 2,
#  'muni': 2,
#  'staffly': 2,
#  'visa': 2,
#  'yespath': 2,
#  '(acquired)': 2,
#  'pkware': 2,
#  'arbré': 2,
#  'orange': 2,
#  'bison': 2,
#  'page': 2,
#  'outro': 2,
#  'de': 2,
#  'brasil': 2,
#  'uk': 2,
#  'saas': 2,
#  'management': 2,
#  'link': 2,
#  'big': 2,
#  'idf': 2,
#  '//': 2,
#  'division': 2,
#  '/': 2,
#  'washington': 2,
#  'ohio': 2,
#  'state': 2,
#  'tyche': 2,
#  'physics': 2,
#  'analytics': 2,
#  'austin': 2,
#  'freshworks': 2,
#  'ieee': 2,
#  'halolife': 2,
#  'jeeliz': 2,
#  'minetta': 2,
#  'brook': 2,
#  'machine': 2,
#  'learning': 2,
#  'chocolate': 2,
#  'soup': 2,
#  'corp': 2,
#  'bithound': 2,
#  'transpose': 2,
#  'virginia': 2,
#  'department': 2,
#  'maryland': 2,
#  'create': 2,
#  'rigplenish': 2,
#  'founder': 2,
#  'peru': 2,
#  's': 2,
#  'ticketless': 2,
#  'cupenya': 2,
#  'nanocloud': 2,
#  'wasteless': 2,
#  'sell': 2,
#  'more': 2,
#  'waste': 2,
#  'less': 2,
#  'weissbeerger': 2,
#  'glassify': 2,
#  'defense': 2,
#  'forces': 2,
#  'unoceros': 2,
#  'iambiq': 2,
#  'world': 2,
#  'catalog': 2,
#  'cloakhire': 2,
#  'butlr': 1,
#  'cedars-sinai': 1,
#  'la': 1,
#  'mvp': 1,
#  'kaiser': 1,
#  'permanente': 1,
#  'smyte': 1,
#  'minefold': 1,
#  'calumo': 1,
#  'thoughtworks': 1,
#  'ticketsnow': 1,
#  'usaid': 1,
#  'tonic': 1,
#  'audio': 1,
#  'filament!': 1,
#  'singly': 1,
#  'toviefor': 1,
#  'loopshot': 1,
#  'sickkids': 1,
#  'pathfactory': 1,
#  '(we': 1,
#  'used': 1,
#  'be': 1,
#  'lookbookhq)': 1,
#  'mobile': 1,
#  'experience': 1,
#  'benevity': 1,
#  'verafin': 1,
#  'eloqua': 1,
#  'wisemobile': 1,
#  'fiksu': 1,
#  'mla': 1,
#  'forereads': 1,
#  'vcflair': 1,
#  'angels': 1,
#  'timista': 1,
#  'virtuoz': 1,
#  'nuance:': 1,
#  'nuan)': 1,
#  'korea': 1,
#  'horse': 1,
#  'julia': 1,
#  'balfour': 1,
#  'automation': 1,
#  'clearstone': 1,
#  'cruise)': 1,
#  'quest': 1,
#  'groupcentric': 1,
#  'stimulus': 1,
#  'processing': 1,
#  'surchx': 1,
#  'strategy': 1,
#  'lifelock': 1,
#  'internet': 1,
#  'ev': 1,
#  'bebopbee': 1,
#  '1871': 1,
#  'lighthouse': 1,
#  'people': 1,
#  'who': 1,
#  'are': 1,
#  'blind': 1,
#  'or': 1,
#  'visually': 1,
#  'impaired': 1,
#  'sinai': 1,
#  'system': 1,
#  'rosalind': 1,
#  'franklin': 1,
#  'captain': 1,
#  'james': 1,
#  'lovell': 1,
#  'federal': 1,
#  'stockton': 1,
#  'cardiology': 1,
#  'linkedin': 1,
#  'yahoo!': 1,
#  'cornell': 1,
#  'hewlett-packard': 1,
#  'aryaka': 1,
#  'clearapp': 1,
#  'netscout': 1,
#  'eastwind': 1,
#  'coat': 1,
#  'solera': 1,
#  'adobe': 1,
#  'six': 1,
#  'exchange': 1,
#  'interwork': 1,
#  'apexe3': 1,
#  'talos': 1,
#  'trading': 1,
#  'imentor': 1,
#  'redox': 1,
#  'talentsonar': 1,
#  "crohn's": 1,
#  'colitis': 1,
#  'webroot': 1,
#  'modulus': 1,
#  'elevate': 1,
#  'zumigo': 1,
#  'kenna': 1,
#  'dotscience': 1,
#  'weaveworks': 1,
#  '(was': 1,
#  'hybridcluster)': 1,
#  'crocus': 1,
#  'publisher': 1,
#  'discovery': 1,
#  'cloudfind': 1,
#  'property': 1,
#  'jungle': 1,
#  'bronco': 1,
#  'melio': 1,
#  'dblb': 1,
#  'mayhem': 1,
#  'revenue': 1,
#  'collective': 1,
#  'seated': 1,
#  'digisure': 1,
#  'warburg': 1,
#  'pincus': 1,
#  'strategic': 1,
#  'corvium': 1,
#  'invaluable': 1,
#  'willow': 1,
#  'acquired': 1,
#  'march': 1,
#  '2018': 1,
#  'gasbuddy': 1,
#  'plug': 1,
#  'play': 1,
#  '(various)': 1,
#  'cloudflare)': 1,
#  'kddi)': 1,
#  'cloudflare': 1,
#  'freebsd': 1,
#  'japan': 1,
#  'morpheus': 1,
#  'symbolic': 1,
#  'storagenix': 1,
#  'hp': 1,
#  'netapp': 1,
#  'willamette': 1,
#  'innovators': 1,
#  'oregon': 1,
#  'aviation': 1,
#  'helicopter': 1,
#  'rpas': 1,
#  'training': 1,
#  'aerosdb': 1,
#  'news': 1,
#  'bling': 1,
#  'brighton': 1,
#  'angel': 1,
#  'wilbur': 1,
#  'redbeacon': 1,
#  'home': 1,
#  'depot)': 1,
#  'boomtown': 1,
#  'paysimple': 1,
#  'loop': 1,
#  'ip': 1,
#  'dave': 1,
#  'johnson': 1,
#  'crowe': 1,
#  'horwath': 1,
#  'kpmg': 1,
#  'ernst': 1,
#  'young': 1,
#  'demartino': 1,
#  'marketing': 1,
#  'sourceress': 1,
#  '(yc': 1,
#  's17)': 1,
#  'lightsail': 1,
#  'impact': 1,
#  'green': 1,
#  'cow': 1,
#  'california': 1,
#  'helen': 1,
#  'keller': 1,
#  'deaf-blind': 1,
#  'youths': 1,
#  'adults': 1,
#  'fatty': 1,
#  'crab': 1,
#  'culinary': 1,
#  "l'ecole": 1,
#  'crafactor': 1,
#  'oceanops': 1,
#  'antler': 1,
#  'avantida': 1,
#  'shipping': 1,
#  '(s': 1,
#  'g': 1,
#  ')': 1,
#  'zim': 1,
#  'grow': 1,
#  'movement': 1,
#  'npc': 1,
#  'south': 1,
#  'beaulieu': 1,
#  'renuco': 1,
#  'fibrochem': 1,
#  'nabis': 1,
#  'cda': 1,
#  'cannabis': 1,
#  'distribution': 1,
#  'pioneer': 1,
#  'pando': 1,
#  'callminer': 1,
#  'clickfox': 1,
#  'journey': 1,
#  'elevated': 1,
#  'acertitude': 1,
#  'nice': 1,
#  'weston': 1,
#  'fc': 1,
#  'glassdoor': 1,
#  'labine': 1,
#  'one': 1,
#  'vcu': 1,
#  'brandcenter': 1,
#  'martin': 1,
#  'agency': 1,
#  'balancegenics': 1,
#  'badd': 1,
#  'dragonslayer': 1,
#  'smg': 1,
#  'thinktank': 1,
#  'girls': 1,
#  'product': 1,
#  'carvana': 1,
#  'ziptask': 1,
#  'toptal': 1,
#  'title': 1,
#  'self': 1,
#  'employed': 1,
#  'exec': 1,
#  'deloitte': 1,
#  'proton': 1,
#  'radio': 1,
#  'xfer': 1,
#  'records': 1,
#  'checkr': 1,
#  'freiburg': 1,
#  'satoshipay': 1,
#  'zolar': 1,
#  'spacy': 1,
#  'uber': 1,
#  'entertainment': 1,
#  'playfab': 1,
#  'immersive': 1,
#  'envelop': 1,
#  'vr': 1,
#  'start': 1,
#  'cle': 1,
#  'entrepreneurship': 1,
#  'consortium': 1,
#  'bounce': 1,
#  'hub': 1,
#  'gener8tor': 1,
#  'blockland': 1,
#  'cleveland': 1,
#  'hotel': 1,
#  'smartcapital': 1,
#  'travelers': 1,
#  'given': 1,
#  'firmiq': 1,
#  'ia': 1,
#  'quant': 1,
#  'charrette': 1,
#  'funnelwise': 1,
#  'valen': 1,
#  'decentralized': 1,
#  'lostin': 1,
#  'space': 1,
#  'states': 1,
#  'service': 1,
#  'reaction': 1,
#  'contabo': 1,
#  'agh': 1,
#  'skydeck': 1,
#  'plesk': 1,
#  '(exit)': 1,
#  'i2coalition': 1,
#  'wp': 1,
#  'bug': 1,
#  'squad': 1,
#  'majestic': 1,
#  'heavy': 1,
#  'element': 1,
#  'establishment': 1,
#  'nys': 1,
#  "d'youville": 1,
#  'mongoose': 1,
#  'proulx|taylor': 1,
#  'campus': 1,
#  'modern': 1,
#  'tribe': 1,
#  'four': 1,
#  'kitchens': 1,
#  'resolve': 1,
#  'simpleapply': 1,
#  'datatel)': 1,
#  'gabler': 1,
#  'stackpath': 1,
#  'help': 1,
#  'easyrent': 1,
#  'affirm': 1,
#  'intercom': 1,
#  'cultivation': 1,
#  'zyper': 1,
#  'pullrequest': 1,
#  'moonlight': 1,
#  'bio': 1,
#  'grail': 1,
#  'klarismo': 1,
#  'atomico': 1,
#  'mindtrust': 1,
#  'west': 1,
#  'unh': 1,
#  "mayor's": 1,
#  'advisory': 1,
#  'commission': 1,
#  'histroy': 1,
#  'court': 1,
#  'appointed': 1,
#  'special': 1,
#  'advocates': 1,
#  'children': 1,
#  'middletown': 1,
#  'ct': 1,
#  'internship': 1,
#  'boeing': 1,
#  'relationalai': 1,
#  'eve': 1,
#  'table': 1,
#  'readyforzero': 1,
#  'nike': 1,
#  'aktive': 1,
#  'ocient': 1,
#  'illinois': 1,
#  'urbana-champaign': 1,
#  'roadmap': 1,
#  'growthcounsel': 1,
#  'kylie': 1,
#  'madison': 1,
#  'cheetah': 1,
#  'lending': 1,
#  'practice': 1,
#  'farm': 1,
#  'credit': 1,
#  'emergent': 1,
#  'agile': 1,
#  'rs2': 1,
#  '(north': 1,
#  'america)': 1,
#  'samsung': 1,
#  'electronics': 1,
#  'serve': 1,
#  'an': 1,
#  'express': 1,
#  'upstart': 1,
#  'stubhub': 1,
#  'san': 1,
#  'francisco': 1,
#  'medium': 1,
#  'various': 1,
#  'startups': 1,
#  'clearstory': 1,
#  'twilio': 1,
#  'lytics': 1,
#  'mintigo': 1,
#  'sasquatch': 1,
#  'studios': 1,
#  'mid-state': 1,
#  'technical': 1,
#  'warm': 1,
#  'living': 1,
#  'wisconsin': 1,
#  'stevens': 1,
#  'point': 1,
#  'launch': 1,
#  'leads': 1,
#  'funcheaporfree:': 1,
#  '❤️jordan': 1,
#  'hey': 1,
#  'freebs': 1,
#  '✌\uf3fb': 1,
#  '@thebudgetbootcamp': 1,
#  '@productivitybootcamp': 1,
#  'magazine': 1,
#  'church': 1,
#  'jesus': 1,
#  'christ': 1,
#  'latter-day': 1,
#  'saints': 1,
#  'threatmetrix': 1,
#  'igs': 1,
#  'desenvolvimento': 1,
#  'dress': 1,
#  'go': 1,
#  'cinemark': 1,
#  'c&a': 1,
#  'gft': 1,
#  'formyl': 1,
#  'banyan': 1,
#  'peterson': 1,
#  'adamatic': 1,
#  'best': 1,
#  'buddies': 1,
#  'changelly': 1,
#  'clearblock': 1,
#  'blockex': 1,
#  'currency': 1,
#  'cryptopay': 1,
#  'qadre': 1,
#  'statezero': 1,
#  'credits': 1,
#  'pokerstars': 1,
#  'n/a': 1,
#  'tiny': 1,
#  'organics': 1,
#  'chief': 1,
#  'human': 1,
#  'wondermento': 1,
#  'mind': 1,
#  'candy': 1,
#  'dollar': 1,
#  'ingredient': 1,
#  'concerns': 1,
#  'flexsecure': 1,
#  'taking': 1,
#  'break': 1,
#  'cisco': 1,
#  'nokia': 1,
#  'siemens': 1,
#  'matcha': 1,
#  'pointer': 1,
#  'internmatch': 1,
#  'toad&co': 1,
#  'outdoor': 1,
#  'industry': 1,
#  'reflection': 1,
#  'riding': 1,
#  'arboretum': 1,
#  'nature': 1,
#  'lost': 1,
#  'art': 1,
#  'stationery': 1,
#  'rock/creek': 1,
#  'alpine': 1,
#  'camp': 1,
#  '(summer': 1,
#  'position)': 1,
#  'lab': 1,
#  '(co': 1,
#  'lab)': 1,
#  'lula': 1,
#  'lake': 1,
#  'land': 1,
#  'trust': 1,
#  'retina': 1,
#  'associates/itronix': 1,
#  'physician': 1,
#  'referral': 1,
#  '(prn)': 1,
#  'wellsky': 1,
#  'intelligent': 1,
#  'retinal': 1,
#  'imaging': 1,
#  'trevia': 1,
#  'itronix': 1,
#  'cerner': 1,
#  'elbo': 1,
#  'access': 1,
#  'snowball': 1,
#  'studios-': 1,
#  'animation': 1,
#  'visual': 1,
#  'effects': 1,
#  'content': 1,
#  'tribal': 1,
#  'ddb': 1,
#  'devpost': 1,
#  'startupbootcamp': 1,
#  'cwt': 1,
#  'tingz': 1,
#  '9900': 1,
#  '8197': 1,
#  'operations': 1,
#  'st': 1,
#  'louis': 1,
#  'mckelvey': 1,
#  'signet': 1,
#  'accel': 1,
#  'ford': 1,
#  'marrin': 1,
#  'mayer': 1,
#  'brown': 1,
#  'hon': 1,
#  'judge': 1,
#  'ann': 1,
#  'aldrich': 1,
#  'information': 1,
#  'sciences': 1,
#  'johns': 1,
#  'hopkins': 1,
#  'applied': 1,
#  'laboratory': 1,
#  'naval': 1,
#  'undersea': 1,
#  'warfare': 1,
#  'stilt': 1,
#  'flash': 1,
#  'technos': 1,
#  'mobio': 1,
#  'bigbinary': 1,
#  'chatwoot': 1,
#  'furlenco': 1,
#  'rajagiri': 1,
#  'oyster™': 1,
#  'carrom': 1,
#  'store2be': 1,
#  'freshdesk)': 1,
#  'vidya': 1,
#  'kelcor': 1,
#  'jumpfund': 1,
#  'rezli': 1,
#  'gaming': 1,
#  'cory': 1,
#  'allison': 1,
#  'autodesk': 1,
#  'carta': 1,
#  'navdy': 1,
#  'storefront': 1,
#  'housecanary': 1,
#  'bridge': 1,
#  'road': 1,
#  'brick': 1,
#  'house': 1,
#  'rentpath': 1,
#  'lovely': 1,
#  'rentpath)': 1,
#  'codenow': 1,
#  'hackbright': 1,
#  'lynx': 1,
#  '3d': 1,
#  'coweb': 1,
#  'webar': 1,
#  'rocks': 1,
#  'spacegoo': 1,
#  'capstone': 1,
#  'square': 1,
#  'nextlevel': 1,
#  'building': 1,
#  'enterprise': 1,
#  'value': 1,
#  'from': 1,
#  'unstructured': 1,
#  'via': 1,
#  'nlp': 1,
#  'fintech': 1,
#  'aelego': 1,
#  'transfomation': 1,
#  'tie': 1,
#  'seattle': 1,
#  'saxo': 1,
#  'banc': 1,
#  'securities': 1,
#  'gemstone': 1,
#  'bloomberg': 1,
#  'squash': 1,
#  'costek': 1,
#  'roadmunk': 1,
#  'numo': 1,
#  'dozr': 1,
#  'intel': 1,
#  'foodlink': 1,
#  'ja': 1,
#  'canada': 1,
#  'fairtunes': 1,
#  'cs': 1,
#  'maritime': 1,
#  'transport': 1,
#  'production': 1,
#  'quality': 1,
#  'computer': 1,
#  'ipm': 1,
#  'hope': 1,
#  'hypothalamic': 1,
#  'hamartomas': 1,
#  'thrively/activity': 1,
#  'kaplan': 1,
#  'test': 1,
#  'prep': 1,
#  'admissions': 1,
#  'allied': 1,
#  'jewish': 1,
#  'federation': 1,
#  'colorado': 1,
#  'shulman': 1,
#  'rogers': 1,
#  'dmv': 1,
#  'food': 1,
#  'truck': 1,
#  'mindshare': 1,
#  'main': 1,
#  'street': 1,
#  'forefront': 1,
#  'distributed': 1,
#  'sun': 1,
#  'aecom': 1,
#  'saratoga': 1,
#  'remix': 1,
#  'midwood': 1,
#  'investment': 1,
#  'development': 1,
#  'rebny': 1,
#  '(the': 1,
#  'york)': 1,
#  'hickey': 1,
#  'houtman': 1,
#  'designs': 1,
#  'british': 1,
#  'columbia': 1,
#  'triumf': 1,
#  'genxcomm': 1,
#  'symmetry': 1,
#  'm87': 1,
#  'accordion': 1,
#  'bonsai': 1,
#  'emory': 1,
#  'wavebridge': 1,
#  'tensility': 1,
#  '7-eleven': 1,
#  'otainfo': 1,
#  'anza': 1,
#  'associated': 1,
#  'student': 1,
#  'body': 1,
#  '(dasb)': 1,
#  'veracity': 1,
#  'hospital': 1,
#  'clinics': 1,
#  'wells': 1,
#  'fargo': 1,
#  'retailigence': 1,
#  'innovaspire': 1,
#  'e2': 1,
#  'minera': 1,
#  'chinalco': 1,
#  'southern': 1,
#  'copper': 1,
#  'bucyrus': 1,
#  'backus': 1,
#  'rebill': 1,
#  'surco': 1,
#  'seguros': 1,
#  'ando': 1,
#  'coderhouse': 1,
#  'shopear': 1,
#  'emprear': 1,
#  'massachusetts': 1,
#  'nuvem': 1,
#  'shop': 1,
#  'jtbd+': 1,
#  'shovel': 1,
#  'apps': 1,
#  'grupo': 1,
#  'edisur': 1,
#  'junior': 1,
#  'achievement': 1,
#  'argentina': 1,
#  'iae': 1,
#  'rockstart': 1,
#  'amboss': 1,
#  'heidelberg': 1,
#  'holidaycheck': 1,
#  'ag': 1,
#  'luke': 1,
#  'hughes': 1,
#  'furniture': 1,
#  'architecture': 1,
#  'consultant': 1,
#  'premium': 1,
#  'brand': 1,
#  "sme's": 1,
#  'innoverne': 1,
#  'sharing': 1,
#  'economy': 1,
#  'snap-on': 1,
#  'omic': 1,
#  'dfuse': 1,
#  'next': 1,
#  'timechain': 1,
#  'nukern': 1,
#  '(techstars': 1,
#  "austin'17)": 1,
#  'pme': 1,
#  'mtl': 1,
#  'collégial': 1,
#  'en': 1,
#  'affaires': 1,
#  'technovation': 1,
#  'paymium': 1,
#  'oyst': 1,
#  'themecloud': 1,
#  'osaka': 1,
#  'founders': 1,
#  'axa': 1,
#  'arbitrage': 1,
#  'koeppel': 1,
#  'rosen': 1,
#  'compushine': 1,
#  ...}

# %%
'''
Company Fundamentals 
    1. How important is the company's CB rank?
'''
ranks = [int(i.replace(',','')) for i in df3['CB Rank (Company)']]
print("Mean CB rank is: {}".format(np.mean(ranks)))
print("Among the top 200 companies, the mean rank is {}".format(str(np.mean(ranks[:200]))))
# Out:
# Mean CB rank is: 95195.0064516129
# Among the top 200 companies, the mean rank is 95195.0064516129

# %%
'''
Company Fundamentals
    2. Are there keywords in a company's description?
'''
descriptionWords = {}
for des_ in df3['Description']:
    for word in re.split('\\s|\.|,',des_):
        if word:
            if word not in descriptionWords:
                descriptionWords[word] = 1
            else:
                descriptionWords[word] += 1
descriptionWords = {k: v for k, v in sorted(descriptionWords.items(), key=lambda item: item[1], reverse=True)}
descriptionWords
# Out:
# {'and': 100,
#  'a': 65,
#  'to': 65,
#  'is': 58,
#  'for': 48,
#  'the': 42,
#  'that': 41,
#  'of': 30,
#  'platform': 27,
#  'software': 23,
#  'with': 20,
#  'your': 17,
#  'their': 17,
#  'provides': 14,
#  'in': 14,
#  'an': 13,
#  'solutions': 12,
#  'mobile': 12,
#  'users': 11,
#  'app': 10,
#  'helps': 9,
#  'on': 9,
#  'by': 9,
#  'data': 9,
#  'We': 8,
#  'help': 8,
#  'industry': 8,
#  'technology': 8,
#  'SaaS': 8,
#  'company': 8,
#  'from': 8,
#  'web': 7,
#  'you': 7,
#  'services': 7,
#  'tools': 7,
#  'apps': 6,
#  'AI': 6,
#  'analytics': 6,
#  'solution': 6,
#  'create': 6,
#  'businesses': 6,
#  'online': 6,
#  'Software': 6,
#  'management': 6,
#  'social': 6,
#  'health': 5,
#  'enables': 5,
#  'Platform': 5,
#  'its': 5,
#  'applications': 5,
#  'financial': 5,
#  'service': 5,
#  '&': 5,
#  'into': 5,
#  'creates': 5,
#  'offers': 5,
#  'world': 5,
#  'information': 5,
#  'tracking': 5,
#  'develops': 5,
#  'A': 5,
#  'search': 5,
#  'business': 5,
#  'tool': 5,
#  'using': 4,
#  'other': 4,
#  'builds': 4,
#  'makes': 4,
#  'easy': 4,
#  'personal': 4,
#  'out': 4,
#  'performance': 4,
#  'first': 4,
#  'Management': 4,
#  'through': 4,
#  'care': 4,
#  'as': 4,
#  'learning': 4,
#  'teams': 4,
#  'marketing': 4,
#  'real-time': 4,
#  'companies': 4,
#  'media': 4,
#  'smart': 4,
#  'development': 4,
#  'developing': 4,
#  'insurance': 3,
#  'all': 3,
#  'develop': 3,
#  'platforms': 3,
#  'hardware': 3,
#  'enterprise': 3,
#  'find': 3,
#  'best': 3,
#  'developers': 3,
#  'build': 3,
#  'or': 3,
#  'based': 3,
#  'next': 3,
#  'generation': 3,
#  'people': 3,
#  'make': 3,
#  'database': 3,
#  'computational': 3,
#  'engine': 3,
#  'commerce': 3,
#  'small': 3,
#  'powerful': 3,
#  'Learning': 3,
#  'website': 3,
#  'process': 3,
#  'new': 3,
#  'way': 3,
#  'payment': 3,
#  'recognition': 3,
#  'Development': 3,
#  'devices': 3,
#  'asset': 3,
#  'links': 3,
#  'about': 3,
#  'Marketing': 3,
#  'networking': 3,
#  'creative': 3,
#  'run': 3,
#  'large': 3,
#  'designed': 3,
#  'content': 3,
#  'efficiency': 3,
#  'team': 3,
#  'products': 3,
#  'healthcare': 2,
#  'simplify': 2,
#  'long': 2,
#  'blockchain': 2,
#  'Sales': 2,
#  'assist': 2,
#  'how': 2,
#  'spend': 2,
#  'ai': 2,
#  'device': 2,
#  'fee': 2,
#  'control': 2,
#  'engagement': 2,
#  'closed': 2,
#  'cloud-based': 2,
#  'detection': 2,
#  'government': 2,
#  'organizations': 2,
#  'vision': 2,
#  'them': 2,
#  'decisions': 2,
#  'take': 2,
#  'economy': 2,
#  'To': 2,
#  'driven': 2,
#  'io': 2,
#  'storage': 2,
#  'compute': 2,
#  'commercial': 2,
#  'drone': 2,
#  'programs': 2,
#  'turns': 2,
#  'browser': 2,
#  'The': 2,
#  'complex': 2,
#  'processes': 2,
#  'medium': 2,
#  'dynamic': 2,
#  'most': 2,
#  'managers': 2,
#  'projects': 2,
#  'machine': 2,
#  'deep': 2,
#  'work': 2,
#  'Predictive': 2,
#  'Analytics': 2,
#  'Machine': 2,
#  'focus': 2,
#  'metrics': 2,
#  'give': 2,
#  'sales': 2,
#  'revenue': 2,
#  'drive': 2,
#  'results': 2,
#  'building': 2,
#  'Easy': 2,
#  'use': 2,
#  'power': 2,
#  'peer': 2,
#  'industries': 2,
#  'connected': 2,
#  '+': 2,
#  'connects': 2,
#  'aims': 2,
#  'Automation': 2,
#  'digital': 2,
#  'made': 2,
#  'API': 2,
#  'support': 2,
#  'experiences': 2,
#  'experts': 2,
#  'cutting-edge': 2,
#  'Big': 2,
#  'transform': 2,
#  'experience': 2,
#  'career': 2,
#  'empowers': 2,
#  'turn': 2,
#  'needs': 2,
#  'track': 2,
#  'Internet': 2,
#  'Create': 2,
#  'property': 2,
#  'time': 2,
#  'each': 2,
#  'application': 2,
#  'cannabis': 2,
#  'dispensaries': 2,
#  'better': 2,
#  'individuals': 2,
#  'enhance': 2,
#  'connect': 2,
#  'collaborate': 2,
#  'brands': 2,
#  'delivery': 2,
#  'automatically': 2,
#  "user's": 2,
#  'focusing': 2,
#  'bar': 2,
#  'Inc': 2,
#  'security': 2,
#  'bugs': 2,
#  'T': 2,
#  'are': 2,
#  'created': 2,
#  'around': 2,
#  'leads': 2,
#  'improving': 2,
#  'driving': 2,
#  'developed': 2,
#  'Consulting': 2,
#  'trainers': 2,
#  'Labs': 2,
#  'AI-based': 2,
#  'reporting': 2,
#  'where': 2,
#  'monitor': 2,
#  'intelligent': 2,
#  'Technology': 2,
#  'any': 2,
#  'Social': 2,
#  'Knowledge': 2,
#  'Joany': 1,
#  'trusted': 1,
#  'concierge': 1,
#  'buying': 1,
#  'year': 1,
#  'Assembly': 1,
#  'collaboration': 1,
#  'widgets': 1,
#  'APIs': 1,
#  'Filament': 1,
#  'and&': 1,
#  'IoT': 1,
#  'Nudge': 1,
#  'Modern': 1,
#  'leverages': 1,
#  'relationship': 1,
#  'strength': 1,
#  'keep': 1,
#  'customers': 1,
#  'Aiden': 1,
#  'intended': 1,
#  'marketers': 1,
#  'budget': 1,
#  'efficiently': 1,
#  'Wit': 1,
#  'it': 1,
#  'Siri-like': 1,
#  'speech': 1,
#  'interface': 1,
#  'Dashride': 1,
#  'automated': 1,
#  'dispatching': 1,
#  'taxi': 1,
#  'limo': 1,
#  'rideshare': 1,
#  'fleets': 1,
#  "SurchX's": 1,
#  'credit': 1,
#  'card': 1,
#  'recovery': 1,
#  'merchants': 1,
#  'regain': 1,
#  'margins': 1,
#  'Patient': 1,
#  '2': 1,
#  '0': 1,
#  'Salesforce': 1,
#  'has': 1,
#  'acquisition': 1,
#  'Griddable': 1,
#  'Eastwind': 1,
#  'Breach': 1,
#  'Detection': 1,
#  'breach': 1,
#  'Building': 1,
#  'operating': 1,
#  'distributed-ledger': 1,
#  'global': 1,
#  'Planwise': 1,
#  'trust': 1,
#  'TalentSonar': 1,
#  'Enables': 1,
#  'Blind': 1,
#  'Resume': 1,
#  'Review': 1,
#  'Remove': 1,
#  'Unconscious': 1,
#  'Bias': 1,
#  'From': 1,
#  'Recruiting': 1,
#  'Cluster': 1,
#  'HQ': 1,
#  'Saas': 1,
#  'container': 1,
#  'virtualisation': 1,
#  'useful': 1,
#  'Grab': 1,
#  'squad': 1,
#  'swipe': 1,
#  'squads': 1,
#  'hang': 1,
#  'if': 1,
#  'match!': 1,
#  'Confirm': 1,
#  'authenticating': 1,
#  'issued': 1,
#  'ID': 1,
#  'fast': 1,
#  'secure': 1,
#  'Neumob': 1,
#  'leader': 1,
#  'reducing': 1,
#  'errors': 1,
#  'speeding': 1,
#  'up': 1,
#  'boosting': 1,
#  'conversions': 1,
#  'Symbolic': 1,
#  'IO': 1,
#  'defined': 1,
#  'solely': 1,
#  'focused': 1,
#  'advanced': 1,
#  'algorithmic': 1,
#  'Drone': 1,
#  'Complier': 1,
#  'enterprise-grade': 1,
#  'sUAS': 1,
#  'Compliance/': 1,
#  'Operations': 1,
#  'Solution': 1,
#  'enabling': 1,
#  'cost': 1,
#  'effective': 1,
#  'Artillery': 1,
#  'modern': 1,
#  'gaming': 1,
#  'console': 1,
#  'HTML5': 1,
#  'IP': 1,
#  'Commerce': 1,
#  'automates': 1,
#  'multi-party': 1,
#  'related': 1,
#  'sized': 1,
#  'Nomiku': 1,
#  'enable': 1,
#  'everyone': 1,
#  'cook': 1,
#  'food': 1,
#  'possible': 1,
#  'OceanOps': 1,
#  'mitigate': 1,
#  'delays': 1,
#  'ocean': 1,
#  'freight': 1,
#  're-routing': 1,
#  'Candor': 1,
#  'Insurance': 1,
#  'private': 1,
#  'exchange': 1,
#  'established': 1,
#  'democratize': 1,
#  'Scaphold': 1,
#  "world's": 1,
#  'GraphQL': 1,
#  'Elevated': 1,
#  'Careers': 1,
#  'ever': 1,
#  'all-in-one': 1,
#  'employee': 1,
#  'employment': 1,
#  'branding': 1,
#  'hiring': 1,
#  'Ziptask': 1,
#  'outsourcing': 1,
#  'employs': 1,
#  'project': 1,
#  'execute': 1,
#  'consumers': 1,
#  'SMEs': 1,
#  'Tax': 1,
#  'independent': 1,
#  'contractors': 1,
#  'RiseML': 1,
#  'scale': 1,
#  'infrastructure': 1,
#  'Envelop': 1,
#  'VR': 1,
#  'play': 1,
#  'virtual': 1,
#  'reality': 1,
#  'Automatic': 1,
#  'Expense': 1,
#  'Reports': 1,
#  'Powered': 1,
#  'FunnelWise': 1,
#  'depth': 1,
#  'key': 1,
#  'funnel': 1,
#  'direct': 1,
#  'path': 1,
#  'increase': 1,
#  'Reaction': 1,
#  'designs': 1,
#  'manufactures': 1,
#  '(re)meet': 1,
#  'basic': 1,
#  'human': 1,
#  'need:': 1,
#  'shelter': 1,
#  'Perfect': 1,
#  'Dashboard': 1,
#  'marketplace': 1,
#  '$19B': 1,
#  'web-hosting': 1,
#  'bringing': 1,
#  'innovation': 1,
#  'tail': 1,
#  'owners': 1,
#  'Submit': 1,
#  'customer': 1,
#  'issue': 1,
#  'GripeO': 1,
#  'Rental': 1,
#  'Property': 1,
#  'Landlords': 1,
#  'Owners': 1,
#  'Investors': 1,
#  'Listings': 1,
#  'Screening': 1,
#  'Leases': 1,
#  'Accepting': 1,
#  'Rent': 1,
#  'Online': 1,
#  'Staffjoy': 1,
#  'automate': 1,
#  'scheduling': 1,
#  'shifts': 1,
#  'staff': 1,
#  'effectively': 1,
#  'Klarismo': 1,
#  'uses': 1,
#  'MRI': 1,
#  'explore': 1,
#  'physiology': 1,
#  'understand': 1,
#  'body': 1,
#  'composition': 1,
#  'unprecedented': 1,
#  'detail': 1,
#  'SoluTech': 1,
#  'innovating': 1,
#  'technologies': 1,
#  'positively': 1,
#  'impact': 1,
#  'today': 1,
#  'Control': 1,
#  'Mobile': 1,
#  'alerts': 1,
#  'subscription': 1,
#  'Eve': 1,
#  'access': 1,
#  'non-programmers': 1,
#  'websites': 1,
#  'databases': 1,
#  'etc': 1,
#  'Rithmio': 1,
#  'gesture': 1,
#  'motion': 1,
#  'wearables': 1,
#  'clothing': 1,
#  'Visual': 1,
#  'Planning': 1,
#  'Strategy': 1,
#  'Product': 1,
#  'Teams:': 1,
#  'whiteboard': 1,
#  'GitHub': 1,
#  'Trello': 1,
#  'Staffly': 1,
#  'instantly': 1,
#  'retailers': 1,
#  'screened': 1,
#  'insured': 1,
#  'trained': 1,
#  'Staffly™': 1,
#  'Staffers': 1,
#  'YesPath': 1,
#  'Account': 1,
#  'Engagement': 1,
#  'reach': 1,
#  'win': 1,
#  'big': 1,
#  'accounts': 1,
#  'Arbré': 1,
#  'Wisconsin-based': 1,
#  'tech': 1,
#  'startup': 1,
#  'revolutionize': 1,
#  'tree': 1,
#  'nurseries': 1,
#  'green': 1,
#  'B2B': 1,
#  'Referral': 1,
#  'Crowdsourced': 1,
#  'Introductions': 1,
#  'Say': 1,
#  'goodbye': 1,
#  'manually': 1,
#  'making': 1,
#  'receiving': 1,
#  'referrals/introductions': 1,
#  'Blockchain': 1,
#  'Platform-As-A-Service': 1,
#  'Wondermento': 1,
#  'physical': 1,
#  'interact': 1,
#  'lovingly': 1,
#  'Scroll': 1,
#  'usher': 1,
#  'privacy': 1,
#  'creation': 1,
#  'decentralized': 1,
#  'empower': 1,
#  'Instant': 1,
#  'host': 1,
#  'sell': 1,
#  'existing': 1,
#  'code': 1,
#  'RootsRated': 1,
#  'outdoor': 1,
#  'hand-': 1,
#  'picked': 1,
#  'local': 1,
#  'TreVia': 1,
#  'diabetes': 1,
#  'Link': 1,
#  'link': 1,
#  'finally': 1,
#  'general': 1,
#  'user': 1,
#  'serving': 1,
#  'Tyche': 1,
#  'discovers': 1,
#  'insurers': 1,
#  'risks': 1,
#  'they': 1,
#  'insure': 1,
#  'Marketfox': 1,
#  'Rezli': 1,
#  'technologists': 1,
#  'passion': 1,
#  'Halolife': 1,
#  'step-by-step': 1,
#  'guidance': 1,
#  'plan': 1,
#  'burial': 1,
#  'cremation': 1,
#  'meets': 1,
#  'neural': 1,
#  'networks': 1,
#  'inside': 1,
#  'webgl': 1,
#  'do': 1,
#  'face': 1,
#  'glasses': 1,
#  'VTO': 1,
#  'webAR': 1,
#  'Minetta': 1,
#  'Brook': 1,
#  'navigate': 1,
#  'discover': 1,
#  'relevant': 1,
#  'bodies': 1,
#  'bitHound': 1,
#  'improve': 1,
#  'workspace': 1,
#  'manage': 1,
#  'assignments': 1,
#  'more': 1,
#  '--': 1,
#  'one': 1,
#  'structured': 1,
#  'Activity': 1,
#  'Rocket': 1,
#  'kind': 1,
#  'compare': 1,
#  'share': 1,
#  'book': 1,
#  "kid's": 1,
#  'classes': 1,
#  'camps': 1,
#  '3D': 1,
#  'mapping': 1,
#  'Accordion': 1,
#  'Health': 1,
#  'innovative': 1,
#  'data-driven': 1,
#  'value-based': 1,
#  'RigPlenish': 1,
#  'reduce': 1,
#  'amount': 1,
#  'paramedics': 1,
#  'documenting': 1,
#  'ambulance': 1,
#  'Shovel': 1,
#  'lets': 1,
#  'awesome': 1,
#  'e-commerce': 1,
#  'Android': 1,
#  'iOS': 1,
#  'just': 1,
#  'few': 1,
#  'minutes': 1,
#  'powered': 1,
#  'Customer': 1,
#  'Service': 1,
#  'Innoverne': 1,
#  'was': 1,
#  'delivered': 1,
#  'sustainable': 1,
#  'product-service': 1,
#  'loop': 1,
#  'models': 1,
#  'CannaBuild': 1,
#  'ensure': 1,
#  'compliance': 1,
#  'serve': 1,
#  'patients': 1,
#  '-': 1,
#  'Automated': 1,
#  'billing': 1,
#  'provisioning': 1,
#  'hosts': 1,
#  'agencies': 1,
#  'Taking': 1,
#  'job': 1,
#  'patent': 1,
#  'pending': 1,
#  'customized': 1,
#  'utilizing': 1,
#  'NLP': 1,
#  'Nanocloud': 1,
#  'vendors': 1,
#  'Vertisense': 1,
#  'sensor-based': 1,
#  'technological': 1,
#  'monitoring': 1,
#  'Unoceros': 1,
#  'cellphone': 1,
#  'ability': 1,
#  'cellphones': 1,
#  'computing': 1,
#  'network': 1,
#  'can': 1,
#  'stand': 1,
#  'this': 1,
#  'creating': 1,
#  'stunning': 1,
#  'mobile-enabled': 1,
#  'Iambiq': 1,
#  'read': 1,
#  'amounts': 1,
#  'text-based': 1,
#  'usually': 1,
#  'handled': 1,
#  'humans': 1,
#  'Branch2': 1,
#  'well-being': 1,
#  'connecting': 1,
#  'communities': 1,
#  'evidence-based': 1,
#  'mindfulness': 1,
#  'practices': 1,
#  'Bandbasher': 1,
#  'learn': 1,
#  'artists': 1,
#  'get': 1,
#  'paid': 1,
#  'Catalog': 1,
#  'production': 1,
#  'consumer': 1,
#  'TrackerSense': 1,
#  'deploys': 1,
#  'parcel': 1,
#  'supply': 1,
#  'chain': 1,
#  'worldwide': 1,
#  'CloakHire': 1,
#  'specializes': 1,
#  'fields': 1,
#  'split': 1,
#  'contracts': 1,
#  'executive': 1,
#  'Deckard': 1,
#  'learns': 1,
#  'structure': 1,
#  'Gazoo': 1,
#  'adds': 1,
#  'hundreds': 1,
#  'cores': 1,
#  'standard': 1,
#  'servers': 1,
#  'Parabola': 1,
#  'advisors': 1,
#  'gamification': 1,
#  'progress': 1,
#  'against': 1,
#  'goals': 1,
#  'K-12': 1,
#  'academic': 1,
#  'improvement': 1,
#  'corporate': 1,
#  'reward': 1,
#  'positive': 1,
#  'operant': 1,
#  'conditioning': 1,
#  'Run': 1,
#  'phone': 1,
#  'AdaptiveWell': 1,
#  'solves': 1,
#  'multi-Billion': 1,
#  'Dollar': 1,
#  'Data': 1,
#  'problem': 1,
#  'Oil': 1,
#  'Gas': 1,
#  'operators': 1,
#  'resulting': 1,
#  'capital': 1,
#  'increased': 1,
#  'profits': 1,
#  'Chameleon': 1,
#  'native': 1,
#  'advertising': 1,
#  'headquartered': 1,
#  'Dublin': 1,
#  'Ecommerce': 1,
#  'built': 1,
#  'Outsourced': 1,
#  'Company': 1,
#  'BarFrog': 1,
#  'opens': 1,
#  'closes': 1,
#  'tab': 1,
#  'simply': 1,
#  'entering': 1,
#  'exiting': 1,
#  'AppBugs': 1,
#  'identify': 1,
#  'ad': 1,
#  'called': 1,
#  'I': 1,
#  'N': 1,
#  'Enginge': 1,
#  'Technologically': 1,
#  'Intuitive': 1,
#  'Targeted': 1,
#  'Ad': 1,
#  'Network': 1,
#  'capable': 1,
#  'realtime': 1,
#  'intuitive': 1,
#  "Beegit's": 1,
#  'kickstart': 1,
#  'efforts': 1,
#  'Qvolve': 1,
#  'regulated': 1,
#  "Qvolve's": 1,
#  'levels': 1,
#  'organization': 1,
#  'mind': 1,
#  'Comprehensive': 1,
#  'workflow': 1,
#  'tablet': 1,
#  'classrooms': 1,
#  'MarTech': 1,
#  'matching': 1,
#  'Marketers': 1,
#  'Millennial': 1,
#  'Shoppers': 1,
#  'Remedify': 1,
#  'iPad': 1,
#  'aids': 1,
#  'technicians': 1,
#  'cleaning': 1,
#  'sterilizing': 1,
#  'reusable': 1,
#  'surgical': 1,
#  'instruments': 1,
#  'Gizlo': 1,
#  'gaining': 1,
#  'valuable': 1,
#  'insights': 1,
#  'opinions': 1,
#  'Cymplar': 1,
#  'flexible': 1,
#  'interaction': 1,
#  'tips': 1,
#  'constantly': 1,
#  'increasing': 1,
#  'chances': 1,
#  'success': 1,
#  'Increasing': 1,
#  'across': 1,
#  'event': 1,
#  'planning': 1,
#  'Satiemployee': 1,
#  'Galileo': 1,
#  'Alpha': 1,
#  'protect': 1,
#  'home': 1,
#  'GalileoUSA': 1,
#  'com': 1,
#  'OSIA': 1,
#  'Medical': 1,
#  'asthma': 1,
#  'sufferers': 1,
#  'respiratory': 1,
#  'specialists': 1,
#  'Sonic': 1,
#  'Payments': 1,
#  'future-proof': 1,
#  'high-volume': 1,
#  'aggregators': 1,
#  'Jimi': 1,
#  'freelance': 1,
#  'independant': 1,
#  'gym': 1,
#  'studios': 1,
#  'custom': 1,
#  'voice': 1,
#  'Amazon': 1,
#  'Alexa': 1,
#  'Google': 1,
#  'Home': 1,
#  '/': 1,
#  'Assistant': 1,
#  'Microsoft': 1,
#  'Cortana': 1,
#  'Apple': 1,
#  'Siri': 1,
#  'Samsung': 1,
#  'Bixby': 1,
#  "Don't": 1,
#  'Panic': 1,
#  'firm': 1,
#  'providing': 1,
#  'consultancy': 1,
#  'provider': 1,
#  'FairTech': 1,
#  'personalized': 1,
#  'household': 1,
#  'inventory': 1,
#  'hassle': 1,
#  'coaching': 1,
#  'quiz': 1,
#  'bowl': 1,
#  'Interact': 1,
#  'those': 1,
#  'sharing': 1,
#  'common': 1,
#  'near': 1,
#  'fun': 1,
#  'BattleGuru': 1,
#  'eSports': 1,
#  'B2B2C': 1,
#  'markets': 1,
#  'Vessix': 1,
#  'consolidating': 1,
#  'POS': 1,
#  'CRM': 1,
#  'Chroma': 1,
#  'engages': 1,
#  'retail': 1,
#  'sale': 1,
#  'specialized': 1,
#  'lines': 1,
#  'merchandise': 1,
#  'CoPilot': 1,
#  'college': 1,
#  'students': 1,
#  'significantly': 1,
#  'improves': 1,
#  'course': 1,
#  'completion': 1,
#  'graduation': 1,
#  'rates': 1,
#  'An': 1,
#  'image': 1,
#  'game': 1,
#  'player': 1,
#  'scan': 1,
#  'logos': 1,
#  'generating': 1,
#  'unique': 1,
#  'seen': 1,
#  'real': 1,
#  'Kontena': 1,
#  'easy-to-use': 1,
#  'fully': 1,
#  'integrated': 1,
#  'DevOps': 1,
#  'deploy': 1,
#  'operate': 1,
#  'containers': 1,
#  'cloud': 1,
#  'Bolzter': 1,
#  'graph': 1,
#  'lead': 1,
#  'connections': 1,
#  'Triggertrap': 1,
#  'variety': 1,
#  'camera': 1,
#  'triggering': 1,
#  'StoreGecko': 1,
#  'product': 1,
#  'well': 1,
#  'stores': 1,
#  'Spectator': 1,
#  'Sports': 1,
#  'booster': 1,
#  'clubs': 1,
#  'streamline': 1,
#  'membership': 1,
#  'accept': 1,
#  'donations': 1,
#  'Music': 1,
#  'Education': 1,
#  'Startup': 1,
#  'DWC': 1,
#  'address': 1,
#  'clients’': 1,
#  'Budzz': 1,
#  'supplies': 1,
#  'multi-platform': 1,
#  'provide': 1,
#  'safe': 1,
#  'credible': 1,
#  'transactions': 1,
#  'Divvi': 1,
#  'facilitates': 1,
#  'uncontested': 1,
#  'divorces': 1,
#  'start': 1,
#  'finish': 1,
#  'DataFlyte™’s': 1,
#  'proprietary': 1,
#  'equipment': 1,
#  'reads': 1,
#  'AMR-style': 1,
#  'meters': 1,
#  'air': 1,
#  'delivers': 1,
#  'back': 1,
#  'utility': 1,
#  'TrustaFact': 1,
#  'determine': 1,
#  'trustworthy': 1,
#  'money': 1,
#  'Softwares': 1,
#  'rethinking': 1,
#  'react': 1,
#  'Allowing': 1,
#  'comparison': 1,
#  'among': 1,
#  'within': 1,
#  ...}

# %%
'''
Company Fundamentals
    3. Number of founders / company location?
    Seems to be covered in General Data above
'''
df3
# Out:
#                                                Organization Name URL  \
# Organization Name
# JOANY              https://www.crunchbase.com/organization/impact...
# Assembly            https://www.crunchbase.com/organization/assembly
# Filament           https://www.crunchbase.com/organization/filame...
# Nudge.ai             https://www.crunchbase.com/organization/nudge-2
# Aiden                https://www.crunchbase.com/organization/aiden-2
# ...                                                              ...
# Dockbit              https://www.crunchbase.com/organization/dockbit
# Rubicore            https://www.crunchbase.com/organization/rubicore
# CareerSofia        https://www.crunchbase.com/organization/career...
# Opz.io                https://www.crunchbase.com/organization/opz-io
# SpreadVision       https://www.crunchbase.com/organization/spread...
#
#                                                           Industries  \
# Organization Name
# JOANY                         Health Care, Insurance, Internet, SaaS
# Assembly           Apps, Collaboration, Crowdsourcing, Software, ...
# Filament           Bitcoin, Blockchain, Hardware, Industrial, Int...
# Nudge.ai           B2B, CRM, Sales, Sales Automation, Social CRM,...
# Aiden              Analytics, Artificial Intelligence, Computer, ...
# ...                                                              ...
# Dockbit            Developer Platform, Developer Tools, Enterpris...
# Rubicore                                   Human Resources, Software
# CareerSofia                                              SaaS, Sales
# Opz.io             Analytics, Artificial Intelligence, Real Time,...
# SpreadVision              Advertising, Internet, Marketing, Software
#
#                                                          Description  \
# Organization Name
# JOANY              Joany is your trusted healthcare concierge. We...
# Assembly           Assembly is a web collaboration platform that ...
# Filament           Filament builds blockchain hardware and& softw...
# Nudge.ai           Nudge is a Modern Sales Platform that leverage...
# Aiden              Aiden provides an AI analytics platform intend...
# ...                                                              ...
# Dockbit            Dockbit turns your software deployments into r...
# Rubicore           At Rubicore, our mission is to enhance perform...
# CareerSofia                     Knowledge Management for Sales Teams
# Opz.io             Opz.io is an intelligent time tracking solutio...
# SpreadVision       Internet company focusing on improving storyte...
#
#                    Last Funding Amount Last Funding Amount Currency  \
# Organization Name
# JOANY                       13000000.0                          USD
# Assembly                           NaN                          NaN
# Filament                    15000000.0                          USD
# Nudge.ai                     6500000.0                          CAD
# Aiden                        1400000.0                          EUR
# ...                                ...                          ...
# Dockbit                            NaN                          NaN
# Rubicore                           NaN                          NaN
# CareerSofia                        NaN                          NaN
# Opz.io                             NaN                          NaN
# SpreadVision                       NaN                          NaN
#
#                    Last Funding Amount Currency (in USD) Last Funding Type  \
# Organization Name
# JOANY                                         13000000.0          Series A
# Assembly                                             NaN              Seed
# Filament                                      15000000.0          Series A
# Nudge.ai                                       4970448.0              Seed
# Aiden                                          1601801.0              Seed
# ...                                                  ...               ...
# Dockbit                                              NaN              Seed
# Rubicore                                             NaN              Seed
# CareerSofia                                          NaN              Seed
# Opz.io                                               NaN              Seed
# SpreadVision                                         NaN              Seed
#
#                   CB Rank (Company)  Number of Funding Rounds  \
# Organization Name
# JOANY                           410                         7
# Assembly                      5,967                         3
# Filament                      6,356                         8
# Nudge.ai                      9,064                         1
# Aiden                        14,044                         2
# ...                             ...                       ...
# Dockbit                     378,771                         1
# Rubicore                    425,410                         1
# CareerSofia                 437,415                         1
# Opz.io                      451,482                         1
# SpreadVision                800,187                         1
#
#                                                             LinkedIn  \
# Organization Name
# JOANY              https://www.linkedin.com/company/joany/?origin...
# Assembly               https://www.linkedin.com/company/assembly-inc
# Filament           https://www.linkedin.com/company/filament-netw...
# Nudge.ai                     http://www.linkedin.com/company/nudgeai
# Aiden                     https://www.linkedin.com/company/aiden.ai/
# ...                                                              ...
# Dockbit                     https://www.linkedin.com/company/Dockbit
# Rubicore           https://www.linkedin.com/company/3577242?trk=t...
# CareerSofia             https://www.linkedin.com/company/careersofia
# Opz.io                    https://www.linkedin.com/company/11006499/
# SpreadVision           https://www.linkedin.com/company/spreadvision
#
#                                           Website  \
# Organization Name
# JOANY                           https://Joany.com
# Assembly                  http://assemblymade.com
# Filament                     https://filament.com
# Nudge.ai                         https://nudge.ai
# Aiden                            http://aiden.ai/
# ...                                           ...
# Dockbit                      https://dockbit.com/
# Rubicore           http://www.rubicoredesigns.com
# CareerSofia            http://www.careersofia.com
# Opz.io                        https://www.opz.io/
# SpreadVision              http://spreadvision.eu/
#
#                                                             Founders  \
# Organization Name
# JOANY                                  Christine Carrillo, Helen Lee
# Assembly                   Chris Lloyd, Dave Newman, Matthew Deiters
# Filament           Allison Clift-Jennings, Jeremie Miller, Sally ...
# Nudge.ai                                  Paul Teshima, Steven Woods
# Aiden                          Marie Outtier, Pierre-Jean Camillieri
# ...                                                              ...
# Dockbit                                  Ahmed ElGamil, Tair Assimov
# Rubicore                                                Nana Dooreck
# CareerSofia                                              Josh Reback
# Opz.io                                     Lawrence Braun de Almeida
# SpreadVision                                        Arsenium Nicolae
#
#                   Estimated Revenue Range  Trend Score (90 Days)  \
# Organization Name
# JOANY                         $1M to $10M                    9.7
# Assembly                              NaN                    7.6
# Filament                    Less than $1M                   -0.6
# Nudge.ai                    Less than $1M                   -0.3
# Aiden                                 NaN                   -1.0
# ...                                   ...                    ...
# Dockbit                               NaN                   -0.7
# Rubicore                              NaN                   -0.6
# CareerSofia                           NaN                   -0.5
# Opz.io                                NaN                   -0.1
# SpreadVision                          NaN                    0.7
#
#                                                      Top 5 Investors  \
# Organization Name
# JOANY              Techstars, Precursor Ventures, Right Side Capi...
# Assembly           Y Combinator, Floodgate, BoxGroup, Union Squar...
# Filament           AngelList, Digital Currency Group, Techstars, ...
# Nudge.ai           OMERS Ventures, Jill Rowley, Neal Dempsey, Bra...
# Aiden              Partech, Kima Ventures, Sophia Bendz, Pierre V...
# ...                                                              ...
# Dockbit                                               NUMA Barcelona
# Rubicore                                                         NaN
# CareerSofia                                                      NaN
# Opz.io                                                 Startup Braga
# SpreadVision                                        Arsenium Nicolae
#
#                                       Headquarters Location  Investment Stage  \
# Organization Name
# JOANY                Los Angeles, California, United States               NaN
# Assembly           San Francisco, California, United States               NaN
# Filament                        Reno, Nevada, United States               NaN
# Nudge.ai                           Toronto, Ontario, Canada               NaN
# Aiden                       London, England, United Kingdom               NaN
# ...                                                     ...               ...
# Dockbit                         Barcelona, Catalonia, Spain               NaN
# Rubicore            Santa Monica, California, United States               NaN
# CareerSofia        San Francisco, California, United States               NaN
# Opz.io                                 Faro, Faro, Portugal               NaN
# SpreadVision                     Ploiesti, Prahova, Romania               NaN
#
#                   Organization Name
# Organization Name
# JOANY                         JOANY
# Assembly                   Assembly
# Filament                   Filament
# Nudge.ai                   Nudge.ai
# Aiden                         Aiden
# ...                             ...
# Dockbit                     Dockbit
# Rubicore                   Rubicore
# CareerSofia             CareerSofia
# Opz.io                       Opz.io
# SpreadVision           SpreadVision
#
# [155 rows x 18 columns]

# %%
''' Saves the extracted data to a CSV'''

df_schools = pd.DataFrame.from_dict(schools, orient='index', columns=['freq'])
df_schools.sort_values(['freq'], ascending=False).to_csv('Failed_schools.csv')

df_fields = pd.DataFrame.from_dict(fields, orient='index', columns=['freq'])
df_fields.sort_values(['freq'], ascending=False).to_csv('Failed_fields.csv')

df_compnames = pd.DataFrame.from_dict(companynames, orient='index', columns=['freq'])
df_compnames.sort_values(['freq'], ascending=False).to_csv('Failed_companynames.csv')

df_titles = pd.DataFrame.from_dict(jobtitle, orient='index', columns=['freq'])
df_titles.sort_values(['freq'], ascending=False).to_csv('Failed_titles.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-cb125970885b> in <module>
#       1 ''' Saves the extracted data to a CSV'''
#       2
# ----> 3 df_schools = pd.DataFrame.from_dict(schools, orient='index', columns=['freq'])
#       4 df_schools.sort_values(['freq'], ascending=False).to_csv('Failed_schools.csv')
#       5
#
# NameError: name 'schools' is not defined
