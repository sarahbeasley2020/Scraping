# %%
# Import statements
import pandas as pd
import numpy as np 
import csv 
from parsel import Selector
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import json
import re

# %%
'''
Class to describe a given company 
    @field: name: a string for the company name
    @field: description: a string for the company description
    @field: founders: a list of Founder objects
    @field: industries: a list of strings for different industries
    @field: website: a string for the website
    @field: lastStage: a string for the last stage of funding (eg. Series A)
    @field: linkedin: a string for the company's LinkedIn profile
    @field: location: a string for the company's location
'''
class Company:
    def __init__(self, companyName):
        self.name = companyName
        self.description = None
        self.founders = []
        self.industries = []
        self.website = None
        self.lastStage = None
        self.linkedin = None
    
    def toJson(self):
        return json.dumps(self, default=lambda o: o.__dict__)
    
'''
Class to describe a founder
    @field: name: a string for the founder's name
    @field: education: an list of education objects
    @field: experience: a list of experience objects
'''
class Founder:
    def __init__(self, founderName):
        self.name = founderName
        self.connections = None
        self.location = None
        self.education = []
        self.experience = []

'''
Class to help describe a founder's education
    @field: degree: a string to describe the degree objective
    @field: school: a string for the school attended
    @field: field: a string to describe the major
'''
class Education:
    def __init__(self, schoolName):
        self.school = schoolName
        self.degree = None
        self.field = None
'''
Class to help describe a founder's experience
    @field: companyName: a string to describe the company's name
    @field: title: a string to describe the title held
    @field: description: a string to describe the job description
'''       
class Experience:
    def __init__(self, companyName):
        self.companyName = companyName
        self.title = None
        self.dates = None

# %%
'''
Loads the dataframe from Query 1 and Query 2 and merges + drops duplicates and NaNs
    @param: csv1: path to CSV 1 (formed by Query 1)
    @param: csv2: path to CSV 2 (formed by Query 2)
    @return: df1: a merged dataframe of csv1 and csv2
'''
def loadBacktestData(csv1, csv2):
    df1 = pd.read_csv(csv1)
    df2 = pd.read_csv(csv2)
    df1 = df1.append(df2)
    df1 = df1.drop_duplicates(subset=['Organization Name'])
    df1 = df1[df1.Founders.notna()]
    df1 = df1[df1.LinkedIn.notna()]
    df1 = df1.reset_index()
    for i in range(len(df1)):
        if df1.iloc[i].LinkedIn.count('about') > 0:
            df1['LinkedIn'][i] = df1['LinkedIn'][i].split('about')[0]
    return df1

# Loads and combines both CSVs into df1 dataframe
df1 = loadBacktestData('backtest1.csv', 'backtest2.csv')
# Creates a company_data dictionary to store scraped data
company_data = {}
# Out:
# /Users/mymacbook/.local/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
'''
Method to set up and log into the LinkedIn using chromedriver
    @param: driverPath: path to the chromedriver.exe file
    @param: liUsername: string of LI username
    @param: liPassword: string of LI password
    @return: driver: the Chrome Webdriver (can be passed into future function arguments)
'''
def setupDriver(driverPath, liUsername, liPassword):
    # Sets up Chrome Webdriver and navigates to LinkedIn
    driver = webdriver.Chrome(driverPath)
    driver.get('https://www.linkedin.com/')
    sleep(2.0)
    
    # Signs in with given credentials and returns the driver
    driver.find_element_by_xpath('//a[text()="Sign in"]').click()
    sleep(2.0)
    username_input = driver.find_element_by_name('session_key')
    username_input.send_keys(liUsername)
    password_input = driver.find_element_by_name('session_password')
    password_input.send_keys(liPassword)
    sleep(2.0)
    driver.find_element_by_xpath('//button[text()="Sign in"]').click()
    return driver

# Launches LinkedIn and logs in
driver = setupDriver('./chromedriver', 'julianvallyeason@gmail.com', 'Acceleprise1')

# %%
'''
Method to save the company data as a txt file (loadable as JSON)
    @param: data: company_data dictionary of Company objects
    @return: None
'''
def saveData(data, fileName):
    data_json = json.dumps(data, default=lambda x: x.__dict__)
    with open(fileName, 'w') as outfile:
        json.dump(data_json, outfile)

'''
Method to load company data into a dictionary (same structure as Company object)
    @param: dataFile: string path to saved txt file
    @return: dataDict: a dictionary with the same structure as a Company object
'''
def loadData(dataFile):
    with open(dataFile) as json_file:
        data = json.load(json_file)
    dataDict = json.loads(data)
    return dataDict

# %%
'''
Method to get the number of connections for a founder on that founder's LI profile
    @param: driver - the chromedriver used
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the number of connections found on the profile
'''
def addConnections(driver, founder_):
    conn_ = driver.find_elements_by_xpath('//ul[@class = "pv-top-card--list pv-top-card--list-bullet mt1"]/li[@class = "inline-block"]')
    try:
        founder_.connections = conn_[0].text
    except:
        print("Connections not found for {}".format(founder_.name))
        
'''
Method to get extract the founder location
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the location found on the profile
'''
def updateLocation(driver, founder_):
    loc_ = driver.find_elements_by_xpath('//li[@class = "t-16 t-black t-normal inline-block"]')
    try:
        founder_.location = loc_[0].text
    except:
        print("Location not found for {}".format(founder_.name))

# %%
'''
Method to get the School Name, FoS and Degree Name for all educational experiences for a founder
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all education experiences
'''
def getSchools(driver, founder_):
    schools = driver.find_elements_by_xpath('//div[@class="pv-entity__degree-info"]')
    for school_ in schools:
        try:
            educ_ = Education(school_.find_element_by_class_name('pv-entity__school-name').text)
            try:
                educ_.degree = school_.find_element_by_class_name('pv-entity__degree-name').text.split('\n')[1]
            except:
                print("No degree info found for {} at {}".format(founder_.name, educ_.school))
            try:
                educ_.field = school_.find_element_by_class_name('pv-entity__fos').text.split('\n')[1]
            except:
                print("No field of study for {} at {}".format(founder_.name, educ_.school))

            # Appends the temporary education object to the founder
            founder_.education.append(educ_)
        except:
            print("No schools found for {}".format(founder_.name))

# %%
'''
Method to get the Company Name, Title and Dates for all work experiences for a founder 
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all work experiences
'''
def getWorkExperience(driver, founder_):
    experiences = driver.find_elements_by_xpath('//a[@data-control-name="background_details_company"]')
    for exp in experiences:
        exp_lst = exp.text.split('\n')
        # The exp_ is formatted as [title, 'companyname', companyname, 'datesemployed', datesemployed, ..]
        try:
            if exp_lst[0] == 'Company Name':
                exp_ = Experience(exp_lst[1])
                founder_.experience.append(exp_)
            else:
                exp_ = Experience(exp_lst[2])
                try:
                    exp_.title = exp_lst[0]
                    exp_.dates = exp_lst[4]
                    founder_.experience.append(exp_)
                except:
                    founder_.experience.append(exp_)
        except:
            print("No experience found for {}".format(str(founder_.name)))

# %%
'''
Extracts the founder information from a LinkedIn search for a founder and adds the founder to the company
    @param: driver - the chromedriver used
    @param: founder - a string for the founder's name
    @param: company_ - the Company object for the company the founder is working at
'''

def getFounderInfo(driver, founder, company_):
    res_ = driver.find_element_by_xpath('//a[@data-control-name="search_srp_result"]')
    if res_:
        res_.click()
        sleep(2.0)
        # Scrolls to the bottom of the webpage (if no scroll, error where the full webpage doens't load)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/2);")
        sleep(0.75)
        # Creates a founder object for the given founder
        founder_ = Founder(founder)
        
        #Extracts data for connections
        addConnections(driver, founder_)
        
        #Extract founder location
        updateLocation(driver, founder_)

        # Extracts degree information (formatted as a list of items)
        getSchools(driver, founder_)
 
        # Extracts experience information (formatted as a list of items)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/3);")
        sleep(1.0)
        getWorkExperience(driver, founder_)
        
        # Appends the temporary founder object to the company
        company_.founders.append(founder_)
        sleep(1.0)
    else:
        founder_ = Founder(founder)
        company_.founders.append(founder_)
        print("{} not found for {}".format(company_.name, founder_.name))
        sleep(1.0)

# %%
'''
Method to search for founder and company on the search bar and extract founder information if found
    @param: driver - the chromedriver used 
    @param: founder - a string for the name of the founder to be searched
    @param: company_ = the company being searched
    @return: None
The founder object is populated and added to the company
'''
def searchForFounder(driver, founder, company_):
    # Finds the search bar on top of the LinkedIn page
    search = driver.find_elements_by_xpath('//input[@class="search-global-typeahead__input always-show-placeholder"]')
    sleep(0.5)
    search[0].click()
    for i in range(50):
        search[0].send_keys(Keys.RIGHT)
    # Clears any existing search
    for i in range(80):
        search[0].send_keys(Keys.BACKSPACE)
    # Types in founder name + company name and searches
#     search[0].send_keys(founder + " " + company_.name.split(" ")[0])
    search[0].send_keys(founder + " " + re.split(" |,", company_.name)[0])
    search[0].send_keys(Keys.ENTER)
    sleep(2.0)
    try:
        getFounderInfo(driver, founder, company_)
    except:
        print("{} not found for {}".format(founder, company_.name))

# %%
'''
Method to add LI information for a company into the company_data dictionary with a new company object
    @param: entry: a pandas series extracted from a single row in the dataframe from loadBacktestData
    @return: None
This method updates the company_data dictionary and returns nothing
'''
def scrapeLI(entry):
    # Adds a new company entry to the company_data dictionary and populates fields
    company_ = Company(entry['Organization Name'])
    company_.description = entry['Description']
    company_.industries = [i.strip() for i in entry['Industries'].split(',')]
    company_.website = entry['Website']
    company_.lastStage = entry['Last Funding Type']
    # Edge case where the LinkedIn link does not end in '/'
    if entry['LinkedIn'][-1] != '/':
        entry['LinkedIn'] = entry['LinkedIn'] + '/'
    company_.linkedin = entry['LinkedIn']
    company_.location = entry['Headquarters Location']
    
    # Generates a list of founder names
    founderNames = [i.strip() for i in entry['Founders'].split(',')]
    try:
        # For each founder in the list, the school name, degree, and major is extracted
        for founder in founderNames:
            searchForFounder(driver, founder, company_)
    except:
        print("Structural Error")
    # Adds the company to the company_data dictionary
    company_data[company_.name] = company_

# %%
for i in range(1100,1200):
    print(i)
    if i%5 == 0:
        sleep(5.0)
    scrapeLI(df1.iloc[i])
# Out:
# 1100
# /Users/mymacbook/.local/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# 1101
# No degree info found for Mark Rich at New York University
# No field of study for Rousseau Kazi at Canyon Springs
# No degree info found for Suman Venkataswamy at Shanghai University
# No field of study for Suman Venkataswamy at Shanghai University
# 1102
# No field of study for Lyal Avery at The University of British Columbia
# 1103
# No degree info found for Chanpory Rith at International Institute for Information Design (IIID)
# No degree info found for Chanpory Rith at Blazing Cloud
# No degree info found for Olof Mathé at Ecole polytechnique
# No field of study for Olof Mathé at Ecole polytechnique
# 1104
# No field of study for Eric Romo at Stanford University Graduate School of Business
# No degree info found for Gavan Wilhite at Punahou School
# No field of study for Gavan Wilhite at Punahou School
# 1105
# No field of study for Coleman Stavish at St. Joseph's Preparatory School
# No degree info found for David West at St. Joseph's Preparatory School
# No field of study for David West at St. Joseph's Preparatory School
# No degree info found for Kristina Li at The Johns Hopkins University
# 1106
# CJ Tjhai not found for Post-Quantum
# 1107
# Patrick Moberg not found for Playdots
# Paul Murphy not found for Playdots
# 1108
# No degree info found for Rory San Miguel at University of New South Wales
# No degree info found for Rory San Miguel at St Aloysius College
# No field of study for Rory San Miguel at St Aloysius College
# 1109
# No degree info found for Shak Patel at Internal School Of Lusaka
# No field of study for Shak Patel at Internal School Of Lusaka
# 1110
# No degree info found for Yannick Martel at Ecole nationale supérieure des Télécommunications
# No degree info found for Yannick Martel at Ecole Normale Supérieure
# No degree info found for Yannick Martel at Lycée Joffre - Montpellier - France
# 1111
# 1112
# 1113
# 1114
# No degree info found for Tim Spratt at University of Oxford
# No field of study for Tim Spratt at University of Oxford
# No degree info found for Tim Spratt at Imperial College London
# No field of study for Tim Spratt at Imperial College London
# No degree info found for Tim Spratt at Y Combinator
# No field of study for Tim Spratt at Y Combinator
# 1115
# No field of study for David Wald at University of Michigan - Stephen M. Ross School of Business
# No field of study for Michael Schultz at University of Michigan
# No field of study for Michael Schultz at Lawrence Technological University
# 1116
# No degree info found for Adam Levene at Verulam School
# No field of study for Adam Levene at Verulam School
# 1117
# 1118
# 1119
# No field of study for Jackson Noel at Harvard Business School
# No degree info found for Jackson Noel at Bucknell University
# No field of study for Jackson Noel at Bucknell University
# 1120
# No degree info found for Thomas Jaklitsch at Regis High School
# No field of study for Thomas Jaklitsch at Regis High School
# No degree info found for Zachary Garippa at Regis High School
# No field of study for Zachary Garippa at Regis High School
# No degree info found for Zachary Garippa at Boston College
# No field of study for Zachary Garippa at Boston College
# 1121
# No field of study for Will Dayton at Stanford University
# No field of study for Will Dayton at Carnegie Mellon University
# 1122
# No degree info found for Fabio Fleitas at Albuquerque Academy
# No field of study for Fabio Fleitas at Albuquerque Academy
# No degree info found for Fabio Fleitas at Y Combinator
# No field of study for Fabio Fleitas at Y Combinator
# 1123
# 1124
# No degree info found for James Dean at King's College London, U. of London
# No field of study for James Dean at King's College London, U. of London
# No degree info found for James Dean at University of California, Irvine
# No field of study for James Dean at University of California, Irvine
# 1125
# No degree info found for Chris Prucha at University of Michigan
# No degree info found for Joel Ong at Raffles Institution
# No field of study for Joel Ong at Raffles Institution
# 1126
# No field of study for Ariel Assaraf at Apelman Dimona
# No field of study for Guy Kroupp at University of Haifa
# 1127
# No degree info found for Peter Brand at London School of Economics and Political Science
# No degree info found for Peter Brand at New Trier Township High School
# No field of study for Peter Brand at New Trier Township High School
# No field of study for Willem Sundblad at Ecole centrale de Paris / Centrale Paris
# 1128
# No field of study for Daniel Nahmias-Leonard at HEC Montréal
# No degree info found for Daniel Nahmias-Leonard at Université Paris-Sorbonne
# No field of study for Felix Heide at Stanford University
# 1129
# No degree info found for Joseph Cohen at Y Combinator
# No field of study for Joseph Cohen at Y Combinator
# 1130
# 1131
# No field of study for Bert Armijo at St. Mary's College of California
# 1132
# No degree info found for Kyle Slager at Tuck School of Business at Dartmouth Summer Bridge Program
# No field of study for Kyle Slager at Tuck School of Business at Dartmouth Summer Bridge Program
# 1133
# Connections not found for Aram Shatakhtsyan
# Location not found for Aram Shatakhtsyan
# No field of study for Sophia Baik at Massachusetts Institute of Technology - Sloan School of Management
# 1134
# 1135
# 1136
# 1137
# No degree info found for Gerald Croes at Ecole Supérieure de Commerce et d'Industrie
# No degree info found for Vincent Pineau at INSA
# 1138
# No degree info found for Alex Cardona at Westminster School
# No field of study for Alex Cardona at Westminster School
# No degree info found for Peter Lord at Dr Challoners Grammar School
# No field of study for Peter Lord at Dr Challoners Grammar School
# 1139
# No degree info found for Nathan Wenzel at Y Combinator
# No field of study for Nathan Wenzel at Y Combinator
# 1140
# No degree info found for Matthew Klein at Florida State University
# No field of study for Matthew Klein at Florida State University
# 1141
# 1142
# 1143
# No degree info found for Aaron Schmid at De La Salle Collegiate
# No field of study for Aaron Schmid at De La Salle Collegiate
# 1144
# No degree info found for Omri Timianker at University of California, Irvine - The Paul Merage School of Business
# No field of study for Omri Timianker at University of California, Irvine - The Paul Merage School of Business
# No field of study for Udi Levy at Bar-Ilan University
# 1145
# No degree info found for Frank Celler at Albert-Schweitzer-Gymnasium, Hürth
# No field of study for Frank Celler at Albert-Schweitzer-Gymnasium, Hürth
# 1146
# No degree info found for Amr Mohamed at Cairo University
# No field of study for Amr Mohamed at Cairo University
# No degree info found for Eric Rachmel at University of Colorado Boulder
# No field of study for Eric Rachmel at University of Colorado Boulder
# No degree info found for Eric Rachmel at University of Virginia
# 1147
# No degree info found for Giovanni Tummarello at KTH Royal Institute of Technology
# No field of study for Giovanni Tummarello at KTH Royal Institute of Technology
# 1148
# No field of study for Ashot Iskandarian at San Diego State University
# No field of study for Ashot Iskandarian at San Diego State University
# 1149
# 1150
# No degree info found for Claus Topholt at Holte Gymnasium
# No field of study for Claus Topholt at Holte Gymnasium
# 1151
# No degree info found for Rainer Kunz at TU Darmstadt
# 1152
# No degree info found for Paul Vallee at Essor
# No field of study for Paul Vallee at Essor
# 1153
# No degree info found for David Pignolet at Northeastern University
# No field of study for David Pignolet at Northeastern University
# No degree info found for David Pignolet at Community College of the Air Force
# 1154
# Connections not found for Anton Lutsevich
# Location not found for Anton Lutsevich
# Stanislav Petrik not found for YCLIENTS
# 1155
# No degree info found for Dave Cullinane at Tufts University
# No field of study for Dave Cullinane at Tufts University
# No field of study for Patrick Coughlin at Stanford University Graduate School of Business
# 1156
# 1157
# No degree info found for Caleb Hailey at Mount Hood Community College
# 1158
# 1159
# No degree info found for Andrew Coward at Nene College, Northampton
# No field of study for Andrew Coward at Nene College, Northampton
# 1160
# No field of study for Aurélien Georget at HETIC
# No field of study for Aurélien Georget at IUT Laval
# No field of study for Aurélien Georget at Lycée Sévigné
# No field of study for Jim Laurie at HETIC
# No field of study for Jim Laurie at Université du Sud Toulon Var
# 1161
# 1162
# Connections not found for Bahaaldine Azarmi
# Location not found for Bahaaldine Azarmi
# 1163
# 1164
# No degree info found for Robert Tallack at St. Francis Xavier University
# No field of study for Robert Tallack at St. Francis Xavier University
# No degree info found for Stephen Blazick at Washburn University
# No degree info found for Stephen Blazick at The University of Texas at Austin
# 1165
# No field of study for Christian Damstra at TAFE NSW
# No degree info found for Christian Damstra at TAFE NSW
# No field of study for Christian Damstra at TAFE NSW
# 1166
# No degree info found for Brian Meehan at Middlebury College
# No field of study for Brian Meehan at Middlebury College
# No degree info found for Susan Estes at University of Redlands
# 1167
# No field of study for Trevor Parsons at University College Dublin
# 1168
# Qinghua Guo not found for GreenValley International Inc
# 1169
# 1170
# No field of study for Anthony Kelly at Law Society of Ireland
# No degree info found for Anthony Kelly at Law Society of Ireland
# No field of study for Conor O'Loughlin at CFA Institute
# No degree info found for Finn Hegarty at Stanford University
# No degree info found for Finn Hegarty at ACCA Association of Chartered Certified Accountants
# 1171
# No field of study for Ernesto DiGiambattista at Suffolk University - Sawyer School of Management
# 1172
# No degree info found for Sahas Katta at University of California, Davis
# No degree info found for Sahas Katta at Saratoga High School
# No field of study for Sahas Katta at Saratoga High School
# No degree info found for Sanketh Katta at University of California, Berkeley
# No degree info found for Sanketh Katta at London School of Economics and Political Science
# 1173
# Connections not found for Chang Tsung-Yao
# Location not found for Chang Tsung-Yao
# 1174
# Hans Andersson not found for Hansoft
# Hans Dahlstrom not found for Hansoft
# No degree info found for Patric Palm at Uppsala University
# No field of study for Patric Palm at Uppsala University
# 1175
# No field of study for Marc Piette at Massachusetts Institute of Technology - Sloan School of Management
# 1176
# No degree info found for David Buxton at University of Oxford
# No field of study for David Buxton at University of Oxford
# 1177
# 1178
# No degree info found for Bradley Tabone at Mt Lilydale College
# No field of study for Bradley Tabone at Mt Lilydale College
# 1179
# No field of study for Lawrence Goldenhersh at University of Virginia School of Law
# 1180
# No degree info found for Roy Russo at Rollins College
# 1181
# Connections not found for Garrett Langley
# Location not found for Garrett Langley
# 1182
# Rick Haythornthwaite not found for QiO Technologies
# 1183
# 1184
# No degree info found for Jason Swenski at California Polytechnic State University-San Luis Obispo
# 1185
# No degree info found for Jeremy Baker at Alchemist Accelerator
# No field of study for Jeremy Baker at Alchemist Accelerator
# 1186
# 1187
# No degree info found for Satish Raghunath at MES College Bangalore
# No field of study for Satish Raghunath at MES College Bangalore
# 1188
# No degree info found for Harrison Proffitt at Kansas State University
# No degree info found for Harrison Proffitt at Kansas State University
# 1189
# 1190
# 1191
# Connections not found for Greg Wunderle
# Location not found for Greg Wunderle
# Connections not found for Soumik Sarkar
# Location not found for Soumik Sarkar
# 1192
# No degree info found for Vadim Lipovetsky at Tel Hai Academic College
# No field of study for Vadim Lipovetsky at Tel Hai Academic College
# 1193
# No degree info found for Meena Sankaran at Stanford University
# 1194
# 1195
# 1196
# No degree info found for Arthur Waller at Sciences Po
# No field of study for Arthur Waller at Sciences Po
# No field of study for Félix Blossier at Ecole nationale d'Administration
# No field of study for Khalid El Guitti at Institut d'Etudes politiques de Paris / Sciences Po Paris
# No field of study for Quentin de Metz at Carnegie Mellon University
# No degree info found for Raphael Théron at Ecole polytechnique
# No field of study for Raphael Théron at Ecole polytechnique
# No degree info found for Tancrède Besnard at Ecole polytechnique
# No field of study for Tancrède Besnard at Ecole polytechnique
# No degree info found for Tancrède Besnard at Lycée Louis le Grand
# 1197
# No field of study for Brett Plotzker at The University of Chicago - Booth School of Business
# No field of study for Brett Plotzker at The University of Texas at Austin
# No degree info found for Jeremy Bluvol at University of Toronto
# Kam Kudla not found for Anagram
# 1198
# No degree info found for Jack Donaghy at University College Dublin
# No field of study for Jack Donaghy at University College Dublin
# No degree info found for Jack Donaghy at Terenure
# No field of study for Jack Donaghy at Terenure
# No field of study for Karl Glennon at Stanford University
# No field of study for Karl Glennon at Dublin City University
# No field of study for Karl Glennon at Reforge
# 1199
# No field of study for Brock Hensen at Wisconsin School of Business
# No field of study for Chris Fernandez at Y Combinator

# %%
saveData(company_data, 'data1200.txt')

# %%
# Used to extract and analyze the data from the saved text file

schools = {}
fields = {}
companynames = {}
jobtitle = {}

for key in loaded.keys():
    for founder in loaded[key]['founders']:
        if founder['education']:
            for educ_ in founder['education']:
                school = educ_['school'].lower()
                for word in school.split(' '):
                    if word in schools:
                        schools[word] += 1
                    else:
                        schools[word] = 1
                if educ_['field']:
                    field = educ_['field'].lower()
                    for word in field.split(' '):
                        if word in fields:
                            fields[word] += 1
                        else:
                            fields[word] = 1
        if founder['experience']:
            for exp_ in founder['experience']:
                companyName = exp_['companyName'].lower()
                for word in companyName.split(' '):
                    if word in companynames:
                        companynames[word] += 1
                    else:
                        companynames[word] = 1
                if exp_['title']:
                    title = exp_['title'].lower()
                    if title in jobtitle:
                        jobtitle[title] += 1
                    else:
                        jobtitle[title] = 1

# %%
''' Saves the extracted data to a CSV'''

df_schools = pd.DataFrame.from_dict(schools, orient='index', columns=['freq'])
df_schools.sort_values(['freq'], ascending=False).to_csv('schools.csv')

df_fields = pd.DataFrame.from_dict(fields, orient='index', columns=['freq'])
df_fields.sort_values(['freq'], ascending=False).to_csv('fields.csv')

df_compnames = pd.DataFrame.from_dict(companynames, orient='index', columns=['freq'])
df_compnames.sort_values(['freq'], ascending=False).to_csv('companynames.csv')

df_titles = pd.DataFrame.from_dict(jobtitle, orient='index', columns=['freq'])
df_titles.sort_values(['freq'], ascending=False).to_csv('titles.csv')
