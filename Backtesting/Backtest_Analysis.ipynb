# %%
# Import statements
import pandas as pd
import numpy as np 
import csv 
import json
import re
import math

# %%
'''
Loads the dataframe from Query 1 and Query 2 and merges + drops duplicates and NaNs
    @param: csv1: path to CSV 1 (formed by Query 1)
    @param: csv2: path to CSV 2 (formed by Query 2)
    @return: df1: a merged dataframe of csv1 and csv2
'''
def loadBacktestData(csv1, csv2):
    df1 = pd.read_csv(csv1)
    df2 = pd.read_csv(csv2)
    df1 = df1.append(df2)
    df1_ = df1.drop_duplicates(subset=['Organization Name'])
    df1 = df1_[df1_.Founders.notna()]
    df1 = df1[df1.LinkedIn.notna()]
    df1 = df1.reset_index()
    for i in range(len(df1)):
        if df1.iloc[i].LinkedIn.count('about') > 0:
            df1['LinkedIn'][i] = df1['LinkedIn'][i].split('about')[0]
    df1 = df1.set_index('Organization Name')
    df1 = df1.drop('index', 1)
    df1['Organization Name'] = df1.index
    df1_ = df1_.set_index('Organization Name')
    return df1, df1_

# Loads and combines both CSVs into df1 dataframe
df1, df1_ = loadBacktestData('backtest1.csv', 'backtest2.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
'''
Method to save the company data as a txt file (loadable as JSON)
    @param: data: company_data dictionary of Company objects
    @return: None
'''
def saveData(data, fileName):
    data_json = json.dumps(data, default=lambda x: x.__dict__)
    with open(fileName, 'w') as outfile:
        json.dump(data_json, outfile)

'''
Method to load company data into a dictionary (same structure as Company object)
    @param: dataFile: string path to saved txt file
    @return: dataDict: a dictionary with the same structure as a Company object
'''
def loadData(dataFile):
    with open(dataFile) as json_file:
        data = json.load(json_file)
    dataDict = json.loads(data)
    return dataDict

# %%
alldata = loadData('alldata_final.txt')

# %%
'''
Structure of Company Dictionary Entry:
    @name - string for the company's name
    @description - string for a company description
    @founders - list of founder dictionaries (single founders)
        Structure of Founder Dictionary Entry
            @name - string for the founder's name
            @connections - string for the founder's # of connections
            @location - string for the founder's location 
            @education - list of education dictionaries (single education experiences)
                Structure of Education Dictionary Entry
                    @school - string for the school name
                    @degree - string for the degree objective (i.e. BS / BA)
                    @field - string for the field studied (i.e. Computer Science)
            @experience - list of experience dictionaries (single experiences)
                Structure of Experience Dictionary Entry
                    @companyName - string for the company's name
                    @title - string for the position held at the company
                    @dates - string for the dates worked at the company (i.e. May 2000 - Jun 2000)
    @industries - list of strings with the industries the company is involved in 
    @website - string for the company's website
    @lastStage - string for the last stage of funding received (i.e. Series A)
    @linkedin - string for the URL of the company's LI profile
    @location - string for the company's HQ location
'''
pass

# %%
df1.index[0]
# Out:
# 'Bright Machines'

# %%
'''
Data Validation: Location
    Please note: county can also mean 'state'
'''
drop_city = {} ; drop_country = {} ; keep_city = {} ; keep_country = {}
drop_county = {} ; keep_county = {}
for i in range(len(df1_)):
    split_item = df1_.iloc[i]['Headquarters Location'].split(',')
    if df1_.index[i] not in alldata:
        if split_item[0] not in drop_city:
            drop_city[split_item[0]] = 1
        else:
            drop_city[split_item[0]] += 1
        if split_item[-1] not in drop_country:
            drop_country[split_item[-1]] = 1
        else:
            drop_country[split_item[-1]] += 1
        if split_item[1] not in drop_county:
            drop_county[split_item[1]] = 1
        else:
            drop_county[split_item[1]] += 1
    else:
        if split_item[0] not in keep_city:
            keep_city[split_item[0]] = 1
        else:
            keep_city[split_item[0]] += 1
        if split_item[-1] not in keep_country:
            keep_country[split_item[-1]] = 1
        else:
            keep_country[split_item[-1]] += 1
        if split_item[1] not in keep_county:
            keep_county[split_item[1]] = 1
        else:
            keep_county[split_item[1]] += 1

drop_city = {k: v for k, v in sorted(drop_city.items(), key=lambda item: item[1], reverse=True)}
drop_country = {k: v for k, v in sorted(drop_country.items(), key=lambda item: item[1], reverse=True)}
keep_city = {k: v for k, v in sorted(keep_city.items(), key=lambda item: item[1], reverse=True)}
keep_country = {k: v for k, v in sorted(keep_country.items(), key=lambda item: item[1], reverse=True)}
drop_county = {k: v for k, v in sorted(keep_county.items(), key=lambda item: item[1], reverse=True)}
keep_county = {k: v for k, v in sorted(keep_county.items(), key=lambda item: item[1], reverse=True)}

for (i,j) in [(drop_country, keep_country), (drop_city, keep_city), (drop_county, keep_county)]:
    df_1 = pd.DataFrame.from_dict(i, orient='index', columns=['freq']).reset_index()
    df_2 = pd.DataFrame.from_dict(j, orient='index', columns=['freq']).reset_index()
    df_item = pd.merge(df_1, df_2, on='index')
    df_item.columns = ['name', 'dropped', 'kept']
    df_item['dropped'] /= df_item['dropped'].sum()
    df_item['kept'] /= df_item['kept'].sum()
    df_item.set_index(['name'])
df_item.head(10)
# Out:
#              name   dropped      kept
# 0      California  0.324667  0.324667
# 1        New York  0.084667  0.084667
# 2         England  0.058667  0.058667
# 3   Massachusetts  0.033333  0.033333
# 4   Ile-de-France  0.031333  0.031333
# 5           Texas  0.027333  0.027333
# 6        Colorado  0.020667  0.020667
# 7      Washington  0.020667  0.020667
# 8         Ontario  0.018667  0.018667
# 9          Berlin  0.018000  0.018000

# %%
'''
Data Validation: Industries
'''     
drop_industries = {}
for name_ in df1_.index:
    for ind_ in [i.strip() for i in df1_.loc[name_]['Industries'].split(',')]:
        if ind_ not in drop_industries:
            drop_industries[ind_] = 1
        else:
            drop_industries[ind_] += 1
drop_industries = {k: v for k, v in sorted(drop_industries.items(), key=lambda item: item[1], reverse=True)} 
df_dropIndustries = pd.DataFrame.from_dict(drop_industries, orient='index', columns=['freq']).reset_index()

kept_industries = {}
for name_ in alldata.keys():
    for ind_ in [i.strip() for i in df1.loc[name_]['Industries'].split(',')]:
        if ind_ not in kept_industries:
            kept_industries[ind_] = 1
        else:
            kept_industries[ind_] += 1
kept_industries = {k: v for k, v in sorted(kept_industries.items(), key=lambda item: item[1], reverse=True)}

# Brings it into a dataframe
df_keptIndustries = pd.DataFrame.from_dict(kept_industries, orient='index', columns=['freq']).reset_index()
df_industries = pd.merge(df_dropIndustries, df_keptIndustries, on='index')
df_industries.columns = ['name', 'dropped', 'kept']
df_industries['dropped'] /= df_industries['dropped'].sum()
df_industries['kept'] /= df_industries['kept'].sum()
df_industries.set_index(['name'])
df_industries.head(10)
# Out:
#                       name   dropped      kept
# 0                 Software  0.199771  0.192458
# 1   Information Technology  0.061318  0.060335
# 2                     SaaS  0.056963  0.059916
# 3  Artificial Intelligence  0.036103  0.036732
# 4         Machine Learning  0.027278  0.028212
# 5      Enterprise Software  0.025559  0.026536
# 6                 Internet  0.025215  0.023603
# 7                Analytics  0.014212  0.014944
# 8                  FinTech  0.013868  0.014525
# 9                 Computer  0.013524  0.013268

# %%
'''
General Data:
    # of Founders
    % Female Founders
    Median Funding Amount
'''
# Import Statement
import gender_guesser.detector as gender

d = gender.Detector()
numFounders = [] ; numFoundersDict = {} ; fundingAmount = [] ; genderDict = {} ;
femaleComp = 0 ; totalComp = 0
for i in range(len(df1)):
    founders_ = df1.iloc[i]['Founders'].split(',')
    amount_ = df1.iloc[i]['Last Funding Amount Currency (in USD)']
    if founders_:
        numFounders.append(len(founders_))
        hasWomen = False ; totalComp += 1
        for founder in founders_:
            founder = founder.strip()
            if founder:
                name = founder.split(' ')[0].strip()
                gen_ = d.get_gender(name)
                if gen_ not in genderDict:
                    genderDict[gen_] = 1
                else:
                    genderDict[gen_] += 1
                if not hasWomen:
                    if gen_ == "mostly_female" or gen_ == "female":
                        femaleComp += 1
                        hasWomen = True
    if amount_ and not math.isnan(amount_):
        try:
            fundingAmount.append(int(amount_))
        except:
            pass
print("Average number of founders is {}".format(str(np.mean(numFounders))))
print("Median number of founders is {}".format(str(np.median(numFounders))))
print("Mean funding amount is ${}".format(str(np.mean(fundingAmount))))
print("Median funding amount is ${}".format(str(np.median(fundingAmount))))
print(genderDict)
print("At least 1 female founder: {}".format(str((femaleComp + (genderDict['andy']/2))/totalComp)))
# Out:
# Average number of founders is 2.18871473354232
# Median number of founders is 2.0
# Mean funding amount is $7921352.245532759
# Median funding amount is $6000000.0
# {'male': 2604, 'unknown': 392, 'female': 243, 'mostly_female': 36, 'andy': 32, 'mostly_male': 184}
# At least 1 female founder: 0.16489028213166143

# %%
'''
General Data:
    Number of Founders by region
'''
countryFounders = {} ; countryByFounders = {}
for i in range(len(df1)):
    founders_ = len(df1.iloc[i]['Founders'].split(','))
    country_ = df1_.iloc[i]['Headquarters Location'].split(',')[-1]
    if not country_ in countryFounders:
        countryFounders[country_] = []
        countryFounders[country_].append(founders_)
    else:
        countryFounders[country_].append(founders_)
    if not country_ in countryByFounders:
        countryByFounders[country_] = founders_
    else:
        countryByFounders[country_] += founders_
averageFounders = {}
for country_ in countryFounders.keys():
    averageFounders[country_] = np.mean(countryFounders[country_])
averageFounders = {k: v for k, v in sorted(averageFounders.items(), key=lambda item: item[1], reverse=True)}                   
countryByFounders = {k: v for k, v in sorted(countryByFounders.items(), key=lambda item: item[1], reverse=True)}
df_countryFounders = pd.DataFrame.from_dict(countryByFounders, orient='index', columns=['freq']).reset_index()
df_averageFounders = pd.DataFrame.from_dict(averageFounders, orient='index', columns=['freq']).reset_index()
df_numFounders = pd.merge(df_countryFounders, df_averageFounders, on='index')
df_numFounders.columns = ['name', 'total', 'average']
df_numFounders.head(10)
# Out:
#               name  total   average
# 0    United States   2304  2.206897
# 1   United Kingdom    271  2.258333
# 2           Canada    134  1.970588
# 3           France    131  2.471698
# 4          Germany    129  2.114754
# 5        Australia     65  1.969697
# 6            Spain     52  2.166667
# 7      Switzerland     39  2.437500
# 8           Sweden     37  2.176471
# 9          Ireland     37  2.312500

# %%
type(df1.iloc[0]['Last Funding Amount Currency (in USD)'])
# Out:
# numpy.float64

# %%
import statsmodels.api as sm
from matplotlib import pyplot as plt
'''
General Data
    Regress funding against CB rank
'''
X = [] ; Y = []
for i in range(len(df1)):
    pos = df1.iloc[i]
    if not math.isnan(pos['Last Funding Amount Currency (in USD)']):
        y = pos['Last Funding Amount Currency (in USD)']
        x = int(pos['CB Rank (Company)'].replace(',',''))
        X.append(x)
        Y.append(y)
plt.xscale('log') ; plt.yscale('log') ; plt.scatter(X, Y) 
plt.xlabel('CB Rank') ; plt.ylabel('Amount Raised') ; 
plt.title('CB Rank vs. Amount Raised (USD)') ; plt.show()
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     81.37
# Date:                Wed, 05 Aug 2020   Prob (F-statistic):           5.53e-19
# Time:                        23:19:07   Log-Likelihood:                -26813.
# No. Observations:                1511   AIC:                         5.363e+04
# Df Residuals:                    1509   BIC:                         5.364e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.081e+07    4.5e+05     23.995      0.000    9.93e+06    1.17e+07
# x1          -119.1553     13.209     -9.021      0.000    -145.065     -93.245
# ==============================================================================
# Omnibus:                     2446.492   Durbin-Watson:                   0.439
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1613617.497
# Skew:                          10.175   Prob(JB):                         0.00
# Kurtosis:                     161.795   Cond. No.                     4.85e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.85e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
'''
Data Validation: Rounds
'''
keptRoundNames = {} ; droppedRoundNames = {}
for name_ in df1_.index:
    round_ = df1_.loc[name_]['Last Funding Type']
    if name_ not in alldata.keys():
        if round_ not in droppedRoundNames:
            droppedRoundNames[round_] = 1
        else:
            droppedRoundNames[round_] += 1
    else:
        if round_ not in keptRoundNames:
            keptRoundNames[round_] = 1
        else:
            keptRoundNames[round_] += 1
print("Dropped round: {}".format(str(droppedRoundNames)))
print("Kept round: {}".format(str(keptRoundNames)))
# Out:
# Dropped round: {'Series A': 190, 'Seed': 196}
# Kept round: {'Series A': 745, 'Seed': 755}

# %%
'''
Loads top schools data
'''
topSchools = pd.read_csv('topSchools.csv', index_col="Score_Rank")
topSchools = topSchools[['University', 'General_name']].head(100)

# %%
'''
Pedigree
    1. Do the majority of successful founders attend a top university?
'''
topcount = 0 ; schoolDict = {} ; founderCount = 0 ; schoolFound = False
for key in alldata.keys():
    if alldata[key]['founders']:
        for founder in alldata[key]['founders']:
            if founder['education']:
                founderCount += 1 ; schoolFound = False
                for educ_ in founder['education']:
                    school_ = educ_['school'].lower()
                    if school_ not in schoolDict:
                        schoolDict[school_] = 1
                    else:
                        schoolDict[school_] += 1
                    if not schoolFound:
                        for topSchool_ in topSchools['University']:
                            if school_ in topSchool_.lower():
                                topcount += 1
                                schoolFound = True
                                break
                    if not schoolFound:
                        for topSchool_ in topSchools['General_name']:
                            if topSchool_ in school_.lower():
                                topcount += 1
                                schoolFound = True
                                break
schoolDict = {k: v for k, v in sorted(schoolDict.items(), key=lambda item: item[1], reverse=True)}                   
print("{} % of founders attended a Top 100 School at some point in their education".format(str(topcount / founderCount * 100)))

print("Top schools attended:")
count = 1
for k in schoolDict.keys():
    if count <= 10:
        print("{}. {}".format(str(count), k))
        count += 1
    else:
        break

df_school = pd.DataFrame.from_dict(schoolDict, orient='index', columns=['freq']).reset_index()
# Out:
# 45.68510038746037 % of founders attended a Top 100 School at some point in their education
# Top schools attended:
# 1. stanford university
# 2. y combinator
# 3. massachusetts institute of technology
# 4. university of california, berkeley
# 5. carnegie mellon university
# 6. harvard university
# 7. harvard business school
# 8. cornell university
# 9. university of cambridge
# 10. university of michigan

# %%
'''
Pedigree
    2. Do the majority of successful founders attend graduate school?
'''
degreeDict = {} ; degreeCount = 0 ; gradCount = 0

def checkGraduateEducation(founder, degreeDict, degreeCount):
    if founder['education']:
        checkDegree = True
        for educ_ in founder['education']:
            if educ_['degree']:
                deg_ = educ_['degree'].lower()
                if checkDegree:
                    degreeCount += 1
                    checkDegree = False
                if deg_ not in degreeDict:
                    degreeDict[deg_] = 1
                else:
                    degreeDict[deg_] += 1
    return degreeDict, degreeCount

for key in alldata.keys():
    if alldata[key]['founders']:
        for founder in alldata[key]['founders']:
            degreeDict, degreeCount = checkGraduateEducation(founder, degreeDict, degreeCount)

degreeDict = {k: v for k, v in sorted(degreeDict.items(), key=lambda item: item[1], reverse=True)}  
for key in degreeDict.keys():
    if key in ['mba', 'ms', 'msc', 'ph.d', 'phd', 'ma', 'jd', 'ph.d', 'md', 'mse', 'meng'] or 'master' in key or 'm.' in key or 'doctor' in key:
        gradCount += 1
print("{} percent of founders have postgraduate education".format(str(gradCount / degreeCount * 100)))
# Out:
# 10.916179337231968 percent of founders have postgraduate education

# %%
'''
Pedigree
    3. Do successful founders study certain fields over others?
'''
fieldDict = {}

def getFields(founder, fieldDict):
    if founder['education']:
        for educ_ in founder['education']:
            if educ_['field']:
                field = educ_['field'].lower()
                if field not in fieldDict:
                    fieldDict[field] = 1
                else:
                    fieldDict[field] += 1
    return fieldDict

for key in alldata.keys():
    if alldata[key]['founders']:
        for founder in alldata[key]['founders']:
            fieldDict = getFields(founder, fieldDict)

fieldDict = {k: v for k, v in sorted(fieldDict.items(), key=lambda item: item[1], reverse=True)}
count = 0 ; totalCount = 0
computerFields = {} ; breakCount = 0
print("Most commonly studied fields:")
for k in fieldDict.keys():
    if breakCount < 10:
        print("{}. {}".format(str(breakCount+1), k))
        breakCount += 1
    if 'computer' in k:
        count += fieldDict[k]
        computerFields[k] = fieldDict[k]
    totalCount += fieldDict[k]
df_fields = pd.DataFrame.from_dict(fieldDict, orient='index', columns=['freq']).reset_index()
df_fields.head(10)
print("Percentage of founders that studied CS and related fields: {}%".format(str(100 * count/totalCount)))
# Out:
# Most commonly studied fields:
# 1. computer science
# 2. economics
# 3. mechanical engineering
# 4. electrical engineering
# 5. computer engineering
# 6. finance
# 7. physics
# 8. business administration and management, general
# 9. mathematics
# 10. marketing
# Percentage of founders that studied CS and related fields: 22.478898267436694%

# %%
'''
Employment Background
    1. Do most founders have experience at startups (CEO, CFO, CTO, COO, Founder)
'''
posDict = {} ; ceosList = [] ; ctosList = []
for key in alldata.keys():
    if alldata[key]['founders']:
        for founder in alldata[key]['founders']:
            if founder['experience']:
                firstCheck = True ; ceoCheck = False ; ctoCheck = False
                for exp_ in founder['experience']:
                    if (not key.split(' ')[0] in exp_['companyName']):
                        if exp_['title']:
                            if 'founder' in exp_['title'].lower() and firstCheck:
                                pass
                            else:
                                pos = exp_['title'].lower()
                                if pos not in posDict:
                                    posDict[pos] = 1
                                else:
                                    posDict[pos] += 1
                            firstCheck = False
                            if not ceoCheck:
                                if 'ceo' in exp_['title'].lower() or 'executive officer' in exp_['title'].lower():
                                    ceosList.append(founder)
                                    ceoCheck = True
                            if not ctoCheck:
                                if 'cto' == exp_['title'].lower() or ' cto' in exp_['title'].lower() or 'cto ' in exp_['title'].lower() or 'technology officer' in exp_['title'].lower() or 'technical officer' in exp_['title'].lower():
                                    ctosList.append(founder)
                                    ctoCheck = True
posDict = {k: v for k, v in sorted(posDict.items(), key=lambda item: item[1], reverse=True)}

df_pos = pd.DataFrame.from_dict(posDict, orient='index', columns=['freq']).reset_index()
print("Previous titles held by founders:")
df_pos.head(10)
# Out:
# Previous titles held by founders:
#                       index  freq
# 0         software engineer   196
# 1                co-founder   180
# 2              board member   178
# 3                       ceo   166
# 4                   founder   143
# 5                   advisor   113
# 6                consultant    86
# 7                       cto    85
# 8                  investor    73
# 9  senior software engineer    67

# %%
'''
Pedigree & Employment:
    Profiles of CEOs vs. CTOs
'''
degreeDict = {} ; degreeCount = 0 ; gradCount = 0
for cto in ctosList:
    degreeDict, degreeCount = checkGraduateEducation(cto, degreeDict, degreeCount)
    
degreeDict = {k: v for k, v in sorted(degreeDict.items(), key=lambda item: item[1], reverse=True)}  
for key in degreeDict.keys():
    if key in ['mba', 'ms', 'msc', 'ph.d', 'phd', 'ma', 'jd', 'ph.d', 'md', 'mse', 'meng'] or 'master' in key or 'm.' in key or 'doctor' in key:
        gradCount += 1
print("{} percent of CTOs have postgraduate education".format(str(gradCount / degreeCount * 100)))

degreeDict = {} ; degreeCount = 0 ; gradCount = 0
for ceo in ceosList:
    degreeDict, degreeCount = checkGraduateEducation(ceo, degreeDict, degreeCount)

degreeDict = {k: v for k, v in sorted(degreeDict.items(), key=lambda item: item[1], reverse=True)}  
for key in degreeDict.keys():
    if key in ['mba', 'ms', 'msc', 'ph.d', 'phd', 'ma', 'jd', 'ph.d', 'md', 'mse', 'meng'] or 'master' in key or 'm.' in key or 'doctor' in key:
        gradCount += 1
print("{} percent of CEOs have postgraduate education".format(str(gradCount / degreeCount * 100)))

fieldDict = {}
for ceo in ceosList:
    fieldDict = getFields(ceo, fieldDict)
    
fieldDict = {k: v for k, v in sorted(fieldDict.items(), key=lambda item: item[1], reverse=True)}
count = 0 ; totalCount = 0
computerFields = {} ; breakCount = 0
print("Most commonly studied fields CEO:")
for k in fieldDict.keys():
    if breakCount < 10:
        print("{}. {}".format(str(breakCount+1), k))
        breakCount += 1
    if 'computer' in k or 'cs' == k or 'software' in k or 'data' in k or 'engine' in k:
        count += fieldDict[k]
        computerFields[k] = fieldDict[k]
    totalCount += fieldDict[k]
df_fields = pd.DataFrame.from_dict(fieldDict, orient='index', columns=['freq']).reset_index()
df_fields.head(10)
print("Percentage of CEOs that studied CS and engineering fields: {}%".format(str(100 * count/totalCount)))

fieldDict = {}
for cto in ctosList:
    fieldDict = getFields(cto, fieldDict)

fieldDict = {k: v for k, v in sorted(fieldDict.items(), key=lambda item: item[1], reverse=True)}
count = 0 ; totalCount = 0
computerFields = {} ; breakCount = 0
print("Most commonly studied fields CTO:")
for k in fieldDict.keys():
    if breakCount < 10:
        print("{}. {}".format(str(breakCount+1), k))
        breakCount += 1
    if 'computer' in k or 'cs' == k or 'software' in k or 'data' in k or 'engine' in k:
        count += fieldDict[k]
        computerFields[k] = fieldDict[k]
    totalCount += fieldDict[k]
df_fields = pd.DataFrame.from_dict(fieldDict, orient='index', columns=['freq']).reset_index()
df_fields.head(10)
print("Percentage of CTOs that studied CS and engineering fields: {}%".format(str(100 * count/totalCount)))

founderCount = 0 ; schoolDict = {}
for founder in ceosList:
    if founder['education']:
        founderCount += 1 ; schoolFound = False
        for educ_ in founder['education']:
            school_ = educ_['school'].lower()
            if school_ not in schoolDict:
                schoolDict[school_] = 1
            else:
                schoolDict[school_] += 1
schoolDict = {k: v for k, v in sorted(schoolDict.items(), key=lambda item: item[1], reverse=True)}
df_schoolCEOs = pd.DataFrame.from_dict(schoolDict, orient='index', columns=['freq']).reset_index()
print("CEO Schools:")
print(df_schoolCEOs.head(10))

founderCount = 0 ; schoolDict = {}
for founder in ctosList:
    if founder['education']:
        founderCount += 1 ; schoolFound = False
        for educ_ in founder['education']:
            school_ = educ_['school'].lower()
            if school_ not in schoolDict:
                schoolDict[school_] = 1
            else:
                schoolDict[school_] += 1
schoolDict = {k: v for k, v in sorted(schoolDict.items(), key=lambda item: item[1], reverse=True)}
df_schoolCTOs = pd.DataFrame.from_dict(schoolDict, orient='index', columns=['freq']).reset_index()
print("CTO Schools:")
print(df_schoolCTOs.head(10))
# Out:
# 21.100917431192663 percent of CTOs have postgraduate education
# 18.202764976958523 percent of CEOs have postgraduate education
# Most commonly studied fields CEO:
# 1. computer science
# 2. economics
# 3. business administration and management, general
# 4. marketing
# 5. finance
# 6. electrical engineering
# 7. business administration
# 8. law
# 9. mathematics
# 10. international business
# Percentage of CEOs that studied CS and engineering fields: 26.658163265306122%
# Most commonly studied fields CTO:
# 1. computer science
# 2. computer engineering
# 3. electrical engineering
# 4. information technology
# 5. mechanical engineering
# 6. physics
# 7. mathematics
# 8. software engineering
# 9. computer science and engineering
# 10. electrical and computer engineering
# Percentage of CTOs that studied CS and engineering fields: 58.1578947368421%
# CEO Schools:
#                                          index  freq
# 0                          stanford university    22
# 1                                 y combinator    19
# 2        massachusetts institute of technology    14
# 3           university of california, berkeley    11
# 4                           harvard university     9
# 5        university of california, los angeles     9
# 6   university of illinois at urbana-champaign     8
# 7                      harvard business school     8
# 8                            boston university     7
# 9  columbia university in the city of new york     6
# CTO Schools:
#                                    index  freq
# 0                           y combinator    17
# 1                    stanford university    10
# 2  massachusetts institute of technology     8
# 3             carnegie mellon university     5
# 4                  university of toronto     5
# 5            technische universität wien     5
# 6                      boston university     4
# 7     the university of british columbia     4
# 8  university of california, los angeles     4
# 9      the university of texas at austin     3

# %%
'''
Employment Background (1) contd.
'''
entrepCount = 0 ; techCount = 0 ; busCount = 0 ; totalCount = 0
for i in range(len(df_pos)):
    pos = df_pos.iloc[i]
    totalCount += pos['freq']
    if 'founder' in pos['index'] or 'ceo' in pos['index'] or 'executive' in pos['index'] or 'board' in pos['index'] or 'president' in pos['index']:
        entrepCount += pos['freq']
    if ('engineer' in pos['index'] or 'cto' in pos['index'] or 'technology' in pos['index'] or 'computer' in pos['index'] or 'developer' in pos['index'] or 
        'science' in pos['index'] or 'data' in pos['index'] or 'research' in pos['index']):
        techCount += pos['freq']
    if ('business' in pos['index'] or 'analyst' in pos['index'] or 'product' in pos['index'] or 'manager' in pos['index'] or 'director' in pos['index'] or 
        'coo' in pos['index'] or 'operating' in pos['index'] or 'associate' in pos['index'] or 'financ' in pos['index'] or 'vp' in pos['index'] or 
        'consultant' in pos['index']):
        busCount += pos['freq']
print("{} percent entrepreneurial/executive".format(str(entrepCount * 100 / totalCount)))
print("{} percent tech".format(str(techCount * 100 / totalCount)))
print("{} percent business/finance/consulting".format(str(busCount * 100 / totalCount)))
# Out:
# 22.187758478081058 percent entrepreneurial/executive
# 30.262613730355667 percent tech
# 30.055831265508687 percent business/finance/consulting

# %%
'''
Employment Background
    2. Do founders have a lot of LinkedIn Connections
'''
connectDict = {} ; countDict = {} ; numFounders = 0 ; totalConnections = 0
for key in alldata.keys():
    numFounders_ = 0 
    try:
        for founder in alldata[key]['founders']:
            if founder['connections']:
                num = int([j for i in founder['connections'].split(' ') for j in i.split('+')][0])
                numFounders += 1 ; totalConnections += num
                numFounders_ += 1
                if key not in connectDict:
                    connectDict[key] = num
                else:
                    connectDict[key] += num
        connectDict[key] /= numFounders_
        countDict[key] = numFounders_
    except Exception as e:
        pass

print("Average number of connections is {}".format(str(totalConnections / numFounders)))

top100count = 0 ; top100founderCount = 0
for top_ in df1['Organization Name'][:100]:
    if top_ in connectDict:
        top100count += connectDict[top_] * countDict[top_]
        top100founderCount += countDict[top_]
print("Average number of connections in Top 100: {}".format(str(top100count / top100founderCount)))
# Out:
# Average number of connections is 468.0364479787939
# Average number of connections in Top 100: 476.81447963800906

# %%
'''
Employment Background
    3. Do founders come from certain job positions prior to starting their company? 
        - are they prior founders?
        - are they prior software engineers
'''
df_pos.head(10)
# Out:
#                       index  freq
# 0         software engineer   196
# 1                co-founder   180
# 2              board member   178
# 3                       ceo   166
# 4                   founder   143
# 5                   advisor   113
# 6                consultant    86
# 7                       cto    85
# 8                  investor    73
# 9  senior software engineer    67

# %%
'''
Employment Background
    4. Do founders come from certain companies (or industries)
'''
expDict_raw = {} ; expDict = {}
for key in alldata.keys():
    for founder in alldata[key]['founders']:
        if founder['experience']:
            for exp_ in founder['experience']:
                exp_name = exp_['companyName'].lower()
                if exp_name not in expDict_raw:
                    expDict_raw[exp_name] = 1
                else:
                    expDict_raw[exp_name] += 1
                short_name = re.split('\\s+|\\.|,', exp_name)
                for word in short_name:
                    if word in expDict.keys():
                        expDict[word] += 1
                    else:
                        expDict[word] = 1
expDict = {k: v for k, v in sorted(expDict.items(), key=lambda item: item[1], reverse=True)}
expDict;

expDict_raw = {k: v for k, v in sorted(expDict_raw.items(), key=lambda item: item[1], reverse=True)}
expDict_raw
# Out:
# {'google': 96,
#  'microsoft': 74,
#  'facebook': 41,
#  'stanford university': 40,
#  'techstars': 33,
#  'ibm': 33,
#  'apple': 27,
#  'self-employed': 25,
#  'freelance': 21,
#  'uber': 20,
#  'mckinsey & company': 20,
#  'forbes technology council': 19,
#  'goldman sachs': 19,
#  'amazon': 18,
#  'accenture': 18,
#  'entrepreneur first': 17,
#  'cisco': 16,
#  'carnegie mellon university': 15,
#  'the apache software foundation': 15,
#  'cisco systems': 15,
#  'palantir technologies': 15,
#  'salesforce': 14,
#  'atlassian': 14,
#  'forbes': 13,
#  'the boston consulting group': 13,
#  'y combinator': 12,
#  'intel corporation': 11,
#  'deloitte': 11,
#  'twitter': 10,
#  'morgan stanley': 10,
#  'various': 10,
#  'zenefits': 10,
#  'boy scouts of america': 10,
#  'oracle': 10,
#  'vmware': 10,
#  'ey': 10,
#  'harvard university': 10,
#  'massachusetts institute of technology': 9,
#  'square': 9,
#  'linkedin': 9,
#  'independent': 9,
#  'deloitte consulting': 9,
#  'box': 9,
#  'university of michigan': 9,
#  'yahoo!': 9,
#  'uc berkeley': 8,
#  'symantec': 8,
#  'zynga': 8,
#  'american express': 8,
#  'booking.com': 8,
#  'siemens': 8,
#  'cadence design systems': 8,
#  'juniper networks': 8,
#  'apple inc.': 7,
#  'self employed': 7,
#  'groupon': 7,
#  'dell': 7,
#  'adobe': 7,
#  'credit suisse': 7,
#  'zoho corporation': 7,
#  'ubs': 7,
#  'sap': 7,
#  'startup weekend': 7,
#  'mit': 7,
#  'university of toronto': 7,
#  'national technical university of athens': 7,
#  'dropbox': 6,
#  'idf': 6,
#  'microsoft corporation': 6,
#  'j.p. morgan': 6,
#  'startx.': 6,
#  'snap inc.': 6,
#  'capgemini': 6,
#  'alcatel-lucent': 6,
#  '500 startups': 6,
#  'jpmorgan chase & co.': 6,
#  'university of oxford': 6,
#  'us army': 6,
#  'stripe': 6,
#  'cornell university': 6,
#  'qualcomm': 6,
#  'university of washington': 6,
#  'solvent': 6,
#  'deutsche bank': 6,
#  'boston university': 6,
#  'doc.ai': 6,
#  'emc': 6,
#  'pricematch': 6,
#  'university of california, berkeley': 5,
#  'amazon web services': 5,
#  'coinbase': 5,
#  'ernst & young': 5,
#  'united states air force': 5,
#  'bain & company': 5,
#  'new york university': 5,
#  'ge healthcare': 5,
#  'microblink': 5,
#  'self': 5,
#  'citi': 5,
#  'airbnb': 5,
#  'national australia bank': 5,
#  'kpmg': 5,
#  'starship': 5,
#  'cowbell': 5,
#  'tableau software': 5,
#  'habitat for humanity international': 5,
#  'pwc': 5,
#  'alchemist accelerator': 5,
#  'hortonworks': 5,
#  'joist': 5,
#  'ieee': 5,
#  'nice systems': 5,
#  'infosys': 5,
#  'mit media lab': 5,
#  'inkrypt': 5,
#  'nor1': 5,
#  'genesys': 5,
#  'livemote': 5,
#  'trinity college dublin': 5,
#  'le wagon': 5,
#  'lance': 5,
#  'founder institute': 5,
#  'robust.ai': 5,
#  'brex': 5,
#  'elph': 5,
#  'massachusetts institute of technology (mit)': 5,
#  'sinch': 5,
#  'gtmhub': 5,
#  'partnerstack': 5,
#  'autodesk': 4,
#  'joyent': 4,
#  'sun microsystems': 4,
#  'israel defense forces': 4,
#  'lively': 4,
#  'vibenomics': 4,
#  'startup institute': 4,
#  'stellar health': 4,
#  'servicenow': 4,
#  'tesla motors': 4,
#  'coyote logistics': 4,
#  'pluralsight': 4,
#  'bosch': 4,
#  'sila': 4,
#  'starbucks': 4,
#  'volkswagen ag': 4,
#  'shopify': 4,
#  'nokia': 4,
#  'snapchat, inc.': 4,
#  'shyft': 4,
#  'amazon.com': 4,
#  'testlio': 4,
#  'tu berlin': 4,
#  "o'reilly media": 4,
#  'hubspot': 4,
#  'university of illinois at urbana-champaign': 4,
#  'princeton university': 4,
#  'simplynk': 4,
#  'private': 4,
#  'ca technologies': 4,
#  'united nations': 4,
#  'ubs investment bank': 4,
#  'procter & gamble': 4,
#  'tenfold': 4,
#  'the white house': 4,
#  'glide': 4,
#  'dfuse': 4,
#  'first': 4,
#  'bloobirds': 4,
#  'the saas institute': 4,
#  'allvision io': 4,
#  'wells fargo': 4,
#  'citrix': 4,
#  'the thiel foundation': 4,
#  'parsons brinckerhoff': 4,
#  'skyselect': 4,
#  'inria': 4,
#  'code intelligence gmbh': 4,
#  'blippar': 4,
#  'remberg': 4,
#  'criteo': 4,
#  'acceldata.io': 4,
#  'nvidia': 4,
#  'ericsson': 4,
#  'tonic': 4,
#  'apex trading': 4,
#  'tradiv': 4,
#  'columbia university': 4,
#  'marketinvoice': 4,
#  'lyfegen': 4,
#  'cloudbackend': 4,
#  'underscore vc': 4,
#  'jive software': 4,
#  'sciences po': 4,
#  'upflow': 4,
#  'south park commons': 4,
#  'rent the runway': 4,
#  'unilever': 4,
#  'even foundation': 4,
#  'independent consultant': 4,
#  'wisy, inc.': 4,
#  'google full-time': 4,
#  'typs': 4,
#  'instarea - big data monetization': 4,
#  'volograms': 4,
#  'rwth aachen university': 4,
#  'valued acts': 4,
#  'promile.me': 4,
#  'claimspace': 4,
#  'securitize': 4,
#  'godaddy': 4,
#  'polarr': 4,
#  'compliancequest': 4,
#  'bear robotics, inc.': 4,
#  'remine': 4,
#  'audi ag': 4,
#  'emc corporation': 4,
#  'tel aviv university': 4,
#  'dutchie': 4,
#  'inkling': 4,
#  'pixvana, inc.': 4,
#  'bank of america merrill lynch': 4,
#  'zivver': 4,
#  'clx communications ab': 4,
#  'odaseva': 4,
#  'georges.tech': 4,
#  'threads': 4,
#  'pullrequest': 4,
#  'proscia': 4,
#  'containous': 4,
#  'netuitive': 4,
#  'liberty in north korea': 4,
#  'ensodata': 4,
#  'orbita, inc.': 4,
#  'ektron': 4,
#  'disruptops': 4,
#  'amazon web services (aws) full-time': 4,
#  'yotascale': 4,
#  'ubimo': 4,
#  'yaguara': 4,
#  'skello': 4,
#  'envelio': 4,
#  'urbantz': 4,
#  'nuvia inc full-time': 3,
#  'texas instruments': 3,
#  'advanced micro devices': 3,
#  'contentstack': 3,
#  'built.io': 3,
#  'salesforce.com': 3,
#  'software ag': 3,
#  'observe.ai': 3,
#  'inmobi': 3,
#  'etsy': 3,
#  'google inc.': 3,
#  'youtube': 3,
#  'lightmatter': 3,
#  'sandia national laboratories': 3,
#  'micron technology': 3,
#  'streamlit': 3,
#  'yale university': 3,
#  'microsoft research': 3,
#  'tecton': 3,
#  'sequoia capital': 3,
#  'capital one': 3,
#  'technion - israel institute of technology': 3,
#  'redesign health': 3,
#  'habu full-time': 3,
#  'metacx': 3,
#  'deel': 3,
#  'prodperfect': 3,
#  'radar': 3,
#  'radar relay': 3,
#  'first data corporation': 3,
#  'forager': 3,
#  'everee': 3,
#  'px4': 3,
#  'the church of jesus christ of latter-day saints': 3,
#  'northeastern university': 3,
#  'flatfile inc.': 3,
#  'spectro cloud': 3,
#  'synaos gmbh': 3,
#  'peace corps': 3,
#  'freedom robotics': 3,
#  'the guardsmen': 3,
#  'marketsandmarkets™': 3,
#  'buildops': 3,
#  'shift.com': 3,
#  'capmo': 3,
#  'blocwatch inc.': 3,
#  'robocorp': 3,
#  'co–star': 3,
#  'vfiles': 3,
#  'xolo': 3,
#  'pricewaterhousecoopers': 3,
#  'psa peugeot citroën': 3,
#  'nielsen': 3,
#  'intuit': 3,
#  'big brother big sister foundation': 3,
#  'optimoroute': 3,
#  'world economic forum': 3,
#  'facilio inc.': 3,
#  'wipro technologies': 3,
#  'stravito': 3,
#  'bridgewater associates': 3,
#  'ververica | original creators of apache flink®': 3,
#  'ge energy': 3,
#  'cb insights': 3,
#  'photomath': 3,
#  'photopay': 3,
#  'seekout': 3,
#  'brandtotal': 3,
#  'blackberry': 3,
#  'jet propulsion laboratory': 3,
#  'source{d}': 3,
#  'tyba': 3,
#  'ie business school': 3,
#  'freshworks': 3,
#  'zarget': 3,
#  'bell canada': 3,
#  'fanplayr': 3,
#  'servicenow full-time': 3,
#  'ryan associates technology': 3,
#  'wealthkernel': 3,
#  'barclays capital': 3,
#  'opentable': 3,
#  'blockchain': 3,
#  'sailthru': 3,
#  'viacom': 3,
#  'university of pennsylvania': 3,
#  'liquidata inc': 3,
#  'ockam': 3,
#  'trustpair': 3,
#  'effilab': 3,
#  'placer': 3,
#  'setsail': 3,
#  'cornell tech': 3,
#  'kambr full-time': 3,
#  'casebook pbc': 3,
#  'case commons, inc.': 3,
#  'braintree': 3,
#  'hsbc': 3,
#  'glue': 3,
#  'mona labs': 3,
#  'offchain labs': 3,
#  'work4': 3,
#  'diagram ventures': 3,
#  "entrepreneurs' organization": 3,
#  'kandji': 3,
#  'redlock': 3,
#  'userzoom': 3,
#  'uplevel full-time': 3,
#  'vivun': 3,
#  'city ai': 3,
#  'sleuth full-time': 3,
#  'bcn3d technologies': 3,
#  'pixar animation studios': 3,
#  'banked': 3,
#  '10x banking': 3,
#  'dover': 3,
#  'deltabid': 3,
#  'founders pledge': 3,
#  'fuzzbuzz': 3,
#  'yeshiva university': 3,
#  'casted': 3,
#  'emarsys': 3,
#  'mosaic.tech': 3,
#  'genentech': 3,
#  'teston': 3,
#  'fullstakk marketing': 3,
#  'aol': 3,
#  'root ai': 3,
#  'soft robotics inc.': 3,
#  'fraunhofer fkie': 3,
#  'legal os': 3,
#  'exist gründerstipendium, bundesministerium für wirtschaft und technologie': 3,
#  'owkin': 3,
#  'innogy innovation hub': 3,
#  'bouncex': 3,
#  'superb ai': 3,
#  'pronto': 3,
#  'rippling': 3,
#  'the boston consulting group (bcg)': 3,
#  'debricked': 3,
#  'amdocs': 3,
#  'azarus.io': 3,
#  'sibex': 3,
#  'gleamer': 3,
#  'futurice': 3,
#  'university of waterloo': 3,
#  'iboss cybersecurity': 3,
#  'siteflow': 3,
#  'nuvia structure': 3,
#  'strix leviathan': 3,
#  'well principled': 3,
#  'cibo technologies': 3,
#  'monsanto company': 3,
#  'roche': 3,
#  'respeecher': 3,
#  'wayfair': 3,
#  'cspa': 3,
#  'jones lang lasalle': 3,
#  'oracle corporation': 3,
#  'sqreen': 3,
#  'jus mundi': 3,
#  'curiousthing.io': 3,
#  'hyper anna': 3,
#  'quantium': 3,
#  'facebook full-time': 3,
#  'ernst and young': 3,
#  'sap labs india': 3,
#  'bloomberg': 3,
#  'mensa germany': 3,
#  'bunnyshell': 3,
#  'innobyte': 3,
#  'roomdex, inc. full-time': 3,
#  'university of miami': 3,
#  'endava': 3,
#  'plain sight': 3,
#  'arachnys': 3,
#  'roivenue': 3,
#  'cross masters s.r.o.': 3,
#  'amenitiz.io': 3,
#  'bibecoffee': 3,
#  'vodafone': 3,
#  'pandora': 3,
#  'plyable': 3,
#  'tandemlaunch inc.': 3,
#  'salesright': 3,
#  'ntua': 3,
#  'arengu': 3,
#  'esimple': 3,
#  'billte': 3,
#  'shopi': 3,
#  'digitty.io gmbh': 3,
#  'bloomberg lp': 3,
#  'vistasuite': 3,
#  'cliqueshare': 3,
#  'theappshack': 3,
#  'serviceform': 3,
#  '-': 3,
#  'dockflow': 3,
#  'creditlogic': 3,
#  'kbc bank ireland': 3,
#  "l'oréal": 3,
#  'ai4': 3,
#  'worlds fair usa': 3,
#  'tellor': 3,
#  'daxia': 3,
#  'factory bucket inc': 3,
#  'instarent': 3,
#  'smiletronix': 3,
#  'dreamfactory software': 3,
#  'nationswell': 3,
#  'actiondesk': 3,
#  'freelance web development': 3,
#  'inevent inc': 3,
#  'plato': 3,
#  'localyze': 3,
#  'shipreality inc.': 3,
#  'prodigal': 3,
#  'nestor': 3,
#  'myspotit': 3,
#  'startupbootcamp': 3,
#  'edelman digital': 3,
#  'uc berkeley college of engineering': 3,
#  'zyng': 3,
#  'spice vc': 3,
#  'efounders': 3,
#  'pynk': 3,
#  'back office.co': 3,
#  'rackspace hosting': 3,
#  'erasmus universiteit rotterdam': 3,
#  'catbird seat gmbh': 3,
#  'modumate': 3,
#  'tibco software': 3,
#  'ecobot': 3,
#  '0smosis': 3,
#  'özyeğin university': 3,
#  'speaking engagements': 3,
#  'coursera': 3,
#  'routable ai': 3,
#  'hampshire college': 3,
#  'iron ox': 3,
#  'botco.ai': 3,
#  'pilota': 3,
#  'toolbx': 3,
#  'alasco': 3,
#  'personio': 3,
#  'layer': 3,
#  'augmentir': 3,
#  'a.t. kearney': 3,
#  'sony': 3,
#  'pollinate international': 3,
#  'manulife financial': 3,
#  'litmus': 3,
#  'stradigi ai': 3,
#  'level access (formerly ssb bart group)': 3,
#  'rev.com': 3,
#  'accel robotics': 3,
#  'hewlett-packard': 3,
#  'light field lab, inc.': 3,
#  'stanford university school of medicine': 3,
#  'rfpio inc.': 3,
#  'grafana labs': 3,
#  'xcalar, inc.': 3,
#  'willow garage': 3,
#  'us navy': 3,
#  'paycore': 3,
#  'clearmetal': 3,
#  'mantech international corporation': 3,
#  'bumblebee spaces': 3,
#  'georgia institute of technology': 3,
#  'banyan security': 3,
#  'refurbed': 3,
#  'armorblox': 3,
#  'bold commerce': 3,
#  'pupil': 3,
#  'frame': 3,
#  'teemo - the drive-to-store marketing platform': 3,
#  'the linux foundation': 3,
#  'zededa inc.': 3,
#  'quixey': 3,
#  'forallsecure, inc': 3,
#  'linksquares': 3,
#  'neurala': 3,
#  'babblelabs, inc.': 3,
#  'phantom auto': 3,
#  'toucan toco': 3,
#  'snips': 3,
#  'jellyfish': 3,
#  'vocus': 3,
#  'ontic technologies': 3,
#  'verint': 3,
#  'oro inc.': 3,
#  'symsoft': 3,
#  'doctrine': 3,
#  'brocade': 3,
#  'carrot': 3,
#  'treez.io': 3,
#  'machinemetrics': 3,
#  'test.ai': 3,
#  'university of california, los angeles': 3,
#  'sawyer': 3,
#  'showvine': 3,
#  'finn ai': 3,
#  'unito': 3,
#  'altspacevr': 3,
#  'agilecraft (acquired by atlassian)': 3,
#  'aclaimant': 3,
#  'swiftly, inc.': 3,
#  'coralogix': 3,
#  'algolux': 3,
#  'opsani': 3,
#  'ge': 3,
#  'opsgenie': 3,
#  'cobwebs technologies': 3,
#  'lumina networks': 3,
#  'strapi': 3,
#  'university college dublin': 3,
#  'glofox': 3,
#  'funraise inc': 3,
#  'wirex systems': 3,
#  'gem': 3,
#  'silicon valley bank': 3,
#  'accelo': 3,
#  'internetrix': 3,
#  'securosis': 3,
#  'conversion logic': 3,
#  'kinduct': 3,
#  'metricly': 3,
#  'sweepr': 3,
#  'humi': 3,
#  'corestack': 3,
#  'npm, inc.': 3,
#  'tetrascience': 3,
#  'dashdash': 3,
#  'idelic': 3,
#  'storageos': 3,
#  'snowflake': 3,
#  'stride software': 3,
#  'cyrus biotechnology': 3,
#  'clearpool group': 3,
#  'akoonu': 3,
#  'openpath': 3,
#  '2ypunto': 3,
#  '2taptap · interactive studio': 3,
#  'signaturit': 3,
#  'leasepilot': 3,
#  'redeam': 3,
#  'buddybuild.com': 3,
#  'whereismytransport': 3,
#  'labpixies': 3,
#  'streamlio (acquired by splunk)': 3,
#  'kosmix': 3,
#  'tackle.io': 3,
#  'pod': 3,
#  'gns inc.': 3,
#  'weta digital': 3,
#  'banzai': 3,
#  'unearth technologies, inc.': 3,
#  'hypertrack': 3,
#  'advizr': 3,
#  'typingdna': 3,
#  'acm, association for computing machinery': 3,
#  'sap full-time': 2,
#  'kodiak robotics': 2,
#  'bigpanda': 2,
#  'raw engineering': 2,
#  'fda': 2,
#  'practo': 2,
#  'bison trails co.': 2,
#  'hashable': 2,
#  'compound': 2,
#  'postmates': 2,
#  'safe shepherd': 2,
#  'kerauno': 2,
#  'planetscale': 2,
#  'united states digital service': 2,
#  'endorse.com': 2,
#  'paypal': 2,
#  'zoox inc.': 2,
#  'anyscale': 2,
#  'nightfall ai': 2,
#  'venrock': 2,
#  'stanford graduate school of business': 2,
#  'oxide computer company': 2,
#  'github': 2,
#  'dataguard': 2,
#  'linklaters': 2,
#  'min doktor': 2,
#  'docly': 2,
#  'persona': 2,
#  'kleiner perkins caufield & byers': 2,
#  'metropolis': 2,
#  'one': 2,
#  'myvest': 2,
#  'epsagon': 2,
#  'lyft': 2,
#  'alchemy': 2,
#  'down to lunch': 2,
#  'akamai technologies': 2,
#  'krux digital': 2,
#  'kiva.org': 2,
#  'unit 8200 - israeli intelligence corps': 2,
#  'high alpha': 2,
#  'lifeslice': 2,
#  'imperial college london': 2,
#  'ethyca': 2,
#  'brandcommerce': 2,
#  'sirona medical': 2,
#  'helmethub': 2,
#  'stroud international': 2,
#  'grax full-time': 2,
#  'digitas': 2,
#  'crossbeam': 2,
#  'philly startup leaders': 2,
#  'near': 2,
#  'gitguardian': 2,
#  'quantiops': 2,
#  'crédit agricole cib': 2,
#  'twaice technologies gmbh': 2,
#  'technical university munich': 2,
#  'freeswitch solutions llc': 2,
#  'barracuda networks': 2,
#  'signalwire': 2,
#  'chronosphere full-time': 2,
#  'dell emc': 2,
#  'aiga colorado': 2,
#  'quality health ideas, inc.': 2,
#  'something new': 2,
#  'appomni': 2,
#  'mitre': 2,
#  'one million degrees': 2,
#  'teem': 2,
#  'everee, inc.': 2,
#  'hale centre theatre': 2,
#  'dura software': 2,
#  'rackspace, the #1 managed cloud company': 2,
#  'auterion': 2,
#  'dronecode': 2,
#  '3d robotics': 2,
#  'university of california, berkeley, haas school of business': 2,
#  'eth zürich': 2,
#  'instagrid': 2,
#  'postal.io': 2,
#  'textrecruit, an icims company': 2,
#  'rivet': 2,
#  'lucid': 2,
#  'kaskada': 2,
#  'kyckglobal, inc.': 2,
#  'checkout.com': 2,
#  'consultant': 2,
#  'irobot': 2,
#  'various companies': 2,
#  'bbva': 2,
#  'simple finance': 2,
#  'envoy inc.': 2,
#  'cliqr technologies': 2,
#  'jabil': 2,
#  'shujinko': 2,
#  'pioneer square labs': 2,
#  'cardfree': 2,
#  'primary venture partners': 2,
#  'peregrine technologies': 2,
#  'special olympics': 2,
#  'daimler ag': 2,
#  'siemens management consulting': 2,
#  'trainual': 2,
#  'yec': 2,
#  'high tide adventure': 2,
#  'majelan': 2,
#  'fitbit': 2,
#  'here': 2,
#  'syncari': 2,
#  'marketo': 2,
#  'independent consulting': 2,
#  'ciena': 2,
#  'soundcommerce': 2,
#  'commercehub': 2,
#  'strala': 2,
#  'omniture': 2,
#  'acquire': 2,
#  'mu sigma': 2,
#  'samya.ai': 2,
#  'move 24/7 - on demand moving & delivery': 2,
#  'la cto forum': 2,
#  'trust.co': 2,
#  'forge platform': 2,
#  'taproot foundation': 2,
#  'trust.co full-time': 2,
#  'trust | trust.co': 2,
#  'twentieth century fox': 2,
#  'bmw group': 2,
#  'qut (queensland university of technology)': 2,
#  'athena security inc.': 2,
#  'secureclouddb full-time': 2,
#  'cloudcheckr': 2,
#  'siili solutions': 2,
#  'flexera': 2,
#  'meta saas': 2,
#  'hackajob': 2,
#  'uec.ee': 2,
#  'webmedia': 2,
#  'holded': 2,
#  'philpark': 2,
#  'espn': 2,
#  'hypori': 2,
#  'bluespace': 2,
#  'startup leadership program': 2,
#  'drust (acquired)': 2,
#  'onewealthplace': 2,
#  'blavity': 2,
#  'mailchimp': 2,
#  'quad connect': 2,
#  'fixt inc': 2,
#  'luka': 2,
#  'scholars at your service': 2,
#  'coffee mobile': 2,
#  'torch labs': 2,
#  'schlumbergersema': 2,
#  'ured za napredno računarstvo (office of advanced computing)': 2,
#  'fer': 2,
#  'worklete': 2,
#  'rabobank': 2,
#  'veracode': 2,
#  'sourceclear': 2,
#  'mcafee': 2,
#  'xertica': 2,
#  'endeavor': 2,
#  'nordstrom': 2,
#  'zulily': 2,
#  'aricent group': 2,
#  'adventnet': 2,
#  'sourcefire, inc.': 2,
#  'izettle': 2,
#  'roland berger strategy consultants': 2,
#  'the society for construction solutions (scs)': 2,
#  'adobe systems': 2,
#  'the galion project': 2,
#  'leaddesk': 2,
#  'finnish defence forces': 2,
#  'smart vision labs': 2,
#  'combagroup': 2,
#  'cgi': 2,
#  'medtronic': 2,
#  'aker solutions': 2,
#  'racuni.hr': 2,
#  'instantcom': 2,
#  'ericsson nikola tesla d.d.': 2,
#  'crayon.co': 2,
#  'ebay': 2,
#  'panoply.io': 2,
#  'mytopia': 2,
#  'metacafe': 2,
#  'ripplematch': 2,
#  'range': 2,
#  'operation wallacea': 2,
#  'nextio': 2,
#  'yandex': 2,
#  'darmiyan': 2,
#  'stanford health care': 2,
#  'kloudless, inc.': 2,
#  'kloudless': 2,
#  'nexkey, inc.': 2,
#  'infoblox': 2,
#  'euflight.de gmbh': 2,
#  'workona inc.': 2,
#  'lucid software inc.': 2,
#  'cryptomove': 2,
#  'hp': 2,
#  'agency.com': 2,
#  'worthix': 2,
#  'perq': 2,
#  'fusebill': 2,
#  'protus ip solutions': 2,
#  'lookback': 2,
#  'spotify': 2,
#  'reup education': 2,
#  'damstra technology': 2,
#  'skygiraffe (acquired by servicenow)': 2,
#  'runscope': 2,
#  'lux fund technology & solutions, inc.': 2,
#  'arthur andersen': 2,
#  'lux fund technology & solutions, llc': 2,
#  'mind foundry': 2,
#  'messengerpeople': 2,
#  'zoovu': 2,
#  'smartassistant (smart information systems)': 2,
#  'wealthsmart': 2,
#  'barclays wealth and investment management': 2,
#  'bnp paribas': 2,
#  'cloudalize': 2,
#  'datagrail': 2,
#  'direction générale du trésor (french treasury)': 2,
#  'harbor, inc.': 2,
#  'yammer, inc.': 2,
#  'accurics': 2,
#  'vision.bi': 2,
#  'saasworks': 2,
#  'convene': 2,
#  'new breed': 2,
#  'fanduel': 2,
#  'anvil foundry, inc.': 2,
#  'muze': 2,
#  'talent alpha': 2,
#  'xperiel': 2,
#  'hyperlex software': 2,
#  'réseau entreprendre paris': 2,
#  'odyssey 38': 2,
#  'panther labs': 2,
#  'verisign': 2,
#  'handle.com': 2,
#  'terratrue': 2,
#  'hogan lovells': 2,
#  'shipfix': 2,
#  'zeller full-time': 2,
#  'visa': 2,
#  'oyster™ full-time': 2,
#  'vault': 2,
#  'department for international trade (dit)': 2,
#  'urbanleap': 2,
#  'agora systems': 2,
#  '8vc': 2,
#  'upflex': 2,
#  'spark labs inc.': 2,
#  'strangeworks': 2,
#  'honest dollar': 2,
#  'big brothers big sisters of massachusetts bay': 2,
#  'grain': 2,
#  'hyro': 2,
#  'turbonomic': 2,
#  'saturn cloud': 2,
#  'revenue management systems': 2,
#  'stylerow': 2,
#  'medallia': 2,
#  'primer full-time': 2,
#  'vr ar association': 2,
#  'maintainx': 2,
#  'townsquared': 2,
#  'hockey canada': 2,
#  'xamarin': 2,
#  'invisible ai full-time': 2,
#  'luminar technologies': 2,
#  'university of virginia': 2,
#  'réseau entreprendre': 2,
#  'mindshare inc.': 2,
#  'kronologic': 2,
#  'kronologic full-time': 2,
#  'rapid7': 2,
#  'quotapath': 2,
#  'trendkite': 2,
#  'mutual mobile': 2,
#  'solidus labs': 2,
#  'brandeis university': 2,
#  'magen david adom in israel': 2,
#  'grid - the new face of spreadsheets': 2,
#  'qlik': 2,
#  'social capital lp': 2,
#  'boingo wireless': 2,
#  'aifora gmbh': 2,
#  'visionular': 2,
#  'interlaced': 2,
#  'splunk': 2,
#  'back': 2,
#  'minodes': 2,
#  'nuclio digital school': 2,
#  'tech start up advisor contract': 2,
#  'encomenda vc': 2,
#  'asc pty ltd': 2,
#  'hippo insurance': 2,
#  'sheltr': 2,
#  'instacart': 2,
#  'cvs health': 2,
#  'kaiser permanente': 2,
#  'allpoint systems, llc': 2,
#  'hulu': 2,
#  'encamp': 2,
#  'indiana university bloomington': 2,
#  'datadog': 2,
#  'yhat, inc.': 2,
#  'assembled': 2,
#  'corrux, inc.': 2,
#  'merantix': 2,
#  'tava health': 2,
#  'zuora': 2,
#  'truenorth': 2,
#  'scotty labs': 2,
#  'mutiny': 2,
#  'gusto!': 2,
#  'reciprocity, inc': 2,
#  'infoobjects inc.': 2,
#  'triggermesh': 2,
#  'mindtouch, inc.': 2,
#  'linear b': 2,
#  'nuance communications': 2,
#  'saic': 2,
#  'forbes finance council': 2,
#  'rebank': 2,
#  'mit computer science and artificial intelligence laboratory (csail)': 2,
#  'pioneer fund': 2,
#  'zycus': 2,
#  'nextmv': 2,
#  'grubhub': 2,
#  'zoomer': 2,
#  'lockheed martin': 2,
#  'hone': 2,
#  'cultureiq': 2,
#  'emotive': 2,
#  'reefer llc': 2,
#  'doselect': 2,
#  'mozilla': 2,
#  'insurami': 2,
#  'emesent': 2,
#  'csiro': 2,
#  'the world bank': 2,
#  'aisight': 2,
#  'abb': 2,
#  'startup grind': 2,
#  'rotaract': 2,
#  'doppler': 2,
#  'kleiner perkins': 2,
#  'aytoo': 2,
#  'smarterhq': 2,
#  'dandy': 2,
#  'upwest labs': 2,
#  'staytuned digital': 2,
#  'beatdapp': 2,
#  'trinity western university': 2,
#  'spiral': 2,
#  'oolong': 2,
#  'capital asset exchange & trading, llc': 2,
#  'roshi': 2,
#  'united biosource corporation': 2,
#  'iqvia': 2,
#  'zenaton': 2,
#  'travayl.com': 2,
#  'mainstreet full-time': 2,
#  'education development center': 2,
#  'rothschild & co': 2,
#  'questdb': 2,
#  'commerzbank ag': 2,
#  'yogi': 2,
#  'clarisights': 2,
#  'adwyze': 2,
#  'pubstack.io': 2,
#  'logmatic.io': 2,
#  'brown university': 2,
#  '3-a sanitary standards, inc.': 2,
#  'iatros': 2,
#  'teleclinic': 2,
#  'cobee': 2,
#  'leibniz universität hannover': 2,
#  'place technology': 2,
#  'blueprint advisory': 2,
#  'greyparrot ai': 2,
#  'academy consult münchen e.v.': 2,
#  'mediquo': 2,
#  'meetingdoctors': 2,
#  'actuate full-time': 2,
#  'wsp in australia & new zealand': 2,
#  'reejig': 2,
#  ...}

# %%
'''
Employment Background
    5. Are there certain words or phrases in a founder's prior job description that stand out
'''
expDict
# Out:
# {'': 1952,
#  'inc': 965,
#  'full-time': 606,
#  'of': 504,
#  'university': 425,
#  'the': 279,
#  '&': 231,
#  'technologies': 227,
#  '-': 218,
#  'group': 212,
#  'llc': 205,
#  'com': 184,
#  'technology': 179,
#  'ltd': 168,
#  'by': 157,
#  'software': 153,
#  'systems': 151,
#  'ai': 146,
#  'gmbh': 143,
#  'for': 140,
#  'capital': 137,
#  'corporation': 121,
#  'solutions': 118,
#  'and': 112,
#  'consulting': 110,
#  'google': 109,
#  'foundation': 109,
#  '(acquired': 108,
#  'company': 107,
#  'school': 99,
#  'labs': 98,
#  'io': 97,
#  'institute': 97,
#  'ventures': 94,
#  'health': 93,
#  'microsoft': 92,
#  'partners': 92,
#  'international': 90,
#  'a': 89,
#  'media': 88,
#  'self-employed': 82,
#  'management': 81,
#  'co': 78,
#  'research': 76,
#  'de': 75,
#  'services': 74,
#  'part-time': 72,
#  'networks': 68,
#  'digital': 67,
#  'business': 67,
#  's': 65,
#  'bank': 63,
#  'center': 62,
#  'national': 61,
#  'college': 61,
#  'stanford': 60,
#  'limited': 60,
#  'ag': 58,
#  'security': 58,
#  'tech': 53,
#  'global': 52,
#  'new': 52,
#  'financial': 50,
#  'in': 50,
#  'freelance': 48,
#  'association': 46,
#  'network': 46,
#  'facebook': 44,
#  'ibm': 44,
#  'startup': 41,
#  '/': 41,
#  'first': 41,
#  'forbes': 40,
#  'at': 40,
#  'cisco': 40,
#  'boston': 40,
#  'apple': 39,
#  'council': 39,
#  'engineering': 39,
#  'amazon': 39,
#  'design': 39,
#  'intelligence': 38,
#  'marketing': 38,
#  'medical': 37,
#  'data': 37,
#  'innovation': 37,
#  'big': 37,
#  'communications': 36,
#  'america': 36,
#  'robotics': 35,
#  'development': 35,
#  'lab': 35,
#  'web': 35,
#  'techstars': 35,
#  'united': 34,
#  'city': 34,
#  '|': 33,
#  'cloud': 32,
#  'ab': 32,
#  'investment': 32,
#  'interactive': 32,
#  'mobile': 32,
#  'corp': 32,
#  'o': 32,
#  'berkeley': 30,
#  'science': 29,
#  'it': 29,
#  'fund': 28,
#  'american': 28,
#  'society': 28,
#  'mit': 27,
#  'llp': 27,
#  'canada': 27,
#  'department': 26,
#  'education': 26,
#  'state': 26,
#  'california': 26,
#  'agency': 25,
#  'energy': 25,
#  'v': 25,
#  'red': 25,
#  'york': 25,
#  'as': 25,
#  'entrepreneur': 25,
#  'australia': 25,
#  'trading': 25,
#  'one': 24,
#  'world': 24,
#  'associates': 24,
#  'deloitte': 24,
#  'contract': 24,
#  'san': 23,
#  'morgan': 23,
#  'computer': 23,
#  'analytics': 23,
#  'commerce': 23,
#  'mckinsey': 23,
#  'venture': 23,
#  'trust': 23,
#  'israel': 22,
#  'accelerator': 22,
#  'information': 22,
#  'project': 22,
#  'app': 22,
#  'goldman': 21,
#  'sachs': 21,
#  'on': 21,
#  'care': 21,
#  '(formerly': 21,
#  'laboratory': 21,
#  'industries': 21,
#  'harvard': 21,
#  'studios': 21,
#  'e': 21,
#  'blockchain': 21,
#  'uber': 20,
#  'alliance': 20,
#  'healthcare': 20,
#  'hospital': 20,
#  'accenture': 20,
#  'games': 20,
#  'pty': 20,
#  'sciences': 20,
#  'sap': 19,
#  'salesforce': 19,
#  'massachusetts': 19,
#  'carnegie': 19,
#  'uc': 19,
#  'u': 19,
#  'apache': 19,
#  'independent': 19,
#  'forum': 19,
#  'washington': 19,
#  'intel': 18,
#  'service': 18,
#  'mellon': 18,
#  'studio': 18,
#  'club': 18,
#  'various': 18,
#  'office': 18,
#  'community': 18,
#  'real': 17,
#  'square': 17,
#  'deutsche': 17,
#  'to': 17,
#  'platform': 17,
#  'technical': 17,
#  'us': 17,
#  'holdings': 17,
#  'finance': 17,
#  'general': 17,
#  'oracle': 16,
#  'self': 16,
#  'social': 16,
#  'medicine': 16,
#  'ge': 16,
#  'academy': 16,
#  'learning': 16,
#  'b': 16,
#  'north': 16,
#  'advanced': 15,
#  'india': 15,
#  'internet': 15,
#  'd': 15,
#  'london': 15,
#  'p': 15,
#  'insurance': 15,
#  'young': 15,
#  'palantir': 15,
#  'siemens': 15,
#  'la': 15,
#  'program': 15,
#  'telecom': 15,
#  'uk': 15,
#  'enterprise': 15,
#  'investments': 15,
#  'internship': 15,
#  'atlassian': 15,
#  'law': 14,
#  'st': 14,
#  'francisco': 14,
#  'advisors': 14,
#  'net': 14,
#  'public': 14,
#  'valley': 14,
#  'blue': 14,
#  'scouts': 14,
#  'brothers': 14,
#  'columbia': 14,
#  'news': 14,
#  'holding': 14,
#  'stanley': 13,
#  'org': 13,
#  'creative': 13,
#  'centre': 13,
#  'vmware': 13,
#  'usa': 13,
#  'life': 13,
#  'park': 13,
#  'credit': 13,
#  'exchange': 13,
#  'y': 13,
#  'combinator': 13,
#  'pvt': 12,
#  'legal': 12,
#  'states': 12,
#  'street': 12,
#  'symantec': 12,
#  'dell': 12,
#  'defense': 12,
#  'high': 12,
#  'startups': 12,
#  'acquired': 12,
#  'corps': 12,
#  'industry': 12,
#  'j': 12,
#  'emc': 12,
#  'logistics': 12,
#  'asset': 12,
#  'entertainment': 12,
#  'vc': 12,
#  'trade': 12,
#  'me': 12,
#  'smart': 12,
#  'ubs': 12,
#  'enterprises': 12,
#  'box': 12,
#  'private': 12,
#  'oxford': 12,
#  'cornell': 12,
#  'michigan': 12,
#  'universität': 12,
#  'toronto': 12,
#  'cross': 12,
#  'yahoo!': 12,
#  '(now': 12,
#  'texas': 11,
#  'revenue': 11,
#  'factory': 11,
#  'employed': 11,
#  'linkedin': 11,
#  'indiana': 11,
#  'central': 11,
#  'markets': 11,
#  'house': 11,
#  'paris': 11,
#  'air': 11,
#  'france': 11,
#  'commons': 11,
#  'group)': 11,
#  'suisse': 11,
#  'open': 11,
#  'bay': 11,
#  'berlin': 11,
#  'organization': 11,
#  'i': 11,
#  'boy': 11,
#  'booking': 11,
#  'computing': 11,
#  'advisory': 11,
#  'code': 11,
#  'federal': 11,
#  'realty': 11,
#  'ey': 11,
#  'le': 11,
#  'online': 11,
#  'r': 11,
#  'system': 11,
#  'beyond': 10,
#  'founders': 10,
#  'twitter': 10,
#  'laboratories': 10,
#  'consultants': 10,
#  'estate': 10,
#  'europe': 10,
#  'securities': 10,
#  'express': 10,
#  'future': 10,
#  'music': 10,
#  'corporate': 10,
#  'quality': 10,
#  'pwc': 10,
#  'companies': 10,
#  'c': 10,
#  'adobe': 10,
#  'union': 10,
#  'zenefits': 10,
#  'capgemini': 10,
#  'arts': 10,
#  'tv': 10,
#  'artificial': 10,
#  'juniper': 10,
#  'des': 10,
#  'white': 10,
#  'visual': 10,
#  'chase': 10,
#  'srl': 10,
#  'kpmg': 10,
#  'sp': 10,
#  'z': 10,
#  'south': 10,
#  'time': 10,
#  'children': 10,
#  '–': 10,
#  'home': 10,
#  'l': 10,
#  'für': 10,
#  'samsung': 10,
#  'consultancy': 10,
#  'cambridge': 10,
#  'iq': 10,
#  'museum': 10,
#  'ireland': 10,
#  'dublin': 10,
#  'com)': 9,
#  'sa': 9,
#  'tu': 9,
#  'transportation': 9,
#  'vision': 9,
#  'silicon': 9,
#  'electronics': 9,
#  'ernst': 9,
#  'power': 9,
#  'insight': 9,
#  'angel': 9,
#  'girls': 9,
#  'snap': 9,
#  'student': 9,
#  'up': 9,
#  'innovations': 9,
#  'property': 9,
#  'ministry': 9,
#  'division': 9,
#  'banking': 9,
#  'human': 9,
#  'illinois': 9,
#  'youth': 9,
#  'ca': 9,
#  'restaurant': 9,
#  'team': 9,
#  'sisters': 9,
#  'plc': 9,
#  'western': 9,
#  'habitat': 9,
#  'culture': 9,
#  'vodafone': 9,
#  'zurich': 9,
#  'cadence': 9,
#  'tie': 9,
#  'nuvia': 8,
#  'next': 8,
#  'zynga': 8,
#  'forces': 8,
#  'alpha': 8,
#  'consultant': 8,
#  'army': 8,
#  'münchen': 8,
#  'automotive': 8,
#  'colorado': 8,
#  'tesla': 8,
#  'chicago': 8,
#  'an': 8,
#  'korea': 8,
#  'your': 8,
#  'mobility': 8,
#  'defence': 8,
#  'strategy': 8,
#  'french': 8,
#  'insights': 8,
#  'prime': 8,
#  'royal': 8,
#  'european': 8,
#  'jpmorgan': 8,
#  'worldwide': 8,
#  'space': 8,
#  'barclays': 8,
#  'citi': 8,
#  'talent': 8,
#  'case': 8,
#  'vr': 8,
#  'humanity': 8,
#  'market': 8,
#  'impact': 8,
#  'trinity': 8,
#  'british': 8,
#  'qualcomm': 8,
#  'soft': 8,
#  'entrepreneurship': 8,
#  'johns': 8,
#  'hopkins': 8,
#  'orange': 8,
#  'athens': 8,
#  'immersive': 8,
#  'et': 8,
#  'aachen': 8,
#  'georgia': 8,
#  'founder': 8,
#  'deep': 8,
#  'cybersecurity': 7,
#  'baker': 7,
#  'yale': 7,
#  'germany': 7,
#  'm': 7,
#  '2': 7,
#  '(acquired)': 7,
#  'studies': 7,
#  'automation': 7,
#  'affairs': 7,
#  'groupon': 7,
#  'work': 7,
#  'foundry': 7,
#  'radar': 7,
#  'stellar': 7,
#  'part': 7,
#  'servicenow': 7,
#  'northern': 7,
#  'angels': 7,
#  'eth': 7,
#  'bosch': 7,
#  'force': 7,
#  'volkswagen': 7,
#  'board': 7,
#  'event': 7,
#  'search': 7,
#  'commercial': 7,
#  'fox': 7,
#  'oy': 7,
#  'bain': 7,
#  'monitor': 7,
#  'economic': 7,
#  'www': 7,
#  'safety': 7,
#  'packard': 7,
#  'wipro': 7,
#  'alcatel-lucent': 7,
#  'zoho': 7,
#  'live': 7,
#  'swiss': 7,
#  'food': 7,
#  't': 7,
#  'ericsson': 7,
#  'initiative': 7,
#  'jet': 7,
#  'commission': 7,
#  'campus': 7,
#  'england': 7,
#  'wealth': 7,
#  'green': 7,
#  ')': 7,
#  '(a': 7,
#  'incorporated': 7,
#  'play': 7,
#  'rocket': 7,
#  'ar': 7,
#  'mission': 7,
#  'investor': 7,
#  'professional': 7,
#  'edge': 7,
#  'aerospace': 7,
#  'stripe': 7,
#  'good': 7,
#  'weekend': 7,
#  'now': 7,
#  '(yc': 7,
#  'greater': 7,
#  'collective': 7,
#  'hub': 7,
#  'imaging': 7,
#  'terra': 7,
#  'nice': 7,
#  'crypto': 7,
#  'sports': 7,
#  'manufacturing': 7,
#  'bloomberg': 7,
#  'hampshire': 7,
#  'access': 7,
#  'hq': 7,
#  'field': 7,
#  'asia': 7,
#  'level': 7,
#  'logic': 7,
#  'rwth': 7,
#  'ecole': 7,
#  'russia': 7,
#  'accel': 7,
#  'diego': 7,
#  'erasmus': 7,
#  'bear': 7,
#  'dynamics': 7,
#  'phantom': 7,
#  'conversionpoint': 7,
#  'instruments': 6,
#  'micro': 6,
#  'devices': 6,
#  'infosys': 6,
#  'applied': 6,
#  'dropbox': 6,
#  'pacific': 6,
#  'inria': 6,
#  'alto': 6,
#  'operations': 6,
#  'personal': 6,
#  'stack': 6,
#  'idf': 6,
#  'unit': 6,
#  'chamber': 6,
#  'partnership': 6,
#  'magento': 6,
#  'product': 6,
#  'building': 6,
#  'family': 6,
#  'ideas': 6,
#  'motors': 6,
#  '3d': 6,
#  'theatre': 6,
#  'shift': 6,
#  'church': 6,
#  'payment': 6,
#  'engine': 6,
#  'better': 6,
#  'magazine': 6,
#  'peace': 6,
#  'homes': 6,
#  'sigma': 6,
#  'tibco': 6,
#  'ebay': 6,
#  'fitness': 6,
#  'startx': 6,
#  'santa': 6,
#  'storage': 6,
#  'saas': 6,
#  'michael': 6,
#  'austin': 6,
#  'designs': 6,
#  'cancer': 6,
#  'iot': 6,
#  'bell': 6,
#  'with': 6,
#  "children's": 6,
#  'jones': 6,
#  'lane': 6,
#  '500': 6,
#  'hr': 6,
#  'point': 6,
#  'abc': 6,
#  'farm': 6,
#  'stealth': 6,
#  'citizen': 6,
#  'john': 6,
#  'administration': 6,
#  'nations': 6,
#  'harbor': 6,
#  'poland': 6,
#  'wireless': 6,
#  'motor': 6,
#  'sales': 6,
#  'starship': 6,
#  'films': 6,
#  'face': 6,
#  'lp': 6,
#  '(aquired': 6,
#  'back': 6,
#  'advisor': 6,
#  'strategic': 6,
#  'semiconductor': 6,
#  'apex': 6,
#  'my': 6,
#  'travel': 6,
#  'los': 6,
#  'sony': 6,
#  'johnson': 6,
#  'superb': 6,
#  'sk': 6,
#  'firma': 6,
#  'ieee': 6,
#  'nvidia': 6,
#  'junior': 6,
#  'iboss': 6,
#  'brain': 6,
#  'zumo': 6,
#  'training': 6,
#  'auto': 6,
#  'even': 6,
#  'water': 6,
#  'solvent': 6,
#  'universidad': 6,
#  'lynch': 6,
#  'genesys': 6,
#  'day': 6,
#  'kg': 6,
#  'esimple': 6,
#  'nhs': 6,
#  'light': 6,
#  'bureau': 6,
#  'all': 6,
#  'wagon': 6,
#  'lance': 6,
#  'tel': 6,
#  'aviv': 6,
#  'philips': 6,
#  'ssb': 6,
#  'rev': 6,
#  'solar': 6,
#  'doc': 6,
#  'navy': 6,
#  'algolux': 6,
#  'clx': 6,
#  'pricematch': 6,
#  'centers': 5,
#  'baltimore': 5,
#  'risk': 5,
#  'palo': 5,
#  'microsystems': 5,
#  'perkins': 5,
#  'alternative': 5,
#  'ux': 5,
#  'nine': 5,
#  'lux': 5,
#  'leaders': 5,
#  'here': 5,
#  'remote': 5,
#  'women': 5,
#  'coinbase': 5,
#  'metropolitan': 5,
#  'everee': 5,
#  'rackspace': 5,
#  'together': 5,
#  '3': 5,
#  'agile': 5,
#  'institut': 5,
#  'china': 5,
#  'shopify': 5,
#  'nokia': 5,
#  'southern': 5,
#  'spark': 5,
#  'entrepreneurs': 5,
#  'leadership': 5,
#  'black': 5,
#  'hewlett': 5,
#  'grid': 5,
#  'computational': 5,
#  'virtual': 5,
#  'construction': 5,
#  'league': 5,
#  'microblink': 5,
#  'hubspot': 5,
#  'think': 5,
#  'technologies)': 5,
#  'hp': 5,
#  'freshworks': 5,
#  'innovative': 5,
#  'domain': 5,
#  'bi': 5,
#  'duke': 5,
#  'advantage': 5,
#  'réseau': 5,
#  'sas': 5,
#  'airbnb': 5,
#  'linear': 5,
#  '(': 5,
#  'placer': 5,
#  'agora': 5,
#  'aviation': 5,
#  'pbc': 5,
#  'telekom': 5,
#  'virginia': 5,
#  'company)': 5,
#  'atlas': 5,
#  'hewlett-packard': 5,
#  'cowbell': 5,
#  '+': 5,
#  'start': 5,
#  'tableau': 5,
#  'biology': 5,
#  'animation': 5,
#  'partner': 5,
#  'hill': 5,
#  'alchemist': 5,
#  'pledge': 5,
#  'angeles': 5,
#  'football': 5,
#  'circle': 5,
#  'base': 5,
#  'retail': 5,
#  'native': 5,
#  'hortonworks': 5,
#  'undergraduate': 5,
#  'government': 5,
#  'norway': 5,
#  'aol': 5,
#  'brown': 5,
#  'fraunhofer': 5,
#  'rover': 5,
#  'motorola': 5,
#  'verizon': 5,
#  'criteo': 5,
#  'treasury': 5,
#  'machine': 5,
#  'joist': 5,
#  'performance': 5,
#  'federation': 5,
#  'resources': 5,
#  'radius': 5,
#  'advertising': 5,
#  '(techstars': 5,
#  'out': 5,
#  'upflow': 5,
#  'brand': 5,
#  'inkrypt': 5,
#  'warrior': 5,
#  'rent': 5,
#  'ecommerce': 5,
#  've': 5,
#  'rwe': 5,
#  'east': 5,
#  'nor1': 5,
#  'motion': 5,
#  'miami': 5,
#  'industrial': 5,
#  'achievement': 5,
#  'diagnostics': 5,
#  'livemote': 5,
#  'art': 5,
#  'seattle': 5,
#  'mcx': 5,
#  'process': 5,
#  'experience': 5,
#  'cleantech': 5,
#  'typs': 5,
#  'aiesec': 5,
#  'kbc': 5,
#  'properties': 5,
#  'epic': 5,
#  'valued': 5,
#  'acts': 5,
#  'alberta': 5,
#  'en': 5,
#  'robust': 5,
#  'layer': 5,
#  'singapore': 5,
#  'brex': 5,
#  'elph': 5,
#  'stradigi': 5,
#  '(mit)': 5,
#  'hat': 5,
#  'merrill': 5,
#  'dev': 5,
#  'a/s': 5,
#  'zivver': 5,
#  'sinch': 5,
#  'mighty': 5,
#  '(aws)': 5,
#  'ektron': 5,
#  'gtmhub': 5,
#  'streamlio': 5,
#  'partnerstack': 5,
#  'envelio': 5,
#  'autodesk': 4,
#  'built': 4,
#  'application': 4,
#  'robert': 4,
#  'maryland': 4,
#  'store': 4,
#  'grand': 4,
#  'committee': 4,
#  'district': 4,
#  'graduate': 4,
#  'joyent': 4,
#  'sun': 4,
#  'kleiner': 4,
#  'jewish': 4,
#  'lively': 4,
#  'people': 4,
#  'habu': 4,
#  'coaching': 4,
#  '8200': 4,
#  'vibenomics': 4,
#  'imperial': 4,
#  'pact': 4,
#  'munich': 4,
#  'symphony': 4,
#  'plus': 4,
#  'strategies': 4,
#  'movement': 4,
#  'language': 4,
#  'spring': 4,
#  'coyote': 4,
#  'smith': 4,
#  'pluralsight': 4,
#  'accounting': 4,
#  'utah': 4,
#  'axa': 4,
#  'direct': 4,
#  'lucid': 4,
#  'sila': 4,
#  'generation': 4,
#  'mcafee': 4,
#  'pioneer': 4,
#  'starbucks': 4,
#  'special': 4,
#  'yec': 4,
#  'js': 4,
#  'samya': 4,
#  'clubs': 4,
#  'cto': 4,
#  'forge': 4,
#  'snapchat': 4,
#  'century': 4,
#  'nova': 4,
#  'technology)': 4,
#  'minds': 4,
#  'robocorp': 4,
#  'grow': 4,
#  'peugeot': 4,
#  'nielsen': 4,
#  'intuit': 4,
#  'shyft': 4,
#  'works': 4,
#  'coffee': 4,
#  'active': 4,
#  'well': 4,
#  'buffalo': 4,
#  'powered': 4,
#  'river': 4,
#  'bolt': 4,
#  'sweden': 4,
#  'testlio': 4,
#  'berger': 4,
#  'path': 4,
#  'ververica': 4,
#  "o'reilly": 4,
#  'générale': 4,
#  'madrid': 4,
#  'pc': 4,
#  'guardian': 4,
#  'rock': 4,
#  'photomath': 4,
#  'win': 4,
#  'urbana-champaign': 4,
#  'lake': 4,
#  'princeton': 4,
#  'saint': 4,
#  'louis': 4,
#  'ny': 4,
#  'kloudless': 4,
#  'simplynk': 4,
#  'cognitive': 4,
#  'propulsion': 4,
#  'nacional': 4,
#  'mode': 4,
#  'firm': 4,
#  'ryan': 4,
#  'arthur': 4,
#  'sf': 4,
#  'emergency': 4,
#  'systems)': 4,
#  'room': 4,
#  'opentable': 4,
#  'du': 4,
#  'pennsylvania': 4,
#  'graphics': 4,
#  'secure': 4,
#  'procter': 4,
#  'gamble': 4,
#  'entreprendre': 4,
#  'tenfold': 4,
#  'growth': 4,
#  'change': 4,
#  'environmental': 4,
#  'productions': 4,
#  'paul': 4,
#  'hack': 4,
#  'kambr': 4,
#  'mango': 4,
#  'casebook': 4,
#  'dream': 4,
#  'navigation': 4,
#  'hsbc': 4,
#  'barcelona': 4,
#  'kitchen': 4,
#  'maintainx': 4,
#  'glide': 4,
#  'seat': 4,
#  '®': 4,
#  'kronologic': 4,
#  'fuel': 4,
#  'mutual': 4,
#  'david': 4,
#  'dfuse': 4,
#  'unito': 4,
#  "entrepreneurs'": 4,
#  'amp': 4,
#  'camp': 4,
#  'splunk': 4,
#  'ecosystem': 4,
#  'bloobirds': 4,
#  'allvision': 4,
#  'uplevel': 4,
#  'amdocs': 4,
#  'way': 4,
#  'rbc': 4,
#  'momentum': 4,
#  'vivun': 4,
#  'standard': 4,
#  'wells': 4,
#  'fargo': 4,
#  'citrix': 4,
#  'at&t': 4,
#  'thiel': 4,
#  'fellowship': 4,
#  'plant': 4,
#  'banked': 4,
#  '10x': 4,
#  'thales': 4,
#  'parsons': 4,
#  'brinckerhoff': 4,
#  'skyselect': 4,
#  'oü': 4,
#  'zealand': 4,
#  'pte': 4,
#  'manchester': 4,
#  'ucla': 4,
#  'pivotal': 4,
#  'emarsys': 4,
#  'banzai': 4,
#  'usc': 4,
#  'bar': 4,
#  'genentech': 4,
#  'norge': 4,
#  'root': 4,
#  'standards': 4,
#  'finn': 4,
#  'blippar': 4,
#  'greyparrot': 4,
#  'remberg': 4,
#  'consult': 4,
#  'ontario': 4,
#  'os': 4,
#  'und': 4,
#  'technologie': 4,
#  'cabinet': 4,
#  'be': 4,
#  'urban': 4,
#  'acceldata': 4,
#  '[24]7': 4,
#  'portfolio': 4,
#  'infotech': 4,
#  '(bcg)': 4,
#  'faculty': 4,
#  'lund': 4,
#  'tonic': 4,
#  'ratings': 4,
#  'sibex': 4,
#  'xdev': 4,
#  'aito': 4,
#  'belgium': 4,
#  '—': 4,
#  'bushel44': 4,
#  'tradiv': 4,
#  'siteflow': 4,
#  ...}

# %%
'''
Company Fundamentals 
    1. How important is the company's CB rank?
'''
ranks = [int(i.replace(',','')) for i in df1['CB Rank (Company)']]
print("Mean CB rank is: {}".format(np.mean(ranks)))
print("Among the top 200 companies, the mean rank is {}".format(str(np.mean(ranks[:200]))))
# Out:
# Mean CB rank is: 25734.267711598746
# Among the top 200 companies, the mean rank is 14329.065

# %%
'''
Company Fundamentals
    2. Are there keywords in a company's description?
'''
descriptionWords = {}
for des_ in df1['Description']:
    for word in re.split('\\s|\.|,',des_):
        if word:
            if word not in descriptionWords:
                descriptionWords[word] = 1
            else:
                descriptionWords[word] += 1
descriptionWords = {k: v for k, v in sorted(descriptionWords.items(), key=lambda item: item[1], reverse=True)}
descriptionWords
# Out:
# {'and': 1013,
#  'is': 775,
#  'a': 721,
#  'to': 577,
#  'for': 523,
#  'the': 470,
#  'that': 416,
#  'platform': 378,
#  'software': 301,
#  'of': 291,
#  'an': 195,
#  'in': 195,
#  'company': 162,
#  'with': 153,
#  'data': 150,
#  'management': 131,
#  'provides': 130,
#  'helps': 111,
#  'their': 103,
#  'SaaS': 101,
#  'on': 100,
#  'AI': 94,
#  'technology': 90,
#  'develops': 78,
#  'solutions': 77,
#  'companies': 76,
#  '&': 73,
#  'your': 71,
#  'businesses': 67,
#  'by': 67,
#  'digital': 63,
#  'intelligence': 62,
#  'offers': 62,
#  'business': 60,
#  'solution': 59,
#  'mobile': 57,
#  'cloud': 56,
#  'analytics': 49,
#  'enables': 47,
#  'The': 46,
#  'designed': 46,
#  'enterprise': 45,
#  'from': 45,
#  'services': 44,
#  'applications': 43,
#  'development': 43,
#  'more': 43,
#  'Platform': 43,
#  'online': 42,
#  'provider': 42,
#  'help': 42,
#  'teams': 42,
#  'service': 41,
#  'app': 40,
#  'customer': 40,
#  'marketing': 40,
#  'tools': 40,
#  'all': 40,
#  'learning': 38,
#  'based': 38,
#  'as': 38,
#  'industry': 38,
#  'manage': 38,
#  'into': 37,
#  'create': 36,
#  'make': 36,
#  'Software': 36,
#  'using': 36,
#  'allows': 35,
#  'automation': 34,
#  'sales': 34,
#  'products': 33,
#  'users': 32,
#  'through': 32,
#  'machine': 31,
#  'application': 31,
#  'better': 31,
#  'system': 30,
#  'new': 30,
#  'build': 30,
#  'cloud-based': 30,
#  'first': 30,
#  'video': 30,
#  'artificial': 29,
#  'building': 29,
#  'you': 29,
#  'way': 29,
#  'developers': 28,
#  'leading': 28,
#  'people': 28,
#  'smart': 28,
#  'operations': 28,
#  'improve': 28,
#  'A': 27,
#  'Management': 27,
#  'faster': 27,
#  'at': 26,
#  'infrastructure': 25,
#  'monitoring': 25,
#  'web': 25,
#  'global': 25,
#  'modern': 25,
#  'security': 25,
#  'startup': 25,
#  'Intelligence': 25,
#  'builds': 24,
#  'organizations': 24,
#  'performance': 24,
#  'one': 24,
#  'process': 24,
#  'insights': 24,
#  'any': 24,
#  'tool': 23,
#  'real-time': 23,
#  'most': 23,
#  'Data': 23,
#  'systems': 23,
#  'B2B': 23,
#  'providing': 23,
#  'product': 23,
#  'experience': 22,
#  'enabling': 22,
#  'computer': 22,
#  'We': 22,
#  'apps': 22,
#  '3D': 22,
#  'work': 22,
#  'developer': 21,
#  'time': 21,
#  'enterprises': 21,
#  'makes': 21,
#  'customers': 21,
#  'focused': 21,
#  'intelligent': 20,
#  'design': 20,
#  'source': 20,
#  'across': 20,
#  'generation': 20,
#  '-': 20,
#  'brands': 20,
#  'scale': 20,
#  'empowers': 20,
#  'world': 19,
#  'power': 19,
#  'use': 19,
#  'network': 19,
#  'control': 19,
#  'real': 19,
#  'decisions': 19,
#  'can': 18,
#  'automated': 18,
#  'collaboration': 18,
#  'next': 18,
#  'are': 18,
#  'IoT': 18,
#  'together': 17,
#  'financial': 17,
#  'Cloud': 17,
#  'powered': 17,
#  'easy': 17,
#  'health': 17,
#  'best': 17,
#  'marketplace': 17,
#  'virtual': 17,
#  'Mobile': 17,
#  'productivity': 16,
#  'open': 16,
#  'advanced': 16,
#  'blockchain': 16,
#  'compliance': 16,
#  'revenue': 16,
#  'specializes': 16,
#  'delivers': 16,
#  'how': 16,
#  'connects': 16,
#  'tech': 16,
#  'AI-powered': 16,
#  'Machine': 16,
#  'Learning': 16,
#  'small': 16,
#  'tracking': 16,
#  'market': 16,
#  'delivery': 16,
#  'reality': 16,
#  'it': 15,
#  'access': 15,
#  'code': 15,
#  'consumer': 15,
#  'deliver': 15,
#  'employees': 15,
#  'App': 15,
#  'powerful': 15,
#  'IT': 15,
#  'built': 15,
#  'professionals': 15,
#  'risk': 15,
#  'quality': 15,
#  'Technology': 15,
#  'Analytics': 15,
#  'content': 14,
#  'future': 14,
#  'technologies': 14,
#  'public': 14,
#  'find': 14,
#  'all-in-one': 14,
#  'information': 14,
#  'human': 14,
#  'automates': 14,
#  'developing': 14,
#  'research': 14,
#  'support': 14,
#  'without': 14,
#  'Technologies': 14,
#  'or': 14,
#  'which': 14,
#  'only': 14,
#  'autonomous': 13,
#  'uses': 13,
#  'integrated': 13,
#  'be': 13,
#  'them': 13,
#  'operates': 13,
#  'care': 13,
#  'innovative': 13,
#  'home': 13,
#  'easily': 13,
#  'engagement': 13,
#  'healthcare': 13,
#  'construction': 13,
#  'creates': 13,
#  'communication': 13,
#  'experiences': 13,
#  'legal': 13,
#  'projects': 13,
#  'data-driven': 13,
#  'Artificial': 13,
#  'clients': 13,
#  'its': 13,
#  'ai': 13,
#  'increase': 13,
#  'voice': 12,
#  'secure': 12,
#  'privacy': 12,
#  'processes': 12,
#  'testing': 12,
#  'cybersecurity': 12,
#  'vision': 12,
#  'team': 12,
#  'efficient': 12,
#  'personalized': 12,
#  'they': 12,
#  'connect': 12,
#  'community': 12,
#  'efficiency': 12,
#  'track': 12,
#  'share': 12,
#  'creating': 12,
#  'understand': 12,
#  'workforce': 12,
#  'estate': 12,
#  'optimize': 12,
#  'production': 11,
#  'run': 11,
#  'banking': 11,
#  'mission': 11,
#  'retailers': 11,
#  'payment': 11,
#  'API': 11,
#  'planning': 11,
#  'designs': 11,
#  'Automation': 11,
#  'commercial': 11,
#  'assets': 11,
#  'end-to-end': 11,
#  'simple': 11,
#  'talent': 11,
#  'need': 11,
#  'test': 11,
#  'everyone': 11,
#  'conversational': 11,
#  'workflow': 11,
#  'professional': 11,
#  'simplifies': 11,
#  'insurance': 11,
#  'training': 11,
#  'analysis': 11,
#  'manufacturing': 11,
#  'creation': 11,
#  'brings': 10,
#  'identity': 10,
#  'hardware': 10,
#  'predictive': 10,
#  'distributed': 10,
#  'automate': 10,
#  'private': 10,
#  'remote': 10,
#  'get': 10,
#  'out': 10,
#  'created': 10,
#  'native': 10,
#  'database': 10,
#  'growth': 10,
#  'safety': 10,
#  'trading': 10,
#  'Labs': 10,
#  'continuous': 10,
#  'high': 10,
#  'feedback': 10,
#  'augmented': 10,
#  'making': 10,
#  'corporate': 10,
#  'up': 10,
#  'Robotics': 9,
#  'unified': 9,
#  'workflows': 9,
#  'improves': 9,
#  'mobility': 9,
#  'operating': 9,
#  'Security': 9,
#  'hiring': 9,
#  'every': 9,
#  'over': 9,
#  'provide': 9,
#  'take': 9,
#  'events': 9,
#  'energy': 9,
#  'science': 9,
#  'environments': 9,
#  'while': 9,
#  'save': 9,
#  'helping': 9,
#  'accessible': 9,
#  "world's": 9,
#  'detection': 9,
#  'industrial': 9,
#  'managing': 9,
#  'fintech': 9,
#  'platforms': 9,
#  'large': 9,
#  'AI-based': 9,
#  'medical': 9,
#  'behavior': 9,
#  'life': 9,
#  'other': 9,
#  'easier': 9,
#  'Service': 9,
#  'Blockchain': 9,
#  'consumers': 9,
#  'accounting': 9,
#  'Systems': 9,
#  'user': 8,
#  'open-source': 8,
#  'trust': 8,
#  'live': 8,
#  'quickly': 8,
#  'industries': 8,
#  'driven': 8,
#  'event': 8,
#  'providers': 8,
#  'growing': 8,
#  'logistics': 8,
#  'storage': 8,
#  'optimization': 8,
#  'payments': 8,
#  'actionable': 8,
#  'personal': 8,
#  'property': 8,
#  'website': 8,
#  'Open': 8,
#  'space': 8,
#  'devices': 8,
#  'place': 8,
#  'what': 8,
#  'vehicle': 8,
#  'processing': 8,
#  'device': 8,
#  'complete': 8,
#  'maintenance': 8,
#  'supply': 8,
#  'engineers': 8,
#  'deployment': 8,
#  'language': 8,
#  'Enterprise': 8,
#  'field': 8,
#  'Saas': 8,
#  'internet': 8,
#  'where': 8,
#  'manages': 8,
#  'about': 8,
#  'Intelligent': 8,
#  'Inc': 8,
#  'physical': 8,
#  'world’s': 8,
#  'restaurant': 8,
#  'ecosystem': 8,
#  'markets': 8,
#  'around': 8,
#  'Smart': 8,
#  'investment': 8,
#  'social': 8,
#  'clinical': 8,
#  'order': 8,
#  'scheduling': 8,
#  'intended': 7,
#  'offering': 7,
#  'models': 7,
#  'APIs': 7,
#  'knowledge': 7,
#  'comprehensive': 7,
#  'stealth': 7,
#  'single': 7,
#  'decentralized': 7,
#  'deploy': 7,
#  'value': 7,
#  'problems': 7,
#  'io': 7,
#  'our': 7,
#  'interface': 7,
#  'streaming': 7,
#  'threat': 7,
#  'grow': 7,
#  'audio': 7,
#  'robotics': 7,
#  'entire': 7,
#  'deep': 7,
#  'suite': 7,
#  'spend': 7,
#  'contracts': 7,
#  'fast': 7,
#  'creative': 7,
#  'contract': 7,
#  'collaborate': 7,
#  'international': 7,
#  'reporting': 7,
#  'booking': 7,
#  'computing': 7,
#  'focuses': 7,
#  'monitor': 7,
#  'do': 7,
#  'costs': 7,
#  'engine': 7,
#  'asset': 7,
#  'Real': 7,
#  'accurate': 7,
#  'chain': 7,
#  'System': 7,
#  'has': 7,
#  'engineering': 7,
#  'solve': 7,
#  'anyone': 7,
#  'local': 7,
#  'Reality': 7,
#  'operators': 7,
#  'rental': 7,
#  'Monitoring': 7,
#  'game': 7,
#  'engage': 7,
#  'complex': 7,
#  'banks': 7,
#  'manufacturers': 7,
#  'patients': 7,
#  'travel': 7,
#  'visual': 7,
#  'who': 7,
#  'finance': 7,
#  'e-commerce': 7,
#  '+': 7,
#  'integration': 7,
#  'recognition': 7,
#  'Deep': 7,
#  'email': 7,
#  'HR': 7,
#  'school': 7,
#  'bring': 7,
#  'connected': 7,
#  'retail': 7,
#  'leader': 7,
#  'resources': 7,
#  'identifies': 6,
#  'so': 6,
#  'Build': 6,
#  'Company': 6,
#  'Digital': 6,
#  'interactions': 6,
#  'powering': 6,
#  'worldwide': 6,
#  'buyers': 6,
#  'payroll': 6,
#  'automatically': 6,
#  'collaborative': 6,
#  'benefits': 6,
#  'intuitive': 6,
#  'Android': 6,
#  'we': 6,
#  'advertising': 6,
#  'channels': 6,
#  'program': 6,
#  'robotic': 6,
#  'between': 6,
#  'Customer': 6,
#  'messaging': 6,
#  'Virtual': 6,
#  'office': 6,
#  'documents': 6,
#  'innovation': 6,
#  'operational': 6,
#  'money': 6,
#  'designers': 6,
#  'maximize': 6,
#  'technical': 6,
#  'skills': 6,
#  'search': 6,
#  'employee': 6,
#  'transportation': 6,
#  'equipment': 6,
#  'transform': 6,
#  'environment': 6,
#  'decision': 6,
#  'collection': 6,
#  'fraud': 6,
#  'effective': 6,
#  'cannabis': 6,
#  'chat': 6,
#  'camera': 6,
#  'custom': 6,
#  'edge': 6,
#  'cities': 6,
#  'recruiting': 6,
#  'made': 6,
#  'on-demand': 6,
#  'works': 6,
#  'Solutions': 6,
#  'contractors': 6,
#  'bringing': 6,
#  'hospitality': 6,
#  'transformation': 6,
#  'Networks': 6,
#  'location': 6,
#  'Web': 6,
#  'disease': 6,
#  'top': 5,
#  'multiple': 5,
#  'communications': 5,
#  'optimizes': 5,
#  'features': 5,
#  'existing': 5,
#  'Healthcare': 5,
#  'adoption': 5,
#  'sensitive': 5,
#  'coaching': 5,
#  'suppliers': 5,
#  'change': 5,
#  'stack': 5,
#  'dental': 5,
#  'practice': 5,
#  'enable': 5,
#  'billing': 5,
#  'retention': 5,
#  'pricing': 5,
#  'fields': 5,
#  'map': 5,
#  'Kubernetes': 5,
#  'cyber': 5,
#  'connectivity': 5,
#  'profitable': 5,
#  'each': 5,
#  'demand': 5,
#  'networks': 5,
#  'drive': 5,
#  'both': 5,
#  'such': 5,
#  'move': 5,
#  'insight': 5,
#  'DevOps': 5,
#  'wellness': 5,
#  'relationships': 5,
#  'communicate': 5,
#  'speed': 5,
#  'protect': 5,
#  'flow': 5,
#  'model': 5,
#  'capabilities': 5,
#  'Human': 5,
#  'Services': 5,
#  'partners': 5,
#  'enablement': 5,
#  'address': 5,
#  'interactive': 5,
#  'deals': 5,
#  'Building': 5,
#  'managers': 5,
#  'transforming': 5,
#  'credit': 5,
#  'safe': 5,
#  'surveillance': 5,
#  'needs': 5,
#  'games': 5,
#  'specifically': 5,
#  'Bringing': 5,
#  'problem': 5,
#  'conversations': 5,
#  'media': 5,
#  'inventory': 5,
#  'vacation': 5,
#  'tasks': 5,
#  'informed': 5,
#  'marketers': 5,
#  'recruitment': 5,
#  'medium': 5,
#  'Network': 5,
#  'predict': 5,
#  'Process': 5,
#  'available': 5,
#  'activities': 5,
#  'Experience': 5,
#  'empowering': 5,
#  'brand': 5,
#  'files': 5,
#  'doctors': 5,
#  'cost': 5,
#  'lets': 5,
#  'authentication': 5,
#  'connecting': 5,
#  'accelerate': 5,
#  'want': 5,
#  'photos': 5,
#  'store': 5,
#  'measurement': 5,
#  'critical': 5,
#  'Our': 5,
#  'points': 5,
#  'hire': 5,
#  'education': 5,
#  'New': 5,
#  'collect': 5,
#  'food': 5,
#  'leaders': 5,
#  'studio': 5,
#  'investors': 5,
#  'plans': 5,
#  'manager': 5,
#  'websites': 5,
#  'goods': 5,
#  'capture': 5,
#  'visibility': 5,
#  'approach': 5,
#  'unlock': 5,
#  'music': 5,
#  'flexible': 4,
#  'robots': 4,
#  'turning': 4,
#  'framework': 4,
#  'become': 4,
#  'compliant': 4,
#  'technological': 4,
#  'One': 4,
#  'dynamic': 4,
#  'troubleshooting': 4,
#  'no-code': 4,
#  'shopping': 4,
#  'takes': 4,
#  'focus': 4,
#  'types': 4,
#  'incentives': 4,
#  'giving': 4,
#  'same': 4,
#  'gives': 4,
#  'leads': 4,
#  'increases': 4,
#  'specialized': 4,
#  'iOS': 4,
#  'Fintech': 4,
#  'just': 4,
#  'everything': 4,
#  'scalable': 4,
#  'agencies': 4,
#  'reduce': 4,
#  'discover': 4,
#  'buy': 4,
#  'ERP': 4,
#  'driving': 4,
#  'For': 4,
#  'easy-to-use': 4,
#  'freight': 4,
#  'issues': 4,
#  'governance': 4,
#  'execution': 4,
#  'plan': 4,
#  'Talent': 4,
#  'Exchange': 4,
#  'log': 4,
#  'com': 4,
#  'ship': 4,
#  'digitizes': 4,
#  'cash': 4,
#  'play': 4,
#  'text': 4,
#  'in-house': 4,
#  'Content': 4,
#  'next-generation': 4,
#  'detect': 4,
#  'spreadsheets': 4,
#  'Estate': 4,
#  'Marketing': 4,
#  'friendly': 4,
#  'Industrial': 4,
#  'easiest': 4,
#  'Health': 4,
#  'when': 4,
#  'directly': 4,
#  'serverless': 4,
#  'Smarter': 4,
#  'Silicon': 4,
#  'Global': 4,
#  'simulation': 4,
#  '–': 4,
#  'startups': 4,
#  'candidates': 4,
#  'Live': 4,
#  'optimized': 4,
#  'attacks': 4,
#  'review': 4,
#  'automating': 4,
#  'Your': 4,
#  'electronics': 4,
#  'response': 4,
#  'buying': 4,
#  'sources': 4,
#  'purchase': 4,
#  'visualize': 4,
#  'will': 4,
#  '(AI)': 4,
#  'transparent': 4,
#  'trade': 4,
#  'observability': 4,
#  'hybrid': 4,
#  'warehouse': 4,
#  'sensor': 4,
#  'gateway': 4,
#  'real-world': 4,
#  'proactive': 4,
#  'transparency': 4,
#  'water': 4,
#  'internal': 4,
#  'project': 4,
#  'traditional': 4,
#  'repair': 4,
#  'Engineering': 4,
#  'patient': 4,
#  'state': 4,
#  '|': 4,
#  'Secure': 4,
#  'gaming': 4,
#  'Group': 4,
#  'practices': 4,
#  'developed': 4,
#  'diagnosis': 4,
#  'right': 4,
#  'Delivery': 4,
#  'expertise': 4,
#  'First': 4,
#  'delivering': 4,
#  'done': 4,
#  'keep': 4,
#  'screening': 4,
#  'fully': 4,
#  'sustainable': 4,
#  'mapping': 4,
#  'own': 4,
#  'programs': 4,
#  'enhances': 4,
#  'than': 4,
#  'videos': 4,
#  'Solution': 4,
#  'cycle': 4,
#  'gain': 4,
#  'anywhere': 4,
#  'speech': 4,
#  'proprietary': 4,
#  'acquisition': 4,
#  'Augmented': 4,
#  'students': 4,
#  'Decentralized': 4,
#  'cards': 4,
#  'smarter': 4,
#  'competitive': 4,
#  'economic': 4,
#  'Salesforce': 4,
#  'modeling': 4,
#  'indoor': 4,
#  'shipping': 4,
#  'city': 4,
#  'lenders': 4,
#  'To': 4,
#  'Marketplace': 4,
#  'Access': 4,
#  'Application': 4,
#  'strategy': 4,
#  'develop': 4,
#  'combines': 4,
#  'including': 4,
#  'Protection': 4,
#  'SaaS-based': 4,
#  'conditions': 4,
#  'popular': 4,
#  'behind': 4,
#  'offer': 4,
#  'transactions': 4,
#  'fitness': 4,
#  'accounts': 4,
#  'powers': 4,
#  'working': 4,
#  'factory': 3,
#  'Identity': 3,
#  'centers': 3,
#  'agents': 3,
#  'rate': 3,
#  'managed': 3,
#  'Computer': 3,
#  'verify': 3,
#  'identities': 3,
#  'start-up': 3,
#  'microservices': 3,
#  'expert': 3,
#  'countries': 3,
#  'success': 3,
#  'dedicated': 3,
#  'implement': 3,
#  'valuable': 3,
#  'UX': 3,
#  'frictionless': 3,
#  'stores': 3,
#  'battery': 3,
#  'analyze': 3,
#  'commerce': 3,
#  'taxes': 3,
#  'World': 3,
#  'host': 3,
#  'high-quality': 3,
#  'notifications': 3,
#  'rapid': 3,
#  'Sales': 3,
#  'Insurance': 3,
#  'Privacy': 3,
#  'B2C': 3,
#  'protects': 3,
#  'firm': 3,
#  'boost': 3,
#  '(SaaS)': 3,
#  'Payroll': 3,
#  'train': 3,
#  'entertainment': 3,
#  'Transforming': 3,
#  'click': 3,
#  'measure': 3,
#  'journey': 3,
#  'under': 3,
#  'mile': 3,
#  'orchestration': 3,
#  'matches': 3,
#  'fastest': 3,
#  'active': 3,
#  'GDPR': 3,
#  'CCPA': 3,
#  'US': 3,
#  'Latin': 3,
#  'America': 3,
#  'analyzing': 3,
#  'throughout': 3,
#  'lifecycle': 3,
#  'sale': 3,
#  'geospatial': 3,
#  'outcomes': 3,
#  'paperwork': 3,
#  'SQL': 3,
#  'highly': 3,
#  'patented': 3,
#  'Energy': 3,
#  'threats': 3,
#  'vendor': 3,
#  'bugs': 3,
#  'fix': 3,
#  'materials': 3,
#  'quantum': 3,
#  'enterprise-level': 3,
#  'Collaboration': 3,
#  'frontline': 3,
#  'know': 3,
#  'Google': 3,
#  'meetings': 3,
#  'transaction': 3,
#  'suspicious': 3,
#  'activity': 3,
#  'turn': 3,
#  'Amazon': 3,
#  'aiming': 3,
#  'spending': 3,
#  'card': 3,
#  'Cyber': 3,
#  'assistant': 3,
#  'maps': 3,
#  'midsize': 3,
#  'fleets': 3,
#  'channel': 3,
#  'leadership': 3,
#  'cloud-native': 3,
#  'Supply': 3,
#  'engines': 3,
#  'printers': 3,
#  'send': 3,
#  'exchange': 3,
#  'day': 3,
#  'applied': 3,
#  'efficiently': 3,
#  'finds': 3,
#  'sourcing': 3,
#  'scales': 3,
#  'Automated': 3,
#  'assistants': 3,
#  'action': 3,
#  'diagnostics': 3,
#  'Marketers': 3,
#  'firmware': 3,
#  'prevention': 3,
#  'orchestrate': 3,
#  'offline': 3,
#  'growers': 3,
#  'Internet': 3,
#  'waste': 3,
#  'Trade': 3,
#  'integrate': 3,
#  'Zero': 3,
#  'reliable': 3,
#  'AWS': 3,
#  'Serverless': 3,
#  'buyer': 3,
#  'unifies': 3,
#  'restaurants': 3,
#  'tax': 3,
#  'homeowners': 3,
#  'account': 3,
#  'software-as-a-service': 3,
#  'page': 3,
#  'on-premises': 3,
#  'image': 3,
#  'economy': 3,
#  'Operations': 3,
#  'cryptocurrency': 3,
#  'spreadsheet': 3,
#  'Games': 3,
#  'independent': 3,
#  'ML': 3,
#  'state-of-the-art': 3,
#  'Make': 3,
#  'conversation': 3,
#  'graphics': 3,
#  'spaces': 3,
#  'early-stage': 3,
#  'complexity': 3,
#  'Business': 3,
#  'I': 3,
#  'predicts': 3,
#  'Edge': 3,
#  'tours': 3,
#  'equity': 3,
#  'neural': 3,
#  'efforts': 3,
#  'Science': 3,
#  'debt': 3,
#  'art': 3,
#  'individuals': 3,
#  'turns': 3,
#  'crypto': 3,
#  'clinics': 3,
#  'hospitals': 3,
#  'Windows': 3,
#  'securing': 3,
#  'diseases': 3,
#  'Chain': 3,
#  'law': 3,
#  'Legal': 3,
#  'backed': 3,
#  'bank': 3,
#  'hotel': 3,
#  'Interactive': 3,
#  'documentation': 3,
#  'revolutionize': 3,
#  'goal': 3,
#  'Hire': 3,
#  'buildings': 3,
#  'Crypto': 3,
#  'Banking': 3,
#  'Payment': 3,
#  'seamless': 3,
#  'distribution': 3,
#  'Media': 3,
#  'pioneer': 3,
#  'changes': 3,
#  'portfolio': 3,
#  'conversion': 3,
#  ...}

# %%
'''
Company Fundamentals
    3. Number of founders / company location?
    Seems to be covered in General Data above
'''
df1
# Out:
#                                                Organization Name URL  \
# Organization Name
# Bright Machines    https://www.crunchbase.com/organization/bright...
# Nuvia              https://www.crunchbase.com/organization/nuvia-...
# Vianai                https://www.crunchbase.com/organization/vianai
# Kodiak Robotics    https://www.crunchbase.com/organization/kodiak...
# Contentstack       https://www.crunchbase.com/organization/conten...
# ...                                                              ...
# Certn                  https://www.crunchbase.com/organization/certn
# Workiz                https://www.crunchbase.com/organization/workiz
# Constructor.io     https://www.crunchbase.com/organization/constr...
# Lightform          https://www.crunchbase.com/organization/lightform
# Trilio             https://www.crunchbase.com/organization/trilio...
#
#                                                           Industries  \
# Organization Name
# Bright Machines    Computer, Information Technology, Machine Lear...
# Nuvia              Data Center, Electronics, Information Technolo...
# Vianai             Artificial Intelligence, Computer, Information...
# Kodiak Robotics    Autonomous Vehicles, Information Technology, L...
# Contentstack       CMS, Content, Content Delivery Network, Digita...
# ...                                                              ...
# Certn              Big Data, Information Services, Information Te...
# Workiz             CRM, Enterprise Software, Recruiting, SaaS, Sm...
# Constructor.io     Artificial Intelligence, Computer, Internet, M...
# Lightform          Art, Augmented Reality, Digital Signage, Hardw...
# Trilio                                     Cloud Computing, Software
#
#                                       Headquarters Location  \
# Organization Name
# Bright Machines    San Francisco, California, United States
# Nuvia                Santa Clara, California, United States
# Vianai                 Palo Alto, California, United States
# Kodiak Robotics    Mountain View, California, United States
# Contentstack       San Francisco, California, United States
# ...                                                     ...
# Certn                    Victoria, British Columbia, Canada
# Workiz                 San Diego, California, United States
# Constructor.io     San Francisco, California, United States
# Lightform          San Francisco, California, United States
# Trilio             Framingham, Massachusetts, United States
#
#                                                          Description  \
# Organization Name
# Bright Machines    Bright Machines brings together flexible facto...
# Nuvia              Nuvia develops processors intended to create h...
# Vianai             Vianai provides enterprise artificial intellig...
# Kodiak Robotics    Kodiak Robotics develops autonomous technology...
# Contentstack       Contentstack develops a cloud based content ma...
# ...                                                              ...
# Certn              Certn is a fast, simple, comprehensive solutio...
# Workiz             Workiz is the the only field service managemen...
# Constructor.io     AI-first search and product discovery that inc...
# Lightform          Lightform is the first computer made for proje...
# Trilio             Cloud-Native Data Protection for Kubernetes, O...
#
#                    Last Funding Amount Last Funding Amount Currency  \
# Organization Name
# Bright Machines            179000000.0                          USD
# Nuvia                       53000000.0                          USD
# Vianai                      50000000.0                          USD
# Kodiak Robotics             40000000.0                          USD
# Contentstack                31500000.0                          USD
# ...                                ...                          ...
# Certn                        5000000.0                          USD
# Workiz                       5000000.0                          USD
# Constructor.io               5000000.0                          USD
# Lightform                    5000000.0                          USD
# Trilio                       5000000.0                          USD
#
#                    Last Funding Amount Currency (in USD) Last Funding Type  \
# Organization Name
# Bright Machines                              179000000.0          Series A
# Nuvia                                         53000000.0          Series A
# Vianai                                        50000000.0              Seed
# Kodiak Robotics                               40000000.0          Series A
# Contentstack                                  31500000.0          Series A
# ...                                                  ...               ...
# Certn                                          5000000.0              Seed
# Workiz                                         5000000.0          Series A
# Constructor.io                                 5000000.0              Seed
# Lightform                                      5000000.0              Seed
# Trilio                                         5000000.0          Series A
#
#                   CB Rank (Company)  Number of Funding Rounds  \
# Organization Name
# Bright Machines              27,640                         1
# Nuvia                         3,520                         1
# Vianai                        7,761                         1
# Kodiak Robotics              32,222                         1
# Contentstack                  4,025                         2
# ...                             ...                       ...
# Certn                         9,928                         3
# Workiz                       10,058                         4
# Constructor.io               10,326                         2
# Lightform                    10,369                         4
# Trilio                       10,528                         1
#
#                                                             LinkedIn  \
# Organization Name
# Bright Machines    https://www.linkedin.com/company/bright-machines/
# Nuvia                     https://www.linkedin.com/company/nuviainc/
# Vianai                      https://www.linkedin.com/company/vianai/
# Kodiak Robotics     https://www.linkedin.com/company/kodiakrobotics/
# Contentstack          https://www.linkedin.com/company/contentstack/
# ...                                                              ...
# Certn                https://www.linkedin.com/company-beta/17891142/
# Workiz                   https://www.linkedin.com/company/workizinc/
# Constructor.io      https://www.linkedin.com/company/constructor-io/
# Lightform                 https://www.linkedin.com/company/lightform
# Trilio                       https://www.linkedin.com/company/trilio
#
#                                           Website  \
# Organization Name
# Bright Machines    https://www.brightmachines.com
# Nuvia                       https://nuviainc.com/
# Vianai                       https://www.vian.ai/
# Kodiak Robotics              http://www.kodiak.ai
# Contentstack         http://www.contentstack.com/
# ...                                           ...
# Certn                         http://www.certn.co
# Workiz                         https://workiz.com
# Constructor.io         https://www.constructor.io
# Lightform                   https://lightform.com
# Trilio                      https://www.trilio.io
#
#                                                        Founders  \
# Organization Name
# Bright Machines                                    Amar Hanspal
# Nuvia              Gerard Williams III, John Bruno, Manu Gulati
# Vianai                                             Vishal Sikka
# Kodiak Robotics                         Don Burnette, Paz Eshel
# Contentstack          Matthew Baier, Neha Sampat, Nishant Patel
# ...                                                         ...
# Certn                  Andrew McLeod, Evan Dalton, Owen Madrick
# Workiz                Erez Marom, Idan Kadosh, Saar Kohanovitch
# Constructor.io                  Dan McCormick, Eli Finkelshteyn
# Lightform             Brett Jones, Kevin Karsch, Rajinder Sodhi
# Trilio               Giri Basava, Murali Balcha, Sanjay Baronia
#
#                   Organization Name
# Organization Name
# Bright Machines     Bright Machines
# Nuvia                         Nuvia
# Vianai                       Vianai
# Kodiak Robotics     Kodiak Robotics
# Contentstack           Contentstack
# ...                             ...
# Certn                         Certn
# Workiz                       Workiz
# Constructor.io       Constructor.io
# Lightform                 Lightform
# Trilio                       Trilio
#
# [1595 rows x 14 columns]

# %%
''' Saves the extracted data to a CSV'''

df_schools = pd.DataFrame.from_dict(schools, orient='index', columns=['freq'])
df_schools.sort_values(['freq'], ascending=False).to_csv('schools.csv')

df_fields = pd.DataFrame.from_dict(fields, orient='index', columns=['freq'])
df_fields.sort_values(['freq'], ascending=False).to_csv('fields.csv')

df_compnames = pd.DataFrame.from_dict(companynames, orient='index', columns=['freq'])
df_compnames.sort_values(['freq'], ascending=False).to_csv('companynames.csv')

df_titles = pd.DataFrame.from_dict(jobtitle, orient='index', columns=['freq'])
df_titles.sort_values(['freq'], ascending=False).to_csv('titles.csv')
