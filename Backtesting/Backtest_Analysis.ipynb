# %%
# Import statements
import pandas as pd
import numpy as np 
import csv 
import json
import re
import math

# %%
'''
Loads the dataframe from Query 1 and Query 2 and merges + drops duplicates and NaNs
    @param: csv1: path to CSV 1 (formed by Query 1)
    @param: csv2: path to CSV 2 (formed by Query 2)
    @return: df1: a merged dataframe of csv1 and csv2
'''
def loadBacktestData(csv1, csv2):
    df1 = pd.read_csv(csv1)
    df2 = pd.read_csv(csv2)
    df1 = df1.append(df2)
    df1_ = df1.drop_duplicates(subset=['Organization Name'])
    df1 = df1_[df1_.Founders.notna()]
    df1 = df1[df1.LinkedIn.notna()]
    df1 = df1.reset_index()
    for i in range(len(df1)):
        if df1.iloc[i].LinkedIn.count('about') > 0:
            df1['LinkedIn'][i] = df1['LinkedIn'][i].split('about')[0]
    df1 = df1.set_index('Organization Name')
    df1 = df1.drop('index', 1)
    df1['Organization Name'] = df1.index
    df1_ = df1_.set_index('Organization Name')
    return df1, df1_

# Loads and combines both CSVs into df1 dataframe
df1, df1_ = loadBacktestData('FailedCompanies.csv', 'notFundedCompanies.csv')
# Out:
# /Users/mymacbook/.local/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
'''
Method to save the company data as a txt file (loadable as JSON)
    @param: data: company_data dictionary of Company objects
    @return: None
'''
def saveData(data, fileName):
    data_json = json.dumps(data, default=lambda x: x.__dict__)
    with open(fileName, 'w') as outfile:
        json.dump(data_json, outfile)

'''
Method to load company data into a dictionary (same structure as Company object)
    @param: dataFile: string path to saved txt file
    @return: dataDict: a dictionary with the same structure as a Company object
'''
def loadData(dataFile):
    with open(dataFile) as json_file:
        data = json.load(json_file)
    dataDict = json.loads(data)
    return dataDict

# %%
alldata = loadData('faileddata_final.txt')

# %%
'''
Structure of Company Dictionary Entry:
    @name - string for the company's name
    @description - string for a company description
    @founders - list of founder dictionaries (single founders)
        Structure of Founder Dictionary Entry
            @name - string for the founder's name
            @connections - string for the founder's # of connections
            @location - string for the founder's location 
            @education - list of education dictionaries (single education experiences)
                Structure of Education Dictionary Entry
                    @school - string for the school name
                    @degree - string for the degree objective (i.e. BS / BA)
                    @field - string for the field studied (i.e. Computer Science)
            @experience - list of experience dictionaries (single experiences)
                Structure of Experience Dictionary Entry
                    @companyName - string for the company's name
                    @title - string for the position held at the company
                    @dates - string for the dates worked at the company (i.e. May 2000 - Jun 2000)
    @industries - list of strings with the industries the company is involved in 
    @website - string for the company's website
    @lastStage - string for the last stage of funding received (i.e. Series A)
    @linkedin - string for the URL of the company's LI profile
    @location - string for the company's HQ location
'''
pass

# %%
'''
Data Validation: Location
    Please note: county can also mean 'state'
'''
def dataValidateLocation(df1, df1_):
    drop_city = {} ; drop_country = {} ; keep_city = {} ; keep_country = {}
    drop_county = {} ; keep_county = {}
    for i in range(len(df1_)):
        split_item = df1_.iloc[i]['Headquarters Location'].split(',')
        if df1_.index[i] not in alldata:
            if split_item[0] not in drop_city:
                drop_city[split_item[0]] = 1
            else:
                drop_city[split_item[0]] += 1
            if split_item[-1] not in drop_country:
                drop_country[split_item[-1]] = 1
            else:
                drop_country[split_item[-1]] += 1
            if split_item[1] not in drop_county:
                drop_county[split_item[1]] = 1
            else:
                drop_county[split_item[1]] += 1
        else:
            if split_item[0] not in keep_city:
                keep_city[split_item[0]] = 1
            else:
                keep_city[split_item[0]] += 1
            if split_item[-1] not in keep_country:
                keep_country[split_item[-1]] = 1
            else:
                keep_country[split_item[-1]] += 1
            if split_item[1] not in keep_county:
                keep_county[split_item[1]] = 1
            else:
                keep_county[split_item[1]] += 1

    drop_city = {k: v for k, v in sorted(drop_city.items(), key=lambda item: item[1], reverse=True)}
    drop_country = {k: v for k, v in sorted(drop_country.items(), key=lambda item: item[1], reverse=True)}
    drop_county = {k: v for k, v in sorted(drop_county.items(), key=lambda item: item[1], reverse=True)}
    keep_country = {k: v for k, v in sorted(keep_country.items(), key=lambda item: item[1], reverse=True)}
    keep_city = {k: v for k, v in sorted(keep_city.items(), key=lambda item: item[1], reverse=True)}
    keep_county = {k: v for k, v in sorted(keep_county.items(), key=lambda item: item[1], reverse=True)}

    for (i,j) in [(drop_country, keep_country), (drop_city, keep_city), (drop_county, keep_county)]:
        df_1 = pd.DataFrame.from_dict(i, orient='index', columns=['freq']).reset_index()
        df_2 = pd.DataFrame.from_dict(j, orient='index', columns=['freq']).reset_index()
        df_item = pd.merge(df_1, df_2, on='index')
        df_item.columns = ['name', 'dropped', 'kept']
        df_item['dropped'] /= df_item['dropped'].sum()
        df_item['kept'] /= df_item['kept'].sum()
        df_item.set_index(['name'])
    return df_item

df_item = dataValidateLocation(df1, df1_)
print("Differences between Dropped & Kept Data:")
print(df_item.head(10))
# Out:
# Differences between Dropped & Kept Data:
#           name   dropped      kept
# 0   California  0.220736  0.204255
# 1      England  0.076923  0.085106
# 2        Texas  0.056856  0.029787
# 3     New York  0.050167  0.069504
# 4      Florida  0.033445  0.025532
# 5      Ontario  0.026756  0.031206
# 6     Colorado  0.023411  0.021277
# 7     Delaware  0.023411  0.011348
# 8       Berlin  0.023411  0.019858
# 9   Washington  0.020067  0.024113

# %%
'''
Data Validation: Industries
'''
def dataValidateIndustries(df1, df1_):
    drop_industries = {}
    for name_ in df1_.index:
        for ind_ in [i.strip() for i in df1_.loc[name_]['Industries'].split(',')]:
            if ind_ not in drop_industries:
                drop_industries[ind_] = 1
            else:
                drop_industries[ind_] += 1
    drop_industries = {k: v for k, v in sorted(drop_industries.items(), key=lambda item: item[1], reverse=True)} 
    df_dropIndustries = pd.DataFrame.from_dict(drop_industries, orient='index', columns=['freq']).reset_index()

    kept_industries = {}
    for name_ in alldata.keys():
        for ind_ in [i.strip() for i in df1.loc[name_]['Industries'].split(',')]:
            if ind_ not in kept_industries:
                kept_industries[ind_] = 1
            else:
                kept_industries[ind_] += 1
    kept_industries = {k: v for k, v in sorted(kept_industries.items(), key=lambda item: item[1], reverse=True)}

    # Brings it into a dataframe
    df_keptIndustries = pd.DataFrame.from_dict(kept_industries, orient='index', columns=['freq']).reset_index()
    df_industries = pd.merge(df_dropIndustries, df_keptIndustries, on='index')
    df_industries.columns = ['name', 'dropped', 'kept']
    df_industries['dropped'] /= df_industries['dropped'].sum()
    df_industries['kept'] /= df_industries['kept'].sum()
    df_industries.set_index(['name'])
    return df_industries

df_industries = dataValidateIndustries(df1, df1_)
print("Differences between Dropped & Kept Data:")
df_industries.head(10)
# Out:
# Differences between Dropped & Kept Data:
#                       name   dropped      kept
# 0                 Software  0.194694  0.188830
# 1   Information Technology  0.071197  0.071375
# 2                     SaaS  0.053827  0.053594
# 3                 Internet  0.033594  0.033058
# 4              Mobile Apps  0.021187  0.019534
# 5                      B2B  0.019851  0.020786
# 6                     Apps  0.019088  0.015778
# 7                   Mobile  0.018324  0.017280
# 8  Artificial Intelligence  0.017942  0.017531
# 9               E-Commerce  0.017942  0.016779

# %%
'''
General Data:
    # of Founders
    % Female Founders
    Median Funding Amount
'''
# Import Statement
import gender_guesser.detector as gender

def dataGender(df1):
    d = gender.Detector()
    numFounders = [] ; numFoundersDict = {} ; fundingAmount = [] ; genderDict = {} ;
    femaleComp = 0 ; totalComp = 0
    for i in range(len(df1)):
        founders_ = df1.iloc[i]['Founders'].split(',')
        amount_ = df1.iloc[i]['Last Funding Amount Currency (in USD)']
        if founders_:
            numFounders.append(len(founders_))
            hasWomen = False ; totalComp += 1
            for founder in founders_:
                founder = founder.strip()
                if founder:
                    name = founder.split(' ')[0].strip()
                    gen_ = d.get_gender(name)
                    if gen_ not in genderDict:
                        genderDict[gen_] = 1
                    else:
                        genderDict[gen_] += 1
                    if not hasWomen:
                        if gen_ == "mostly_female" or gen_ == "female":
                            femaleComp += 1
                            hasWomen = True
        if amount_ and not math.isnan(amount_):
            try:
                fundingAmount.append(int(amount_))
            except:
                pass
    return numFounders, fundingAmount, genderDict, femaleComp, totalComp

numFounders, fundingAmount, genderDict, femaleComp, totalComp = dataGender(df1)
print("Average number of founders is {}".format(str(np.mean(numFounders))))
print("Median number of founders is {}".format(str(np.median(numFounders))))
print("Mean funding amount is ${}".format(str(np.mean(fundingAmount))))
print("Median funding amount is ${}".format(str(np.median(fundingAmount))))
print(genderDict)
print("At least 1 female founder: {}".format(str((femaleComp + (genderDict['andy']/2))/totalComp)))
# Out:
# Average number of founders is 1.607843137254902
# Median number of founders is 1.0
# Mean funding amount is $1674604.5603448276
# Median funding amount is $422500.0
# {'female': 155, 'mostly_male': 60, 'male': 1061, 'unknown': 173, 'andy': 8, 'mostly_female': 19}
# At least 1 female founder: 0.1644880174291939

# %%
'''
General Data:
    Number of Founders by region
'''

def dataRegion(df1, df1_):
    countryFounders = {} ; countryByFounders = {}
    for i in range(len(df1)):
        founders_ = len(df1.iloc[i]['Founders'].split(','))
        country_ = df1_.iloc[i]['Headquarters Location'].split(',')[-1]
        if not country_ in countryFounders:
            countryFounders[country_] = []
            countryFounders[country_].append(founders_)
        else:
            countryFounders[country_].append(founders_)
        if not country_ in countryByFounders:
            countryByFounders[country_] = founders_
        else:
            countryByFounders[country_] += founders_
    averageFounders = {}
    for country_ in countryFounders.keys():
        averageFounders[country_] = np.mean(countryFounders[country_])
    averageFounders = {k: v for k, v in sorted(averageFounders.items(), key=lambda item: item[1], reverse=True)}                   
    countryByFounders = {k: v for k, v in sorted(countryByFounders.items(), key=lambda item: item[1], reverse=True)}
    df_countryFounders = pd.DataFrame.from_dict(countryByFounders, orient='index', columns=['freq']).reset_index()
    df_averageFounders = pd.DataFrame.from_dict(averageFounders, orient='index', columns=['freq']).reset_index()
    df_numFounders = pd.merge(df_countryFounders, df_averageFounders, on='index')
    df_numFounders.columns = ['name', 'total', 'average']
    return df_numFounders

df_numFounders = dataRegion(df1, df1_)
print("Founders by region:")
print(df_numFounders.head(10))
# Out:
# Founders by region:
#                name  total   average
# 0     United States    824  1.698969
# 1    United Kingdom    148  1.510204
# 2            Canada     85  1.634615
# 3           Germany     55  1.617647
# 4            France     44  1.571429
# 5         Australia     31  1.550000
# 6             Spain     28  1.555556
# 7   The Netherlands     24  1.600000
# 8       Switzerland     23  1.642857
# 9           Romania     19  1.900000

# %%
import statsmodels.api as sm
from matplotlib import pyplot as plt
'''
General Data
    Regress funding against CB rank
'''
def regressCB(df1):
    X = [] ; Y = []
    for i in range(len(df1)):
        pos = df1.iloc[i]
        if not math.isnan(pos['Last Funding Amount Currency (in USD)']):
            y = pos['Last Funding Amount Currency (in USD)']
            x = int(pos['CB Rank (Company)'].replace(',',''))
            X.append(x)
            Y.append(y)
    plt.xscale('log') ; plt.yscale('log') ; plt.scatter(X, Y) 
    plt.xlabel('CB Rank') ; plt.ylabel('Amount Raised') ; 
    plt.title('CB Rank vs. Amount Raised (USD)') ; plt.show()
    X = sm.add_constant(X)
    model = sm.OLS(Y, X).fit()
    return model

model = regressCB(df1)
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.175
# Model:                            OLS   Adj. R-squared:                  0.167
# Method:                 Least Squares   F-statistic:                     24.13
# Date:                Thu, 13 Aug 2020   Prob (F-statistic):           3.03e-06
# Time:                        10:31:39   Log-Likelihood:                -1881.4
# No. Observations:                 116   AIC:                             3767.
# Df Residuals:                     114   BIC:                             3772.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        3.72e+06   4.86e+05      7.654      0.000    2.76e+06    4.68e+06
# x1           -28.6781      5.838     -4.913      0.000     -40.242     -17.114
# ==============================================================================
# Omnibus:                       76.926   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              300.894
# Skew:                           2.506   Prob(JB):                     4.59e-66
# Kurtosis:                       9.093   Cond. No.                     1.61e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.61e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
'''
Data Validation: Rounds
'''
def dataRounds(df1_):
    keptRoundNames = {} ; droppedRoundNames = {}
    for name_ in df1_.index:
        round_ = df1_.loc[name_]['Last Funding Type']
        if name_ not in alldata.keys():
            if round_ not in droppedRoundNames:
                droppedRoundNames[round_] = 1
            else:
                droppedRoundNames[round_] += 1
        else:
            if round_ not in keptRoundNames:
                keptRoundNames[round_] = 1
            else:
                keptRoundNames[round_] += 1
    return droppedRoundNames, keptRoundNames

droppedRoundNames, keptRoundNames = dataRounds(df1_)
print("Dropped vs. Kept Rounds Composition")
print("Dropped round: {}".format(str(droppedRoundNames)))
print("Kept round: {}".format(str(keptRoundNames)))
# Out:
# Dropped vs. Kept Rounds Composition
# Dropped round: {'Series A': 7, 'Seed': 73, 'Pre-Seed': 3, nan: 237}
# Kept round: {'Series A': 23, 'Seed': 125, 'Pre-Seed': 7, nan: 763}

# %%
'''
Loads top schools data
'''
topSchools = pd.read_csv('topSchools.csv', index_col="Score_Rank")
topSchools = topSchools[['University', 'General_name']].head(100)

# %%
'''
Pedigree
    1. Do the majority of successful founders attend a top university?
'''
def pedigreeUniversity(alldata, topSchools):
    topCount = 0 ; schoolDict = {} ; founderCount = 0 ; schoolFound = False
    for key in alldata.keys():
        if alldata[key]['founders']:
            for founder in alldata[key]['founders']:
                if founder['education']:
                    founderCount += 1 ; schoolFound = False
                    for educ_ in founder['education']:
                        school_ = educ_['school'].lower()
                        if school_ not in schoolDict:
                            schoolDict[school_] = 1
                        else:
                            schoolDict[school_] += 1
                        if not schoolFound:
                            for topSchool_ in topSchools['University']:
                                if school_ in topSchool_.lower():
                                    topCount += 1
                                    schoolFound = True
                                    break
                        if not schoolFound:
                            for topSchool_ in topSchools['General_name']:
                                if topSchool_ in school_.lower():
                                    topCount += 1
                                    schoolFound = True
                                    break
    schoolDict = {k: v for k, v in sorted(schoolDict.items(), key=lambda item: item[1], reverse=True)}
    return schoolDict, topCount, founderCount

schoolDict, topCount, founderCount = pedigreeUniversity(alldata, topSchools)
print("{} % of founders attended a Top 100 School at some point in their education".format(str(topCount / founderCount * 100)))

print("Top schools attended:")
count = 1
for k in schoolDict.keys():
    if count <= 10:
        print("{}. {}".format(str(count), k))
        count += 1
    else:
        break

df_school = pd.DataFrame.from_dict(schoolDict, orient='index', columns=['freq']).reset_index()
# Out:
# 28.460686600221486 % of founders attended a Top 100 School at some point in their education
# Top schools attended:
# 1. university of alberta
# 2. stanford university
# 3. harvard university
# 4. massachusetts institute of technology
# 5. wroclaw university of science and technology
# 6. university of california, berkeley
# 7. georgia institute of technology
# 8. new york university
# 9. universitatea „babeș-bolyai” din cluj-napoca
# 10. copenhagen business school

# %%
'''
Pedigree
    2. Do the majority of successful founders attend graduate school?
'''
degreeDict = {} ; degreeCount = 0 ; gradCount = 0

def checkGraduateEducation(founder, degreeDict, degreeCount):
    if founder['education']:
        checkDegree = True
        for educ_ in founder['education']:
            if educ_['degree']:
                deg_ = educ_['degree'].lower()
                if checkDegree:
                    degreeCount += 1
                    checkDegree = False
                if deg_ not in degreeDict:
                    degreeDict[deg_] = 1
                else:
                    degreeDict[deg_] += 1
    return degreeDict, degreeCount

for key in alldata.keys():
    if alldata[key]['founders']:
        for founder in alldata[key]['founders']:
            degreeDict, degreeCount = checkGraduateEducation(founder, degreeDict, degreeCount)

degreeDict = {k: v for k, v in sorted(degreeDict.items(), key=lambda item: item[1], reverse=True)}  
for key in degreeDict.keys():
    if key in ['mba', 'ms', 'msc', 'ph.d', 'phd', 'ma', 'jd', 'ph.d', 'md', 'mse', 'meng'] or 'master' in key or 'm.' in key or 'doctor' in key:
        gradCount += 1
print("{} percent of founders have postgraduate education".format(str(gradCount / degreeCount * 100)))
# Out:
# 15.679012345679014 percent of founders have postgraduate education

# %%
'''
Pedigree
    3. Do successful founders study certain fields over others?
'''
fieldDict = {}

def getFields(founder, fieldDict):
    if founder['education']:
        for educ_ in founder['education']:
            if educ_['field']:
                field = educ_['field'].lower()
                if field not in fieldDict:
                    fieldDict[field] = 1
                else:
                    fieldDict[field] += 1
    return fieldDict

for key in alldata.keys():
    if alldata[key]['founders']:
        for founder in alldata[key]['founders']:
            fieldDict = getFields(founder, fieldDict)

fieldDict = {k: v for k, v in sorted(fieldDict.items(), key=lambda item: item[1], reverse=True)}
count = 0 ; totalCount = 0
computerFields = {} ; breakCount = 0
print("Most commonly studied fields:")
for k in fieldDict.keys():
    if breakCount < 10:
        print("{}. {}".format(str(breakCount+1), k))
        breakCount += 1
    if 'computer' in k:
        count += fieldDict[k]
        computerFields[k] = fieldDict[k]
    totalCount += fieldDict[k]
df_fields = pd.DataFrame.from_dict(fieldDict, orient='index', columns=['freq']).reset_index()
df_fields.head(10)
print("Percentage of founders that studied CS and related fields: {}%".format(str(100 * count/totalCount)))
# Out:
# Most commonly studied fields:
# 1. computer science
# 2. business administration and management, general
# 3. economics
# 4. mechanical engineering
# 5. finance
# 6. computer engineering
# 7. information technology
# 8. computer software engineering
# 9. marketing
# 10. physics
# Percentage of founders that studied CS and related fields: 16.25746516257465%

# %%
'''
Employment Background
    1. Do most founders have experience at startups (CEO, CFO, CTO, COO, Founder)
'''
posDict = {} ; ceosList = [] ; ctosList = []
for key in alldata.keys():
    if alldata[key]['founders']:
        for founder in alldata[key]['founders']:
            if founder['experience']:
                ceoCheck = False ; ctoCheck = False
                for exp_ in founder['experience']:
                    if (not key.split(' ')[0] in exp_['companyName']):
                        if exp_['title']:
                            if 'founder' in exp_['title'].lower():
                                pass
                            else:
                                pos = exp_['title'].lower()
                                if pos not in posDict:
                                    posDict[pos] = 1
                                else:
                                    posDict[pos] += 1
                            if not ceoCheck:
                                if 'ceo' in exp_['title'].lower() or 'executive officer' in exp_['title'].lower():
                                    ceosList.append(founder)
                                    ceoCheck = True
                            if not ctoCheck:
                                if 'cto' == exp_['title'].lower() or ' cto' in exp_['title'].lower() or 'cto ' in exp_['title'].lower() or 'technology officer' in exp_['title'].lower() or 'technical officer' in exp_['title'].lower():
                                    ctosList.append(founder)
                                    ctoCheck = True
posDict = {k: v for k, v in sorted(posDict.items(), key=lambda item: item[1], reverse=True)}

df_pos = pd.DataFrame.from_dict(posDict, orient='index', columns=['freq']).reset_index()
print("Previous titles held by founders:")
df_pos.head(10)
# Out:
# Previous titles held by founders:
#                index  freq
# 0  software engineer    45
# 1                ceo    36
# 2              owner    30
# 3       board member    29
# 4             mentor    29
# 5            advisor    29
# 6  managing director    27
# 7           director    25
# 8          president    23
# 9    project manager    22

# %%
'''
Pedigree & Employment:
    Profiles of CEOs vs. CTOs
'''
degreeDict = {} ; degreeCount = 0 ; gradCount = 0
for cto in ctosList:
    degreeDict, degreeCount = checkGraduateEducation(cto, degreeDict, degreeCount)
    
degreeDict = {k: v for k, v in sorted(degreeDict.items(), key=lambda item: item[1], reverse=True)}  
for key in degreeDict.keys():
    if key in ['mba', 'ms', 'msc', 'ph.d', 'phd', 'ma', 'jd', 'ph.d', 'md', 'mse', 'meng'] or 'master' in key or 'm.' in key or 'doctor' in key:
        gradCount += 1
print("{} percent of CTOs have postgraduate education".format(str(gradCount / degreeCount * 100)))

degreeDict = {} ; degreeCount = 0 ; gradCount = 0
for ceo in ceosList:
    degreeDict, degreeCount = checkGraduateEducation(ceo, degreeDict, degreeCount)

degreeDict = {k: v for k, v in sorted(degreeDict.items(), key=lambda item: item[1], reverse=True)}  
for key in degreeDict.keys():
    if key in ['mba', 'ms', 'msc', 'ph.d', 'phd', 'ma', 'jd', 'ph.d', 'md', 'mse', 'meng'] or 'master' in key or 'm.' in key or 'doctor' in key:
        gradCount += 1
print("{} percent of CEOs have postgraduate education".format(str(gradCount / degreeCount * 100)))

fieldDict = {}
for ceo in ceosList:
    fieldDict = getFields(ceo, fieldDict)
    
fieldDict = {k: v for k, v in sorted(fieldDict.items(), key=lambda item: item[1], reverse=True)}
count = 0 ; totalCount = 0
computerFields = {} ; breakCount = 0
print("Most commonly studied fields CEO:")
for k in fieldDict.keys():
    if breakCount < 10:
        print("{}. {}".format(str(breakCount+1), k))
        breakCount += 1
    if 'computer' in k or 'cs' == k or 'software' in k or 'data' in k or 'engine' in k:
        count += fieldDict[k]
        computerFields[k] = fieldDict[k]
    totalCount += fieldDict[k]
df_fields = pd.DataFrame.from_dict(fieldDict, orient='index', columns=['freq']).reset_index()
df_fields.head(10)
print("Percentage of CEOs that studied CS and engineering fields: {}%".format(str(100 * count/totalCount)))

fieldDict = {}
for cto in ctosList:
    fieldDict = getFields(cto, fieldDict)

fieldDict = {k: v for k, v in sorted(fieldDict.items(), key=lambda item: item[1], reverse=True)}
count = 0 ; totalCount = 0
computerFields = {} ; breakCount = 0
print("Most commonly studied fields CTO:")
for k in fieldDict.keys():
    if breakCount < 10:
        print("{}. {}".format(str(breakCount+1), k))
        breakCount += 1
    if 'computer' in k or 'cs' == k or 'software' in k or 'data' in k or 'engine' in k:
        count += fieldDict[k]
        computerFields[k] = fieldDict[k]
    totalCount += fieldDict[k]
df_fields = pd.DataFrame.from_dict(fieldDict, orient='index', columns=['freq']).reset_index()
df_fields.head(10)
print("Percentage of CTOs that studied CS and engineering fields: {}%".format(str(100 * count/totalCount)))

founderCount = 0 ; schoolDict = {}
for founder in ceosList:
    if founder['education']:
        founderCount += 1 ; schoolFound = False
        for educ_ in founder['education']:
            school_ = educ_['school'].lower()
            if school_ not in schoolDict:
                schoolDict[school_] = 1
            else:
                schoolDict[school_] += 1
schoolDict = {k: v for k, v in sorted(schoolDict.items(), key=lambda item: item[1], reverse=True)}
df_schoolCEOs = pd.DataFrame.from_dict(schoolDict, orient='index', columns=['freq']).reset_index()
print("CEO Schools:")
print(df_schoolCEOs.head(10))

founderCount = 0 ; schoolDict = {}
for founder in ctosList:
    if founder['education']:
        founderCount += 1 ; schoolFound = False
        for educ_ in founder['education']:
            school_ = educ_['school'].lower()
            if school_ not in schoolDict:
                schoolDict[school_] = 1
            else:
                schoolDict[school_] += 1
schoolDict = {k: v for k, v in sorted(schoolDict.items(), key=lambda item: item[1], reverse=True)}
df_schoolCTOs = pd.DataFrame.from_dict(schoolDict, orient='index', columns=['freq']).reset_index()
print("CTO Schools:")
print(df_schoolCTOs.head(10))
# Out:
# 20.689655172413794 percent of CTOs have postgraduate education
# 28.08219178082192 percent of CEOs have postgraduate education
# Most commonly studied fields CEO:
# 1. computer science
# 2. business administration and management, general
# 3. economics
# 4. accounting and finance
# 5. information technology
# 6. mechanical engineering
# 7. mathematics
# 8. finance, general
# 9. finance
# 10. psychology
# Percentage of CEOs that studied CS and engineering fields: 20.44609665427509%
# Most commonly studied fields CTO:
# 1. computer science
# 2. information technology
# 3. ingeniería informática
# 4. economics
# 5. computer engineering
# 6. computing, entrepreneurship, and innovation - nyu courant institute and nyu stern school of business
# 7. applied mathematics
# 8. applied mathematics and physics
# 9. computer and information sciences
# 10. advanced mathematics
# Percentage of CTOs that studied CS and engineering fields: 44.680851063829785%
# CEO Schools:
#                                                index  freq
# 0                              university of alberta     7
# 1                              university of cologne     4
# 2                                         ifa zürich     3
# 3     budapesti mûszaki és gazdaságtudományi egyetem     3
# 4                             santa clara university     3
# 5                                 ie business school     3
# 6                                 fordham university     2
# 7  maastricht university school of business and e...     2
# 8       universitatea „babeș-bolyai” din cluj-napoca     2
# 9                        the university of edinburgh     2
# CTO Schools:
#                                              index  freq
# 0                  université paris dauphine - psl     2
# 1                            university of florida     2
# 2                                      viden djurs     2
# 3       moscow institute of physics and technology     2
# 4                   universidad autónoma de madrid     2
# 5  epfl (école polytechnique fédérale de lausanne)     2
# 6   florida state university - college of business     2
# 7            massachusetts institute of technology     2
# 8                        seoul national university     2
# 9                      university of new hampshire     1

# %%
'''
Employment Background (1) contd.
'''
entrepCount = 0 ; techCount = 0 ; busCount = 0 ; totalCount = 0
for i in range(len(df_pos)):
    pos = df_pos.iloc[i]
    totalCount += pos['freq']
    if 'founder' in pos['index'] or 'ceo' in pos['index'] or 'executive' in pos['index'] or 'board' in pos['index'] or 'president' in pos['index']:
        entrepCount += pos['freq']
    if ('engineer' in pos['index'] or 'cto' in pos['index'] or 'technology' in pos['index'] or 'computer' in pos['index'] or 'developer' in pos['index'] or 
        'science' in pos['index'] or 'data' in pos['index'] or 'research' in pos['index']):
        techCount += pos['freq']
    if ('business' in pos['index'] or 'analyst' in pos['index'] or 'product' in pos['index'] or 'manager' in pos['index'] or 'director' in pos['index'] or 
        'coo' in pos['index'] or 'operating' in pos['index'] or 'associate' in pos['index'] or 'financ' in pos['index'] or 'vp' in pos['index'] or 
        'consultant' in pos['index']):
        busCount += pos['freq']
print("{} percent entrepreneurial/executive".format(str(entrepCount * 100 / totalCount)))
print("{} percent tech".format(str(techCount * 100 / totalCount)))
print("{} percent business/finance/consulting".format(str(busCount * 100 / totalCount)))
# Out:
# 10.643314247221287 percent entrepreneurial/executive
# 27.147187605254295 percent tech
# 33.546648703267095 percent business/finance/consulting

# %%
'''
Employment Background
    2. Do founders have a lot of LinkedIn Connections
'''
connectDict = {} ; countDict = {} ; numFounders = 0 ; totalConnections = 0
for key in alldata.keys():
    numFounders_ = 0 
    try:
        for founder in alldata[key]['founders']:
            if founder['connections']:
                num = int([j for i in founder['connections'].split(' ') for j in i.split('+')][0])
                numFounders += 1 ; totalConnections += num
                numFounders_ += 1
                if key not in connectDict:
                    connectDict[key] = num
                else:
                    connectDict[key] += num
        connectDict[key] /= numFounders_
        countDict[key] = numFounders_
    except Exception as e:
        pass

print("Average number of connections is {}".format(str(totalConnections / numFounders)))

top100count = 0 ; top100founderCount = 0
for top_ in df1['Organization Name'][:100]:
    if top_ in connectDict:
        top100count += connectDict[top_] * countDict[top_]
        top100founderCount += countDict[top_]
print("Average number of connections in Top 100: {}".format(str(top100count / top100founderCount)))
# Out:
# Average number of connections is 435.7244582043344
# Average number of connections in Top 100: 447.66153846153844

# %%
'''
Employment Background
    3. Do founders come from certain job positions prior to starting their company? 
        - are they prior founders?
        - are they prior software engineers
'''
df_pos.head(10)
# Out:
#                index  freq
# 0         co-founder    71
# 1            founder    52
# 2  software engineer    45
# 3                ceo    36
# 4              owner    30
# 5       board member    29
# 6             mentor    29
# 7            advisor    29
# 8  managing director    27
# 9           director    25

# %%
'''
Employment Background
    4. Do founders come from certain companies (or industries)
'''
expDict_raw = {} ; expDict = {}
for key in alldata.keys():
    for founder in alldata[key]['founders']:
        if founder['experience']:
            for exp_ in founder['experience']:
                exp_name = exp_['companyName'].lower()
                if exp_name not in expDict_raw:
                    expDict_raw[exp_name] = 1
                else:
                    expDict_raw[exp_name] += 1
                short_name = re.split('\\s+|\\.|,', exp_name)
                for word in short_name:
                    if word in expDict.keys():
                        expDict[word] += 1
                    else:
                        expDict[word] = 1
expDict = {k: v for k, v in sorted(expDict.items(), key=lambda item: item[1], reverse=True)}
expDict;

expDict_raw = {k: v for k, v in sorted(expDict_raw.items(), key=lambda item: item[1], reverse=True)}
expDict_raw
# Out:
# {'microsoft': 14,
#  'self-employed': 10,
#  'facebook': 9,
#  'google': 9,
#  'freelance': 8,
#  'accenture': 8,
#  'apple': 7,
#  'ibm': 7,
#  'bmw group': 6,
#  '3d talo finland oy': 6,
#  'at&t': 5,
#  'self employed': 5,
#  'amazon': 5,
#  'boy scouts of america': 5,
#  'flair digital': 5,
#  'linkedin': 5,
#  'westpac': 5,
#  'seasonally fresh, inc': 5,
#  'google full-time': 4,
#  'founders network': 4,
#  'toastmasters international': 4,
#  'deloitte': 4,
#  'techstars': 4,
#  'productivist': 4,
#  'freelabster': 4,
#  'university of alberta': 4,
#  'freelancer': 4,
#  'qualysoft': 4,
#  'aviva plc': 4,
#  '3d talo': 4,
#  'salesforce': 4,
#  'ericsson': 4,
#  'blackbelt technology kft.': 4,
#  'brandox': 4,
#  'cruise': 4,
#  'appselent': 3,
#  'arobs transilvania software': 3,
#  'capital one': 3,
#  '...': 3,
#  'smplicity': 3,
#  'university of pennsylvania': 3,
#  'shell': 3,
#  'socialbeat': 3,
#  'capgemini': 3,
#  'hubroad': 3,
#  '1871': 3,
#  'canadian armed forces | forces armées canadiennes': 3,
#  'hewlett packard enterprise': 3,
#  'itechart group': 3,
#  'opencore gmbh & co. kg': 3,
#  'gartner': 3,
#  'soul vapour': 3,
#  'hp': 3,
#  'mimir blockchain solutions': 3,
#  'citi': 3,
#  'alter bug tracer': 3,
#  'codeaware gmbh': 3,
#  'stanford university': 3,
#  'sun microsystems': 3,
#  'coinnect sa': 3,
#  'twitter': 3,
#  'willow': 3,
#  'alignvr': 3,
#  'caffeine overdose oy': 3,
#  'the university of british columbia': 3,
#  'viper nights': 3,
#  'ubs': 3,
#  'greenride sharing limited': 3,
#  'creditclick': 3,
#  'explicit selection': 3,
#  'eproval': 3,
#  'pocket sized hands': 3,
#  'deepstributed': 3,
#  'wroclaw university of science and technology': 3,
#  'hivemetric': 3,
#  'hi-impact': 3,
#  'thales': 3,
#  'hewlett-packard': 3,
#  'tradingtwins gmbh': 3,
#  'ormigo gmbh': 3,
#  'flylancer': 3,
#  'placemint': 3,
#  'vancouver startup week': 3,
#  'datenna': 3,
#  'maxbrain ag': 3,
#  'wit.ai (acquired by facebook)': 3,
#  'sobrio, llc': 3,
#  'talent sonar': 3,
#  'association of russian banks': 2,
#  'sf appworks': 2,
#  'trayce.io': 2,
#  'bnp paribas fortis': 2,
#  'galvanize inc': 2,
#  'vendorvid, inc.': 2,
#  'eigenherd gmbh': 2,
#  'unity technologies full-time': 2,
#  'techwomen': 2,
#  'kpmg uk': 2,
#  'procter & gamble full-time': 2,
#  'jeffrey holding sa': 2,
#  'barbosa & duvanel sarl': 2,
#  'vodafone': 2,
#  'shortcutz cascais': 2,
#  'rtp': 2,
#  'world academy portugal full-time': 2,
#  'world academy portugal': 2,
#  'saasx — execute better. grow faster.': 2,
#  'mohawk college': 2,
#  'virgin startup': 2,
#  'jobs in salesforce ltd': 2,
#  'usable experience': 2,
#  "tomorrow's people": 2,
#  'foodcycle': 2,
#  'kalisio': 2,
#  'spherea': 2,
#  'nokia': 2,
#  'adobe': 2,
#  'immersionone': 2,
#  'rotary international': 2,
#  'driftio': 2,
#  'sonetel': 2,
#  'kitvendr': 2,
#  'ibm global business services': 2,
#  'brightguide inc. self-employed': 2,
#  'crowdloc': 2,
#  'young professionals in energy': 2,
#  'kuva': 2,
#  'fontown': 2,
#  'hackbright academy': 2,
#  'gdg león': 2,
#  'université de sherbrooke': 2,
#  'awayup agency': 2,
#  'inovaction services': 2,
#  'value lab': 2,
#  'university of sussex': 2,
#  'ey': 2,
#  'incyzr': 2,
#  'bidyets': 2,
#  'b4coach': 2,
#  '500 startups': 2,
#  'eqela': 2,
#  'job and esther technologies': 2,
#  'inceptions, inc.': 2,
#  'tresup': 2,
#  'international vapor group': 2,
#  'lunchbox': 2,
#  'restoply': 2,
#  'bell': 2,
#  'intel corporation': 2,
#  'global blockchain business council': 2,
#  'artbit, inc.': 2,
#  'atlassian': 2,
#  'hyfer technologies': 2,
#  'knotify inc. full-time': 2,
#  'campus brainiac corp.': 2,
#  'feed nova scotia': 2,
#  'the ottawa hospital contract': 2,
#  'iversoft full-time': 2,
#  'hyfer tech': 2,
#  'knotify full-time': 2,
#  'sigma systems part-time': 2,
#  'vaughan public libraries': 2,
#  'lassonde school of engineering': 2,
#  'ecogroceries': 2,
#  'socialbus': 2,
#  'wittel comunicações': 2,
#  'jugl llc': 2,
#  'eazyfill': 2,
#  'dataspectrum.io': 2,
#  'exxonmobil': 2,
#  'madhatter coalition': 2,
#  'cbre': 2,
#  'exponential-e': 2,
#  'university of applied sciences and arts northwestern switzerland fhnw': 2,
#  'mindmakers': 2,
#  'pixalib': 2,
#  'zummit solutions': 2,
#  'p2ux, inc.': 2,
#  'us army': 2,
#  'ippon technologies usa internship': 2,
#  'the apache software foundation': 2,
#  'logica': 2,
#  'year here': 2,
#  'london borough of hounslow': 2,
#  'akiosurvey': 2,
#  'strategy of things': 2,
#  'deloitte consulting': 2,
#  'cree': 2,
#  'k&l gates': 2,
#  'code and effect': 2,
#  'tadum': 2,
#  'kios research and innovation center of excellence': 2,
#  'phoebe research and innovation ltd': 2,
#  'inceptit': 2,
#  'jam 3 company': 2,
#  'smop technologies': 2,
#  'kpmg': 2,
#  'sensi labs sp. z o. o.': 2,
#  'toptal': 2,
#  'trade development authority of pakistan (tdap)': 2,
#  'wells fargo': 2,
#  'kitchenlogs': 2,
#  'tapstak': 2,
#  'emc': 2,
#  'esb': 2,
#  'sensee': 2,
#  'pixels & bytes': 2,
#  'basil security, inc.': 2,
#  'amazon web services (aws) full-time': 2,
#  'city of seattle': 2,
#  'geeks in the woods': 2,
#  'geeks venture studio': 2,
#  'go madrid': 2,
#  'disruptual': 2,
#  'yieldify': 2,
#  'upper.ai': 2,
#  'worktojob': 2,
#  'poplo': 2,
#  'bitwar b.v.': 2,
#  'holojam inc': 2,
#  'nyu future reality lab': 2,
#  'spoke digital agency': 2,
#  'insightfulvr': 2,
#  'ionic ai': 2,
#  'mindray north america': 2,
#  'datascope': 2,
#  'parkmaven': 2,
#  'ted conferences': 2,
#  'ecade': 2,
#  'lys.fashion': 2,
#  'mobilexpense': 2,
#  'touring': 2,
#  'sony pictures entertainment': 2,
#  'th-ey': 2,
#  'blackrock': 2,
#  'j.p. morgan': 2,
#  'knotify': 2,
#  'chainsulting': 2,
#  'clearat (clear advanced technologies)': 2,
#  'housecheckr services limited': 2,
#  'revright inc.': 2,
#  'meetup': 2,
#  'multimedia support': 2,
#  'pragmaticad': 2,
#  'aiesec': 2,
#  'amazon.com': 2,
#  'astellent': 2,
#  'emerge': 2,
#  'nuorese calcio': 2,
#  'pwc': 2,
#  'cyanapse': 2,
#  'innovela': 2,
#  's[k]aleup ventures inc.': 2,
#  'bank of america': 2,
#  'kindred': 2,
#  'kaiser permanente': 2,
#  'maphubs': 2,
#  'sparringspartnerne': 2,
#  'nextal solutions inc.': 2,
#  'red cross blood services': 2,
#  'frankly full-time': 2,
#  'omen capital inc.': 2,
#  'vrcave inc.': 2,
#  'allsports & cycle inc./allsports replay': 2,
#  'mastercard': 2,
#  'gikken': 2,
#  'twopeople software': 2,
#  'solidcomp oy': 2,
#  'yell canada': 2,
#  'mount baker council, boy scouts of america': 2,
#  'datama': 2,
#  'bain & company': 2,
#  'lawgarithm': 2,
#  'tikabu pty ltd': 2,
#  'qbe insurance': 2,
#  'westpac institutional bank': 2,
#  'projectai': 2,
#  'yummrun': 2,
#  'okta, inc.': 2,
#  'seatd': 2,
#  'demathieu bard': 2,
#  'netapp': 2,
#  'moko': 2,
#  'frankfurt school of finance & management': 2,
#  'mazars uk': 2,
#  'haerlem capital': 2,
#  'ul transaction security': 2,
#  'xiid corp.': 2,
#  'extenua inc.': 2,
#  'u&us, llc': 2,
#  'assurance storage software': 2,
#  'atrato, inc (acquired by assurance storage software, private equity)': 2,
#  'okizu': 2,
#  'yahoo!': 2,
#  'emory university': 2,
#  'knowhow': 2,
#  'bootkik': 2,
#  'founders embassy': 2,
#  'launch platform': 2,
#  'university of calgary': 2,
#  'lobe (acquired by microsoft)': 2,
#  'apple inc.': 2,
#  'geoxtreme, llc': 2,
#  'pawpeeps, inc.': 2,
#  'alphamoon': 2,
#  'volvo it': 2,
#  'h2t digital co.': 2,
#  'cst consulting': 2,
#  'seated': 2,
#  'emplifyer full-time': 2,
#  'hocaboo': 2,
#  'showing assistance': 2,
#  'turkcell': 2,
#  'voodootix': 2,
#  'bizfit': 2,
#  'b-talent | soft skills university': 2,
#  'bizpills': 2,
#  'idex world': 2,
#  'valley health': 2,
#  'private full-time': 2,
#  'freeform labs': 2,
#  'global shapers community': 2,
#  'contractize': 2,
#  'heropolis': 2,
#  'thales communications': 2,
#  'aneo': 2,
#  'ivsz - it association of hungary': 2,
#  'suncor': 2,
#  'united nations association in canada': 2,
#  'cognizant technology solutions': 2,
#  'wegardn': 2,
#  'virusbay': 2,
#  'skedgit': 2,
#  'tru north consulting group': 2,
#  'insidesales.com': 2,
#  'heronius': 2,
#  'kcctech': 2,
#  'silicon valley startups': 2,
#  'victor mundi': 2,
#  'alchemist accelerator': 2,
#  'leadingage': 2,
#  'aionys (medical software)': 2,
#  'eventwaves': 2,
#  'iolite foundation': 2,
#  'adaptifyed, inc': 2,
#  'university of california, irvine - the paul merage school of business': 2,
#  'productz mib gmbh': 2,
#  'booklikes': 2,
#  'okazjum': 2,
#  'aig': 2,
#  'gdpr in schools': 2,
#  'groupcall ltd': 2,
#  'dentistreet': 2,
#  'adp': 2,
#  'vibespot': 2,
#  'fwollo llc': 2,
#  'm force staffing': 2,
#  'babbel': 2,
#  'wow intelligence': 2,
#  'rikodu': 2,
#  'propertyshark.com': 2,
#  'thalamos': 2,
#  '5w155 sa': 2,
#  'sonder studio': 2,
#  'quartz': 2,
#  'opo.network': 2,
#  'baboom limited': 2,
#  'triworks': 2,
#  'folkwang university of arts': 2,
#  'wizardry labs': 2,
#  'tugboat coding limited': 2,
#  'entrepreneur first': 2,
#  'skrible, inc.': 2,
#  'vrcave': 2,
#  'savicon': 2,
#  'homeplate labs, inc.': 2,
#  'human rights campaign': 2,
#  'odd one out': 2,
#  'alphateam hackers gmbh': 2,
#  'vq labs': 2,
#  'prontoforms': 2,
#  'g-dii': 2,
#  'heylink': 2,
#  'compriso': 2,
#  'eposly': 2,
#  'coursy full-time': 2,
#  'opus online': 2,
#  'girl scouts of northern california': 2,
#  'fueled on bacon': 2,
#  'boastable': 2,
#  'joany': 2,
#  'humanize health': 2,
#  'assembly made': 2,
#  'mckinsey & company': 2,
#  'oracle': 2,
#  'twitter full-time': 2,
#  'aiden.ai': 2,
#  'nabla': 2,
#  'nuance communications': 2,
#  'dashride': 2,
#  'y combinator': 2,
#  'griddable.io': 2,
#  'jobvention': 2,
#  'clusterhq': 2,
#  'cava capital': 2,
#  'confirm': 2,
#  'drone complier': 2,
#  'artillery games': 2,
#  'nomiku': 2,
#  'candor': 2,
#  'scaphold, inc.': 2,
#  'zen99': 2,
#  'riseml': 2,
#  'expensebot': 2,
#  'freeagent': 2,
#  'the american institute of architects, iowa chapter': 2,
#  'digitalika ag': 1,
#  'fgi fintech growth investment gmbh': 1,
#  'filewave': 1,
#  'vita34 ag': 1,
#  'advanon ag': 1,
#  'focal systems, inc.': 1,
#  'yipp': 1,
#  'uc berkeley': 1,
#  'butler automatic inc.': 1,
#  'international electronic machines corporation': 1,
#  'nobias': 1,
#  'arkera': 1,
#  'new york university': 1,
#  'citigroup': 1,
#  'multiple': 1,
#  'netbeez, inc.': 1,
#  'cloudneeti': 1,
#  'tempered networks': 1,
#  'vidder, inc. (acquired by verizon)': 1,
#  'better homes and gardens real estate': 1,
#  'coldwell banker residential brokerage': 1,
#  're/max pacific realty': 1,
#  'homeward pet adoption center': 1,
#  'shanti project': 1,
#  'keller williams realty, inc.': 1,
#  'gyrostream investments full-time': 1,
#  'edgestone australia': 1,
#  'laborde motorsport': 1,
#  'the natural hemp corporation': 1,
#  'australian business credit': 1,
#  'risk & capital compliance solutions self-employed': 1,
#  'risk & capital compliance solutions pty ltd.': 1,
#  'fuqua school of business': 1,
#  'alfa-bank': 1,
#  'tatfig': 1,
#  'techfest club': 1,
#  'frida vibes': 1,
#  'everist': 1,
#  'imperative': 1,
#  'downtown pittsfield inc': 1,
#  'barrington stage company': 1,
#  'national alliance for musical theatre': 1,
#  'ball state university': 1,
#  'johnny mercer songwriters project': 1,
#  'sharon power': 1,
#  'trio entertainment group': 1,
#  'kavon theatre restuarant': 1,
#  'lusic': 1,
#  'marketsource inc.': 1,
#  'softvision': 1,
#  'lateral inc.': 1,
#  'fluid trends': 1,
#  'halcyon mobile': 1,
#  'rivo software': 1,
#  'compass': 1,
#  'vidulist': 1,
#  'premier properties denver': 1,
#  're/max professionals': 1,
#  'pinnacle security': 1,
#  'streamcrux': 1,
#  'danske bank': 1,
#  'charlie tango': 1,
#  'transformator design': 1,
#  'carlsberg group': 1,
#  'mindjumpers': 1,
#  'gomore': 1,
#  'rainmaking': 1,
#  'hosting4devs': 1,
#  'premium leads s.l. | grupo ipglobal': 1,
#  'xilon solutions': 1,
#  'atsistemas': 1,
#  'acierto.com': 1,
#  '7 flows': 1,
#  'reworx': 1,
#  'beyond experience labs self-employed': 1,
#  'yoygi': 1,
#  'varsity ventures': 1,
#  'sharerado ug': 1,
#  'q2web': 1,
#  'nerdette.io': 1,
#  'lison weiler holding gmbh': 1,
#  'q2web gmbh': 1,
#  'bits on disk': 1,
#  'freenome': 1,
#  'trifacta': 1,
#  'university of california, san diego (ucsd)': 1,
#  'rwth aachen university': 1,
#  'université de montpellier': 1,
#  'ies- institute of electronics and systems': 1,
#  'argento mining s.a.': 1,
#  'itiem, engineering school, national university of cuyo': 1,
#  'quality construction & restoration': 1,
#  'jmt construction': 1,
#  'wells fargo home mortgage': 1,
#  'best rate funding corporation': 1,
#  'open public services': 1,
#  'az you inc.': 1,
#  'red cubez inc.': 1,
#  'solar studio': 1,
#  'ingenuity private limited': 1,
#  'fusion alliance': 1,
#  'm/i homes, inc.': 1,
#  'endeavor colorado full-time': 1,
#  'relentful': 1,
#  'alx': 1,
#  'tandem': 1,
#  'startup weekend': 1,
#  'starter studio': 1,
#  'city year': 1,
#  'urquía & bas correduría de seguros, sl full-time': 1,
#  'blueindic': 1,
#  'centre integral fp ilerna': 1,
#  'mainfor soluciones tecnológicas y formación': 1,
#  'dhl supply chain - cliente mahou san miguel lleida': 1,
#  'toolboxit ltd': 1,
#  'hillingdon flooring company limited': 1,
#  'houtman designs': 1,
#  'department of physics, university of british columbia': 1,
#  'triumf': 1,
#  'ecotext, inc self-employed': 1,
#  'triumph software llc self-employed': 1,
#  'york ie part-time': 1,
#  'unh rines angel fund': 1,
#  "st. paul's school internship": 1,
#  'university of new hampshire': 1,
#  'unh ecenter (peter t. paul entrepreneurship center)': 1,
#  'on the house': 1,
#  'fitby agency': 1,
#  'fitby app': 1,
#  'pi!ng': 1,
#  'leemii': 1,
#  'sift software, inc.': 1,
#  'independa, inc.': 1,
#  'tailwind web llc': 1,
#  'akira technologies, inc': 1,
#  'generation c entertainment': 1,
#  'booz allen hamilton': 1,
#  'geico': 1,
#  'crowdstrike': 1,
#  'pantone designs, llc': 1,
#  'strayer university': 1,
#  'aol': 1,
#  'medcreds part-time': 1,
#  'flare.build freelance': 1,
#  'coinbase full-time': 1,
#  'flow contract': 1,
#  'reinventone, inc.': 1,
#  'yocto project, a linux foundation project freelance': 1,
#  'embedded apprentice linux engineer': 1,
#  'the linux foundation contract': 1,
#  'converse in code inc': 1,
#  'llvmlinux': 1,
#  'axon': 1,
#  'extensius': 1,
#  'panera bread': 1,
#  'novyspec': 1,
#  'sodius': 1,
#  'laboratoire xtal': 1,
#  'advanced software concepts': 1,
#  'iso/iec jtc 1/sc7 software and systems engineering': 1,
#  'incose': 1,
#  'take two productions, inc': 1,
#  'self': 1,
#  'hotbed gmbh': 1,
#  'freelancing': 1,
#  'fortbildung.com': 1,
#  'sap ag': 1,
#  'kalorimeta ag & co. kg': 1,
#  'kalo)gruppe - urbana - kalorimeta - ikw': 1,
#  'siemens ag, energy sector - fossile stromerzeugung': 1,
#  'siemens ag, energy sector - automatisierung, leit-, schutz- & elektrotechnik': 1,
#  'vulcan inc. full-time': 1,
#  'networthy': 1,
#  'picmonkey full-time': 1,
#  'picnik full-time': 1,
#  'dcu chemical science school': 1,
#  'uct chemistry department': 1,
#  'centre for high performance computing': 1,
#  'uct': 1,
#  'sasol research & technology': 1,
#  'engageme apps': 1,
#  'evalueserve': 1,
#  'magic software': 1,
#  'maruti suzuki': 1,
#  'greaves cotton': 1,
#  'braincircle': 1,
#  'cmore': 1,
#  'trendhuis': 1,
#  'savant media': 1,
#  'vice media benelux': 1,
#  'underscope': 1,
#  'mediportal.com': 1,
#  'ocbc bank': 1,
#  'zettabox': 1,
#  'searchbox labs': 1,
#  'iprospect': 1,
#  'elite sem': 1,
#  'spark marketing corporation': 1,
#  'monex': 1,
#  'power yoga canada': 1,
#  'f45 training': 1,
#  'beez': 1,
#  'oms soft': 1,
#  'orange tree - online advertising': 1,
#  'tsm new project': 1,
#  'maramures resort': 1,
#  'caneberry full-time': 1,
#  'land & ladle': 1,
#  'subcast': 1,
#  'flipboard inc.': 1,
#  'washington c.a.s.h. (community alliance for self-help)': 1,
#  'een consulting gmbh': 1,
#  'power of pricing': 1,
#  'innosuisse - schweizerische agentur für innovationsförderung': 1,
#  'syngenta': 1,
#  'filecaddie': 1,
#  'blippar': 1,
#  'parabolic games': 1,
#  'kuato studios': 1,
#  'london south bank university': 1,
#  '3d planeta full-time': 1,
#  'overwound blues band part-time': 1,
#  '10speak innovation': 1,
#  'itacit inc.': 1,
#  'accreon inc.': 1,
#  'startup fredericton': 1,
#  'startup nb': 1,
#  'planet hatch': 1,
#  'kroger': 1,
#  'cintrifuse': 1,
#  'picnic insights': 1,
#  'familytech': 1,
#  'candidly': 1,
#  'the brandery': 1,
#  'greater cincinnati venture association': 1,
#  'alchemy (a p&g company)': 1,
#  'picnic insights (formerly trekmarker)': 1,
#  'choremonster powered by familytech': 1,
#  'university of cincinnati': 1,
#  'greater cincinnati coalition for the homeless': 1,
#  'comptabilité': 1,
#  'protectas sa': 1,
#  'totor.ch self-employed': 1,
#  'bleu ocean sa': 1,
#  'màd genève': 1,
#  'endeavor': 1,
#  'dapos bid': 1,
#  'latam airlines': 1,
#  'somma consulting group': 1,
#  'newlink group': 1,
#  'flying wild hog full-time': 1,
#  'techland': 1,
#  'badsmallcat': 1,
#  'foundry 42, cloud imperium games': 1,
#  '-': 1,
#  'we-assist | een applicatie voor online klantenservice': 1,
#  'iqfy b.v.': 1,
#  'livecom international': 1,
#  'livecom': 1,
#  'device authority': 1,
#  'deciphered_': 1,
#  'workgaps ltd': 1,
#  'red hot penny': 1,
#  'insitetrack': 1,
#  'qartrock': 1,
#  'quality assurance group': 1,
#  'corevalue services': 1,
#  'malkosua': 1,
#  'globallogic': 1,
#  'arthur ventures full-time': 1,
#  'beacon9': 1,
#  'founders advisors': 1,
#  'recurring capital partners': 1,
#  'a cloud guru full-time': 1,
#  'linux academy': 1,
#  'beacon9 saas advisory': 1,
#  'matcha': 1,
#  'datalevel ag (vormals taxlevel ag)': 1,
#  'strittmatter gmbh it-services': 1,
#  'qbic ag': 1,
#  'modern it': 1,
#  'ifb, informatik für banken': 1,
#  'datalevel': 1,
#  'win it-services gmbh': 1,
#  'slascone': 1,
#  'white duck software': 1,
#  'cubeware gmbh': 1,
#  'astm international contract': 1,
#  'adler & dale fintech': 1,
#  'comcast': 1,
#  'concept key | product innovation lab': 1,
#  'rental investor': 1,
#  'volunteers for smiles': 1,
#  'mcmaster university contract': 1,
#  'freelance freelance': 1,
#  'seneca college full-time': 1,
#  'transportation association of canada / association des transports du canada': 1,
#  'cite': 1,
#  'data science institute': 1,
#  'nuinside': 1,
#  'data kettle': 1,
#  'tube2vr': 1,
#  'cute brick': 1,
#  'data intelligence society of concordia (disc)': 1,
#  'iae nice (graduate school of management)': 1,
#  'greenhouse.co': 1,
#  'the lean traveler': 1,
#  'alle carte': 1,
#  'ucn - university college nordjylland full-time': 1,
#  'ucn - university college nordjylland internship': 1,
#  'kickstart aalborg': 1,
#  'precursive full-time': 1,
#  'sonara ltd': 1,
#  'scci alphatrack ltd': 1,
#  'united utilities': 1,
#  'outreach digital': 1,
#  'hilton contract': 1,
#  'invision full-time': 1,
#  'social security administration contract': 1,
#  'koding lab': 1,
#  'the german university in cairo full-time': 1,
#  'wefunder': 1,
#  'arkatecht': 1,
#  'depaul': 1,
#  'rochester institute of technology': 1,
#  'y mattox research and consulting': 1,
#  'jack and jill of america foundation, inc.': 1,
#  'startup grind': 1,
#  'telespazio france': 1,
#  'cs communication & systèmes': 1,
#  'tiwak (ubisoft)': 1,
#  'luc claustres': 1,
#  'telespazio / vega': 1,
#  'onesia': 1,
#  'playstation full-time': 1,
#  'signum audio': 1,
#  'rockstar north': 1,
#  'trc family entertainment limited': 1,
#  'brikkuni': 1,
#  'mekandagez matterport': 1,
#  'mantopor yalıtım çözümleri self-employed': 1,
#  'kop dağı tüneli ve ovit dağı tünelleri': 1,
#  'turk ytong': 1,
#  'eskil belediyesi': 1,
#  'provenir': 1,
#  'readear ltd full-time': 1,
#  'lgux design creative full-time': 1,
#  'zolt new york full-time': 1,
#  'kauffman fasttrac apprenticeship': 1,
#  'posti group oyj': 1,
#  'readear ltd': 1,
#  'ezyinsights': 1,
#  'tribune media services': 1,
#  'chicago tribune': 1,
#  'f-secure corporation': 1,
#  'tapaus': 1,
#  'readear oy': 1,
#  'innovationhousefinland': 1,
#  'mannerheim league for child welfare': 1,
#  'helsingin suomalainen yhteiskoulu': 1,
#  'extendlaw': 1,
#  'riigikohus (supreme court of estonia)': 1,
#  'ravel law': 1,
#  'borenius attorneys, estonia': 1,
#  'faculty of mathematics and computer science of university of tartu': 1,
#  'databitty': 1,
#  '99designs': 1,
#  'medium': 1,
#  'designcrowd': 1,
#  'firecracker pr': 1,
#  'd-link systems': 1,
#  'envision financial systems': 1,
#  'gateway, inc.': 1,
#  'unannounced startup': 1,
#  'blizzard entertainment': 1,
#  'the haven collection': 1,
#  'the coggeshall club': 1,
#  'established consulting': 1,
#  'tui': 1,
#  'national sailing hall of fame': 1,
#  'iyrs school of technology & trades': 1,
#  'bomoniti, inc.': 1,
#  'renova medikal mühendislik': 1,
#  'turkcell superonline': 1,
#  'empatel telekom (avaya platinum partner)': 1,
#  'asm telekom': 1,
#  'eassymo': 1,
#  'grupo luis hoyo': 1,
#  'geekosofia': 1,
#  'epic queen': 1,
#  'facemydoc live': 1,
#  'know the candidates': 1,
#  'barenberg capital partners': 1,
#  'connectatd': 1,
#  'kryptoin etfs': 1,
#  'ymca': 1,
#  'ymca of greater fort wayne': 1,
#  'ymca of central ohio': 1,
#  'part time college positions': 1,
#  'u.s. army - aviation': 1,
#  'brightpoint': 1,
#  'blue jacket, inc.': 1,
#  'tapkit': 1,
#  'sas': 1,
#  'randomwalk technologies llc': 1,
#  'danfoss power solutions': 1,
#  'iowa state university': 1,
#  'the tau beta pi association, inc.': 1,
#  'habitat for humanity of durham': 1,
#  'rojina computer ltd.': 1,
#  'snapp!': 1,
#  'raoko (tagrio)': 1,
#  'raoko pty ltd': 1,
#  'eventorial': 1,
#  'screensoft self-employed': 1,
#  'drug & alcohol testing complaince services full-time': 1,
#  'archib venture advisers': 1,
#  'increm invest utveckling': 1,
#  'netlight': 1,
#  'driftio ab': 1,
#  'teknologkåren vid lunds tekniska högskola (tlth)': 1,
#  'learner sweden ab': 1,
#  'scatch full-time': 1,
#  'stauferdigital full-time': 1,
#  'nxtuser full-time': 1,
#  'moonkind part-time': 1,
#  'kaufregal part-time': 1,
#  'opendat': 1,
#  'institut für künstliche intelligenz und data science (ikids)': 1,
#  'astronomische forschungsgemeinschaft baden-württemberg': 1,
#  'vetstrategy full-time': 1,
#  'imlocum | imthriving': 1,
#  'registered veterinary technologists & technicians of canada (rvttc)': 1,
#  'primary and emergency clinics full-time': 1,
#  'alberta veterinary medical association': 1,
#  'europeanfoothold': 1,
#  'ibiitt part-time': 1,
#  'globalware solutions': 1,
#  'centrix inc.': 1,
#  'wise solutions / altiris': 1,
#  'aiwee self-employed': 1,
#  'prosperity promotions ltd': 1,
#  'ecsilent ltd.': 1,
#  'aiwee': 1,
#  'loytz': 1,
#  'prominic.net': 1,
#  'jbilling.com': 1,
#  'phase4digital full-time': 1,
#  'xreach.io': 1,
#  'asentech llc': 1,
#  'confidential digital health (in stealth mode)': 1,
#  'castegy': 1,
#  'joyhype self-employed': 1,
#  'talk.onl full-time': 1,
#  'monster energy self-employed': 1,
#  'so-gnar full-time': 1,
#  'game medic self-employed': 1,
#  'hirerated inc': 1,
#  'scm connections': 1,
#  'thinkscm': 1,
#  'eli lilly': 1,
#  'groupe psa full-time': 1,
#  'hway digital': 1,
#  'renault-nissan-mitsubishi': 1,
#  'sylpheo': 1,
#  'digibe inc.': 1,
#  'weave digital self-employed': 1,
#  'digital main street contract': 1,
#  'tomyum contract': 1,
#  'wavelip tech solutions corporation contract': 1,
#  'hacking health waterloo region': 1,
#  'home self-employed': 1,
#  'university of waterloo': 1,
#  'university of hyderabad': 1,
#  'baraan soft': 1,
#  'teknique': 1,
#  'apreet': 1,
#  'fucine film solutions srl.': 1,
#  'positioning tech self-employed': 1,
#  'connectedriver & smart mobility': 1,
#  'anagog': 1,
#  'lbs consulting': 1,
#  'aircapture llc': 1,
#  'trolysis, inc.': 1,
#  'mozaik media': 1,
#  'bloom energy': 1,
#  'simul tech': 1,
#  'fly up': 1,
#  'patacu': 1,
#  'rolling waves pictures': 1,
#  'bno design, llc': 1,
#  'b heroes': 1,
#  'mark lundin studio': 1,
#  'mother': 1,
#  'the farm creative': 1,
#  'wwav rapp collins': 1,
#  'the fwa': 1,
#  'potato': 1,
#  'dare': 1,
#  'start judgegill limited': 1,
#  'billionhands': 1,
#  'the neon project': 1,
#  'flaranda crafted software': 1,
#  'fonoma': 1,
#  'rails girls': 1,
#  'google developers group': 1,
#  'cabify full-time': 1,
#  'comando cran': 1,
#  'the big house': 1,
#  'by new roman': 1,
#  'pima.app full-time': 1,
#  'marana': 1,
#  'zinc by servicemax': 1,
#  'jpmorgan chase': 1,
#  'bloomspot.com': 1,
#  'grupotres': 1,
#  'mediaroom solutions': 1,
#  'smarkia': 1,
#  'ileon.com': 1,
#  '3d printer party': 1,
#  'up global': 1,
#  'ton équipier self-employed': 1,
#  'modern sales pros self-employed': 1,
#  'coopérathon': 1,
#  'hardbacon': 1,
#  "le pignon d'argent": 1,
#  'movember': 1,
#  'fondation jean lapointe': 1,
#  'ton équipier': 1,
#  'eagleview by tekinno corporation inc.': 1,
#  'kinova robotics': 1,
#  'montrealizer': 1,
#  "mouvement des accélérateurs d'innovation du québec": 1,
#  'centech mtl': 1,
#  'libretrend': 1,
#  'lovelyads full-time': 1,
#  'paymytable': 1,
#  'syone': 1,
#  'noesis portugal': 1,
#  'aximona full-time': 1,
#  'fete': 1,
#  'eventory': 1,
#  'spinme.io': 1,
#  'bge consulting': 1,
#  'atol business solutions ltd.': 1,
#  'salesmanago marketing automation': 1,
#  'imetvr full-time': 1,
#  'theconcertbox part-time': 1,
#  'awe (augmented world expo)': 1,
#  'mrsv.io': 1,
#  '360talking': 1,
#  'loyalty company': 1,
#  'epitech': 1,
#  'iseeds software': 1,
#  'dekibae': 1,
#  'loyalty technology': 1,
#  'dymension': 1,
#  'comcard': 1,
#  'updg': 1,
#  'tys creative': 1,
#  'wonder jewelers': 1,
#  'global 3 pictures, inc.': 1,
#  'sensitive i/o': 1,
#  "gamec - galleria d'arte moderna e contemporanea di bergamo": 1,
#  'cesvi fondazione onlus': 1,
#  'sesaab': 1,
#  'beiersdorf': 1,
#  'deloitte italia': 1,
#  'italian chamber of commerce in canada west': 1,
#  'cisoshare': 1,
#  'cyberforward by cisoshare': 1,
#  'cyber progress index': 1,
#  'cisohandbook.com': 1,
#  'auxilio': 1,
#  'orange county united way': 1,
#  'easy marketing contract': 1,
#  'café el rey s.a': 1,
#  'uniqlo europe ltd full-time': 1,
#  'chicken2me self-employed': 1,
#  'ennismore contract': 1,
#  'house of fraser': 1,
#  'kisaco research': 1,
#  'chicken2me': 1,
#  'informa': 1,
#  ...}

# %%
'''
Employment Background
    4B. CEO vs. CTO company background
'''
posDictCeo = {} ; posDictCto = {} ; otherDict = {}
for key in alldata.keys():
    for founder in alldata[key]['founders']:
        if founder['experience']:
            firstCheck = True ; isCeo = False ; isCto = False
            for exp_ in founder['experience']:
                position = exp_['companyName'].lower()
                if exp_['title'] and firstCheck:
                    title = exp_['title'].lower()
                    if ('ceo' in title) or ('executive officer' in title):
                        isCeo = True
                    if ('cto' in title) or ('technology officer' in title) or ('technical officer' in title):
                        isCto = True
                    firstCheck = False
                if isCeo:
                        if position not in posDictCeo:
                            posDictCeo[position] = 1
                        else:
                            posDictCeo[position] += 1
                elif isCto:
                    if position not in posDictCto:
                        posDictCto[position] = 1
                    else:
                        posDictCto[position] += 1
                else:
                    if position not in otherDict:
                        otherDict[position] = 1
                    else:
                        otherDict[position] += 1

posDictCeo = {k: v for k, v in sorted(posDictCeo.items(), key=lambda item: item[1], reverse=True)}
df_posCEOs = pd.DataFrame.from_dict(posDictCeo, orient='index', columns=['freq']).reset_index()
print(df_posCEOs.head(10))

posDictCto = {k: v for k, v in sorted(posDictCto.items(), key=lambda item: item[1], reverse=True)}
df_posCTOs = pd.DataFrame.from_dict(posDictCto, orient='index', columns=['freq']).reset_index()
print(df_posCTOs.head(10))

otherDict = {k: v for k, v in sorted(otherDict.items(), key=lambda item: item[1], reverse=True)}
df_others = pd.DataFrame.from_dict(otherDict, orient='index', columns=['freq']).reset_index()
print(df_others.head(10))
# Out:
#                                             index  freq
# 0                                            1871     3
# 1                           university of alberta     3
# 2                    association of russian banks     2
# 3                                   self employed     2
# 4                              hackbright academy     2
# 5                                       techstars     2
# 6                                  itechart group     2
# 7  trade development authority of pakistan (tdap)     2
# 8                                       freelance     2
# 9                                   revright inc.     2
#                         index  freq
# 0                   microsoft     5
# 1                     westpac     5
# 2                   accenture     4
# 3               flair digital     4
# 4  hewlett packard enterprise     3
# 5                 soul vapour     3
# 6                   qualysoft     3
# 7      vancouver startup week     3
# 8                talent sonar     3
# 9                   smplicity     2
#                    index  freq
# 0               facebook     8
# 1              microsoft     8
# 2                  apple     6
# 3                    ibm     6
# 4          self-employed     6
# 5                 google     6
# 6                   at&t     5
# 7              freelance     5
# 8  boy scouts of america     5
# 9               linkedin     5

# %%
'''
Employment Background
    5. Are there certain words or phrases in a founder's prior job description that stand out
'''
expDict;

# %%
'''
Company Fundamentals 
    1. How important is the company's CB rank?
'''
ranks = [int(i.replace(',','')) for i in df1['CB Rank (Company)']]
print("Mean CB rank is: {}".format(np.mean(ranks)))
print("Among the top 200 companies, the mean rank is {}".format(str(np.mean(ranks[:200]))))
# Out:
# Mean CB rank is: 389326.454248366
# Among the top 200 companies, the mean rank is 259258.72

# %%
'''
Company Fundamentals
    2. Are there keywords in a company's description?
'''
descriptionWords = {}
for des_ in df1['Description']:
    for word in re.split('\\s|\.|,',des_):
        if word:
            if word not in descriptionWords:
                descriptionWords[word] = 1
            else:
                descriptionWords[word] += 1
descriptionWords = {k: v for k, v in sorted(descriptionWords.items(), key=lambda item: item[1], reverse=True)}
descriptionWords;

# %%
'''
Company Fundamentals
    3. B2B vs. SaaS
'''
b2bcompanies = {} ; saascompanies = {}
for i in range(len(df1)):
    ind_ = df1.iloc[i]['Industries'].lower()
    if 'b2b' in ind_:
        b2bcompanies[df1.iloc[i]['Organization Name']] = 1
    if 'saas' or 'software' in ind_:
        saascompanies[df1.iloc[i]['Organization Name']] = 1

posDictb2b = {} ; posDictsaas = {}
for key in alldata.keys():
    if key in b2bcompanies:
        for founder in alldata[key]['founders']:
            if founder['experience']:
                for exp_ in founder['experience']:
                    company = exp_['companyName'].lower()
                    if company not in posDictb2b:
                        posDictb2b[company] = 1
                    else:
                        posDictb2b[company] += 1
    if key in saascompanies:
        for founder in alldata[key]['founders']:
            if founder['experience']:
                for exp_ in founder['experience']:
                    company = exp_['companyName'].lower()
                    if company not in posDictsaas:
                        posDictsaas[company] = 1
                    else:
                        posDictsaas[company] += 1
posDictb2b = {k: v for k, v in sorted(posDictb2b.items(), key=lambda item: item[1], reverse=True)}
df_b2b = pd.DataFrame.from_dict(posDictb2b, orient='index', columns=['freq']).reset_index()
posDictsaas = {k: v for k, v in sorted(posDictsaas.items(), key=lambda item: item[1], reverse=True)}
df_saas = pd.DataFrame.from_dict(posDictsaas, orient='index', columns=['freq']).reset_index()

print("B2B:")
print(df_b2b.head(10))
print("SaaS:")
print(df_saas.head(10))
# Out:
# B2B:
#                    index  freq
# 0  seasonally fresh, inc     5
# 1      tradingtwins gmbh     3
# 2            ormigo gmbh     3
# 3              flylancer     3
# 4                datenna     3
# 5               crowdloc     2
# 6           ecogroceries     2
# 7               eazyfill     2
# 8             exxonmobil     2
# 9    madhatter coalition     2
# SaaS:
#                 index  freq
# 0           microsoft    14
# 1       self-employed    10
# 2            facebook     9
# 3              google     9
# 4           freelance     8
# 5           accenture     8
# 6               apple     7
# 7                 ibm     7
# 8           bmw group     6
# 9  3d talo finland oy     6
