# %%
# Import statements
import pandas as pd
import numpy as np 
import csv 
from parsel import Selector
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import json
import re

# %%
'''
Class to describe a given company 
    @field: name: a string for the company name
    @field: description: a string for the company description
    @field: founders: a list of Founder objects
    @field: industries: a list of strings for different industries
    @field: website: a string for the website
    @field: lastStage: a string for the last stage of funding (eg. Series A)
    @field: linkedin: a string for the company's LinkedIn profile
    @field: location: a string for the company's location
'''
class Company:
    def __init__(self, companyName):
        self.name = companyName
        self.description = None
        self.founders = []
        self.industries = []
        self.website = None
        self.lastStage = None
        self.linkedin = None
    
    def toJson(self):
        return json.dumps(self, default=lambda o: o.__dict__)
    
'''
Class to describe a founder
    @field: name: a string for the founder's name
    @field: education: an list of education objects
    @field: experience: a list of experience objects
'''
class Founder:
    def __init__(self, founderName):
        self.name = founderName
        self.connections = None
        self.location = None
        self.education = []
        self.experience = []

'''
Class to help describe a founder's education
    @field: degree: a string to describe the degree objective
    @field: school: a string for the school attended
    @field: field: a string to describe the major
'''
class Education:
    def __init__(self, schoolName):
        self.school = schoolName
        self.degree = None
        self.field = None
'''
Class to help describe a founder's experience
    @field: companyName: a string to describe the company's name
    @field: title: a string to describe the title held
    @field: description: a string to describe the job description
'''       
class Experience:
    def __init__(self, companyName):
        self.companyName = companyName
        self.title = None
        self.dates = None

# %%
'''
Loads the dataframe from Query 1 and Query 2 and merges + drops duplicates and NaNs
    @param: csv1: path to CSV 1 (formed by Query 1)
    @param: csv2: path to CSV 2 (formed by Query 2)
    @return: df1: a merged dataframe of csv1 and csv2
'''
def loadBacktestData(csv1, csv2):
    df1 = pd.read_csv(csv1)
    df2 = pd.read_csv(csv2)
    df1 = df1.append(df2)
    df1 = df1.drop_duplicates(subset=['Organization Name'])
    df1 = df1[df1.Founders.notna()]
    df1 = df1[df1.LinkedIn.notna()]
    df1 = df1.reset_index()
    for i in range(len(df1)):
        if df1.iloc[i].LinkedIn.count('about') > 0:
            df1['LinkedIn'][i] = df1['LinkedIn'][i].split('about')[0]
    df1 = df1.set_index('Organization Name')
    df1 = df1.drop('index', 1)
    df1['Organization Name'] = df1.index
    return df1

# Loads and combines both CSVs into df1 dataframe
df1 = loadBacktestData('backtest1.csv', 'backtest2.csv')
# Creates a company_data dictionary to store scraped data
df2 = loadBacktestData('FailedCompanies.csv', 'FailedCompanies.csv')

company_data = {}
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df2.shape)
df2
# Out:
# (155, 18)
#                                                Organization Name URL  \
# Organization Name
# JOANY              https://www.crunchbase.com/organization/impact...
# Assembly            https://www.crunchbase.com/organization/assembly
# Filament           https://www.crunchbase.com/organization/filame...
# Nudge.ai             https://www.crunchbase.com/organization/nudge-2
# Aiden                https://www.crunchbase.com/organization/aiden-2
# ...                                                              ...
# Dockbit              https://www.crunchbase.com/organization/dockbit
# Rubicore            https://www.crunchbase.com/organization/rubicore
# CareerSofia        https://www.crunchbase.com/organization/career...
# Opz.io                https://www.crunchbase.com/organization/opz-io
# SpreadVision       https://www.crunchbase.com/organization/spread...
#
#                                                           Industries  \
# Organization Name
# JOANY                         Health Care, Insurance, Internet, SaaS
# Assembly           Apps, Collaboration, Crowdsourcing, Software, ...
# Filament           Bitcoin, Blockchain, Hardware, Industrial, Int...
# Nudge.ai           B2B, CRM, Sales, Sales Automation, Social CRM,...
# Aiden              Analytics, Artificial Intelligence, Computer, ...
# ...                                                              ...
# Dockbit            Developer Platform, Developer Tools, Enterpris...
# Rubicore                                   Human Resources, Software
# CareerSofia                                              SaaS, Sales
# Opz.io             Analytics, Artificial Intelligence, Real Time,...
# SpreadVision              Advertising, Internet, Marketing, Software
#
#                                                          Description  \
# Organization Name
# JOANY              Joany is your trusted healthcare concierge. We...
# Assembly           Assembly is a web collaboration platform that ...
# Filament           Filament builds blockchain hardware and& softw...
# Nudge.ai           Nudge is a Modern Sales Platform that leverage...
# Aiden              Aiden provides an AI analytics platform intend...
# ...                                                              ...
# Dockbit            Dockbit turns your software deployments into r...
# Rubicore           At Rubicore, our mission is to enhance perform...
# CareerSofia                     Knowledge Management for Sales Teams
# Opz.io             Opz.io is an intelligent time tracking solutio...
# SpreadVision       Internet company focusing on improving storyte...
#
#                    Last Funding Amount Last Funding Amount Currency  \
# Organization Name
# JOANY                       13000000.0                          USD
# Assembly                           NaN                          NaN
# Filament                    15000000.0                          USD
# Nudge.ai                     6500000.0                          CAD
# Aiden                        1400000.0                          EUR
# ...                                ...                          ...
# Dockbit                            NaN                          NaN
# Rubicore                           NaN                          NaN
# CareerSofia                        NaN                          NaN
# Opz.io                             NaN                          NaN
# SpreadVision                       NaN                          NaN
#
#                    Last Funding Amount Currency (in USD) Last Funding Type  \
# Organization Name
# JOANY                                         13000000.0          Series A
# Assembly                                             NaN              Seed
# Filament                                      15000000.0          Series A
# Nudge.ai                                       4970448.0              Seed
# Aiden                                          1601801.0              Seed
# ...                                                  ...               ...
# Dockbit                                              NaN              Seed
# Rubicore                                             NaN              Seed
# CareerSofia                                          NaN              Seed
# Opz.io                                               NaN              Seed
# SpreadVision                                         NaN              Seed
#
#                   CB Rank (Company)  Number of Funding Rounds  \
# Organization Name
# JOANY                           410                         7
# Assembly                      5,967                         3
# Filament                      6,356                         8
# Nudge.ai                      9,064                         1
# Aiden                        14,044                         2
# ...                             ...                       ...
# Dockbit                     378,771                         1
# Rubicore                    425,410                         1
# CareerSofia                 437,415                         1
# Opz.io                      451,482                         1
# SpreadVision                800,187                         1
#
#                                                             LinkedIn  \
# Organization Name
# JOANY              https://www.linkedin.com/company/joany/?origin...
# Assembly               https://www.linkedin.com/company/assembly-inc
# Filament           https://www.linkedin.com/company/filament-netw...
# Nudge.ai                     http://www.linkedin.com/company/nudgeai
# Aiden                     https://www.linkedin.com/company/aiden.ai/
# ...                                                              ...
# Dockbit                     https://www.linkedin.com/company/Dockbit
# Rubicore           https://www.linkedin.com/company/3577242?trk=t...
# CareerSofia             https://www.linkedin.com/company/careersofia
# Opz.io                    https://www.linkedin.com/company/11006499/
# SpreadVision           https://www.linkedin.com/company/spreadvision
#
#                                           Website  \
# Organization Name
# JOANY                           https://Joany.com
# Assembly                  http://assemblymade.com
# Filament                     https://filament.com
# Nudge.ai                         https://nudge.ai
# Aiden                            http://aiden.ai/
# ...                                           ...
# Dockbit                      https://dockbit.com/
# Rubicore           http://www.rubicoredesigns.com
# CareerSofia            http://www.careersofia.com
# Opz.io                        https://www.opz.io/
# SpreadVision              http://spreadvision.eu/
#
#                                                             Founders  \
# Organization Name
# JOANY                                  Christine Carrillo, Helen Lee
# Assembly                   Chris Lloyd, Dave Newman, Matthew Deiters
# Filament           Allison Clift-Jennings, Jeremie Miller, Sally ...
# Nudge.ai                                  Paul Teshima, Steven Woods
# Aiden                          Marie Outtier, Pierre-Jean Camillieri
# ...                                                              ...
# Dockbit                                  Ahmed ElGamil, Tair Assimov
# Rubicore                                                Nana Dooreck
# CareerSofia                                              Josh Reback
# Opz.io                                     Lawrence Braun de Almeida
# SpreadVision                                        Arsenium Nicolae
#
#                   Estimated Revenue Range  Trend Score (90 Days)  \
# Organization Name
# JOANY                         $1M to $10M                    9.7
# Assembly                              NaN                    7.6
# Filament                    Less than $1M                   -0.6
# Nudge.ai                    Less than $1M                   -0.3
# Aiden                                 NaN                   -1.0
# ...                                   ...                    ...
# Dockbit                               NaN                   -0.7
# Rubicore                              NaN                   -0.6
# CareerSofia                           NaN                   -0.5
# Opz.io                                NaN                   -0.1
# SpreadVision                          NaN                    0.7
#
#                                                      Top 5 Investors  \
# Organization Name
# JOANY              Techstars, Precursor Ventures, Right Side Capi...
# Assembly           Y Combinator, Floodgate, BoxGroup, Union Squar...
# Filament           AngelList, Digital Currency Group, Techstars, ...
# Nudge.ai           OMERS Ventures, Jill Rowley, Neal Dempsey, Bra...
# Aiden              Partech, Kima Ventures, Sophia Bendz, Pierre V...
# ...                                                              ...
# Dockbit                                               NUMA Barcelona
# Rubicore                                                         NaN
# CareerSofia                                                      NaN
# Opz.io                                                 Startup Braga
# SpreadVision                                        Arsenium Nicolae
#
#                                       Headquarters Location  Investment Stage  \
# Organization Name
# JOANY                Los Angeles, California, United States               NaN
# Assembly           San Francisco, California, United States               NaN
# Filament                        Reno, Nevada, United States               NaN
# Nudge.ai                           Toronto, Ontario, Canada               NaN
# Aiden                       London, England, United Kingdom               NaN
# ...                                                     ...               ...
# Dockbit                         Barcelona, Catalonia, Spain               NaN
# Rubicore            Santa Monica, California, United States               NaN
# CareerSofia        San Francisco, California, United States               NaN
# Opz.io                                 Faro, Faro, Portugal               NaN
# SpreadVision                     Ploiesti, Prahova, Romania               NaN
#
#                   Organization Name
# Organization Name
# JOANY                         JOANY
# Assembly                   Assembly
# Filament                   Filament
# Nudge.ai                   Nudge.ai
# Aiden                         Aiden
# ...                             ...
# Dockbit                     Dockbit
# Rubicore                   Rubicore
# CareerSofia             CareerSofia
# Opz.io                       Opz.io
# SpreadVision           SpreadVision
#
# [155 rows x 18 columns]

# %%
'''
Method to set up and log into the LinkedIn using chromedriver
    @param: driverPath: path to the chromedriver.exe file
    @param: liUsername: string of LI username
    @param: liPassword: string of LI password
    @return: driver: the Chrome Webdriver (can be passed into future function arguments)
'''
def setupDriver(driverPath, liUsername, liPassword):
    # Sets up Chrome Webdriver and navigates to LinkedIn
    driver = webdriver.Chrome(driverPath)
    driver.get('https://www.linkedin.com/')
    sleep(2.0)
    
    # Signs in with given credentials and returns the driver
    driver.find_element_by_xpath('//a[text()="Sign in"]').click()
    sleep(2.0)
    username_input = driver.find_element_by_name('session_key')
    username_input.send_keys(liUsername)
    password_input = driver.find_element_by_name('session_password')
    password_input.send_keys(liPassword)
    sleep(2.0)
    driver.find_element_by_xpath('//button[text()="Sign in"]').click()
    return driver

# Launches LinkedIn and logs in
driver = setupDriver('./chromedriver', 'beasley.sarahe@gmail.com', 'Che$$ie2020')

# %%
'''
Method to save the company data as a txt file (loadable as JSON)
    @param: data: company_data dictionary of Company objects
    @return: None
'''
def saveData(data, fileName):
    data_json = json.dumps(data, default=lambda x: x.__dict__)
    with open(fileName, 'w') as outfile:
        json.dump(data_json, outfile)

'''
Method to load company data into a dictionary (same structure as Company object)
    @param: dataFile: string path to saved txt file
    @return: dataDict: a dictionary with the same structure as a Company object
'''
def loadData(dataFile):
    with open(dataFile) as json_file:
        data = json.load(json_file)
    dataDict = json.loads(data)
    return dataDict

# %%
'''
Method to get the number of connections for a founder on that founder's LI profile
    @param: driver - the chromedriver used
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the number of connections found on the profile
'''
def addConnections(driver, founder_):
    conn_ = driver.find_elements_by_xpath('//ul[@class = "pv-top-card--list pv-top-card--list-bullet mt1"]/li[@class = "inline-block"]')
    try:
        founder_.connections = conn_[0].text
    except:
        print("Connections not found for {}".format(founder_.name))
        
'''
Method to get extract the founder location
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the location found on the profile
'''
def updateLocation(driver, founder_):
    loc_ = driver.find_elements_by_xpath('//li[@class = "t-16 t-black t-normal inline-block"]')
    try:
        founder_.location = loc_[0].text
    except:
        print("Location not found for {}".format(founder_.name))

# %%
'''
Method to get the School Name, FoS and Degree Name for all educational experiences for a founder
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all education experiences
'''
def getSchools(driver, founder_):
    schools = driver.find_elements_by_xpath('//div[@class="pv-entity__degree-info"]')
    for school_ in schools:
        try:
            educ_ = Education(school_.find_element_by_class_name('pv-entity__school-name').text)
            try:
                educ_.degree = school_.find_element_by_class_name('pv-entity__degree-name').text.split('\n')[1]
            except:
                print("No degree info found for {} at {}".format(founder_.name, educ_.school))
            try:
                educ_.field = school_.find_element_by_class_name('pv-entity__fos').text.split('\n')[1]
            except:
                print("No field of study for {} at {}".format(founder_.name, educ_.school))

            # Appends the temporary education object to the founder
            founder_.education.append(educ_)
        except:
            print("No schools found for {}".format(founder_.name))

# %%
'''
Method to get the Company Name, Title and Dates for all work experiences for a founder 
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all work experiences
'''
def getWorkExperience(driver, founder_):
    experiences = driver.find_elements_by_xpath('//a[@data-control-name="background_details_company"]')
    for exp in experiences:
        exp_lst = exp.text.split('\n')
        # The exp_ is formatted as [title, 'companyname', companyname, 'datesemployed', datesemployed, ..]
        try:
            if exp_lst[0] == 'Company Name':
                exp_ = Experience(exp_lst[1])
                founder_.experience.append(exp_)
            else:
                exp_ = Experience(exp_lst[2])
                try:
                    exp_.title = exp_lst[0]
                    exp_.dates = exp_lst[4]
                    founder_.experience.append(exp_)
                except:
                    founder_.experience.append(exp_)
        except:
            print("No experience found for {}".format(str(founder_.name)))

# %%
'''
Extracts the founder information from a LinkedIn search for a founder and adds the founder to the company
    @param: driver - the chromedriver used
    @param: founder - a string for the founder's name
    @param: company_ - the Company object for the company the founder is working at
'''

def getFounderInfo(driver, founder, company_):
    res_ = driver.find_element_by_xpath('//a[@data-control-name="search_srp_result"]')
    if res_:
        res_.click()
        sleep(2.0)
        # Scrolls to the bottom of the webpage (if no scroll, error where the full webpage doens't load)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/2);")
        sleep(0.75)
        # Creates a founder object for the given founder
        founder_ = Founder(founder)
        
        #Extracts data for connections
        addConnections(driver, founder_)
        
        #Extract founder location
        updateLocation(driver, founder_)

        # Extracts degree information (formatted as a list of items)
        getSchools(driver, founder_)
 
        # Extracts experience information (formatted as a list of items)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/3);")
        sleep(1.0)
        getWorkExperience(driver, founder_)
        
        # Appends the temporary founder object to the company
        company_.founders.append(founder_)
        sleep(1.0)
    else:
        founder_ = Founder(founder)
        company_.founders.append(founder_)
        print("{} not found for {}".format(company_.name, founder_.name))
        sleep(1.0)

# %%
'''
Method to search for founder and company on the search bar and extract founder information if found
    @param: driver - the chromedriver used 
    @param: founder - a string for the name of the founder to be searched
    @param: company_ = the company being searched
    @return: None
The founder object is populated and added to the company
'''
def searchForFounder(driver, founder, company_):
    # Finds the search bar on top of the LinkedIn page
    search = driver.find_elements_by_xpath('//input[@class="search-global-typeahead__input always-show-placeholder"]')
    sleep(0.5)
    search[0].click()
    for i in range(50):
        search[0].send_keys(Keys.RIGHT)
    # Clears any existing search
    for i in range(80):
        search[0].send_keys(Keys.BACKSPACE)
    # Types in founder name + company name and searches
#     search[0].send_keys(founder + " " + company_.name.split(" ")[0])
    search[0].send_keys(founder + " " + re.split(" |,", company_.name)[0])
    search[0].send_keys(Keys.ENTER)
    sleep(2.0)
    try:
        getFounderInfo(driver, founder, company_)
    except:
        print("{} not found for {}".format(founder, company_.name))

# %%
'''
Method to add LI information for a company into the company_data dictionary with a new company object
    @param: entry: a pandas series extracted from a single row in the dataframe from loadBacktestData
    @return: None
This method updates the company_data dictionary and returns nothing
'''
def scrapeLI(entry):
    # Adds a new company entry to the company_data dictionary and populates fields
    company_ = Company(entry['Organization Name'])
    company_.description = entry['Description']
    company_.industries = [i.strip() for i in entry['Industries'].split(',')]
    company_.website = entry['Website']
    company_.lastStage = entry['Last Funding Type']
    # Edge case where the LinkedIn link does not end in '/'
    if entry['LinkedIn'][-1] != '/':
        entry['LinkedIn'] = entry['LinkedIn'] + '/'
    company_.linkedin = entry['LinkedIn']
    company_.location = entry['Headquarters Location']
    
    # Generates a list of founder names
    founderNames = [i.strip() for i in entry['Founders'].split(',')]
    try: 
        # For each founder in the list, the school name, degree, and major is extracted
        for founder in founderNames:
            searchForFounder(driver, founder, company_)
    except:
        print("Structural Error")
    # Adds the company to the company_data dictionary
#     company_data[company_.name] = company_
    company_data[company_.name] = company_

# %%
for i in range(len(df2)):
    scrapeLI(df2.iloc[i])
saveData(company_data, 'failed.txt')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# No degree info found for Christine Carrillo at University of La Verne
# Jeremie Miller not found for Filament
# Sally Carson not found for Filament
# No degree info found for Marie Outtier at EBS Universität für Wirtschaft und Recht
# No degree info found for Marie Outtier at Preparatory Classes - Lycée Charles-de-Gaulle
# No degree info found for Alexandre Lebrun at Y Combinator W14
# No degree info found for Laurent Landowski at Ecole Centrale Lille
# No field of study for Laurent Landowski at Ecole Centrale Lille
# No degree info found for Nadav Ullman at University of Connecticut
# No field of study for Nadav Ullman at University of Connecticut
# No field of study for Puneet Grewal at GOMCO PATIALA
# No degree info found for Rajeev Bharadhwaj at Indian Institute of Technology, Madras
# No field of study for Rajeev Bharadhwaj at Indian Institute of Technology, Madras
# Connections not found for Vincent Turner
# Location not found for Vincent Turner
# No degree info found for Rob Haswell at Ripon Grammar School
# No field of study for Rob Haswell at Ripon Grammar School
# No field of study for Bob Geiman at Harvard Business School
# No field of study for Walt Doyle at University of Pennsylvania - The Wharton School
# No degree info found for Walt Doyle at Middlesex School
# No field of study for Walt Doyle at Middlesex School
# No degree info found for Jeff Kim at Montgomery Blair High School
# No field of study for Jeff Kim at Montgomery Blair High School
# No degree info found for Wayne Rochat at La Trobe University
# No field of study for Wayne Rochat at La Trobe University
# No degree info found for Ankur Pansari at Brighton High School
# No field of study for Ankur Pansari at Brighton High School
# No degree info found for Alfred Kahn IV at Colorado State University
# No field of study for Alfred Kahn IV at Colorado State University
# No degree info found for Alfred Kahn IV at CCDS
# No field of study for Alfred Kahn IV at CCDS
# No degree info found for Good John at Georgia Southern University
# No field of study for Good John at Georgia Southern University
# No field of study for Vincent Ning at University of Virginia
# No degree info found for Vincent Ning at Peking University
# No degree info found for Vincent Ning at Langley High School
# No field of study for Vincent Ning at Langley High School
# No field of study for Christopher Daniels at New York University - Leonard N. Stern School of Business
# No field of study for Christopher Daniels at Florida Atlantic University
# No degree info found for Tristan Zier at Woodside High School
# No field of study for Tristan Zier at Woodside High School
# No field of study for Yan Lhert at Y Combinator
# No degree info found for Ed Buchholz at Bowling Green State University
# No field of study for Ed Buchholz at Bowling Green State University
# No field of study for Matt Ostanik at Iowa State University
# No field of study for Matt Ostanik at Greater Des Moines Leadership Institute
# No degree info found for Aleksander Kuczek at University of California, Berkeley
# No field of study for Bartek Jazwinski at University of California, Berkeley
# No degree info found for Bartek Jazwinski at US Market Access Center Entrepreneurial Training / Acceleration Program
# No field of study for Bartek Jazwinski at US Market Access Center Entrepreneurial Training / Acceleration Program
# No degree info found for Piotr Moćko at University of California, Berkeley
# No degree info found for Jim Proulx at Alfred State College - SUNY College of Technology
# No field of study for Jim Proulx at Alfred State College - SUNY College of Technology
# No degree info found for Jim Proulx at Arkport Central
# No field of study for Jim Proulx at Arkport Central
# Nicholas Campanile not found for GripeO
# Richard Panek not found for GripeO
# Steve Makula not found for GripeO
# No field of study for Philip I. Thomas at Y Combinator
# Jack Kreindler not found for Klarismo
# No field of study for Joseph Nicklas at University of New Haven
# No degree info found for Khashab Khashab at Gateway Community College
# No degree info found for Samuel Opper at Lord Fairfax Community College
# No field of study for Samuel Opper at Lord Fairfax Community College
# No degree info found for Kathryn Loewen at Abraham Baldwin Agricultural College
# No field of study for Kathryn Loewen at Abraham Baldwin Agricultural College
# No degree info found for Kathryn Loewen at Perry High School
# No field of study for Kathryn Loewen at Perry High School
# No degree info found for Brian Zotter at Stony Brook University
# No field of study for Matthieu Vollmer at University of Wisconsin-Stevens Point
# No degree info found for Matthieu Vollmer at Chilton High School
# No field of study for Matthieu Vollmer at Chilton High School
# No degree info found for Nick Williamson at Illinois Institute of Technology
# No field of study for Joseph Nicklas at University of New Haven
# No degree info found for Khashab Khashab at Gateway Community College
# Mia Sumra not found for Scroll
# Nathan Pitruzzello not found for Scroll
# No degree info found for Samuel Opper at Lord Fairfax Community College
# No field of study for Samuel Opper at Lord Fairfax Community College
# Dawson Wheeler not found for RootsRated
# No degree info found for Gordon Seabury at Hamilton College
# No field of study for Gordon Seabury at Hamilton College
# No degree info found for Gordon Seabury at St. Lawrence University
# No field of study for Gordon Seabury at St. Lawrence University
# No field of study for David Dyer at University of Kansas School of Medicine
# David Hulshof not found for TreVia Digital Health
# No field of study for Yinon Werner at University of Haifa
# No field of study for Adam Cassady at University of Chicago Law School
# No degree info found for Mohammed Aboobacker at Y Combinator
# No field of study for Mohammed Aboobacker at Y Combinator
# No field of study for Mohammed Aboobacker at Rajagiri School of Engineering & Technology
# No degree info found for Mohammed Aboobacker at METEMHSS
# Sojan V Jose not found for Marketfox
# No degree info found for Sony Mathew at Y Combinator
# No degree info found for Cory Allison at The Bryn Mawr School
# No field of study for Cory Allison at The Bryn Mawr School
# No degree info found for Jake Beyer at Y Combinator
# No field of study for Jake Beyer at Y Combinator
# No degree info found for Jake Beyer at Nankai University
# No degree info found for Chouki Hadri at HETIC
# No field of study for Chouki Hadri at HETIC
# No degree info found for Xavier Bourry at École Polytechnique
# No field of study for Xavier Bourry at École Polytechnique
# Chandra Jonelagadda not found for Minetta Brook
# No field of study for Deepak Bharadwaj at MIT Sloan School of Management
# No degree info found for Deepak Bharadwaj at The Wharton School (Microsoft Bench Program)
# No degree info found for Prabhu Venkatesh at St. Xavier's, Ranchi
# No field of study for Prabhu Venkatesh at St. Xavier's, Ranchi
# Raghu Govindaraj not found for Minetta Brook
# Sharad Rao not found for Minetta Brook
# No degree info found for Dan Silivestru at University of Waterloo
# No field of study for Dan Silivestru at University of Waterloo
# No degree info found for Gord Tanner at Conestoga College
# No field of study for Pj Lowe at University of Guelph
# No degree info found for Pj Lowe at Western University
# No field of study for Pj Lowe at Western University
# Hussein Ahmed not found for Transpose
# Skyler Johnson-Wagner not found for Transpose
# No degree info found for Nupur Mehta at Harvard University
# No degree info found for Tejaswi Sagiraju at Y Combinator
# No field of study for Tejaswi Sagiraju at Y Combinator
# No field of study for Edward Villegas at Universidad Nacional de San Agustin de Arequipa
# No field of study for Nahuel Candia at Escuela Superior de Comercio "Carlos Pellegrini"
# No degree info found for Nicolas Martinez Sala at Scalabl Academy
# Samuel Chalela Naffah not found for Shovel Apps
# No degree info found for Elmar Weber at Universität Paderborn / University of Paderborn
# No degree info found for Julian Thomas at Marlborough College
# No field of study for Julian Thomas at Marlborough College
# Zach Marburger not found for CannaBuild
# Isaac Choi not found for WrkRiot
# No degree info found for Ben Biron at The Open University of Israel
# No degree info found for Ben Biron at Oregon State University
# No degree info found for Jonathan Ofir at The Open University of Israel
# No degree info found for Jonathan Ofir at Oregon State University
# No degree info found for Max Koeppel at Trinity-Pawling School
# No field of study for Max Koeppel at Trinity-Pawling School
# Jacob Garlick not found for RevSite
# No degree info found for Rosa Lin at Northwestern University
# No field of study for Rosa Lin at Northwestern University
# No field of study for Rosa Lin at Texas A&M University
# No field of study for Patrick Ip at Sciences Po Paris
# No degree info found for Wayne Soutter at Capricorn
# No field of study for Wayne Soutter at Capricorn
# No degree info found for Brandon Malson at John Cabot University
# Max Miller not found for CloakHire
# Sharon McILnay not found for CloakHire
# No degree info found for Tom Miller at University of Detroit Mercy School of Law
# No field of study for Tom Miller at University of Detroit Mercy School of Law
# Chris McDonald not found for Gazoo
# No field of study for Jeff McDougall at The University of Texas at Austin - The Red McCombs School of Business
# Joshua Hatter not found for Parabola
# Chris Hanson not found for eager-academy-inc
# Connections not found for Chris Nicholas
# Location not found for Chris Nicholas
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error
# Structural Error

# %%
saveData(company_data, 'failed1.txt')

# %%
# Used to extract and analyze the data from the saved text file

schools = {}
fields = {}
companynames = {}
jobtitle = {}

for key in loaded.keys():
    for founder in loaded[key]['founders']:
        if founder['education']:
            for educ_ in founder['education']:
                school = educ_['school'].lower()
                for word in school.split(' '):
                    if word in schools:
                        schools[word] += 1
                    else:
                        schools[word] = 1
                if educ_['field']:
                    field = educ_['field'].lower()
                    for word in field.split(' '):
                        if word in fields:
                            fields[word] += 1
                        else:
                            fields[word] = 1
        if founder['experience']:
            for exp_ in founder['experience']:
                companyName = exp_['companyName'].lower()
                for word in companyName.split(' '):
                    if word in companynames:
                        companynames[word] += 1
                    else:
                        companynames[word] = 1
                if exp_['title']:
                    title = exp_['title'].lower()
                    if title in jobtitle:
                        jobtitle[title] += 1
                    else:
                        jobtitle[title] = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0356f98ce50f> in <module>
#       6 jobtitle = {}
#       7
# ----> 8 for key in loaded.keys():
#       9     for founder in loaded[key]['founders']:
#      10         if founder['education']:
#
# NameError: name 'loaded' is not defined

# %%
''' Saves the extracted data to a CSV'''

df_schools = pd.DataFrame.from_dict(schools, orient='index', columns=['freq'])
df_schools.sort_values(['freq'], ascending=False).to_csv('schools.csv')

df_fields = pd.DataFrame.from_dict(fields, orient='index', columns=['freq'])
df_fields.sort_values(['freq'], ascending=False).to_csv('fields.csv')

df_compnames = pd.DataFrame.from_dict(companynames, orient='index', columns=['freq'])
df_compnames.sort_values(['freq'], ascending=False).to_csv('companynames.csv')

df_titles = pd.DataFrame.from_dict(jobtitle, orient='index', columns=['freq'])
df_titles.sort_values(['freq'], ascending=False).to_csv('titles.csv')
