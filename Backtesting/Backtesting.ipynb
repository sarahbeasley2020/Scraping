# %%
# Import statements
import pandas as pd
import numpy as np 
import csv 
from parsel import Selector
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import json
import re

# %%
'''
Class to describe a given company 
    @field: name: a string for the company name
    @field: description: a string for the company description
    @field: founders: a list of Founder objects
    @field: industries: a list of strings for different industries
    @field: website: a string for the website
    @field: lastStage: a string for the last stage of funding (eg. Series A)
    @field: linkedin: a string for the company's LinkedIn profile
    @field: location: a string for the company's location
'''
class Company:
    def __init__(self, companyName):
        self.name = companyName
        self.description = None
        self.founders = []
        self.industries = []
        self.website = None
        self.lastStage = None
        self.linkedin = None
    
    def toJson(self):
        return json.dumps(self, default=lambda o: o.__dict__)
    
'''
Class to describe a founder
    @field: name: a string for the founder's name
    @field: education: an list of education objects
    @field: experience: a list of experience objects
'''
class Founder:
    def __init__(self, founderName):
        self.name = founderName
        self.connections = None
        self.location = None
        self.education = []
        self.experience = []

'''
Class to help describe a founder's education
    @field: degree: a string to describe the degree objective
    @field: school: a string for the school attended
    @field: field: a string to describe the major
'''
class Education:
    def __init__(self, schoolName):
        self.school = schoolName
        self.degree = None
        self.field = None
'''
Class to help describe a founder's experience
    @field: companyName: a string to describe the company's name
    @field: title: a string to describe the title held
    @field: description: a string to describe the job description
'''       
class Experience:
    def __init__(self, companyName):
        self.companyName = companyName
        self.title = None
        self.dates = None

# %%
'''
Loads the dataframe from Query 1 and Query 2 and merges + drops duplicates and NaNs
    @param: csv1: path to CSV 1 (formed by Query 1)
    @param: csv2: path to CSV 2 (formed by Query 2)
    @return: df1: a merged dataframe of csv1 and csv2
'''
def loadBacktestData(csv1, csv2):
    df1 = pd.read_csv(csv1)
    df2 = pd.read_csv(csv2)
    df1 = df1.append(df2)
    df1 = df1.drop_duplicates(subset=['Organization Name'])
    df1 = df1[df1.Founders.notna()]
    df1 = df1[df1.LinkedIn.notna()]
    df1 = df1.reset_index()
    for i in range(len(df1)):
        if df1.iloc[i].LinkedIn.count('about') > 0:
            df1['LinkedIn'][i] = df1['LinkedIn'][i].split('about')[0]
    return df1

# Loads and combines both CSVs into df1 dataframe
df1 = loadBacktestData('backtest1.csv', 'backtest2.csv')
# Creates a company_data dictionary to store scraped data
company_data = {}
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
'''
Method to set up and log into the LinkedIn using chromedriver
    @param: driverPath: path to the chromedriver.exe file
    @param: liUsername: string of LI username
    @param: liPassword: string of LI password
    @return: driver: the Chrome Webdriver (can be passed into future function arguments)
'''
def setupDriver(driverPath, liUsername, liPassword):
    # Sets up Chrome Webdriver and navigates to LinkedIn
    driver = webdriver.Chrome(driverPath)
    driver.get('https://www.linkedin.com/')
    sleep(2.0)
    
    # Signs in with given credentials and returns the driver
    driver.find_element_by_xpath('//a[text()="Sign in"]').click()
    sleep(2.0)
    username_input = driver.find_element_by_name('session_key')
    username_input.send_keys(liUsername)
    password_input = driver.find_element_by_name('session_password')
    password_input.send_keys(liPassword)
    sleep(2.0)
    driver.find_element_by_xpath('//button[text()="Sign in"]').click()
    return driver

# Launches LinkedIn and logs in
driver = setupDriver('./chromedriver', 'julianvallyeason@gmail.com', 'Acceleprise1')

# %%
'''
Method to save the company data as a txt file (loadable as JSON)
    @param: data: company_data dictionary of Company objects
    @return: None
'''
def saveData(data, fileName):
    data_json = json.dumps(data, default=lambda x: x.__dict__)
    with open(fileName, 'w') as outfile:
        json.dump(data_json, outfile)

'''
Method to load company data into a dictionary (same structure as Company object)
    @param: dataFile: string path to saved txt file
    @return: dataDict: a dictionary with the same structure as a Company object
'''
def loadData(dataFile):
    with open(dataFile) as json_file:
        data = json.load(json_file)
    dataDict = json.loads(data)
    return dataDict

# %%
'''
Method to get the number of connections for a founder on that founder's LI profile
    @param: driver - the chromedriver used
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the number of connections found on the profile
'''
def addConnections(driver, founder_):
    conn_ = driver.find_elements_by_xpath('//ul[@class = "pv-top-card--list pv-top-card--list-bullet mt1"]/li[@class = "inline-block"]')
    try:
        founder_.connections = conn_[0].text
    except:
        print("Connections not found for {}".format(founder_.name))
        
'''
Method to get extract the founder location
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the location found on the profile
'''
def updateLocation(driver, founder_):
    loc_ = driver.find_elements_by_xpath('//li[@class = "t-16 t-black t-normal inline-block"]')
    try:
        founder_.location = loc_[0].text
    except:
        print("Location not found for {}".format(founder_.name))

# %%
'''
Method to get the School Name, FoS and Degree Name for all educational experiences for a founder
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all education experiences
'''
def getSchools(driver, founder_):
    schools = driver.find_elements_by_xpath('//div[@class="pv-entity__degree-info"]')
    for school_ in schools:
        try:
            educ_ = Education(school_.find_element_by_class_name('pv-entity__school-name').text)
            try:
                educ_.degree = school_.find_element_by_class_name('pv-entity__degree-name').text.split('\n')[1]
            except:
                print("No degree info found for {} at {}".format(founder_.name, educ_.school))
            try:
                educ_.field = school_.find_element_by_class_name('pv-entity__fos').text.split('\n')[1]
            except:
                print("No field of study for {} at {}".format(founder_.name, educ_.school))

            # Appends the temporary education object to the founder
            founder_.education.append(educ_)
        except:
            print("No schools found for {}".format(founder_.name))

# %%
'''
Method to get the Company Name, Title and Dates for all work experiences for a founder 
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all work experiences
'''
def getWorkExperience(driver, founder_):
    experiences = driver.find_elements_by_xpath('//a[@data-control-name="background_details_company"]')
    for exp in experiences:
        exp_lst = exp.text.split('\n')
        # The exp_ is formatted as [title, 'companyname', companyname, 'datesemployed', datesemployed, ..]
        try:
            if exp_lst[0] == 'Company Name':
                exp_ = Experience(exp_lst[1])
                founder_.experience.append(exp_)
            else:
                exp_ = Experience(exp_lst[2])
                try:
                    exp_.title = exp_lst[0]
                    exp_.dates = exp_lst[4]
                    founder_.experience.append(exp_)
                except:
                    founder_.experience.append(exp_)
        except:
            print("No experience found for {}".format(str(founder_.name)))

# %%
'''
Extracts the founder information from a LinkedIn search for a founder and adds the founder to the company
    @param: driver - the chromedriver used
    @param: founder - a string for the founder's name
    @param: company_ - the Company object for the company the founder is working at
'''

def getFounderInfo(driver, founder, company_):
    res_ = driver.find_element_by_xpath('//a[@data-control-name="search_srp_result"]')
    if res_:
        res_.click()
        sleep(2.0)
        # Scrolls to the bottom of the webpage (if no scroll, error where the full webpage doens't load)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/2);")
        sleep(0.75)
        # Creates a founder object for the given founder
        founder_ = Founder(founder)
        
        #Extracts data for connections
        addConnections(driver, founder_)
        
        #Extract founder location
        updateLocation(driver, founder_)

        # Extracts degree information (formatted as a list of items)
        getSchools(driver, founder_)
 
        # Extracts experience information (formatted as a list of items)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/3);")
        sleep(1.0)
        getWorkExperience(driver, founder_)
        
        # Appends the temporary founder object to the company
        company_.founders.append(founder_)
        sleep(1.0)
    else:
        founder_ = Founder(founder)
        company_.founders.append(founder_)
        print("{} not found for {}".format(company_.name, founder_.name))
        sleep(1.0)

# %%
'''
Method to search for founder and company on the search bar and extract founder information if found
    @param: driver - the chromedriver used 
    @param: founder - a string for the name of the founder to be searched
    @param: company_ = the company being searched
    @return: None
The founder object is populated and added to the company
'''
def searchForFounder(driver, founder, company_):
    # Finds the search bar on top of the LinkedIn page
    search = driver.find_elements_by_xpath('//input[@class="search-global-typeahead__input always-show-placeholder"]')
    sleep(0.5)
    search[0].click()
    for i in range(50):
        search[0].send_keys(Keys.RIGHT)
    # Clears any existing search
    for i in range(80):
        search[0].send_keys(Keys.BACKSPACE)
    # Types in founder name + company name and searches
#     search[0].send_keys(founder + " " + company_.name.split(" ")[0])
    search[0].send_keys(founder + " " + re.split(" |,", company_.name)[0])
    search[0].send_keys(Keys.ENTER)
    sleep(2.0)
    try:
        getFounderInfo(driver, founder, company_)
    except:
        print("{} not found for {}".format(founder, company_.name))

# %%
'''
Method to add LI information for a company into the company_data dictionary with a new company object
    @param: entry: a pandas series extracted from a single row in the dataframe from loadBacktestData
    @return: None
This method updates the company_data dictionary and returns nothing
'''
def scrapeLI(entry):
    # Adds a new company entry to the company_data dictionary and populates fields
    company_ = Company(entry['Organization Name'])
    company_.description = entry['Description']
    company_.industries = [i.strip() for i in entry['Industries'].split(',')]
    company_.website = entry['Website']
    company_.lastStage = entry['Last Funding Type']
    # Edge case where the LinkedIn link does not end in '/'
    if entry['LinkedIn'][-1] != '/':
        entry['LinkedIn'] = entry['LinkedIn'] + '/'
    company_.linkedin = entry['LinkedIn']
    company_.location = entry['Headquarters Location']
    
    # Generates a list of founder names
    founderNames = [i.strip() for i in entry['Founders'].split(',')]
    try:
        # For each founder in the list, the school name, degree, and major is extracted
        for founder in founderNames:
            searchForFounder(driver, founder, company_)
    except:
        print("Structural Error")
    # Adds the company to the company_data dictionary
    company_data[company_.name] = company_

# %%
for i in range(1300,1400):
    print(i)
    if i%5 == 0:
        sleep(5.0)
    scrapeLI(df1.iloc[i])
# Out:
# 1300
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# No degree info found for David Champion at George Watson's College
# No field of study for David Champion at George Watson's College
# No degree info found for Joel Milton at University of St Andrews
# 1301
# No degree info found for Novo Abakare at St Paul's School
# No field of study for Novo Abakare at St Paul's School
# 1302
# Connections not found for Nadav Tal-Israel
# Location not found for Nadav Tal-Israel
# 1303
# 1304
# No field of study for Jaime Bosch at Telefonica universitas
# 1305
# 1306
# No degree info found for Arto Ruotsalainen at Jyväskylän yliopisto
# 1307
# No field of study for Frederic Haitz at European School Karlsruhe
# No field of study for Maximilian Waldmann at European School Frankfurt
# 1308
# No field of study for Alex Kelly at Law Society of Ireland
# No degree info found for Ian Nolan at Belvedere College SJ
# No field of study for Ian Nolan at Belvedere College SJ
# 1309
# No field of study for Gabriel Safar at Boston College Law School
# No degree info found for Gabriel Safar at The George Washington University
# No field of study for Gabriel Safar at The George Washington University
# No degree info found for Jonathan Eskow at Benjamin N. Cardozo School of Law, Yeshiva University
# No field of study for Jonathan Eskow at Benjamin N. Cardozo School of Law, Yeshiva University
# 1310
# 1311
# No degree info found for Alex Kremer at Theresianum
# No field of study for Alex Kremer at Theresianum
# No degree info found for Leith Stevens at Sir William Borlase's Grammar School
# No field of study for Leith Stevens at Sir William Borlase's Grammar School
# No degree info found for Nathan Probst at Washington State University
# 1312
# No degree info found for Arnaud Dupuis at Pierre and Marie Curie University
# No field of study for Arnaud Dupuis at Pierre and Marie Curie University
# 1313
# 1314
# 1315
# 1316
# 1317
# 1318
# No field of study for Adam Pisoni at Leaders In Tech
# 1319
# No degree info found for Prem Luthra at University of Arizona
# No field of study for Prem Luthra at University of Arizona
# 1320
# No degree info found for Anna-Katrina Shedletsky at UC Berkeley Haas School of Business
# No field of study for Anna-Katrina Shedletsky at UC Berkeley Haas School of Business
# No degree info found for Samuel Weiss at Massachusetts Institute of Technology
# No field of study for Samuel Weiss at Massachusetts Institute of Technology
# 1321
# 1322
# No field of study for Sameer Penakalapati at Harvard Business School
# No field of study for Sameer Penakalapati at Birla Institute of Technology and Science, Pilani
# No field of study for Sameer Penakalapati at Gulbarga University
# 1323
# 1324
# No degree info found for Arman Eshraghi at Ebn Yamin High School
# No field of study for Arman Eshraghi at Ebn Yamin High School
# 1325
# No degree info found for Chris King at Rondebosch Boys
# No field of study for Chris King at Rondebosch Boys
# No degree info found for Dave New at Rondebosch Boys' High School
# No field of study for Dave New at Rondebosch Boys' High School
# 1326
# No degree info found for Gilad Amitai at Tel Aviv University
# No field of study for Gilad Amitai at The College of Management Academic Studies
# No degree info found for Oded Poncz at Ben Tzvi
# No field of study for Oded Poncz at Ben Tzvi
# 1327
# No degree info found for Matteo Merli at ENSEIRB-MATMECA
# No field of study for Matteo Merli at ENSEIRB-MATMECA
# No degree info found for Sanjeev Kulkarni at P.C. Jabins Science College
# No field of study for Sanjeev Kulkarni at P.C. Jabins Science College
# 1328
# No degree info found for Andy Schwartz at Cherry Hill East
# No field of study for Andy Schwartz at Cherry Hill East
# Connections not found for Bhavik Patel
# Location not found for Bhavik Patel
# Chaz Brown not found for xtraCHEF
# 1329
# Tavis Morello not found for Sober Grid
# 1330
# 1331
# No field of study for Maria Chatzou Dunford at Hellenic Open University
# 1332
# No field of study for Maggie Shih at University of Southern California
# 1333
# 1334
# 1335
# Keldon Paxman not found for Listen Technologies
# 1336
# 1337
# 1338
# 1339
# No field of study for Madhu Mathihalli at Basel Mission
# 1340
# 1341
# No degree info found for Brian Denker at Naperville North High School
# No field of study for Brian Denker at Naperville North High School
# 1342
# No degree info found for Chad Nickell at Clemson University
# No degree info found for Chad Nickell at United States Naval Academy
# No degree info found for Greg Parker at Franklin High School
# No field of study for Greg Parker at Franklin High School
# No degree info found for Jonathan Smalley at Samford University
# No field of study for Jonathan Smalley at Samford University
# No field of study for Patrick Williamson at University of Colorado at Boulder
# No degree info found for Patrick Williamson at Appalachian State University
# 1343
# No degree info found for Bryn Jones at Y Combinator
# No field of study for Bryn Jones at Y Combinator
# No degree info found for Jonathan Mendes at University of the West Indies, Cave Hill Campus
# No field of study for Jonathan Mendes at University of the West Indies, Cave Hill Campus
# No degree info found for Jonathan Mendes at Y Combinator
# No field of study for Jonathan Mendes at Y Combinator
# No degree info found for Luke Swanek at St. Peter's Secondary School
# No field of study for Luke Swanek at St. Peter's Secondary School
# 1344
# No degree info found for Abhay Parekh at The Johns Hopkins University
# No field of study for Abhay Parekh at The Johns Hopkins University
# 1345
# 1346
# Eric Stone not found for Flipside Crypto
# 1347
# 1348
# No degree info found for Benjamin Chouraqui at HEC Paris
# No field of study for Benjamin Chouraqui at HEC Paris
# No degree info found for Benjamin Chouraqui at HEC Paris
# No field of study for Benjamin Chouraqui at HEC Paris
# No field of study for Lionel Chouraqui at ESSEC Business School
# 1349
# 1350
# Connections not found for Tim Zheng
# Location not found for Tim Zheng
# 1351
# 1352
# No degree info found for Alexander Kvamme at Duke University
# No field of study for Alexander Kvamme at Duke University
# No degree info found for Alexander Kvamme at Menlo High School
# No field of study for Alexander Kvamme at Menlo High School
# 1353
# No degree info found for Fabian Blaicher at Karlsruhe Institute of Technology (KIT)
# No degree info found for Fabian Blaicher at Carnegie Mellon University
# No degree info found for Fabian Blaicher at Nanyang Technological University
# No degree info found for Jenna Brown at Chesham High
# No field of study for Jenna Brown at Chesham High
# No degree info found for Jenna Brown at University of International Relations, Beijing
# 1354
# No field of study for Jonathan Bensamoun at The University of Chicago - Booth School of Business
# 1355
# No degree info found for Mark Heys at University of Toronto
# 1356
# No field of study for Jeremy Hindle at Y Combinator
# No degree info found for Nicholas Shekerdemian at Cheung Kong Graduate School of Business
# No degree info found for Nicholas Shekerdemian at Y Combinator
# No field of study for Nicholas Shekerdemian at Y Combinator
# 1357
# No field of study for Samir Diwan at University of Washington, Michael G. Foster School of Business
# 1358
# No degree info found for Quentin Nickmans at Solvay Business School
# No degree info found for Sandro Munda at HEPL - Haute Ecole de la Province de Liège
# No degree info found for Thibaud Elziere at Ecole centrale de Lyon
# No degree info found for Thibaud Elziere at Technische Universität Berlin
# No degree info found for Thibaud Elziere at Université Lumière (Lyon II)
# 1359
# No field of study for Jernej Barbic at Gimnazija Tolmin
# 1360
# No degree info found for Alexey Melnichenko at North Carolina State University
# No degree info found for Alexey Melnichenko at North Carolina School of Science and Mathematics
# No field of study for Alexey Melnichenko at North Carolina School of Science and Mathematics
# No degree info found for Joe Davy at North Carolina School of Science and Mathematics
# No field of study for Joe Davy at North Carolina School of Science and Mathematics
# 1361
# 1362
# No field of study for Abhishek Poddar at Stanford Graduate School of Business
# No field of study for Abhishek Poddar at Indian Institute of Technology, Kanpur
# No field of study for Tapan Pandita at Indian Institute of Technology, Bombay
# No field of study for Tapan Pandita at St. Francis D'Assisi High School
# 1363
# 1364
# 1365
# No field of study for Florian Motlik at Technische Universität Wien
# No degree info found for Florian Motlik at Technische Universität Wien
# No field of study for Florian Motlik at Technische Universität Wien
# No degree info found for Manuel Weiss at business.academy.donaustadt
# No field of study for Manuel Weiss at business.academy.donaustadt
# 1366
# No degree info found for Ray Myers at University of Florida
# 1367
# No degree info found for Danny Donado at Thomas Jefferson Highschool
# No field of study for Danny Donado at Thomas Jefferson Highschool
# No field of study for James Cameron at Stanford University Graduate School of Business
# No experience found for James Cameron
# 1368
# 1369
# No degree info found for Yael Sherman at IDF - Programming School (Mamram)
# 1370
# 1371
# 1372
# 1373
# 1374
# 1375
# Stephen Gartside not found for GenXComm
# 1376
# Bob Hiller not found for HireAthena
# No field of study for Kristen Koh Goldstein at Harvard Business School
# No field of study for Kristen Koh Goldstein at Cornell University
# Mark Goldstein not found for HireAthena
# 1377
# No degree info found for Tim Szeto at York University
# No field of study for Tim Szeto at York University
# 1378
# 1379
# No field of study for Karthik Bala at MIT Sloan School of Management
# No degree info found for Karthik Bala at Brighton High School
# No field of study for Karthik Bala at Brighton High School
# 1380
# No degree info found for Cristian Tamas at Griffiths School of Management
# No field of study for Raul Popa at Universitatea „Babeș-Bolyai” din Cluj-Napoca
# No degree info found for Raul Popa at Emanuil Gojdu National College
# 1381
# Connections not found for Srinivas Krishnamurti
# Location not found for Srinivas Krishnamurti
# 1382
# No degree info found for Chris Andrasick at Iolani School
# No field of study for Chris Andrasick at Iolani School
# 1383
# No degree info found for Arnulf Hsu at UC Irvine
# 1384
# 1385
# Bjorn Kolbmuller not found for Zenloop
# Connections not found for Paul Schwarzenholz
# Location not found for Paul Schwarzenholz
# 1386
# No field of study for Emmanuelle Fauchier Magnan at 42
# No field of study for Emmanuelle Fauchier Magnan at HEC School of Management
# No degree info found for Quitterie Mathelin-Moreaux at Preparatory School - Saint louis de Gonzague
# No field of study for Quitterie Mathelin-Moreaux at Preparatory School - Saint louis de Gonzague
# No degree info found for Quitterie Mathelin-Moreaux at --
# No field of study for Quitterie Mathelin-Moreaux at --
# 1387
# No degree info found for Paul Powers at Harvard University
# 1388
# No field of study for Fabien Potencier at HEC School of Management
# No degree info found for Fabien Potencier at Ecole Nationale Supérieure des Mines de Nancy
# No field of study for Fabien Potencier at Ecole Nationale Supérieure des Mines de Nancy
# 1389
# 1390
# No degree info found for Grant Jurgeneit at University of Windsor
# No field of study for Grant Jurgeneit at University of Windsor
# 1391
# 1392
# 1393
# No degree info found for John Grange at University of Nebraska at Omaha
# Manuel Quevedo not found for OpsCompass
# 1394
# 1395
# No degree info found for Moritz Cramer at Kungliga tekniska högskolan / KTH Royal Institute of Technology
# No degree info found for Simon Koopmann at UNITECH International
# 1396
# Dimitri De Boose not found for URBANTZ
# No degree info found for Jérémy Jaquet at Haute Ecole 'Groupe ICHEC - ISC Saint-Louis - ISFSC', Bruxelles
# No degree info found for Jérémy Jaquet at College d'Alzon Bure
# No field of study for Jérémy Jaquet at College d'Alzon Bure
# 1397
# No degree info found for Jeff Carr at Broomfield HS
# No field of study for Jeff Carr at Broomfield HS
# 1398
# No degree info found for Jason Kerr at Marlborough Boys College
# No field of study for Jason Kerr at Marlborough Boys College
# 1399
# No field of study for Ken Charhut at Cornell University
# No field of study for Ken Charhut at The University of Chicago Booth School of Business
# No field of study for Mark Pollard at Purdue University

# %%
saveData(company_data, 'data1300.txt')

# %%
# Used to extract and analyze the data from the saved text file

schools = {}
fields = {}
companynames = {}
jobtitle = {}

for key in loaded.keys():
    for founder in loaded[key]['founders']:
        if founder['education']:
            for educ_ in founder['education']:
                school = educ_['school'].lower()
                for word in school.split(' '):
                    if word in schools:
                        schools[word] += 1
                    else:
                        schools[word] = 1
                if educ_['field']:
                    field = educ_['field'].lower()
                    for word in field.split(' '):
                        if word in fields:
                            fields[word] += 1
                        else:
                            fields[word] = 1
        if founder['experience']:
            for exp_ in founder['experience']:
                companyName = exp_['companyName'].lower()
                for word in companyName.split(' '):
                    if word in companynames:
                        companynames[word] += 1
                    else:
                        companynames[word] = 1
                if exp_['title']:
                    title = exp_['title'].lower()
                    if title in jobtitle:
                        jobtitle[title] += 1
                    else:
                        jobtitle[title] = 1

# %%
''' Saves the extracted data to a CSV'''

df_schools = pd.DataFrame.from_dict(schools, orient='index', columns=['freq'])
df_schools.sort_values(['freq'], ascending=False).to_csv('schools.csv')

df_fields = pd.DataFrame.from_dict(fields, orient='index', columns=['freq'])
df_fields.sort_values(['freq'], ascending=False).to_csv('fields.csv')

df_compnames = pd.DataFrame.from_dict(companynames, orient='index', columns=['freq'])
df_compnames.sort_values(['freq'], ascending=False).to_csv('companynames.csv')

df_titles = pd.DataFrame.from_dict(jobtitle, orient='index', columns=['freq'])
df_titles.sort_values(['freq'], ascending=False).to_csv('titles.csv')
