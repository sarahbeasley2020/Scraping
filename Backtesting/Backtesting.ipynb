# %%
# Import statements
import pandas as pd
import numpy as np 
import csv 
from parsel import Selector
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import json
import re

# %%
'''
Class to describe a given company 
    @field: name: a string for the company name
    @field: description: a string for the company description
    @field: founders: a list of Founder objects
    @field: industries: a list of strings for different industries
    @field: website: a string for the website
    @field: lastStage: a string for the last stage of funding (eg. Series A)
    @field: linkedin: a string for the company's LinkedIn profile
    @field: location: a string for the company's location
'''
class Company:
    def __init__(self, companyName):
        self.name = companyName
        self.description = None
        self.founders = []
        self.industries = []
        self.website = None
        self.lastStage = None
        self.linkedin = None
    
    def toJson(self):
        return json.dumps(self, default=lambda o: o.__dict__)
    
'''
Class to describe a founder
    @field: name: a string for the founder's name
    @field: education: an list of education objects
    @field: experience: a list of experience objects
'''
class Founder:
    def __init__(self, founderName):
        self.name = founderName
        self.connections = None
        self.location = None
        self.education = []
        self.experience = []

'''
Class to help describe a founder's education
    @field: degree: a string to describe the degree objective
    @field: school: a string for the school attended
    @field: field: a string to describe the major
'''
class Education:
    def __init__(self, schoolName):
        self.school = schoolName
        self.degree = None
        self.field = None
'''
Class to help describe a founder's experience
    @field: companyName: a string to describe the company's name
    @field: title: a string to describe the title held
    @field: description: a string to describe the job description
'''       
class Experience:
    def __init__(self, companyName):
        self.companyName = companyName
        self.title = None
        self.dates = None

# %%
'''
Loads the dataframe from Query 1 and Query 2 and merges + drops duplicates and NaNs
    @param: csv1: path to CSV 1 (formed by Query 1)
    @param: csv2: path to CSV 2 (formed by Query 2)
    @return: df1: a merged dataframe of csv1 and csv2
'''
def loadBacktestData(csv1, csv2):
    df1 = pd.read_csv(csv1)
    df2 = pd.read_csv(csv2)
    df1 = df1.append(df2)
    df1 = df1.drop_duplicates(subset=['Organization Name'])
    df1 = df1[df1.Founders.notna()]
    df1 = df1[df1.LinkedIn.notna()]
    df1 = df1.reset_index()
    for i in range(len(df1)):
        if df1.iloc[i].LinkedIn.count('about') > 0:
            df1['LinkedIn'][i] = df1['LinkedIn'][i].split('about')[0]
    return df1

# Loads and combines both CSVs into df1 dataframe
df1 = loadBacktestData('backtest1.csv', 'backtest2.csv')
# Creates a company_data dictionary to store scraped data
company_data = {}
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
'''
Method to set up and log into the LinkedIn using chromedriver
    @param: driverPath: path to the chromedriver.exe file
    @param: liUsername: string of LI username
    @param: liPassword: string of LI password
    @return: driver: the Chrome Webdriver (can be passed into future function arguments)
'''
def setupDriver(driverPath, liUsername, liPassword):
    # Sets up Chrome Webdriver and navigates to LinkedIn
    driver = webdriver.Chrome(driverPath)
    driver.get('https://www.linkedin.com/')
    sleep(2.0)
    
    # Signs in with given credentials and returns the driver
    driver.find_element_by_xpath('//a[text()="Sign in"]').click()
    sleep(2.0)
    username_input = driver.find_element_by_name('session_key')
    username_input.send_keys(liUsername)
    password_input = driver.find_element_by_name('session_password')
    password_input.send_keys(liPassword)
    sleep(2.0)
    driver.find_element_by_xpath('//button[text()="Sign in"]').click()
    return driver

# Launches LinkedIn and logs in
driver = setupDriver('./chromedriver', 'julianvallyeason@gmail.com', 'Acceleprise1')

# %%
'''
Method to save the company data as a txt file (loadable as JSON)
    @param: data: company_data dictionary of Company objects
    @return: None
'''
def saveData(data, fileName):
    data_json = json.dumps(data, default=lambda x: x.__dict__)
    with open(fileName, 'w') as outfile:
        json.dump(data_json, outfile)

'''
Method to load company data into a dictionary (same structure as Company object)
    @param: dataFile: string path to saved txt file
    @return: dataDict: a dictionary with the same structure as a Company object
'''
def loadData(dataFile):
    with open(dataFile) as json_file:
        data = json.load(json_file)
    dataDict = json.loads(data)
    return dataDict

# %%
'''
Method to get the number of connections for a founder on that founder's LI profile
    @param: driver - the chromedriver used
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the number of connections found on the profile
'''
def addConnections(driver, founder_):
    conn_ = driver.find_elements_by_xpath('//ul[@class = "pv-top-card--list pv-top-card--list-bullet mt1"]/li[@class = "inline-block"]')
    try:
        founder_.connections = conn_[0].text
    except:
        print("Connections not found for {}".format(founder_.name))
        
'''
Method to get extract the founder location
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the location found on the profile
'''
def updateLocation(driver, founder_):
    loc_ = driver.find_elements_by_xpath('//li[@class = "t-16 t-black t-normal inline-block"]')
    try:
        founder_.location = loc_[0].text
    except:
        print("Location not found for {}".format(founder_.name))

# %%
'''
Method to get the School Name, FoS and Degree Name for all educational experiences for a founder
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all education experiences
'''
def getSchools(driver, founder_):
    schools = driver.find_elements_by_xpath('//div[@class="pv-entity__degree-info"]')
    for school_ in schools:
        try:
            educ_ = Education(school_.find_element_by_class_name('pv-entity__school-name').text)
            try:
                educ_.degree = school_.find_element_by_class_name('pv-entity__degree-name').text.split('\n')[1]
            except:
                print("No degree info found for {} at {}".format(founder_.name, educ_.school))
            try:
                educ_.field = school_.find_element_by_class_name('pv-entity__fos').text.split('\n')[1]
            except:
                print("No field of study for {} at {}".format(founder_.name, educ_.school))

            # Appends the temporary education object to the founder
            founder_.education.append(educ_)
        except:
            print("No schools found for {}".format(founder_.name))

# %%
'''
Method to get the Company Name, Title and Dates for all work experiences for a founder 
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all work experiences
'''
def getWorkExperience(driver, founder_):
    experiences = driver.find_elements_by_xpath('//a[@data-control-name="background_details_company"]')
    for exp in experiences:
        exp_lst = exp.text.split('\n')
        # The exp_ is formatted as [title, 'companyname', companyname, 'datesemployed', datesemployed, ..]
        try:
            if exp_lst[0] == 'Company Name':
                exp_ = Experience(exp_lst[1])
                founder_.experience.append(exp_)
            else:
                exp_ = Experience(exp_lst[2])
                try:
                    exp_.title = exp_lst[0]
                    exp_.dates = exp_lst[4]
                    founder_.experience.append(exp_)
                except:
                    founder_.experience.append(exp_)
        except:
            print("No experience found for {}".format(str(founder_.name)))

# %%
'''
Extracts the founder information from a LinkedIn search for a founder and adds the founder to the company
    @param: driver - the chromedriver used
    @param: founder - a string for the founder's name
    @param: company_ - the Company object for the company the founder is working at
'''

def getFounderInfo(driver, founder, company_):
    res_ = driver.find_element_by_xpath('//a[@data-control-name="search_srp_result"]')
    if res_:
        res_.click()
        sleep(2.0)
        # Scrolls to the bottom of the webpage (if no scroll, error where the full webpage doens't load)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/2);")
        sleep(0.75)
        # Creates a founder object for the given founder
        founder_ = Founder(founder)
        
        #Extracts data for connections
        addConnections(driver, founder_)
        
        #Extract founder location
        updateLocation(driver, founder_)

        # Extracts degree information (formatted as a list of items)
        getSchools(driver, founder_)
 
        # Extracts experience information (formatted as a list of items)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/3);")
        sleep(1.0)
        getWorkExperience(driver, founder_)
        
        # Appends the temporary founder object to the company
        company_.founders.append(founder_)
        sleep(1.0)
    else:
        founder_ = Founder(founder)
        company_.founders.append(founder_)
        print("{} not found for {}".format(company_.name, founder_.name))
        sleep(1.0)

# %%
'''
Method to search for founder and company on the search bar and extract founder information if found
    @param: driver - the chromedriver used 
    @param: founder - a string for the name of the founder to be searched
    @param: company_ = the company being searched
    @return: None
The founder object is populated and added to the company
'''
def searchForFounder(driver, founder, company_):
    # Finds the search bar on top of the LinkedIn page
    search = driver.find_elements_by_xpath('//input[@class="search-global-typeahead__input always-show-placeholder"]')
    sleep(0.5)
    search[0].click()
    for i in range(50):
        search[0].send_keys(Keys.RIGHT)
    # Clears any existing search
    for i in range(80):
        search[0].send_keys(Keys.BACKSPACE)
    # Types in founder name + company name and searches
#     search[0].send_keys(founder + " " + company_.name.split(" ")[0])
    search[0].send_keys(founder + " " + re.split(" |,", company_.name)[0])
    search[0].send_keys(Keys.ENTER)
    sleep(2.0)
    try:
        getFounderInfo(driver, founder, company_)
    except:
        print("{} not found for {}".format(founder, company_.name))

# %%
'''
Method to add LI information for a company into the company_data dictionary with a new company object
    @param: entry: a pandas series extracted from a single row in the dataframe from loadBacktestData
    @return: None
This method updates the company_data dictionary and returns nothing
'''
def scrapeLI(entry):
    # Adds a new company entry to the company_data dictionary and populates fields
    company_ = Company(entry['Organization Name'])
    company_.description = entry['Description']
    company_.industries = [i.strip() for i in entry['Industries'].split(',')]
    company_.website = entry['Website']
    company_.lastStage = entry['Last Funding Type']
    # Edge case where the LinkedIn link does not end in '/'
    if entry['LinkedIn'][-1] != '/':
        entry['LinkedIn'] = entry['LinkedIn'] + '/'
    company_.linkedin = entry['LinkedIn']
    company_.location = entry['Headquarters Location']
    
    # Generates a list of founder names
    founderNames = [i.strip() for i in entry['Founders'].split(',')]
    try:
        # For each founder in the list, the school name, degree, and major is extracted
        for founder in founderNames:
            searchForFounder(driver, founder, company_)
    except:
        print("Structural Error")
    # Adds the company to the company_data dictionary
    company_data[company_.name] = company_

# %%
for i in range(700,800):
    print(i)
    if i%5 == 0:
        sleep(5.0)
    scrapeLI(df1.iloc[i])
# Out:
# 700
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# 701
# 702
# 703
# No degree info found for Elliott Risby at Australian Film Television Radio School
# No field of study for Elliott Risby at Australian Film Television Radio School
# 704
# No degree info found for Thimo Buchheister at Westfälische Wilhelms-Universität Münster
# No field of study for Thimo Buchheister at Wirtschaftsgymnasium Ibbenbüren
# 705
# 706
# No degree info found for Sarah Sanders at Indian Hill High School
# No field of study for Sarah Sanders at Indian Hill High School
# 707
# 708
# No degree info found for Billy Brush at University of Pittsburgh
# Juan Delgado not found for DarkHorse
# 709
# No degree info found for Arda Helvacılar at Anadolu Üniversitesi
# No field of study for Arda Helvacılar at Kabataş Erkek Lisesi
# 710
# Javier Amozurrutia not found for Mazmobi
# 711
# No degree info found for Jakob Adeltoft at DTU - Technical University of Denmark
# No degree info found for Jakob Adeltoft at Higher Technical Examination Programme
# No field of study for Jakob Adeltoft at Higher Technical Examination Programme
# 712
# No field of study for Chris Defour at The Hotchkiss School
# No field of study for Mark Methot at John Molson School of Business
# No degree info found for Mark Methot at CEGEP - John Abbott College
# No field of study for Mark Methot at CEGEP - John Abbott College
# No degree info found for Mark Methot at Collège Bourget
# No field of study for Mark Methot at Collège Bourget
# No degree info found for Mat Diab at Concordia University
# No degree info found for Mat Diab at Groton School
# No field of study for Mat Diab at Groton School
# 713
# 714
# No degree info found for Joseph Shiraz at Universidad Latinoamericana de Ciencia y Tecnología
# 715
# Connections not found for Brian Koenigberg
# Location not found for Brian Koenigberg
# 716
# No degree info found for Adrian Kitto at University of Canterbury
# No field of study for Adrian Kitto at University of Canterbury
# No field of study for Andy Budiman at Western Australian School of Art Design & Media
# No degree info found for Andy Budiman at Wesley College, Perth
# No field of study for Andy Budiman at Wesley College, Perth
# 717
# No degree info found for Yunus ÖZCAN at Karadeniz Teknik Üniversitesi
# 718
# 719
# No field of study for Aaron John at Trinity Western University
# No degree info found for George Metcalfe at Wales Comprehensive School
# No field of study for George Metcalfe at Wales Comprehensive School
# 720
# No degree info found for Denise Umubyeyi at University of Notre Dame London
# No field of study for Denise Umubyeyi at University of Notre Dame London
# No field of study for Jasmine Shells at La Fundación de Ortega y Gasset
# 721
# 722
# Bert Navarrete not found for BlockIDE
# No degree info found for Casey Gardiner at Tigerlabs
# No field of study for Casey Gardiner at Tigerlabs
# No field of study for Casey Gardiner at University of California, Berkeley
# Connections not found for Chen Atlas
# Location not found for Chen Atlas
# 723
# No degree info found for Dmitrii Kislenko at Lyceum 64
# No field of study for Simon Litvinov at Secondary General School 73
# 724
# 725
# 726
# No field of study for Stefan Jeftić at RMIT University
# 727
# Connections not found for Kieran Fitzsimons
# Location not found for Kieran Fitzsimons
# 728
# 729
# 730
# Piotr Jerzy Mamenas not found for Finphare
# 731
# No degree info found for Andrew Pratt at Sandpoint High School
# 732
# Mihai Luchian not found for crystal-matrix.com
# 733
# No field of study for Duncan Cowan at Liverpool Blue Coat School
# No degree info found for Jake Jenner at Colchester Royal Grammar School
# No field of study for Jake Jenner at Colchester Royal Grammar School
# No field of study for Neil Tanna at BPP Law School
# No degree info found for Neil Tanna at Prior Park College
# No field of study for Neil Tanna at Prior Park College
# 734
# No field of study for Jamie H. Finn at Tabor Academy
# 735
# No degree info found for Benjamin Netter at Y Combinator
# No field of study for Benjamin Netter at Y Combinator
# No degree info found for Benjamin Netter at EPITECH - European Institute of Technology
# No field of study for Benjamin Netter at EPITECH - European Institute of Technology
# No degree info found for Benjamin Netter at Concordia University
# No field of study for Benjamin Netter at Concordia University
# 736
# No degree info found for Melanie Fellay at University of Virginia Semester at Sea
# No field of study for Zari Zahra at Harvard Business School
# 737
# No degree info found for Alexandre Louisy at Y Combinator
# No field of study for Alexandre Louisy at Y Combinator
# No field of study for Barnaby Malet at Y Combinator
# No degree info found for Thibaud Elziere at Ecole centrale de Lyon
# No degree info found for Thibaud Elziere at Technische Universität Berlin
# No degree info found for Thibaud Elziere at Université Lumière (Lyon II)
# 738
# 739
# No field of study for Amir Kavousian at Stanford Graduate School of Business
# No degree info found for Michael Coates at Universidade Federal do Ceará
# 740
# No field of study for Felix Feng at Consensys Academy
# No field of study for Felix Feng at Bradfield School of Computer Science
# No field of study for Inje Yeo at Rhode Island School of Design
# No field of study for Inje Yeo at Arthur L. Johnson High School
# 741
# No degree info found for Oona Rokyta at The Australian National University
# No degree info found for Oren Reuveni at Hunter College
# No field of study for Oren Reuveni at Hunter College
# 742
# No degree info found for Mark Little at Saïd Business School, University of Oxford
# No degree info found for Mark Little at Growth Tribe Academy
# No degree info found for Mark Little at University of Exeter
# No degree info found for Rupert Barksfield at Reading Blue Coat School
# 743
# No field of study for Edwin Mejia at Boston University School of Law
# No degree info found for Edwin Mejia at Boston Latin School
# No field of study for Edwin Mejia at Boston Latin School
# No field of study for Felix Rodriguez at Saint Raymonds
# 744
# No field of study for Sanj Sanampudi at Columbia University - Columbia Business School
# No field of study for Sanj Sanampudi at London Business School
# 745
# 746
# Connections not found for Chris Grabowski
# Location not found for Chris Grabowski
# No field of study for Oskar Kiwic at Medical University of Silesia
# No field of study for MD at Erasmus Universiteit Rotterdam
# No field of study for MD at Technische Universiteit Delft
# No degree info found for Przemysław Magaczewski at Lapin yliopisto
# Connections not found for Rodney J. Anderson
# Location not found for Rodney J. Anderson
# No field of study for MD at Erasmus Universiteit Rotterdam
# No field of study for MD at Technische Universiteit Delft
# Connections not found for Tom Jadczyk
# Location not found for Tom Jadczyk
# 747
# No degree info found for David Francis at Cypress College
# No degree info found for David Francis at Arizona State University
# No field of study for Tim Duncan at Washington University School of Law
# No field of study for Tim Duncan at University of Wisconsin-Madison
# 748
# No field of study for Jake Mor at Y Combinator
# 749
# No degree info found for Mike Ross Kane at Central High School
# No field of study for Mike Ross Kane at Central High School
# 750
# No degree info found for Hans Nickel at Technische Universität München
# 751
# 752
# Connections not found for Cameron MacArthur
# Location not found for Cameron MacArthur
# 753
# 754
# No degree info found for Larry Neumann at University of Waterloo
# No field of study for Larry Neumann at University of Waterloo
# No degree info found for Larry Neumann at Bethel Public School
# No field of study for Larry Neumann at Bethel Public School
# No field of study for Richman Neumann at Cameron Heights Collegiate Institute
# 755
# No field of study for Daniel Dinh at Y Combinator
# No degree info found for Daniel Dinh at Beijing Film Academy
# No field of study for Daniel Dinh at Beijing Film Academy
# No field of study for Marc Höffl at Y Combinator
# 756
# No field of study for Alyssa Emmungil at Thiga Academy
# No field of study for Alyssa Emmungil at UVSQ Université de Versailles Saint-Quentin-en-Yvelines
# No field of study for Rim zerhouni at ESSEC - ESSEC Business School
# No field of study for Rim zerhouni at IPADE Business School
# 757
# Shivaprakash Bidlur not found for OpenAVN
# 758
# 759
# No degree info found for Jeremy Schewe at Northern Arizona University
# No field of study for Jeremy Schewe at Northern Arizona University
# No degree info found for Jeremy Schewe at St. Xavier High School
# No field of study for Jeremy Schewe at St. Xavier High School
# 760
# 761
# No degree info found for Maciej Lobodzinski at Y Combinator
# No field of study for Maciej Lobodzinski at Y Combinator
# 762
# 763
# No degree info found for Timothy Baynes at University of Dayton
# 764
# Elizabeth Bochner not found for Convesio
# Thomas Fanelli not found for Convesio
# 765
# No field of study for Baran Korkmaz at Y Combinator
# 766
# 767
# No degree info found for Paul Christy at College for Creative Studies
# 768
# No degree info found for Lamont Tang at Stanford University
# No field of study for Lamont Tang at Stanford University
# Connections not found for Shingchun Yu
# Location not found for Shingchun Yu
# 769
# No field of study for James Davis at University of Virginia Frank Batten School of Leadership and Public Policy
# No degree info found for Vishal Vasanji at Louisiana State University
# 770
# No field of study for Joseph Plowman at Vanderbilt University - Owen Graduate School of Management
# No degree info found for Joseph Plowman at Belmont University - Jack C. Massey Graduate School of Business
# 771
# Connections not found for Peter Capkovic
# Location not found for Peter Capkovic
# 772
# No degree info found for Andy Petrella at Athénée Royal de Herstal
# No field of study for Andy Petrella at Athénée Royal de Herstal
# 773
# 774
# No field of study for Aashay Patel at Icahn School of Medicine at Mount Sinai
# 775
# 776
# 777
# No degree info found for David Beberman at Various Certificate Programs
# No degree info found for David Beberman at Boston University
# No degree info found for Jay Moore at University of Oregon
# No degree info found for Michael Holdmann at University of Nevada-Las Vegas
# 778
# 779
# 780
# 781
# No field of study for Sascha Stockem at Starway Institute - Dr. Mateusz Grzesiak
# No field of study for Sascha Stockem at bib-international
# No degree info found for Sascha Stockem at Hubertus-Schwartz-Berufskolleg Soest
# 782
# Joelle Berdugo-Adler not found for BLOQS4
# 783
# 784
# No field of study for Greg Zaharchuk at Harvard University
# 785
# Ali Beydoun not found for Fletch
# Diondre Lewis not found for Fletch
# No field of study for Marquett Burton at The Johns Hopkins University
# No field of study for Marquett Burton at University of California, Berkeley
# 786
# No field of study for Iñaki Murcia at Universidad del País Vasco/Euskal Herriko Unibertsitatea
# 787
# No field of study for Jad Sabra at Harvard Business School
# No degree info found for Jad Sabra at American University of Beirut
# 788
# 789
# No degree info found for Kevin Kramer at Westminster
# No field of study for Kevin Kramer at Westminster
# 790
# Dmitri Martirosyan not found for Outfox AI
# No degree info found for Philipp Tsipman at Columbia University - Fu Foundation School of Engineering and Applied Science
# No field of study for Philipp Tsipman at Columbia University - Fu Foundation School of Engineering and Applied Science
# 791
# No field of study for Nirman Dave at The Galaxy School
# No degree info found for Tapojit Debnath at Mastermind School
# No field of study for Tapojit Debnath at Mastermind School
# 792
# 793
# No field of study for Anu Shukla at St. Stephen's College
# No field of study for Chris Maeda at Southern New Hampshire University
# No degree info found for Rebecca Clyde at Asociacion Escuelas Lincoln, Buenos Aires, Argentina
# No field of study for Rebecca Clyde at Asociacion Escuelas Lincoln, Buenos Aires, Argentina
# 794
# No field of study for Amar Gautam at HBX / Harvard Business School
# 795
# 796
# No degree info found for Omer Winrauke at The Schechter School Of Long Island
# No field of study for Omer Winrauke at The Schechter School Of Long Island
# No field of study for Saniya Shah at Boston University
# No degree info found for Saniya Shah at The Derryfield School
# No field of study for Saniya Shah at The Derryfield School
# 797
# No field of study for Henrik Christensen at Aalborg University
# No degree info found for Mohamed Amer at Cairo University
# No field of study for Mohamed Amer at Cairo University
# 798
# No field of study for Chris Stringer at Western University
# No degree info found for Chris Stringer at CFA Institute
# No field of study for Chris Stringer at CFA Institute
# No degree info found for Chris Stringer at Canadian Securities Institute
# No field of study for Chris Stringer at Canadian Securities Institute
# No degree info found for Erik Bornstein at Fanshawe College
# No field of study for Mark Hinnen at Western University
# No field of study for Mark Hinnen at Stanford University
# No degree info found for Mark Hinnen at Bitmaker
# 799
# No degree info found for Anselm Bauer at UC Berkeley

# %%
saveData(company_data, 'data800.txt')

# %%
# Used to extract and analyze the data from the saved text file

schools = {}
fields = {}
companynames = {}
jobtitle = {}

for key in loaded.keys():
    for founder in loaded[key]['founders']:
        if founder['education']:
            for educ_ in founder['education']:
                school = educ_['school'].lower()
                for word in school.split(' '):
                    if word in schools:
                        schools[word] += 1
                    else:
                        schools[word] = 1
                if educ_['field']:
                    field = educ_['field'].lower()
                    for word in field.split(' '):
                        if word in fields:
                            fields[word] += 1
                        else:
                            fields[word] = 1
        if founder['experience']:
            for exp_ in founder['experience']:
                companyName = exp_['companyName'].lower()
                for word in companyName.split(' '):
                    if word in companynames:
                        companynames[word] += 1
                    else:
                        companynames[word] = 1
                if exp_['title']:
                    title = exp_['title'].lower()
                    if title in jobtitle:
                        jobtitle[title] += 1
                    else:
                        jobtitle[title] = 1

# %%
''' Saves the extracted data to a CSV'''

df_schools = pd.DataFrame.from_dict(schools, orient='index', columns=['freq'])
df_schools.sort_values(['freq'], ascending=False).to_csv('schools.csv')

df_fields = pd.DataFrame.from_dict(fields, orient='index', columns=['freq'])
df_fields.sort_values(['freq'], ascending=False).to_csv('fields.csv')

df_compnames = pd.DataFrame.from_dict(companynames, orient='index', columns=['freq'])
df_compnames.sort_values(['freq'], ascending=False).to_csv('companynames.csv')

df_titles = pd.DataFrame.from_dict(jobtitle, orient='index', columns=['freq'])
df_titles.sort_values(['freq'], ascending=False).to_csv('titles.csv')
