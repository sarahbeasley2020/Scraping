# %%
# Import statements
import pandas as pd
import numpy as np 
import csv 
from parsel import Selector
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import json
import re

# %%
'''
Class to describe a given company 
    @field: name: a string for the company name
    @field: description: a string for the company description
    @field: founders: a list of Founder objects
    @field: industries: a list of strings for different industries
    @field: website: a string for the website
    @field: lastStage: a string for the last stage of funding (eg. Series A)
    @field: linkedin: a string for the company's LinkedIn profile
    @field: location: a string for the company's location
'''
class Company:
    def __init__(self, companyName):
        self.name = companyName
        self.description = None
        self.founders = []
        self.industries = []
        self.website = None
        self.lastStage = None
        self.linkedin = None
    
    def toJson(self):
        return json.dumps(self, default=lambda o: o.__dict__)
    
'''
Class to describe a founder
    @field: name: a string for the founder's name
    @field: education: an list of education objects
    @field: experience: a list of experience objects
'''
class Founder:
    def __init__(self, founderName):
        self.name = founderName
        self.connections = None
        self.location = None
        self.education = []
        self.experience = []

'''
Class to help describe a founder's education
    @field: degree: a string to describe the degree objective
    @field: school: a string for the school attended
    @field: field: a string to describe the major
'''
class Education:
    def __init__(self, schoolName):
        self.school = schoolName
        self.degree = None
        self.field = None
'''
Class to help describe a founder's experience
    @field: companyName: a string to describe the company's name
    @field: title: a string to describe the title held
    @field: description: a string to describe the job description
'''       
class Experience:
    def __init__(self, companyName):
        self.companyName = companyName
        self.title = None
        self.dates = None

# %%
'''
Loads the dataframe from Query 1 and Query 2 and merges + drops duplicates and NaNs
    @param: csv1: path to CSV 1 (formed by Query 1)
    @param: csv2: path to CSV 2 (formed by Query 2)
    @return: df1: a merged dataframe of csv1 and csv2
'''
def loadBacktestData(csv1, csv2):
    df1 = pd.read_csv(csv1)
    df2 = pd.read_csv(csv2)
    df1 = df1.append(df2)
    df1 = df1.drop_duplicates(subset=['Organization Name'])
    df1 = df1[df1.Founders.notna()]
    df1 = df1[df1.LinkedIn.notna()]
    df1 = df1.reset_index()
    for i in range(len(df1)):
        if df1.iloc[i].LinkedIn.count('about') > 0:
            df1['LinkedIn'][i] = df1['LinkedIn'][i].split('about')[0]
    return df1

# Loads and combines both CSVs into df1 dataframe
df1 = loadBacktestData('backtest1.csv', 'backtest2.csv')
# Creates a company_data dictionary to store scraped data
company_data = {}
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
'''
Method to set up and log into the LinkedIn using chromedriver
    @param: driverPath: path to the chromedriver.exe file
    @param: liUsername: string of LI username
    @param: liPassword: string of LI password
    @return: driver: the Chrome Webdriver (can be passed into future function arguments)
'''
def setupDriver(driverPath, liUsername, liPassword):
    # Sets up Chrome Webdriver and navigates to LinkedIn
    driver = webdriver.Chrome(driverPath)
    driver.get('https://www.linkedin.com/')
    sleep(2.0)
    
    # Signs in with given credentials and returns the driver
    driver.find_element_by_xpath('//a[text()="Sign in"]').click()
    sleep(2.0)
    username_input = driver.find_element_by_name('session_key')
    username_input.send_keys(liUsername)
    password_input = driver.find_element_by_name('session_password')
    password_input.send_keys(liPassword)
    sleep(2.0)
    driver.find_element_by_xpath('//button[text()="Sign in"]').click()
    return driver

# Launches LinkedIn and logs in
driver = setupDriver('./chromedriver', 'julianvallyeason@gmail.com', 'Acceleprise1')

# %%
'''
Method to save the company data as a txt file (loadable as JSON)
    @param: data: company_data dictionary of Company objects
    @return: None
'''
def saveData(data, fileName):
    data_json = json.dumps(data, default=lambda x: x.__dict__)
    with open(fileName, 'w') as outfile:
        json.dump(data_json, outfile)

'''
Method to load company data into a dictionary (same structure as Company object)
    @param: dataFile: string path to saved txt file
    @return: dataDict: a dictionary with the same structure as a Company object
'''
def loadData(dataFile):
    with open(dataFile) as json_file:
        data = json.load(json_file)
    dataDict = json.loads(data)
    return dataDict

# %%
'''
Method to get the number of connections for a founder on that founder's LI profile
    @param: driver - the chromedriver used
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the number of connections found on the profile
'''
def addConnections(driver, founder_):
    conn_ = driver.find_elements_by_xpath('//ul[@class = "pv-top-card--list pv-top-card--list-bullet mt1"]/li[@class = "inline-block"]')
    try:
        founder_.connections = conn_[0].text
    except:
        print("Connections not found for {}".format(founder_.name))
        
'''
Method to get extract the founder location
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with the location found on the profile
'''
def updateLocation(driver, founder_):
    loc_ = driver.find_elements_by_xpath('//li[@class = "t-16 t-black t-normal inline-block"]')
    try:
        founder_.location = loc_[0].text
    except:
        print("Location not found for {}".format(founder_.name))

# %%
'''
Method to get the School Name, FoS and Degree Name for all educational experiences for a founder
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all education experiences
'''
def getSchools(driver, founder_):
    schools = driver.find_elements_by_xpath('//div[@class="pv-entity__degree-info"]')
    for school_ in schools:
        try:
            educ_ = Education(school_.find_element_by_class_name('pv-entity__school-name').text)
            try:
                educ_.degree = school_.find_element_by_class_name('pv-entity__degree-name').text.split('\n')[1]
            except:
                print("No degree info found for {} at {}".format(founder_.name, educ_.school))
            try:
                educ_.field = school_.find_element_by_class_name('pv-entity__fos').text.split('\n')[1]
            except:
                print("No field of study for {} at {}".format(founder_.name, educ_.school))

            # Appends the temporary education object to the founder
            founder_.education.append(educ_)
        except:
            print("No schools found for {}".format(founder_.name))

# %%
'''
Method to get the Company Name, Title and Dates for all work experiences for a founder 
    @param: driver - the chromedriver used 
    @param: founder_ - the founder object
    @return: None
Updates the founder object with all work experiences
'''
def getWorkExperience(driver, founder_):
    experiences = driver.find_elements_by_xpath('//a[@data-control-name="background_details_company"]')
    for exp in experiences:
        exp_lst = exp.text.split('\n')
        # The exp_ is formatted as [title, 'companyname', companyname, 'datesemployed', datesemployed, ..]
        try:
            if exp_lst[0] == 'Company Name':
                exp_ = Experience(exp_lst[1])
                founder_.experience.append(exp_)
            else:
                exp_ = Experience(exp_lst[2])
                try:
                    exp_.title = exp_lst[0]
                    exp_.dates = exp_lst[4]
                    founder_.experience.append(exp_)
                except:
                    founder_.experience.append(exp_)
        except:
            print("No experience found for {}".format(str(founder_.name)))

# %%
'''
Extracts the founder information from a LinkedIn search for a founder and adds the founder to the company
    @param: driver - the chromedriver used
    @param: founder - a string for the founder's name
    @param: company_ - the Company object for the company the founder is working at
'''

def getFounderInfo(driver, founder, company_):
    res_ = driver.find_element_by_xpath('//a[@data-control-name="search_srp_result"]')
    if res_:
        res_.click()
        sleep(2.0)
        # Scrolls to the bottom of the webpage (if no scroll, error where the full webpage doens't load)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/2);")
        sleep(0.75)
        # Creates a founder object for the given founder
        founder_ = Founder(founder)
        
        #Extracts data for connections
        addConnections(driver, founder_)
        
        #Extract founder location
        updateLocation(driver, founder_)

        # Extracts degree information (formatted as a list of items)
        getSchools(driver, founder_)
 
        # Extracts experience information (formatted as a list of items)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight/3);")
        sleep(1.0)
        getWorkExperience(driver, founder_)
        
        # Appends the temporary founder object to the company
        company_.founders.append(founder_)
        sleep(1.0)
    else:
        founder_ = Founder(founder)
        company_.founders.append(founder_)
        print("{} not found for {}".format(company_.name, founder_.name))
        sleep(1.0)

# %%
'''
Method to search for founder and company on the search bar and extract founder information if found
    @param: driver - the chromedriver used 
    @param: founder - a string for the name of the founder to be searched
    @param: company_ = the company being searched
    @return: None
The founder object is populated and added to the company
'''
def searchForFounder(driver, founder, company_):
    # Finds the search bar on top of the LinkedIn page
    search = driver.find_elements_by_xpath('//input[@class="search-global-typeahead__input always-show-placeholder"]')
    sleep(0.5)
    search[0].click()
    for i in range(50):
        search[0].send_keys(Keys.RIGHT)
    # Clears any existing search
    for i in range(80):
        search[0].send_keys(Keys.BACKSPACE)
    # Types in founder name + company name and searches
#     search[0].send_keys(founder + " " + company_.name.split(" ")[0])
    search[0].send_keys(founder + " " + re.split(" |,", company_.name)[0])
    search[0].send_keys(Keys.ENTER)
    sleep(2.0)
    try:
        getFounderInfo(driver, founder, company_)
    except:
        print("{} not found for {}".format(founder, company_.name))

# %%
'''
Method to add LI information for a company into the company_data dictionary with a new company object
    @param: entry: a pandas series extracted from a single row in the dataframe from loadBacktestData
    @return: None
This method updates the company_data dictionary and returns nothing
'''
def scrapeLI(entry):
    # Adds a new company entry to the company_data dictionary and populates fields
    company_ = Company(entry['Organization Name'])
    company_.description = entry['Description']
    company_.industries = [i.strip() for i in entry['Industries'].split(',')]
    company_.website = entry['Website']
    company_.lastStage = entry['Last Funding Type']
    # Edge case where the LinkedIn link does not end in '/'
    if entry['LinkedIn'][-1] != '/':
        entry['LinkedIn'] = entry['LinkedIn'] + '/'
    company_.linkedin = entry['LinkedIn']
    company_.location = entry['Headquarters Location']
    
    # Generates a list of founder names
    founderNames = [i.strip() for i in entry['Founders'].split(',')]
    try:
        # For each founder in the list, the school name, degree, and major is extracted
        for founder in founderNames:
            searchForFounder(driver, founder, company_)
    except:
        print("Structural Error")
    # Adds the company to the company_data dictionary
    company_data[company_.name] = company_

# %%
for i in range(800,900):
    print(i)
    if i%5 == 0:
        sleep(5.0)
    scrapeLI(df1.iloc[i])
# Out:
# 800
# Constantin Schünemann not found for Layer
# No field of study for Moritz ten Eikelder at Harvard University
# 801
# 802
# No degree info found for Karan Talati at University of Illinois at Urbana-Champaign
# No degree info found for Karan Talati at Adlai E. Stevenson High School
# No field of study for Karan Talati at Adlai E. Stevenson High School
# Connections not found for Neal Sarraf
# Location not found for Neal Sarraf
# 803
# Connections not found for Jacob L. Jaremko
# Location not found for Jacob L. Jaremko
# 804
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# 805
# Connections not found for Bu'Hussain Hayee
# Location not found for Bu'Hussain Hayee
# No field of study for Gareth Parkes at King's College London
# No field of study for Gareth Parkes at Queen Mary, U. of London
# No degree info found for Nader Alaghband at University of Law
# No degree info found for Nader Alaghband at St Paul's School
# No field of study for Nader Alaghband at St Paul's School
# 806
# Connections not found for Matt Mayberry
# Location not found for Matt Mayberry
# 807
# Eloise Palmi not found for NoGrey
# Grant Collins not found for NoGrey
# Nikki Williamson not found for NoGrey
# 808
# No field of study for Ali Vahabzadeh at Y Combinator
# 809
# No field of study for David Agus at John Hopkins Hospital
# No degree info found for Rowan Chapman at community college of Baltimore
# 810
# No degree info found for Ritik Malhotra at Y Combinator
# No field of study for Ritik Malhotra at Lynbrook High School
# No degree info found for Sarat Ravi at Y Combinator
# No field of study for Sarat Ravi at Solon High School
# No field of study for Tanooj Luthra at Canyon Crest Academy
# No field of study for Vamsi Chitters at Y Combinator
# 811
# No field of study for John Canosa at Clarkson University
# 812
# 813
# José Antonio Arellano Ibáñez not found for Delta Protect
# 814
# No field of study for Stavros Papadopoulos at Sasin Graduate Institute of Business Administration of Chulalongkorn University
# 815
# No field of study for Simon Hamacher at CEMS - The Global Alliance in Management Education
# No field of study for Simon Hamacher at University of Economics in Prague
# 816
# Dan Mathews not found for ROOM8
# No field of study for Jessica Chen at University of California, Berkeley - Walter A. Haas School of Business
# 817
# 818
# 819
# No field of study for Bryan Johnson at The University of Chicago Booth School of Business
# No field of study for Bryan Johnson at Brigham Young University
# 820
# 821
# Al Lukies not found for Pollinate Networks
# No degree info found for TIM JOSLYN at Business School Sao Paulo
# 822
# No degree info found for Mark DiPaola at University of California, Berkeley
# No degree info found for Mark DiPaola at University of California, Berkeley, Haas School of Business
# No degree info found for Mark DiPaola at University of California, Berkeley, Haas School of Business
# No field of study for Mark DiPaola at University of California, Berkeley, Haas School of Business
# 823
# No degree info found for Kumar Ritesh at Manipal Academy of Higher Education
# 824
# No field of study for Andrew Smith at Tuck School of Business at Dartmouth
# 825
# No degree info found for Nima Negahban at University of Maryland
# No field of study for Nima Negahban at University of Maryland
# 826
# Connections not found for Reuven Moskowitz
# Location not found for Reuven Moskowitz
# 827
# No field of study for Alexander Hudek at University of Toronto
# No field of study for Noah Waisberg at New York University School of Law
# 828
# No degree info found for David Smalley at Royal Latin School
# No field of study for David Smalley at Royal Latin School
# No field of study for Paul Farnell at Manchester Metropolitan University Business School
# 829
# No field of study for Mark Austin at West Wythenshawe College
# No degree info found for Mark Austin at Poundswick High School
# No field of study for Mark Austin at Poundswick High School
# No degree info found for Paul Kenyon at Peel College
# 830
# No degree info found for Parker Conrad at Collegiate
# No field of study for Parker Conrad at Collegiate
# 831
# No degree info found for Giovanni Coglitore at University of California, Los Angeles
# No field of study for Giovanni Coglitore at University of California, Los Angeles
# 832
# No field of study for David Kelso at The University of Queensland
# No degree info found for Ian McHenry at Claremont High School
# No field of study for Ian McHenry at Claremont High School
# 833
# 834
# No degree info found for Albert Liu at University of California, Berkeley
# No field of study for Albert Liu at University of California, Berkeley
# No degree info found for Albert Liu at University of California, Los Angeles
# No field of study for Albert Liu at University of California, Los Angeles
# No degree info found for Albert Liu at University of California, San Diego
# No field of study for Albert Liu at University of California, San Diego
# 835
# No field of study for David Sherez at The Hebrew University of Jerusalem
# No degree info found for David Sherez at Kolot
# No degree info found for Or Bokobza at IDC
# No field of study for Or Bokobza at IDC
# 836
# 837
# 838
# No degree info found for Heath Oderman at University of Virginia
# No field of study for Heath Oderman at University of Virginia
# 839
# No degree info found for Kevin Gough at Cate School
# No field of study for Kevin Gough at Cate School
# No degree info found for Kevin Gough at Harvard-Westlake School
# No field of study for Kevin Gough at Harvard-Westlake School
# 840
# No degree info found for GEORGE NG at Lowell High School
# No field of study for GEORGE NG at Lowell High School
# 841
# 842
# No field of study for Govardhan Muralidhar at Bangalore University
# No degree info found for Govardhan Muralidhar at National College
# No field of study for Govardhan Muralidhar at National College
# No field of study for Govardhan Muralidhar at Bangalore University
# No degree info found for Govardhan Muralidhar at National College
# No field of study for Govardhan Muralidhar at National College
# 843
# 844
# No degree info found for Paul Martini at University of California, San Diego
# No field of study for Paul Martini at University of California, San Diego
# 845
# No field of study for Javier Darriba at IESE Business School
# No field of study for Xavier Mestres at UAB Law School
# 846
# No field of study for Steve Shwartz at The Johns Hopkins University
# No field of study for Steve Shwartz at New College of Florida
# 847
# Connections not found for J Weston Lunsford
# Location not found for J Weston Lunsford
# 848
# Connections not found for Sander van de Rijdt
# Location not found for Sander van de Rijdt
# 849
# No degree info found for Jason Chicola at Miami Palmetto Senior High
# No field of study for Jason Chicola at Miami Palmetto Senior High
# No degree info found for Josh Breinlinger at Pinkerton Academy
# No field of study for Josh Breinlinger at Pinkerton Academy
# No field of study for Mark Chen at Harvard Business School
# 850
# No field of study for Patrick Wall at University of Oxford
# No degree info found for Patrick Wall at St Joseph's Comprehensive Swindon
# No field of study for Patrick Wall at St Joseph's Comprehensive Swindon
# 851
# No degree info found for John Ha at Seoul Science High School
# No field of study for John Ha at Seoul Science High School
# No field of study for Juan Higueros at Massachusetts Institute of Technology - Sloan School of Management
# 852
# 853
# 854
# No degree info found for Martin Cseh at New York University
# No degree info found for Martin Cseh at Enosburg Falls High School
# No field of study for Martin Cseh at Enosburg Falls High School
# 855
# No degree info found for Mark Schacknies at Leysin American School
# No field of study for Mark Schacknies at Leysin American School
# 856
# No field of study for Michelle Hall at Rensselaer Polytechnic Institute at Hartford
# 857
# Connections not found for Saurabh Dhoot
# Location not found for Saurabh Dhoot
# 858
# 859
# 860
# No field of study for David Mindell at Massachusetts Institute of Technology
# No degree info found for Gary Cohen at Beijing Language and Culture University
# 861
# No field of study for Ed Ibe at San Jose State University
# 862
# No degree info found for Adrian Locher at Stanford University
# 863
# 864
# No field of study for Lori Evans Bernstein at Ohio Wesleyan University
# No field of study for Lori Evans Bernstein at Richard Montgomery High School
# 865
# No degree info found for David Fox at Ecole Active Bilingue Jeannine Manuel
# No field of study for David Fox at Ecole Active Bilingue Jeannine Manuel
# 866
# 867
# 868
# 869
# Alexander Klizhentas not found for Gravitational
# No degree info found for Taylor Wakefield at MUHS
# No field of study for Taylor Wakefield at MUHS
# 870
# No degree info found for Marcus Furuholmen at The Oslo School of Architecture and Design (AHO)
# 871
# 872
# 873
# 874
# No field of study for Jason Forrester at University of Colorado at Denver
# 875
# No field of study for Davida Herzl at University of San Diego School of Law
# No degree info found for Reuben Herzl at Univerzita Karlova v Praze
# 876
# No degree info found for Raj Dutt at Rensselaer Polytechnic Institute
# 877
# 878
# No field of study for Jamie Marshall at Moses Brown School
# No degree info found for Jamie Marshall at The London School of Economics and Political Science (LSE)
# No degree info found for Kevin Tan at Y Combinator
# No field of study for Kevin Tan at Y Combinator
# No degree info found for Kevin Tan at University School
# No field of study for Kevin Tan at University School
# 879
# No degree info found for Alexandre Augusto da Rocha at Universidade Federal Fluminense / UFF
# No degree info found for Alexandre Augusto da Rocha at University of Maryland University College
# No degree info found for Bill Schell at Washington Lee High School
# No field of study for Bill Schell at Washington Lee High School
# 880
# 881
# No degree info found for Fernando Herrera at Tecnológico de Monterrey
# 882
# No degree info found for Roland Keijzer at Rotterdam University of Applied Sciences
# 883
# 884
# 885
# No degree info found for Craig Wilkins at Helena High School
# No field of study for Craig Wilkins at Helena High School
# 886
# No degree info found for Peter Schrammel at Ecole polytechnique fédérale de Lausanne
# 887
# Connections not found for Jin Tu
# Location not found for Jin Tu
# No field of study for Matthew Spoke at Canadian Institute of Chartered Accountants
# No degree info found for Matthew Spoke at Jiao Tong University
# No field of study for Matthew Spoke at Jiao Tong University
# 888
# 889
# No degree info found for Jerene Yang at Raffles Junior College
# No field of study for Jerene Yang at Raffles Junior College
# 890
# No degree info found for Serge Ioffe at Northwestern University
# 891
# No degree info found for Arjun Bansal at University of Southern California
# No degree info found for Naveen Rao at Stanford University
# 892
# No degree info found for Luka Crnkovic-Friis at Stockholms universitet / Stockholm University
# No degree info found for Luka Crnkovic-Friis at Kungliga musikhögskolan / Royal College of Music in Stockholm
# 893
# 894
# Cooper Bane not found for BoomTown
# 895
# No field of study for Omri Yoffe at Northwestern University - Kellogg School of Management
# No field of study for Omri Yoffe at Singularity University
# No degree info found for Zvika Orron at Singularity University
# 896
# No degree info found for Anand Babu Periasamy at Malco Vidyalaya
# No field of study for Anand Babu Periasamy at Malco Vidyalaya
# 897
# No degree info found for Reghu Hariharan at Madurai Kamaraj University
# No field of study for Reghu Hariharan at Madurai Kamaraj University
# No degree info found for Reghu Hariharan at University of Kerala
# No field of study for Reghu Hariharan at University of Kerala
# 898
# Herbert Axilrod not found for ActivTrak
# 899

# %%
saveData(company_data, 'data900.txt')

# %%
# Used to extract and analyze the data from the saved text file

schools = {}
fields = {}
companynames = {}
jobtitle = {}

for key in loaded.keys():
    for founder in loaded[key]['founders']:
        if founder['education']:
            for educ_ in founder['education']:
                school = educ_['school'].lower()
                for word in school.split(' '):
                    if word in schools:
                        schools[word] += 1
                    else:
                        schools[word] = 1
                if educ_['field']:
                    field = educ_['field'].lower()
                    for word in field.split(' '):
                        if word in fields:
                            fields[word] += 1
                        else:
                            fields[word] = 1
        if founder['experience']:
            for exp_ in founder['experience']:
                companyName = exp_['companyName'].lower()
                for word in companyName.split(' '):
                    if word in companynames:
                        companynames[word] += 1
                    else:
                        companynames[word] = 1
                if exp_['title']:
                    title = exp_['title'].lower()
                    if title in jobtitle:
                        jobtitle[title] += 1
                    else:
                        jobtitle[title] = 1

# %%
''' Saves the extracted data to a CSV'''

df_schools = pd.DataFrame.from_dict(schools, orient='index', columns=['freq'])
df_schools.sort_values(['freq'], ascending=False).to_csv('schools.csv')

df_fields = pd.DataFrame.from_dict(fields, orient='index', columns=['freq'])
df_fields.sort_values(['freq'], ascending=False).to_csv('fields.csv')

df_compnames = pd.DataFrame.from_dict(companynames, orient='index', columns=['freq'])
df_compnames.sort_values(['freq'], ascending=False).to_csv('companynames.csv')

df_titles = pd.DataFrame.from_dict(jobtitle, orient='index', columns=['freq'])
df_titles.sort_values(['freq'], ascending=False).to_csv('titles.csv')
